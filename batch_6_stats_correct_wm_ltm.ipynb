# %%
library(lme4)
library(simr)
library(dplyr)
library(broom)
install.packages("sjPlot")
library(sjPlot)
install.packages("broom.mixed")
library(broom.mixed)
# Out:
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpGCFv8F/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpGCFv8F/downloaded_packages

# %%
# install.packages("car")
library(car)
install.packages("stargazer")

library(stargazer)
# Out:
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpGCFv8F/downloaded_packages

# %%
file_path <- 'pilot6_stats/correct_wm_ltm.csv'
df <- read.csv(file_path) 
# %>%
#     select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z )

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
head(df$recall_answ)
# Out:
# [1] 1 1 1 1 1 1

# %%
# names(df)

# %%
head(df$reliability_binary_z)
# Out:
# [1]  0.9988748  0.9988748  0.9988748  0.9988748  0.9988748 -1.0009939

# %%
head(df$attend_binary)
# Out:
# [1] 1 1 1 1 0 1

# %%
formula1 <- glmer(recall_answ ~ (it_ltm_sign_z + it_ltm_sign_sq_z) * it_pos_neg_ltm_abs * reliability_binary_z *  
                  attend_binary_z + (v2_ltm_sign_z + v2_ltm_sign_sq_z) * v2_pos_neg_ltm_abs * reliability_binary_z *  
                  attend_binary_z + tested_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 45 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_ltm_sign_z + it_ltm_sign_sq_z) * it_pos_neg_ltm_abs *
#     reliability_binary_z * attend_binary_z + (v2_ltm_sign_z +
#     v2_ltm_sign_sq_z) * v2_pos_neg_ltm_abs * reliability_binary_z *
#     attend_binary_z + tested_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   7542.4   7861.1  -3725.2   7450.4     7504
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8935  0.1733  0.3750  0.5585  1.7849
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5652   0.7518
# Number of obs: 7550, groups:  participant, 132
#
# Fixed effects:
#                                                                          Estimate
# (Intercept)                                                               1.39479
# it_ltm_sign_z                                                            -0.07233
# it_ltm_sign_sq_z                                                          0.02248
# it_pos_neg_ltm_abs                                                        0.10182
# reliability_binary_z                                                      0.07091
# attend_binary_z                                                           0.31837
# v2_ltm_sign_z                                                             0.13702
# v2_ltm_sign_sq_z                                                          0.06929
# v2_pos_neg_ltm_abs                                                       -0.15181
# tested_binary_z                                                          -0.58774
# it_ltm_sign_z:it_pos_neg_ltm_abs                                         -0.01416
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                       0.10617
# it_ltm_sign_z:reliability_binary_z                                       -0.16917
# it_ltm_sign_sq_z:reliability_binary_z                                    -0.15566
# it_pos_neg_ltm_abs:reliability_binary_z                                   0.23466
# it_ltm_sign_z:attend_binary_z                                             0.15041
# it_ltm_sign_sq_z:attend_binary_z                                          0.03004
# it_pos_neg_ltm_abs:attend_binary_z                                       -0.09096
# reliability_binary_z:attend_binary_z                                      0.25128
# v2_ltm_sign_z:v2_pos_neg_ltm_abs                                         -0.06369
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                                      -0.03924
# reliability_binary_z:v2_ltm_sign_z                                        0.19811
# reliability_binary_z:v2_ltm_sign_sq_z                                     0.14882
# reliability_binary_z:v2_pos_neg_ltm_abs                                  -0.17959
# attend_binary_z:v2_ltm_sign_z                                             0.11155
# attend_binary_z:v2_ltm_sign_sq_z                                          0.26506
# attend_binary_z:v2_pos_neg_ltm_abs                                       -0.09180
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                     0.21151
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z                  0.08099
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z                         -0.03447
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z                      -0.14333
# it_ltm_sign_z:reliability_binary_z:attend_binary_z                        0.09074
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z                     0.04933
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z                  -0.11751
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                    -0.25890
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                 -0.12022
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                         -0.36117
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                      -0.08336
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z                       -0.26680
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z                     0.06748
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs                   0.21213
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z    -0.11330
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z  0.03977
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs    -0.26287
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs  0.17264
#                                                                          Std. Error
# (Intercept)                                                                 0.25066
# it_ltm_sign_z                                                               0.12725
# it_ltm_sign_sq_z                                                            0.09788
# it_pos_neg_ltm_abs                                                          0.11203
# reliability_binary_z                                                        0.24216
# attend_binary_z                                                             0.24261
# v2_ltm_sign_z                                                               0.23575
# v2_ltm_sign_sq_z                                                            0.20163
# v2_pos_neg_ltm_abs                                                          0.21621
# tested_binary_z                                                             0.03728
# it_ltm_sign_z:it_pos_neg_ltm_abs                                            0.12676
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                         0.09786
# it_ltm_sign_z:reliability_binary_z                                          0.12742
# it_ltm_sign_sq_z:reliability_binary_z                                       0.09804
# it_pos_neg_ltm_abs:reliability_binary_z                                     0.11221
# it_ltm_sign_z:attend_binary_z                                               0.12762
# it_ltm_sign_sq_z:attend_binary_z                                            0.09826
# it_pos_neg_ltm_abs:attend_binary_z                                          0.11236
# reliability_binary_z:attend_binary_z                                        0.24296
# v2_ltm_sign_z:v2_pos_neg_ltm_abs                                            0.23856
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                                         0.19990
# reliability_binary_z:v2_ltm_sign_z                                          0.23684
# reliability_binary_z:v2_ltm_sign_sq_z                                       0.20244
# reliability_binary_z:v2_pos_neg_ltm_abs                                     0.21714
# attend_binary_z:v2_ltm_sign_z                                               0.23693
# attend_binary_z:v2_ltm_sign_sq_z                                            0.20223
# attend_binary_z:v2_pos_neg_ltm_abs                                          0.21719
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                       0.12706
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z                    0.09802
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z                            0.12719
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z                         0.09819
# it_ltm_sign_z:reliability_binary_z:attend_binary_z                          0.12767
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z                       0.09834
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z                     0.11231
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                       0.23937
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                    0.20081
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                            0.23927
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                         0.20071
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z                          0.23675
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z                       0.20218
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs                     0.21717
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z       0.12745
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z    0.09824
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs       0.23942
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs    0.20061
#                                                                          z value
# (Intercept)                                                                5.565
# it_ltm_sign_z                                                             -0.568
# it_ltm_sign_sq_z                                                           0.230
# it_pos_neg_ltm_abs                                                         0.909
# reliability_binary_z                                                       0.293
# attend_binary_z                                                            1.312
# v2_ltm_sign_z                                                              0.581
# v2_ltm_sign_sq_z                                                           0.344
# v2_pos_neg_ltm_abs                                                        -0.702
# tested_binary_z                                                          -15.766
# it_ltm_sign_z:it_pos_neg_ltm_abs                                          -0.112
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                        1.085
# it_ltm_sign_z:reliability_binary_z                                        -1.328
# it_ltm_sign_sq_z:reliability_binary_z                                     -1.588
# it_pos_neg_ltm_abs:reliability_binary_z                                    2.091
# it_ltm_sign_z:attend_binary_z                                              1.179
# it_ltm_sign_sq_z:attend_binary_z                                           0.306
# it_pos_neg_ltm_abs:attend_binary_z                                        -0.810
# reliability_binary_z:attend_binary_z                                       1.034
# v2_ltm_sign_z:v2_pos_neg_ltm_abs                                          -0.267
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                                       -0.196
# reliability_binary_z:v2_ltm_sign_z                                         0.836
# reliability_binary_z:v2_ltm_sign_sq_z                                      0.735
# reliability_binary_z:v2_pos_neg_ltm_abs                                   -0.827
# attend_binary_z:v2_ltm_sign_z                                              0.471
# attend_binary_z:v2_ltm_sign_sq_z                                           1.311
# attend_binary_z:v2_pos_neg_ltm_abs                                        -0.423
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                      1.665
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z                   0.826
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z                          -0.271
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z                       -1.460
# it_ltm_sign_z:reliability_binary_z:attend_binary_z                         0.711
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z                      0.502
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z                   -1.046
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                     -1.082
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                  -0.599
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                          -1.509
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                       -0.415
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z                        -1.127
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z                      0.334
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs                    0.977
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z     -0.889
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z   0.405
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs     -1.098
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs   0.861
#                                                                          Pr(>|z|)
# (Intercept)                                                              2.63e-08
# it_ltm_sign_z                                                              0.5698
# it_ltm_sign_sq_z                                                           0.8183
# it_pos_neg_ltm_abs                                                         0.3634
# reliability_binary_z                                                       0.7697
# attend_binary_z                                                            0.1894
# v2_ltm_sign_z                                                              0.5611
# v2_ltm_sign_sq_z                                                           0.7311
# v2_pos_neg_ltm_abs                                                         0.4826
# tested_binary_z                                                           < 2e-16
# it_ltm_sign_z:it_pos_neg_ltm_abs                                           0.9110
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                        0.2780
# it_ltm_sign_z:reliability_binary_z                                         0.1843
# it_ltm_sign_sq_z:reliability_binary_z                                      0.1123
# it_pos_neg_ltm_abs:reliability_binary_z                                    0.0365
# it_ltm_sign_z:attend_binary_z                                              0.2386
# it_ltm_sign_sq_z:attend_binary_z                                           0.7598
# it_pos_neg_ltm_abs:attend_binary_z                                         0.4182
# reliability_binary_z:attend_binary_z                                       0.3010
# v2_ltm_sign_z:v2_pos_neg_ltm_abs                                           0.7895
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                                        0.8444
# reliability_binary_z:v2_ltm_sign_z                                         0.4029
# reliability_binary_z:v2_ltm_sign_sq_z                                      0.4622
# reliability_binary_z:v2_pos_neg_ltm_abs                                    0.4082
# attend_binary_z:v2_ltm_sign_z                                              0.6378
# attend_binary_z:v2_ltm_sign_sq_z                                           0.1900
# attend_binary_z:v2_pos_neg_ltm_abs                                         0.6725
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                      0.0960
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z                   0.4087
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z                           0.7864
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z                        0.1444
# it_ltm_sign_z:reliability_binary_z:attend_binary_z                         0.4772
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z                      0.6159
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z                    0.2955
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                      0.2794
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                   0.5494
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                           0.1312
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                        0.6779
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z                         0.2598
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z                      0.7386
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs                    0.3287
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z      0.3740
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z   0.6856
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs      0.2722
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs   0.3895
#
# (Intercept)                                                              ***
# it_ltm_sign_z
# it_ltm_sign_sq_z
# it_pos_neg_ltm_abs
# reliability_binary_z
# attend_binary_z
# v2_ltm_sign_z
# v2_ltm_sign_sq_z
# v2_pos_neg_ltm_abs
# tested_binary_z                                                          ***
# it_ltm_sign_z:it_pos_neg_ltm_abs
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs
# it_ltm_sign_z:reliability_binary_z
# it_ltm_sign_sq_z:reliability_binary_z
# it_pos_neg_ltm_abs:reliability_binary_z                                  *
# it_ltm_sign_z:attend_binary_z
# it_ltm_sign_sq_z:attend_binary_z
# it_pos_neg_ltm_abs:attend_binary_z
# reliability_binary_z:attend_binary_z
# v2_ltm_sign_z:v2_pos_neg_ltm_abs
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs
# reliability_binary_z:v2_ltm_sign_z
# reliability_binary_z:v2_ltm_sign_sq_z
# reliability_binary_z:v2_pos_neg_ltm_abs
# attend_binary_z:v2_ltm_sign_z
# attend_binary_z:v2_ltm_sign_sq_z
# attend_binary_z:v2_pos_neg_ltm_abs
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                    .
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z
# it_ltm_sign_z:reliability_binary_z:attend_binary_z
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_ltm_diff_sign_z + it_ltm_diff_sign_sq_z) * it_pos_neg_ltm * reliability_binary_z *  
                  attend_binary_z + (v2_ltm_diff_sign_z + v2_ltm_diff_sign_sq_z) * v2_pos_neg_ltm * reliability_binary_z *  
                  attend_binary_z + tested_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 45 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_ltm_diff_sign_z + it_ltm_diff_sign_sq_z) *
#     it_pos_neg_ltm * reliability_binary_z * attend_binary_z +
#     (v2_ltm_diff_sign_z + v2_ltm_diff_sign_sq_z) * v2_pos_neg_ltm *
#         reliability_binary_z * attend_binary_z + tested_binary_z +
#     (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   7552.9   7871.7  -3730.5   7460.9     7504
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9999  0.1748  0.3767  0.5600  1.6442
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5661   0.7524
# Number of obs: 7550, groups:  participant, 132
#
# Fixed effects:
#                                                                             Estimate
# (Intercept)                                                                1.3533778
# it_ltm_diff_sign_z                                                         0.0983072
# it_ltm_diff_sign_sq_z                                                     -0.0139683
# it_pos_neg_ltm                                                             0.0407668
# reliability_binary_z                                                       0.0134530
# attend_binary_z                                                           -0.0522250
# v2_ltm_diff_sign_z                                                        -0.0153796
# v2_ltm_diff_sign_sq_z                                                      0.0792207
# v2_pos_neg_ltm                                                             0.0140643
# tested_binary_z                                                           -0.5850489
# it_ltm_diff_sign_z:it_pos_neg_ltm                                          0.0019997
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm                                       0.0285346
# it_ltm_diff_sign_z:reliability_binary_z                                   -0.0004944
# it_ltm_diff_sign_sq_z:reliability_binary_z                                -0.0537070
# it_pos_neg_ltm:reliability_binary_z                                        0.0536225
# it_ltm_diff_sign_z:attend_binary_z                                        -0.0090530
# it_ltm_diff_sign_sq_z:attend_binary_z                                      0.0047591
# it_pos_neg_ltm:attend_binary_z                                             0.0262568
# reliability_binary_z:attend_binary_z                                      -0.0228378
# v2_ltm_diff_sign_z:v2_pos_neg_ltm                                          0.0145617
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                                      -0.0117505
# reliability_binary_z:v2_ltm_diff_sign_z                                    0.0037265
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                -0.0338947
# reliability_binary_z:v2_pos_neg_ltm                                       -0.0062525
# attend_binary_z:v2_ltm_diff_sign_z                                        -0.0321285
# attend_binary_z:v2_ltm_diff_sign_sq_z                                      0.0141018
# attend_binary_z:v2_pos_neg_ltm                                             0.0338173
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z                    -0.0069814
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z                  0.0113577
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z                         -0.0084515
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z                       0.0043908
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                    0.0444901
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                 0.0727150
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z                       -0.0151631
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                    -0.0312195
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                 -0.0125660
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                          0.0294151
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                       0.0014369
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                   -0.0740752
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z                 0.0214106
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm                        0.0143902
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z     0.0291483
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z  0.0152082
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm    -0.0630437
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm  0.0111430
#                                                                           Std. Error
# (Intercept)                                                                0.0730487
# it_ltm_diff_sign_z                                                         0.0301941
# it_ltm_diff_sign_sq_z                                                      0.0299551
# it_pos_neg_ltm                                                             0.0313928
# reliability_binary_z                                                       0.0303125
# attend_binary_z                                                            0.0360972
# v2_ltm_diff_sign_z                                                         0.0304255
# v2_ltm_diff_sign_sq_z                                                      0.0302650
# v2_pos_neg_ltm                                                             0.0308734
# tested_binary_z                                                            0.0370914
# it_ltm_diff_sign_z:it_pos_neg_ltm                                          0.0305314
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm                                       0.0308768
# it_ltm_diff_sign_z:reliability_binary_z                                    0.0304037
# it_ltm_diff_sign_sq_z:reliability_binary_z                                 0.0300704
# it_pos_neg_ltm:reliability_binary_z                                        0.0314927
# it_ltm_diff_sign_z:attend_binary_z                                         0.0302559
# it_ltm_diff_sign_sq_z:attend_binary_z                                      0.0299709
# it_pos_neg_ltm:attend_binary_z                                             0.0314770
# reliability_binary_z:attend_binary_z                                       0.0309005
# v2_ltm_diff_sign_z:v2_pos_neg_ltm                                          0.0317847
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                                       0.0308624
# reliability_binary_z:v2_ltm_diff_sign_z                                    0.0305239
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                 0.0304000
# reliability_binary_z:v2_pos_neg_ltm                                        0.0310107
# attend_binary_z:v2_ltm_diff_sign_z                                         0.0304364
# attend_binary_z:v2_ltm_diff_sign_sq_z                                      0.0303529
# attend_binary_z:v2_pos_neg_ltm                                             0.0310838
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z                     0.0306615
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z                  0.0309455
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z                          0.0306712
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z                       0.0309491
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                    0.0304513
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                 0.0299840
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z                        0.0315139
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                     0.0316863
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                  0.0308477
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                          0.0317321
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                       0.0308744
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                    0.0304394
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z                 0.0303004
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm                        0.0310398
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z     0.0307209
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z  0.0310044
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm     0.0318297
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm  0.0309635
#                                                                           z value
# (Intercept)                                                                18.527
# it_ltm_diff_sign_z                                                          3.256
# it_ltm_diff_sign_sq_z                                                      -0.466
# it_pos_neg_ltm                                                              1.299
# reliability_binary_z                                                        0.444
# attend_binary_z                                                            -1.447
# v2_ltm_diff_sign_z                                                         -0.505
# v2_ltm_diff_sign_sq_z                                                       2.618
# v2_pos_neg_ltm                                                              0.456
# tested_binary_z                                                           -15.773
# it_ltm_diff_sign_z:it_pos_neg_ltm                                           0.065
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm                                        0.924
# it_ltm_diff_sign_z:reliability_binary_z                                    -0.016
# it_ltm_diff_sign_sq_z:reliability_binary_z                                 -1.786
# it_pos_neg_ltm:reliability_binary_z                                         1.703
# it_ltm_diff_sign_z:attend_binary_z                                         -0.299
# it_ltm_diff_sign_sq_z:attend_binary_z                                       0.159
# it_pos_neg_ltm:attend_binary_z                                              0.834
# reliability_binary_z:attend_binary_z                                       -0.739
# v2_ltm_diff_sign_z:v2_pos_neg_ltm                                           0.458
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                                       -0.381
# reliability_binary_z:v2_ltm_diff_sign_z                                     0.122
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                 -1.115
# reliability_binary_z:v2_pos_neg_ltm                                        -0.202
# attend_binary_z:v2_ltm_diff_sign_z                                         -1.056
# attend_binary_z:v2_ltm_diff_sign_sq_z                                       0.465
# attend_binary_z:v2_pos_neg_ltm                                              1.088
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z                     -0.228
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z                   0.367
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z                          -0.276
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z                        0.142
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                     1.461
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                  2.425
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z                        -0.481
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                     -0.985
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                  -0.407
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                           0.927
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                        0.047
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                    -2.434
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z                  0.707
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm                         0.464
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z      0.949
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z   0.491
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm     -1.981
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm   0.360
#                                                                           Pr(>|z|)
# (Intercept)                                                                < 2e-16
# it_ltm_diff_sign_z                                                         0.00113
# it_ltm_diff_sign_sq_z                                                      0.64099
# it_pos_neg_ltm                                                             0.19408
# reliability_binary_z                                                       0.65718
# attend_binary_z                                                            0.14796
# v2_ltm_diff_sign_z                                                         0.61322
# v2_ltm_diff_sign_sq_z                                                      0.00886
# v2_pos_neg_ltm                                                             0.64871
# tested_binary_z                                                            < 2e-16
# it_ltm_diff_sign_z:it_pos_neg_ltm                                          0.94778
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm                                       0.35541
# it_ltm_diff_sign_z:reliability_binary_z                                    0.98703
# it_ltm_diff_sign_sq_z:reliability_binary_z                                 0.07409
# it_pos_neg_ltm:reliability_binary_z                                        0.08862
# it_ltm_diff_sign_z:attend_binary_z                                         0.76478
# it_ltm_diff_sign_sq_z:attend_binary_z                                      0.87383
# it_pos_neg_ltm:attend_binary_z                                             0.40419
# reliability_binary_z:attend_binary_z                                       0.45986
# v2_ltm_diff_sign_z:v2_pos_neg_ltm                                          0.64686
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                                       0.70340
# reliability_binary_z:v2_ltm_diff_sign_z                                    0.90283
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                 0.26487
# reliability_binary_z:v2_pos_neg_ltm                                        0.84021
# attend_binary_z:v2_ltm_diff_sign_z                                         0.29115
# attend_binary_z:v2_ltm_diff_sign_sq_z                                      0.64222
# attend_binary_z:v2_pos_neg_ltm                                             0.27662
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z                     0.81989
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z                  0.71360
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z                          0.78289
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z                       0.88718
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                    0.14401
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                 0.01530
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z                        0.63041
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                     0.32449
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                  0.68375
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                          0.35394
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                       0.96288
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                    0.01495
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z                 0.47981
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm                        0.64293
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z     0.34272
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z  0.62377
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm     0.04763
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm  0.71894
#
# (Intercept)                                                               ***
# it_ltm_diff_sign_z                                                        **
# it_ltm_diff_sign_sq_z
# it_pos_neg_ltm
# reliability_binary_z
# attend_binary_z
# v2_ltm_diff_sign_z
# v2_ltm_diff_sign_sq_z                                                     **
# v2_pos_neg_ltm
# tested_binary_z                                                           ***
# it_ltm_diff_sign_z:it_pos_neg_ltm
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm
# it_ltm_diff_sign_z:reliability_binary_z
# it_ltm_diff_sign_sq_z:reliability_binary_z                                .
# it_pos_neg_ltm:reliability_binary_z                                       .
# it_ltm_diff_sign_z:attend_binary_z
# it_ltm_diff_sign_sq_z:attend_binary_z
# it_pos_neg_ltm:attend_binary_z
# reliability_binary_z:attend_binary_z
# v2_ltm_diff_sign_z:v2_pos_neg_ltm
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm
# reliability_binary_z:v2_ltm_diff_sign_z
# reliability_binary_z:v2_ltm_diff_sign_sq_z
# reliability_binary_z:v2_pos_neg_ltm
# attend_binary_z:v2_ltm_diff_sign_z
# attend_binary_z:v2_ltm_diff_sign_sq_z
# attend_binary_z:v2_pos_neg_ltm
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                *
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                   *
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm    *
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_ltm_z + it_ltm_sq_z)  * reliability_binary_z *  
                  attend_binary_z + (v2_ltm_z + v2_ltm_sq_z) * reliability_binary_z *  
                  attend_binary_z + tested_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_ltm_z + it_ltm_sq_z) * reliability_binary_z *
#     attend_binary_z + (v2_ltm_z + v2_ltm_sq_z) * reliability_binary_z *
#     attend_binary_z + tested_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   7527.5   7680.0  -3741.8   7483.5     7528
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8521  0.1797  0.3798  0.5630  1.6323
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5626   0.7501
# Number of obs: 7550, groups:  participant, 132
#
# Fixed effects:
#                                                   Estimate Std. Error z value
# (Intercept)                                       1.349887   0.072706  18.566
# it_ltm_z                                         -0.000233   0.050617  -0.005
# it_ltm_sq_z                                       0.072205   0.050905   1.418
# reliability_binary_z                              0.012088   0.029895   0.404
# attend_binary_z                                  -0.044517   0.035696  -1.247
# v2_ltm_z                                         -0.078518   0.081434  -0.964
# v2_ltm_sq_z                                       0.101074   0.083059   1.217
# tested_binary_z                                  -0.590387   0.036978 -15.966
# it_ltm_z:reliability_binary_z                     0.137095   0.050927   2.692
# it_ltm_sq_z:reliability_binary_z                 -0.094820   0.051149  -1.854
# it_ltm_z:attend_binary_z                          0.054197   0.050819   1.066
# it_ltm_sq_z:attend_binary_z                      -0.048511   0.050996  -0.951
# reliability_binary_z:attend_binary_z             -0.019684   0.030461  -0.646
# reliability_binary_z:v2_ltm_z                     0.066778   0.081644   0.818
# reliability_binary_z:v2_ltm_sq_z                 -0.076023   0.083145  -0.914
# attend_binary_z:v2_ltm_z                         -0.077669   0.081654  -0.951
# attend_binary_z:v2_ltm_sq_z                       0.118653   0.083163   1.427
# it_ltm_z:reliability_binary_z:attend_binary_z    -0.172554   0.051020  -3.382
# it_ltm_sq_z:reliability_binary_z:attend_binary_z  0.152044   0.051182   2.971
# reliability_binary_z:attend_binary_z:v2_ltm_z     0.062058   0.081750   0.759
# reliability_binary_z:attend_binary_z:v2_ltm_sq_z -0.082434   0.083242  -0.990
#                                                  Pr(>|z|)
# (Intercept)                                       < 2e-16 ***
# it_ltm_z                                         0.996327
# it_ltm_sq_z                                      0.156065
# reliability_binary_z                             0.685961
# attend_binary_z                                  0.212360
# v2_ltm_z                                         0.334952
# v2_ltm_sq_z                                      0.223647
# tested_binary_z                                   < 2e-16 ***
# it_ltm_z:reliability_binary_z                    0.007103 **
# it_ltm_sq_z:reliability_binary_z                 0.063769 .
# it_ltm_z:attend_binary_z                         0.286216
# it_ltm_sq_z:attend_binary_z                      0.341469
# reliability_binary_z:attend_binary_z             0.518159
# reliability_binary_z:v2_ltm_z                    0.413406
# reliability_binary_z:v2_ltm_sq_z                 0.360535
# attend_binary_z:v2_ltm_z                         0.341503
# attend_binary_z:v2_ltm_sq_z                      0.153650
# it_ltm_z:reliability_binary_z:attend_binary_z    0.000719 ***
# it_ltm_sq_z:reliability_binary_z:attend_binary_z 0.002972 **
# reliability_binary_z:attend_binary_z:v2_ltm_z    0.447780
# reliability_binary_z:attend_binary_z:v2_ltm_sq_z 0.322031
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_ltm_diff_z + it_ltm_diff_sq_z)  * reliability_binary_z *  
                  attend_binary_z + (v2_ltm_diff_z + v2_ltm_diff_sq_z) * reliability_binary_z *  
                  attend_binary_z + tested_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_ltm_diff_z + it_ltm_diff_sq_z) * reliability_binary_z *
#     attend_binary_z + (v2_ltm_diff_z + v2_ltm_diff_sq_z) * reliability_binary_z *
#     attend_binary_z + tested_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   7534.5   7687.0  -3745.3   7490.5     7528
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9097  0.1825  0.3785  0.5588  1.6190
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.56     0.7483
# Number of obs: 7550, groups:  participant, 132
#
# Fixed effects:
#                                                        Estimate Std. Error
# (Intercept)                                            1.345956   0.072535
# it_ltm_diff_z                                          0.034918   0.030597
# it_ltm_diff_sq_z                                       0.095594   0.030225
# reliability_binary_z                                   0.015971   0.029829
# attend_binary_z                                       -0.042310   0.035592
# v2_ltm_diff_z                                          0.017829   0.029909
# v2_ltm_diff_sq_z                                       0.003826   0.029815
# tested_binary_z                                       -0.588498   0.036908
# it_ltm_diff_z:reliability_binary_z                     0.039182   0.030788
# it_ltm_diff_sq_z:reliability_binary_z                 -0.012448   0.030402
# it_ltm_diff_z:attend_binary_z                          0.023797   0.030735
# it_ltm_diff_sq_z:attend_binary_z                      -0.013541   0.030288
# reliability_binary_z:attend_binary_z                  -0.022023   0.030397
# reliability_binary_z:v2_ltm_diff_z                    -0.018464   0.030023
# reliability_binary_z:v2_ltm_diff_sq_z                 -0.004368   0.029910
# attend_binary_z:v2_ltm_diff_z                          0.039240   0.030056
# attend_binary_z:v2_ltm_diff_sq_z                      -0.027747   0.029836
# it_ltm_diff_z:reliability_binary_z:attend_binary_z    -0.015737   0.030750
# it_ltm_diff_sq_z:reliability_binary_z:attend_binary_z  0.049875   0.030441
# reliability_binary_z:attend_binary_z:v2_ltm_diff_z    -0.009190   0.030032
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sq_z -0.056949   0.029818
#                                                       z value Pr(>|z|)
# (Intercept)                                            18.556  < 2e-16 ***
# it_ltm_diff_z                                           1.141  0.25378
# it_ltm_diff_sq_z                                        3.163  0.00156 **
# reliability_binary_z                                    0.535  0.59237
# attend_binary_z                                        -1.189  0.23454
# v2_ltm_diff_z                                           0.596  0.55109
# v2_ltm_diff_sq_z                                        0.128  0.89789
# tested_binary_z                                       -15.945  < 2e-16 ***
# it_ltm_diff_z:reliability_binary_z                      1.273  0.20314
# it_ltm_diff_sq_z:reliability_binary_z                  -0.409  0.68221
# it_ltm_diff_z:attend_binary_z                           0.774  0.43877
# it_ltm_diff_sq_z:attend_binary_z                       -0.447  0.65481
# reliability_binary_z:attend_binary_z                   -0.725  0.46875
# reliability_binary_z:v2_ltm_diff_z                     -0.615  0.53856
# reliability_binary_z:v2_ltm_diff_sq_z                  -0.146  0.88389
# attend_binary_z:v2_ltm_diff_z                           1.306  0.19170
# attend_binary_z:v2_ltm_diff_sq_z                       -0.930  0.35237
# it_ltm_diff_z:reliability_binary_z:attend_binary_z     -0.512  0.60882
# it_ltm_diff_sq_z:reliability_binary_z:attend_binary_z   1.638  0.10134
# reliability_binary_z:attend_binary_z:v2_ltm_diff_z     -0.306  0.75959
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sq_z  -1.910  0.05615 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
