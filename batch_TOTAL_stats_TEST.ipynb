# %%
library(lme4)
library(simr)
library(dplyr)
library(lmerTest)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
# install.packages("car")
library(car)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode

# %%
file_path <- "pilot_total.csv"

df <- read.csv(file_path) %>%
    select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z, rt,tested_memorability_resmem_z, v2_pos_neg_abs_z, it_pos_neg_abs_z, it_pos_neg_z, v2_pos_neg_z, it_sim_dis_diff_test_sign_z, it_sim_dis_diff_test_sign_sq_z,v2_sim_dis_diff_test_sign_z, v2_sim_dis_diff_test_sign_sq_z, it_sim_dis_test_sign_z, it_sim_dis_test_sign_sq_z,v2_sim_dis_test_sign_z, v2_sim_dis_test_sign_sq_z, it_int_abs, v2_int_abs, it_int_rel, v2_int_rel, it_int_rel_sq, v2_int_rel_sq, it_int_abs, v2_int_abs, it_int_abs_sq, v2_int_abs_sq, it_pos_neg_abs, v2_pos_neg_abs, it_pos_neg, v2_pos_neg)

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
df_correct <- subset(df, resp_correct == 1)
#

# %%
# names(df)

# %%
# mean(df$it_sim_dis_diff)

# %%
# model <- glm(
#   resp_correct ~ it_sim_dis_diff_test_z * reliability_binary * validity_binary + 
#              v2_sim_dis_diff_test_z * reliability_binary * validity_binary,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # head(df$v2_sim_dis_test_z)



# formula1 <- glmer(resp_correct ~  v2_sim_dis_test_z * reliability_binary * validity_binary +  
#                    it_sim_dis_test_z * reliability_binary * validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# model <- glm(
#   resp_correct ~ reliability_binary * validity_binary + (1 | participant),
#              y,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # IT*V2*reliability*validity + itsq+v2sq



# formula1 <- glmer(resp_correct ~ it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z * reliability_binary * validity_binary +  
#                    v2_sim_dis_diff_test_sq_z + it_sim_dis_diff_test_sq_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  84487.7  84682.8 -42222.9  84445.7    80079
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0667 -0.7754  0.4413  0.5869  1.6141
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4802   0.693
# Number of obs: 80100, groups:  participant, 267
#
# Fixed effects:
#                                                              Estimate
# (Intercept)                                                  1.181960
# it_sim_dis_test_z                                            0.069223
# it_sim_dis_test_sq_z                                        -0.041560
# reliability_binary_z                                         0.027504
# validity_binary_z                                            0.206293
# v2_sim_dis_test_z                                            0.002032
# v2_sim_dis_test_sq_z                                        -0.028351
# it_sim_dis_test_z:reliability_binary_z                      -0.007785
# it_sim_dis_test_sq_z:reliability_binary_z                    0.010950
# it_sim_dis_test_z:validity_binary_z                          0.005305
# it_sim_dis_test_sq_z:validity_binary_z                      -0.002470
# reliability_binary_z:validity_binary_z                       0.077589
# reliability_binary_z:v2_sim_dis_test_z                      -0.008741
# reliability_binary_z:v2_sim_dis_test_sq_z                   -0.006093
# validity_binary_z:v2_sim_dis_test_z                         -0.005556
# validity_binary_z:v2_sim_dis_test_sq_z                       0.002318
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    -0.010308
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.002827
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.002158
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.007478
#                                                             Std. Error z value
# (Intercept)                                                   0.043383  27.245
# it_sim_dis_test_z                                             0.008752   7.909
# it_sim_dis_test_sq_z                                          0.008690  -4.782
# reliability_binary_z                                          0.008650   3.180
# validity_binary_z                                             0.008489  24.302
# v2_sim_dis_test_z                                             0.010090   0.201
# v2_sim_dis_test_sq_z                                          0.009617  -2.948
# it_sim_dis_test_z:reliability_binary_z                        0.008751  -0.890
# it_sim_dis_test_sq_z:reliability_binary_z                     0.008698   1.259
# it_sim_dis_test_z:validity_binary_z                           0.008603   0.617
# it_sim_dis_test_sq_z:validity_binary_z                        0.008556  -0.289
# reliability_binary_z:validity_binary_z                        0.008478   9.152
# reliability_binary_z:v2_sim_dis_test_z                        0.009784  -0.893
# reliability_binary_z:v2_sim_dis_test_sq_z                     0.009610  -0.634
# validity_binary_z:v2_sim_dis_test_z                           0.009726  -0.571
# validity_binary_z:v2_sim_dis_test_sq_z                        0.009463   0.245
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z      0.008602  -1.198
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z   0.008558   0.330
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z      0.009729   0.222
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z   0.009465   0.790
#                                                             Pr(>|z|)
# (Intercept)                                                  < 2e-16 ***
# it_sim_dis_test_z                                           2.59e-15 ***
# it_sim_dis_test_sq_z                                        1.73e-06 ***
# reliability_binary_z                                         0.00147 **
# validity_binary_z                                            < 2e-16 ***
# v2_sim_dis_test_z                                            0.84039
# v2_sim_dis_test_sq_z                                         0.00320 **
# it_sim_dis_test_z:reliability_binary_z                       0.37364
# it_sim_dis_test_sq_z:reliability_binary_z                    0.20806
# it_sim_dis_test_z:validity_binary_z                          0.53750
# it_sim_dis_test_sq_z:validity_binary_z                       0.77283
# reliability_binary_z:validity_binary_z                       < 2e-16 ***
# reliability_binary_z:v2_sim_dis_test_z                       0.37162
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.52605
# validity_binary_z:v2_sim_dis_test_z                          0.56781
# validity_binary_z:v2_sim_dis_test_sq_z                       0.80648
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.23078
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.74119
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.82448
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.42944
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_z +
#     v2_sim_dis_diff_test_sq_z) * reliability_binary_z * validity_binary_z +
#     it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  84434.1  84638.5 -42195.1  84390.1    80078
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1810 -0.7707  0.4408  0.5868  1.6849
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4808   0.6934
# Number of obs: 80100, groups:  participant, 267
#
# Fixed effects:
#                                                                    Estimate
# (Intercept)                                                       1.1807334
# it_sim_dis_diff_test_z                                            0.0741959
# it_sim_dis_diff_test_sq_z                                        -0.0461996
# reliability_binary_z                                              0.0280871
# validity_binary_z                                                 0.2060150
# v2_sim_dis_diff_test_z                                            0.0077156
# v2_sim_dis_diff_test_sq_z                                        -0.0543671
# it_sim_dis_diff_test_z:reliability_binary_z                      -0.0065643
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.0028584
# it_sim_dis_diff_test_z:validity_binary_z                          0.0035934
# it_sim_dis_diff_test_sq_z:validity_binary_z                       0.0066780
# reliability_binary_z:validity_binary_z                            0.0772820
# reliability_binary_z:v2_sim_dis_diff_test_z                      -0.0118004
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    0.0018081
# validity_binary_z:v2_sim_dis_diff_test_z                          0.0053218
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       0.0009227
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     0.0135261
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    -0.0073911
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  0.0075358
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.0123751
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z -0.0056633
#                                                                  Std. Error
# (Intercept)                                                       0.0434344
# it_sim_dis_diff_test_z                                            0.0087183
# it_sim_dis_diff_test_sq_z                                         0.0089548
# reliability_binary_z                                              0.0086557
# validity_binary_z                                                 0.0084951
# v2_sim_dis_diff_test_z                                            0.0087111
# v2_sim_dis_diff_test_sq_z                                         0.0088396
# it_sim_dis_diff_test_z:reliability_binary_z                       0.0087189
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.0086079
# it_sim_dis_diff_test_z:validity_binary_z                          0.0085607
# it_sim_dis_diff_test_sq_z:validity_binary_z                       0.0084194
# reliability_binary_z:validity_binary_z                            0.0084848
# reliability_binary_z:v2_sim_dis_diff_test_z                       0.0087057
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    0.0086177
# validity_binary_z:v2_sim_dis_diff_test_z                          0.0085299
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       0.0083971
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     0.0090878
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     0.0085615
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  0.0084193
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.0085324
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  0.0083987
#                                                                  z value
# (Intercept)                                                       27.184
# it_sim_dis_diff_test_z                                             8.510
# it_sim_dis_diff_test_sq_z                                         -5.159
# reliability_binary_z                                               3.245
# validity_binary_z                                                 24.251
# v2_sim_dis_diff_test_z                                             0.886
# v2_sim_dis_diff_test_sq_z                                         -6.150
# it_sim_dis_diff_test_z:reliability_binary_z                       -0.753
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.332
# it_sim_dis_diff_test_z:validity_binary_z                           0.420
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.793
# reliability_binary_z:validity_binary_z                             9.108
# reliability_binary_z:v2_sim_dis_diff_test_z                       -1.355
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.210
# validity_binary_z:v2_sim_dis_diff_test_z                           0.624
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.110
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      1.488
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     -0.863
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.895
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      1.450
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  -0.674
#                                                                  Pr(>|z|)
# (Intercept)                                                       < 2e-16 ***
# it_sim_dis_diff_test_z                                            < 2e-16 ***
# it_sim_dis_diff_test_sq_z                                        2.48e-07 ***
# reliability_binary_z                                              0.00117 **
# validity_binary_z                                                 < 2e-16 ***
# v2_sim_dis_diff_test_z                                            0.37577
# v2_sim_dis_diff_test_sq_z                                        7.73e-10 ***
# it_sim_dis_diff_test_z:reliability_binary_z                       0.45152
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.73984
# it_sim_dis_diff_test_z:validity_binary_z                          0.67467
# it_sim_dis_diff_test_sq_z:validity_binary_z                       0.42768
# reliability_binary_z:validity_binary_z                            < 2e-16 ***
# reliability_binary_z:v2_sim_dis_diff_test_z                       0.17526
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    0.83381
# validity_binary_z:v2_sim_dis_diff_test_z                          0.53269
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       0.91250
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     0.13665
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     0.38798
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  0.37075
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.14696
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  0.50012
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# formula11 <- glmer(resp_correct ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_attend_z + v2_sim_dis_attend_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula11)

# %%
# formula10 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_diff_z * v2_sim_dis_diff_z +  (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula10)

# %%
formula_rt1 <- lmer(rt ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
                validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
                validity_binary_z + (1 | participant), 
                data = df_correct, control = lmerControl(optimizer = "bobyqa"))
summary(formula_rt1)  # Will now include p-values
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# rt ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df_correct
# Control: lmerControl(optimizer = "bobyqa")
#
# REML criterion at convergence: 79316.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.3597 -0.7358 -0.1700  0.5752  3.9487
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.0353   0.1879
#  Residual                0.2174   0.4662
# Number of obs: 59591, groups:  participant, 267
#
# Fixed effects:
#                                                               Estimate
# (Intercept)                                                  1.570e+00
# it_sim_dis_test_z                                           -1.270e-02
# it_sim_dis_test_sq_z                                         1.516e-02
# reliability_binary_z                                        -1.719e-02
# validity_binary_z                                           -4.271e-02
# v2_sim_dis_test_z                                           -2.538e-03
# v2_sim_dis_test_sq_z                                        -2.790e-03
# it_sim_dis_test_z:reliability_binary_z                       1.629e-03
# it_sim_dis_test_sq_z:reliability_binary_z                    2.224e-03
# it_sim_dis_test_z:validity_binary_z                         -1.142e-03
# it_sim_dis_test_sq_z:validity_binary_z                       3.359e-03
# reliability_binary_z:validity_binary_z                      -1.980e-02
# reliability_binary_z:v2_sim_dis_test_z                      -2.951e-04
# reliability_binary_z:v2_sim_dis_test_sq_z                   -5.274e-05
# validity_binary_z:v2_sim_dis_test_z                         -1.853e-03
# validity_binary_z:v2_sim_dis_test_sq_z                       5.008e-03
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    -1.303e-03
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  4.072e-04
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z    -1.791e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  2.423e-04
#                                                             Std. Error
# (Intercept)                                                  1.167e-02
# it_sim_dis_test_z                                            2.010e-03
# it_sim_dis_test_sq_z                                         1.997e-03
# reliability_binary_z                                         1.964e-03
# validity_binary_z                                            2.090e-03
# v2_sim_dis_test_z                                            2.317e-03
# v2_sim_dis_test_sq_z                                         2.223e-03
# it_sim_dis_test_z:reliability_binary_z                       2.010e-03
# it_sim_dis_test_sq_z:reliability_binary_z                    1.998e-03
# it_sim_dis_test_z:validity_binary_z                          2.140e-03
# it_sim_dis_test_sq_z:validity_binary_z                       2.131e-03
# reliability_binary_z:validity_binary_z                       2.085e-03
# reliability_binary_z:v2_sim_dis_test_z                       2.244e-03
# reliability_binary_z:v2_sim_dis_test_sq_z                    2.220e-03
# validity_binary_z:v2_sim_dis_test_z                          2.419e-03
# validity_binary_z:v2_sim_dis_test_sq_z                       2.364e-03
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     2.139e-03
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  2.131e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     2.419e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  2.365e-03
#                                                                     df t value
# (Intercept)                                                  2.671e+02 134.540
# it_sim_dis_test_z                                            5.931e+04  -6.318
# it_sim_dis_test_sq_z                                         5.932e+04   7.590
# reliability_binary_z                                         5.931e+04  -8.753
# validity_binary_z                                            5.933e+04 -20.435
# v2_sim_dis_test_z                                            5.949e+04  -1.095
# v2_sim_dis_test_sq_z                                         5.933e+04  -1.255
# it_sim_dis_test_z:reliability_binary_z                       5.931e+04   0.810
# it_sim_dis_test_sq_z:reliability_binary_z                    5.932e+04   1.113
# it_sim_dis_test_z:validity_binary_z                          5.931e+04  -0.534
# it_sim_dis_test_sq_z:validity_binary_z                       5.932e+04   1.576
# reliability_binary_z:validity_binary_z                       5.931e+04  -9.497
# reliability_binary_z:v2_sim_dis_test_z                       5.932e+04  -0.131
# reliability_binary_z:v2_sim_dis_test_sq_z                    5.932e+04  -0.024
# validity_binary_z:v2_sim_dis_test_z                          5.932e+04  -0.766
# validity_binary_z:v2_sim_dis_test_sq_z                       5.932e+04   2.118
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     5.931e+04  -0.609
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  5.932e+04   0.191
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     5.932e+04  -0.740
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  5.932e+04   0.102
#                                                             Pr(>|t|)
# (Intercept)                                                  < 2e-16 ***
# it_sim_dis_test_z                                           2.67e-10 ***
# it_sim_dis_test_sq_z                                        3.24e-14 ***
# reliability_binary_z                                         < 2e-16 ***
# validity_binary_z                                            < 2e-16 ***
# v2_sim_dis_test_z                                             0.2734
# v2_sim_dis_test_sq_z                                          0.2094
# it_sim_dis_test_z:reliability_binary_z                        0.4177
# it_sim_dis_test_sq_z:reliability_binary_z                     0.2658
# it_sim_dis_test_z:validity_binary_z                           0.5936
# it_sim_dis_test_sq_z:validity_binary_z                        0.1150
# reliability_binary_z:validity_binary_z                       < 2e-16 ***
# reliability_binary_z:v2_sim_dis_test_z                        0.8954
# reliability_binary_z:v2_sim_dis_test_sq_z                     0.9810
# validity_binary_z:v2_sim_dis_test_z                           0.4437
# validity_binary_z:v2_sim_dis_test_sq_z                        0.0342 *
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z      0.5426
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z   0.8485
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z      0.4591
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z   0.9184
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula_rt2 <- lmer(rt ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant), 
                  data = df_correct, control = lmerControl(optimizer = "bobyqa"))

summary(formula_rt2)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# rt ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + it_sim_dis_diff_test_z *
#     v2_sim_dis_diff_test_z + (1 | participant)
#    Data: df_correct
# Control: lmerControl(optimizer = "bobyqa")
#
# REML criterion at convergence: 79302
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.3814 -0.7353 -0.1702  0.5771  3.9548
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.0353   0.1879
#  Residual                0.2173   0.4661
# Number of obs: 59591, groups:  participant, 267
#
# Fixed effects:
#                                                                    Estimate
# (Intercept)                                                       1.571e+00
# it_sim_dis_diff_test_z                                           -1.456e-02
# it_sim_dis_diff_test_sq_z                                         1.361e-02
# reliability_binary_z                                             -1.723e-02
# validity_binary_z                                                -4.274e-02
# v2_sim_dis_diff_test_z                                           -6.337e-03
# v2_sim_dis_diff_test_sq_z                                         7.209e-03
# it_sim_dis_diff_test_z:reliability_binary_z                       1.019e-03
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    1.923e-03
# it_sim_dis_diff_test_z:validity_binary_z                          1.010e-04
# it_sim_dis_diff_test_sq_z:validity_binary_z                       4.134e-03
# reliability_binary_z:validity_binary_z                           -1.976e-02
# reliability_binary_z:v2_sim_dis_diff_test_z                      -1.915e-04
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    1.789e-03
# validity_binary_z:v2_sim_dis_diff_test_z                          9.092e-05
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       3.040e-03
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                    -3.365e-03
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    -5.596e-04
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  1.456e-04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    -3.164e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  1.034e-03
#                                                                  Std. Error
# (Intercept)                                                       1.168e-02
# it_sim_dis_diff_test_z                                            2.003e-03
# it_sim_dis_diff_test_sq_z                                         2.042e-03
# reliability_binary_z                                              1.964e-03
# validity_binary_z                                                 2.089e-03
# v2_sim_dis_diff_test_z                                            2.004e-03
# v2_sim_dis_diff_test_sq_z                                         2.022e-03
# it_sim_dis_diff_test_z:reliability_binary_z                       2.003e-03
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    1.968e-03
# it_sim_dis_diff_test_z:validity_binary_z                          2.131e-03
# it_sim_dis_diff_test_sq_z:validity_binary_z                       2.087e-03
# reliability_binary_z:validity_binary_z                            2.083e-03
# reliability_binary_z:v2_sim_dis_diff_test_z                       2.003e-03
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    1.971e-03
# validity_binary_z:v2_sim_dis_diff_test_z                          2.120e-03
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       2.081e-03
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     2.089e-03
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     2.130e-03
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  2.086e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     2.120e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  2.082e-03
#                                                                          df
# (Intercept)                                                       2.676e+02
# it_sim_dis_diff_test_z                                            5.931e+04
# it_sim_dis_diff_test_sq_z                                         5.931e+04
# reliability_binary_z                                              5.931e+04
# validity_binary_z                                                 5.933e+04
# v2_sim_dis_diff_test_z                                            5.932e+04
# v2_sim_dis_diff_test_sq_z                                         5.931e+04
# it_sim_dis_diff_test_z:reliability_binary_z                       5.931e+04
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    5.932e+04
# it_sim_dis_diff_test_z:validity_binary_z                          5.931e+04
# it_sim_dis_diff_test_sq_z:validity_binary_z                       5.932e+04
# reliability_binary_z:validity_binary_z                            5.931e+04
# reliability_binary_z:v2_sim_dis_diff_test_z                       5.932e+04
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    5.932e+04
# validity_binary_z:v2_sim_dis_diff_test_z                          5.932e+04
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       5.932e+04
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     5.931e+04
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     5.931e+04
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  5.932e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     5.932e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  5.932e+04
#                                                                  t value
# (Intercept)                                                      134.539
# it_sim_dis_diff_test_z                                            -7.269
# it_sim_dis_diff_test_sq_z                                          6.664
# reliability_binary_z                                              -8.772
# validity_binary_z                                                -20.459
# v2_sim_dis_diff_test_z                                            -3.162
# v2_sim_dis_diff_test_sq_z                                          3.565
# it_sim_dis_diff_test_z:reliability_binary_z                        0.509
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.977
# it_sim_dis_diff_test_z:validity_binary_z                           0.047
# it_sim_dis_diff_test_sq_z:validity_binary_z                        1.981
# reliability_binary_z:validity_binary_z                            -9.485
# reliability_binary_z:v2_sim_dis_diff_test_z                       -0.096
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.908
# validity_binary_z:v2_sim_dis_diff_test_z                           0.043
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        1.461
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     -1.611
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     -0.263
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.070
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     -1.492
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.496
#                                                                  Pr(>|t|)
# (Intercept)                                                       < 2e-16 ***
# it_sim_dis_diff_test_z                                           3.68e-13 ***
# it_sim_dis_diff_test_sq_z                                        2.68e-11 ***
# reliability_binary_z                                              < 2e-16 ***
# validity_binary_z                                                 < 2e-16 ***
# v2_sim_dis_diff_test_z                                           0.001570 **
# v2_sim_dis_diff_test_sq_z                                        0.000365 ***
# it_sim_dis_diff_test_z:reliability_binary_z                      0.611024
# it_sim_dis_diff_test_sq_z:reliability_binary_z                   0.328501
# it_sim_dis_diff_test_z:validity_binary_z                         0.962195
# it_sim_dis_diff_test_sq_z:validity_binary_z                      0.047635 *
# reliability_binary_z:validity_binary_z                            < 2e-16 ***
# reliability_binary_z:v2_sim_dis_diff_test_z                      0.923818
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   0.363930
# validity_binary_z:v2_sim_dis_diff_test_z                         0.965794
# validity_binary_z:v2_sim_dis_diff_test_sq_z                      0.144132
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                    0.107227
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    0.792741
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z 0.944363
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    0.135628
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z 0.619563
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# formula_rt3 <- lmer(rt ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_attend_z + v2_sim_dis_attend_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant), 
#                   data = df_correct, control = lmerControl(optimizer = "bobyqa"))
# summary(formula_rt3)

# %%
# formula_rt4 <- lmer(rt ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_diff_z * v2_sim_dis_diff_z +  (1 | participant), 
#                   data = df_correct, control = lmerControl(optimizer = "bobyqa"))
# summary(formula_rt4)

# %%
# tested_memorability_resmem_z

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
#                   validity_binary_z + tested_memorability_resmem_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + tested_memorability_resmem_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# summary(formula1)

# %%
# formula_rt1 <- lmer(rt ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
#                 validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
#                 validity_binary_z + tested_memorability_resmem_z + (1 | participant), 
#                 data = df_correct, control = lmerControl(optimizer = "bobyqa"))
# summary(formula_rt1)  # Will now include p-values

# %%
# formula_rt2 <- lmer(rt ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + tested_memorability_resmem_z + (1 | participant), 
#                   data = df_correct, control = lmerControl(optimizer = "bobyqa"))

# summary(formula_rt2)

# %%
# EDITS

# %%
#explicitly adding the sign value

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) * it_pos_neg_abs * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs * reliability_binary_z *  
#                   validity_binary_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa",
#                                         optCtrl = list(maxfun = 500000),
#                                         calc.derivs = FALSE))

# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) * it_pos_neg * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_diff_test_sign_z + v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *  
#                   validity_binary_z + (1 | participant), 
#                   data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
#                                         optCtrl = list(maxfun = 500000),
#                                         calc.derivs = FALSE))

# summary(formula1)

# %%
# formula_rt1 <- lmer(rt ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) * it_pos_neg_abs * reliability_binary_z *  
#                 validity_binary_z + (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs * reliability_binary_z *  
#                 validity_binary_z + (1 | participant), 
#                 data = df_correct, control = lmerControl(optimizer = "bobyqa"))
# summary(formula_rt1)

# %%
# formula_rt2 <- lmer(rt ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) * it_pos_neg  * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_diff_test_sign_z + v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *  
#                   validity_binary_z   + (1 | participant), 
#                   data = df_correct, control =lmerControl(optimizer = "bobyqa"))



# summary(formula_rt2)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula10 <- glmer(resp_correct ~ (it_sim_dis_unattend_z + it_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_unattend_z + v2_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula10)
