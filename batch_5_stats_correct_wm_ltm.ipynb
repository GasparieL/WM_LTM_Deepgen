# %%
library(lme4)
library(simr)
library(dplyr)
library(broom)
install.packages("sjPlot")
library(sjPlot)
install.packages("broom.mixed")
library(broom.mixed)
# Out:
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpW1bZsy/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpW1bZsy/downloaded_packages

# %%
# install.packages("car")
library(car)
install.packages("stargazer")

library(stargazer)
# Out:
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpW1bZsy/downloaded_packages

# %%
file_path <- 'pilot5_stats/correct_wm_ltm.csv'
df <- read.csv(file_path) 
# %>%
#     select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z )

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
# head(df$recall_answ)

# %%
# names(df)

# %%
# head(df$attend_binary_z)

# %%
formula1 <- glmer(recall_answ ~ (it_ltm_sign_z + it_ltm_sign_sq_z)  *it_pos_neg_ltm_abs * reliability_binary_z *  
                  attend_binary_z + (v2_ltm_sign_z + v2_ltm_sign_sq_z) * v2_pos_neg_ltm_abs * reliability_binary_z *  
                  attend_binary_z + tested_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 45 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_ltm_sign_z + it_ltm_sign_sq_z) * it_pos_neg_ltm_abs *
#     reliability_binary_z * attend_binary_z + (v2_ltm_sign_z +
#     v2_ltm_sign_sq_z) * v2_pos_neg_ltm_abs * reliability_binary_z *
#     attend_binary_z + tested_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   6856.7   7173.5  -3382.3   6764.7     7184
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.5863  0.2067  0.3483  0.5411  2.0836
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5855   0.7651
# Number of obs: 7230, groups:  participant, 133
#
# Fixed effects:
#                                                                            Estimate
# (Intercept)                                                               1.1045411
# it_ltm_sign_z                                                            -0.4912502
# it_ltm_sign_sq_z                                                         -0.0399041
# it_pos_neg_ltm_abs                                                        0.3526768
# reliability_binary_z                                                      0.0362437
# attend_binary_z                                                          -0.2496266
# v2_ltm_sign_z                                                            -0.2998643
# v2_ltm_sign_sq_z                                                         -0.2247108
# v2_pos_neg_ltm_abs                                                        0.3041413
# tested_binary_z                                                          -0.6002562
# it_ltm_sign_z:it_pos_neg_ltm_abs                                          0.1064815
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                       0.4126084
# it_ltm_sign_z:reliability_binary_z                                        0.1663634
# it_ltm_sign_sq_z:reliability_binary_z                                    -0.0384870
# it_pos_neg_ltm_abs:reliability_binary_z                                  -0.1150435
# it_ltm_sign_z:attend_binary_z                                            -0.1808827
# it_ltm_sign_sq_z:attend_binary_z                                         -0.1547053
# it_pos_neg_ltm_abs:attend_binary_z                                        0.1433797
# reliability_binary_z:attend_binary_z                                      0.3498961
# v2_ltm_sign_z:v2_pos_neg_ltm_abs                                          0.2676159
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                                       0.2260365
# reliability_binary_z:v2_ltm_sign_z                                        0.1003451
# reliability_binary_z:v2_ltm_sign_sq_z                                    -0.0759369
# reliability_binary_z:v2_pos_neg_ltm_abs                                  -0.0643188
# attend_binary_z:v2_ltm_sign_z                                            -0.0963685
# attend_binary_z:v2_ltm_sign_sq_z                                         -0.1202922
# attend_binary_z:v2_pos_neg_ltm_abs                                        0.1501574
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                     0.0123933
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z                 -0.1399211
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z                          0.1794880
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z                       0.1891196
# it_ltm_sign_z:reliability_binary_z:attend_binary_z                        0.2038351
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z                     0.0122044
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z                  -0.1788930
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                     0.0273046
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                 -0.0651898
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                          0.0172940
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                       0.1418396
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z                        0.2242344
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z                     0.3192126
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs                  -0.1782544
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z    -0.0008729
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z -0.1852315
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs    -0.3709734
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs -0.1391261
#                                                                          Std. Error
# (Intercept)                                                               0.2873467
# it_ltm_sign_z                                                             0.1764964
# it_ltm_sign_sq_z                                                          0.1170059
# it_pos_neg_ltm_abs                                                        0.1555273
# reliability_binary_z                                                      0.2804935
# attend_binary_z                                                           0.2798183
# v2_ltm_sign_z                                                             0.2498503
# v2_ltm_sign_sq_z                                                          0.2345655
# v2_pos_neg_ltm_abs                                                        0.2327590
# tested_binary_z                                                           0.0397089
# it_ltm_sign_z:it_pos_neg_ltm_abs                                          0.1758229
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                       0.1170469
# it_ltm_sign_z:reliability_binary_z                                        0.1760879
# it_ltm_sign_sq_z:reliability_binary_z                                     0.1170275
# it_pos_neg_ltm_abs:reliability_binary_z                                   0.1551627
# it_ltm_sign_z:attend_binary_z                                             0.1759103
# it_ltm_sign_sq_z:attend_binary_z                                          0.1168578
# it_pos_neg_ltm_abs:attend_binary_z                                        0.1550510
# reliability_binary_z:attend_binary_z                                      0.2803006
# v2_ltm_sign_z:v2_pos_neg_ltm_abs                                          0.2504647
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                                       0.2343494
# reliability_binary_z:v2_ltm_sign_z                                        0.2506074
# reliability_binary_z:v2_ltm_sign_sq_z                                     0.2361520
# reliability_binary_z:v2_pos_neg_ltm_abs                                   0.2334232
# attend_binary_z:v2_ltm_sign_z                                             0.2500558
# attend_binary_z:v2_ltm_sign_sq_z                                          0.2346031
# attend_binary_z:v2_pos_neg_ltm_abs                                        0.2326485
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                     0.1759390
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z                  0.1165989
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z                          0.1759347
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z                       0.1163549
# it_ltm_sign_z:reliability_binary_z:attend_binary_z                        0.1755652
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z                     0.1168800
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z                   0.1547771
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                     0.2516448
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                  0.2358135
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                          0.2507664
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                       0.2345567
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z                        0.2509631
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z                     0.2357719
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs                   0.2336957
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z     0.1755787
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z  0.1162375
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs     0.2516048
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs  0.2356280
#                                                                          z value
# (Intercept)                                                                3.844
# it_ltm_sign_z                                                             -2.783
# it_ltm_sign_sq_z                                                          -0.341
# it_pos_neg_ltm_abs                                                         2.268
# reliability_binary_z                                                       0.129
# attend_binary_z                                                           -0.892
# v2_ltm_sign_z                                                             -1.200
# v2_ltm_sign_sq_z                                                          -0.958
# v2_pos_neg_ltm_abs                                                         1.307
# tested_binary_z                                                          -15.116
# it_ltm_sign_z:it_pos_neg_ltm_abs                                           0.606
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                        3.525
# it_ltm_sign_z:reliability_binary_z                                         0.945
# it_ltm_sign_sq_z:reliability_binary_z                                     -0.329
# it_pos_neg_ltm_abs:reliability_binary_z                                   -0.741
# it_ltm_sign_z:attend_binary_z                                             -1.028
# it_ltm_sign_sq_z:attend_binary_z                                          -1.324
# it_pos_neg_ltm_abs:attend_binary_z                                         0.925
# reliability_binary_z:attend_binary_z                                       1.248
# v2_ltm_sign_z:v2_pos_neg_ltm_abs                                           1.068
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                                        0.965
# reliability_binary_z:v2_ltm_sign_z                                         0.400
# reliability_binary_z:v2_ltm_sign_sq_z                                     -0.322
# reliability_binary_z:v2_pos_neg_ltm_abs                                   -0.276
# attend_binary_z:v2_ltm_sign_z                                             -0.385
# attend_binary_z:v2_ltm_sign_sq_z                                          -0.513
# attend_binary_z:v2_pos_neg_ltm_abs                                         0.645
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                      0.070
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z                  -1.200
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z                           1.020
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z                        1.625
# it_ltm_sign_z:reliability_binary_z:attend_binary_z                         1.161
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z                      0.104
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z                   -1.156
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                      0.109
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                  -0.276
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                           0.069
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                        0.605
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z                         0.893
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z                      1.354
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs                   -0.763
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z     -0.005
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z  -1.594
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs     -1.474
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs  -0.590
#                                                                          Pr(>|z|)
# (Intercept)                                                              0.000121
# it_ltm_sign_z                                                            0.005380
# it_ltm_sign_sq_z                                                         0.733071
# it_pos_neg_ltm_abs                                                       0.023352
# reliability_binary_z                                                     0.897188
# attend_binary_z                                                          0.372338
# v2_ltm_sign_z                                                            0.230071
# v2_ltm_sign_sq_z                                                         0.338069
# v2_pos_neg_ltm_abs                                                       0.191322
# tested_binary_z                                                           < 2e-16
# it_ltm_sign_z:it_pos_neg_ltm_abs                                         0.544768
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                      0.000423
# it_ltm_sign_z:reliability_binary_z                                       0.344774
# it_ltm_sign_sq_z:reliability_binary_z                                    0.742253
# it_pos_neg_ltm_abs:reliability_binary_z                                  0.458428
# it_ltm_sign_z:attend_binary_z                                            0.303824
# it_ltm_sign_sq_z:attend_binary_z                                         0.185544
# it_pos_neg_ltm_abs:attend_binary_z                                       0.355108
# reliability_binary_z:attend_binary_z                                     0.211925
# v2_ltm_sign_z:v2_pos_neg_ltm_abs                                         0.285305
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                                      0.334781
# reliability_binary_z:v2_ltm_sign_z                                       0.688856
# reliability_binary_z:v2_ltm_sign_sq_z                                    0.747786
# reliability_binary_z:v2_pos_neg_ltm_abs                                  0.782897
# attend_binary_z:v2_ltm_sign_z                                            0.699950
# attend_binary_z:v2_ltm_sign_sq_z                                         0.608128
# attend_binary_z:v2_pos_neg_ltm_abs                                       0.518651
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z                    0.943843
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z                 0.230131
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z                         0.307635
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z                      0.104084
# it_ltm_sign_z:reliability_binary_z:attend_binary_z                       0.245633
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z                    0.916838
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z                  0.247759
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                    0.913595
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                 0.782205
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs                         0.945018
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs                      0.545369
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z                       0.371592
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z                    0.175767
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs                  0.445605
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z    0.996033
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z 0.111034
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs    0.140366
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs 0.554890
#
# (Intercept)                                                              ***
# it_ltm_sign_z                                                            **
# it_ltm_sign_sq_z
# it_pos_neg_ltm_abs                                                       *
# reliability_binary_z
# attend_binary_z
# v2_ltm_sign_z
# v2_ltm_sign_sq_z
# v2_pos_neg_ltm_abs
# tested_binary_z                                                          ***
# it_ltm_sign_z:it_pos_neg_ltm_abs
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs                                      ***
# it_ltm_sign_z:reliability_binary_z
# it_ltm_sign_sq_z:reliability_binary_z
# it_pos_neg_ltm_abs:reliability_binary_z
# it_ltm_sign_z:attend_binary_z
# it_ltm_sign_sq_z:attend_binary_z
# it_pos_neg_ltm_abs:attend_binary_z
# reliability_binary_z:attend_binary_z
# v2_ltm_sign_z:v2_pos_neg_ltm_abs
# v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs
# reliability_binary_z:v2_ltm_sign_z
# reliability_binary_z:v2_ltm_sign_sq_z
# reliability_binary_z:v2_pos_neg_ltm_abs
# attend_binary_z:v2_ltm_sign_z
# attend_binary_z:v2_ltm_sign_sq_z
# attend_binary_z:v2_pos_neg_ltm_abs
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z
# it_ltm_sign_z:it_pos_neg_ltm_abs:attend_binary_z
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:attend_binary_z
# it_ltm_sign_z:reliability_binary_z:attend_binary_z
# it_ltm_sign_sq_z:reliability_binary_z:attend_binary_z
# it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z
# reliability_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs
# reliability_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs
# attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs
# attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm_abs
# it_ltm_sign_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z
# it_ltm_sign_sq_z:it_pos_neg_ltm_abs:reliability_binary_z:attend_binary_z
# reliability_binary_z:attend_binary_z:v2_ltm_sign_z:v2_pos_neg_ltm_abs
# reliability_binary_z:attend_binary_z:v2_ltm_sign_sq_z:v2_pos_neg_ltm_abs
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# mm <- model.matrix(formula(formula1), data = df)
# qr_mm <- qr(mm)
# qr_mm$rank
# ncol(mm)
# deps <- qr_mm$pivot[(qr_mm$rank + 1):ncol(mm)]
# colnames(mm)[deps]


# it_pos_neg_ltm_abs

# %%
formula1 <- glmer(recall_answ ~ (it_ltm_diff_sign_z + it_ltm_diff_sign_sq_z) * it_pos_neg_ltm * reliability_binary_z *  
                  attend_binary_z + (v2_ltm_diff_sign_z + v2_ltm_diff_sign_sq_z) * v2_pos_neg_ltm * reliability_binary_z *  
                  attend_binary_z + tested_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 45 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_ltm_diff_sign_z + it_ltm_diff_sign_sq_z) *
#     it_pos_neg_ltm * reliability_binary_z * attend_binary_z +
#     (v2_ltm_diff_sign_z + v2_ltm_diff_sign_sq_z) * v2_pos_neg_ltm *
#         reliability_binary_z * attend_binary_z + tested_binary_z +
#     (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   6874.5   7191.3  -3391.3   6782.5     7184
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8805  0.2089  0.3517  0.5438  1.8856
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5782   0.7604
# Number of obs: 7230, groups:  participant, 133
#
# Fixed effects:
#                                                                            Estimate
# (Intercept)                                                                1.482719
# it_ltm_diff_sign_z                                                         0.031463
# it_ltm_diff_sign_sq_z                                                      0.066537
# it_pos_neg_ltm                                                             0.010944
# reliability_binary_z                                                       0.043499
# attend_binary_z                                                           -0.053690
# v2_ltm_diff_sign_z                                                         0.036914
# v2_ltm_diff_sign_sq_z                                                     -0.023027
# v2_pos_neg_ltm                                                             0.032799
# tested_binary_z                                                           -0.606443
# it_ltm_diff_sign_z:it_pos_neg_ltm                                         -0.058495
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm                                      -0.003995
# it_ltm_diff_sign_z:reliability_binary_z                                   -0.032722
# it_ltm_diff_sign_sq_z:reliability_binary_z                                -0.021119
# it_pos_neg_ltm:reliability_binary_z                                        0.017583
# it_ltm_diff_sign_z:attend_binary_z                                         0.060908
# it_ltm_diff_sign_sq_z:attend_binary_z                                      0.006697
# it_pos_neg_ltm:attend_binary_z                                            -0.016074
# reliability_binary_z:attend_binary_z                                       0.016697
# v2_ltm_diff_sign_z:v2_pos_neg_ltm                                         -0.017668
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                                       0.040891
# reliability_binary_z:v2_ltm_diff_sign_z                                   -0.084814
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                -0.055229
# reliability_binary_z:v2_pos_neg_ltm                                        0.022559
# attend_binary_z:v2_ltm_diff_sign_z                                        -0.044713
# attend_binary_z:v2_ltm_diff_sign_sq_z                                     -0.048145
# attend_binary_z:v2_pos_neg_ltm                                             0.044240
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z                    -0.029489
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z                  0.016193
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z                          0.031570
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z                      -0.027462
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                    0.055162
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                -0.013747
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z                       -0.046719
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                    -0.059044
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                 -0.054167
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                         -0.026743
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                       0.038804
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                    0.014807
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z                 0.027308
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm                        0.036779
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z     0.036149
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z -0.022526
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm     0.041984
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm -0.005442
#                                                                           Std. Error
# (Intercept)                                                                 0.074502
# it_ltm_diff_sign_z                                                          0.033286
# it_ltm_diff_sign_sq_z                                                       0.032541
# it_pos_neg_ltm                                                              0.033310
# reliability_binary_z                                                        0.032529
# attend_binary_z                                                             0.038120
# v2_ltm_diff_sign_z                                                          0.032664
# v2_ltm_diff_sign_sq_z                                                       0.032128
# v2_pos_neg_ltm                                                              0.034209
# tested_binary_z                                                             0.039709
# it_ltm_diff_sign_z:it_pos_neg_ltm                                           0.033363
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm                                        0.033445
# it_ltm_diff_sign_z:reliability_binary_z                                     0.033144
# it_ltm_diff_sign_sq_z:reliability_binary_z                                  0.032627
# it_pos_neg_ltm:reliability_binary_z                                         0.033365
# it_ltm_diff_sign_z:attend_binary_z                                          0.033109
# it_ltm_diff_sign_sq_z:attend_binary_z                                       0.032592
# it_pos_neg_ltm:attend_binary_z                                              0.033426
# reliability_binary_z:attend_binary_z                                        0.033140
# v2_ltm_diff_sign_z:v2_pos_neg_ltm                                           0.033018
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                                        0.032285
# reliability_binary_z:v2_ltm_diff_sign_z                                     0.032844
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                  0.032294
# reliability_binary_z:v2_pos_neg_ltm                                         0.034240
# attend_binary_z:v2_ltm_diff_sign_z                                          0.032732
# attend_binary_z:v2_ltm_diff_sign_sq_z                                       0.032135
# attend_binary_z:v2_pos_neg_ltm                                              0.034358
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z                      0.033401
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z                   0.033531
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z                           0.033518
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z                        0.033631
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                     0.033172
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                  0.032553
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z                         0.033432
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                      0.033032
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                   0.032203
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                           0.032992
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                        0.032234
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                     0.032749
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z                  0.032234
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm                         0.034272
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z      0.033430
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z   0.033664
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm      0.033035
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm   0.032230
#                                                                           z value
# (Intercept)                                                                19.902
# it_ltm_diff_sign_z                                                          0.945
# it_ltm_diff_sign_sq_z                                                       2.045
# it_pos_neg_ltm                                                              0.329
# reliability_binary_z                                                        1.337
# attend_binary_z                                                            -1.408
# v2_ltm_diff_sign_z                                                          1.130
# v2_ltm_diff_sign_sq_z                                                      -0.717
# v2_pos_neg_ltm                                                              0.959
# tested_binary_z                                                           -15.272
# it_ltm_diff_sign_z:it_pos_neg_ltm                                          -1.753
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm                                       -0.119
# it_ltm_diff_sign_z:reliability_binary_z                                    -0.987
# it_ltm_diff_sign_sq_z:reliability_binary_z                                 -0.647
# it_pos_neg_ltm:reliability_binary_z                                         0.527
# it_ltm_diff_sign_z:attend_binary_z                                          1.840
# it_ltm_diff_sign_sq_z:attend_binary_z                                       0.205
# it_pos_neg_ltm:attend_binary_z                                             -0.481
# reliability_binary_z:attend_binary_z                                        0.504
# v2_ltm_diff_sign_z:v2_pos_neg_ltm                                          -0.535
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                                        1.267
# reliability_binary_z:v2_ltm_diff_sign_z                                    -2.582
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                 -1.710
# reliability_binary_z:v2_pos_neg_ltm                                         0.659
# attend_binary_z:v2_ltm_diff_sign_z                                         -1.366
# attend_binary_z:v2_ltm_diff_sign_sq_z                                      -1.498
# attend_binary_z:v2_pos_neg_ltm                                              1.288
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z                     -0.883
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z                   0.483
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z                           0.942
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z                       -0.817
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                     1.663
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                 -0.422
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z                        -1.397
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                     -1.787
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                  -1.682
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                          -0.811
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                        1.204
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                     0.452
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z                  0.847
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm                         1.073
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z      1.081
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z  -0.669
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm      1.271
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm  -0.169
#                                                                           Pr(>|z|)
# (Intercept)                                                                < 2e-16
# it_ltm_diff_sign_z                                                         0.34454
# it_ltm_diff_sign_sq_z                                                      0.04088
# it_pos_neg_ltm                                                             0.74250
# reliability_binary_z                                                       0.18114
# attend_binary_z                                                            0.15900
# v2_ltm_diff_sign_z                                                         0.25842
# v2_ltm_diff_sign_sq_z                                                      0.47354
# v2_pos_neg_ltm                                                             0.33767
# tested_binary_z                                                            < 2e-16
# it_ltm_diff_sign_z:it_pos_neg_ltm                                          0.07956
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm                                       0.90493
# it_ltm_diff_sign_z:reliability_binary_z                                    0.32351
# it_ltm_diff_sign_sq_z:reliability_binary_z                                 0.51746
# it_pos_neg_ltm:reliability_binary_z                                        0.59819
# it_ltm_diff_sign_z:attend_binary_z                                         0.06582
# it_ltm_diff_sign_sq_z:attend_binary_z                                      0.83721
# it_pos_neg_ltm:attend_binary_z                                             0.63059
# reliability_binary_z:attend_binary_z                                       0.61438
# v2_ltm_diff_sign_z:v2_pos_neg_ltm                                          0.59257
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                                       0.20531
# reliability_binary_z:v2_ltm_diff_sign_z                                    0.00981
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                 0.08723
# reliability_binary_z:v2_pos_neg_ltm                                        0.51000
# attend_binary_z:v2_ltm_diff_sign_z                                         0.17193
# attend_binary_z:v2_ltm_diff_sign_sq_z                                      0.13409
# attend_binary_z:v2_pos_neg_ltm                                             0.19787
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z                     0.37731
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z                  0.62914
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z                          0.34625
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z                       0.41418
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                    0.09633
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z                 0.67282
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z                        0.16228
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                     0.07386
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                  0.09257
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                          0.41760
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                       0.22866
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z                    0.65118
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z                 0.39690
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm                        0.28320
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z     0.27956
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z  0.50339
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm     0.20376
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm  0.86593
#
# (Intercept)                                                               ***
# it_ltm_diff_sign_z
# it_ltm_diff_sign_sq_z                                                     *
# it_pos_neg_ltm
# reliability_binary_z
# attend_binary_z
# v2_ltm_diff_sign_z
# v2_ltm_diff_sign_sq_z
# v2_pos_neg_ltm
# tested_binary_z                                                           ***
# it_ltm_diff_sign_z:it_pos_neg_ltm                                         .
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm
# it_ltm_diff_sign_z:reliability_binary_z
# it_ltm_diff_sign_sq_z:reliability_binary_z
# it_pos_neg_ltm:reliability_binary_z
# it_ltm_diff_sign_z:attend_binary_z                                        .
# it_ltm_diff_sign_sq_z:attend_binary_z
# it_pos_neg_ltm:attend_binary_z
# reliability_binary_z:attend_binary_z
# v2_ltm_diff_sign_z:v2_pos_neg_ltm
# v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm
# reliability_binary_z:v2_ltm_diff_sign_z                                   **
# reliability_binary_z:v2_ltm_diff_sign_sq_z                                .
# reliability_binary_z:v2_pos_neg_ltm
# attend_binary_z:v2_ltm_diff_sign_z
# attend_binary_z:v2_ltm_diff_sign_sq_z
# attend_binary_z:v2_pos_neg_ltm
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z
# it_ltm_diff_sign_z:it_pos_neg_ltm:attend_binary_z
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:attend_binary_z
# it_ltm_diff_sign_z:reliability_binary_z:attend_binary_z                   .
# it_ltm_diff_sign_sq_z:reliability_binary_z:attend_binary_z
# it_pos_neg_ltm:reliability_binary_z:attend_binary_z
# reliability_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm                    .
# reliability_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm                 .
# attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm
# attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z
# reliability_binary_z:attend_binary_z:v2_pos_neg_ltm
# it_ltm_diff_sign_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z
# it_ltm_diff_sign_sq_z:it_pos_neg_ltm:reliability_binary_z:attend_binary_z
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_z:v2_pos_neg_ltm
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sign_sq_z:v2_pos_neg_ltm
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# mm <- model.matrix(formula(formula1), data = df)
# qr_mm <- qr(mm)
# qr_mm$rank
# ncol(mm)
# deps <- qr_mm$pivot[(qr_mm$rank + 1):ncol(mm)]
# colnames(mm)[deps]

# %%
formula1 <- glmer(recall_answ ~ (it_ltm_z + it_ltm_sq_z)  * reliability_binary_z *  
                  attend_binary_z + (v2_ltm_z + v2_ltm_sq_z) * reliability_binary_z *  
                  attend_binary_z + tested_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_ltm_z + it_ltm_sq_z) * reliability_binary_z *
#     attend_binary_z + (v2_ltm_z + v2_ltm_sq_z) * reliability_binary_z *
#     attend_binary_z + tested_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   6855.8   7007.3  -3405.9   6811.8     7208
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.4279  0.2148  0.3530  0.5497  1.8157
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5774   0.7599
# Number of obs: 7230, groups:  participant, 133
#
# Fixed effects:
#                                                   Estimate Std. Error z value
# (Intercept)                                       1.470880   0.074027  19.870
# it_ltm_z                                         -0.096754   0.055164  -1.754
# it_ltm_sq_z                                       0.085878   0.057103   1.504
# reliability_binary_z                              0.042540   0.031629   1.345
# attend_binary_z                                  -0.049707   0.037438  -1.328
# v2_ltm_z                                         -0.087252   0.124010  -0.704
# v2_ltm_sq_z                                       0.136624   0.127115   1.075
# tested_binary_z                                  -0.595292   0.039419 -15.102
# it_ltm_z:reliability_binary_z                     0.031834   0.055211   0.577
# it_ltm_sq_z:reliability_binary_z                 -0.034868   0.057139  -0.610
# it_ltm_z:attend_binary_z                         -0.058181   0.055275  -1.053
# it_ltm_sq_z:attend_binary_z                       0.054455   0.057160   0.953
# reliability_binary_z:attend_binary_z              0.009576   0.032208   0.297
# reliability_binary_z:v2_ltm_z                     0.255412   0.124275   2.055
# reliability_binary_z:v2_ltm_sq_z                 -0.319764   0.127568  -2.507
# attend_binary_z:v2_ltm_z                          0.203122   0.124378   1.633
# attend_binary_z:v2_ltm_sq_z                      -0.172808   0.127414  -1.356
# it_ltm_z:reliability_binary_z:attend_binary_z     0.015613   0.055380   0.282
# it_ltm_sq_z:reliability_binary_z:attend_binary_z -0.027617   0.057225  -0.483
# reliability_binary_z:attend_binary_z:v2_ltm_z    -0.007250   0.124270  -0.058
# reliability_binary_z:attend_binary_z:v2_ltm_sq_z  0.082572   0.127504   0.648
#                                                  Pr(>|z|)
# (Intercept)                                        <2e-16 ***
# it_ltm_z                                           0.0794 .
# it_ltm_sq_z                                        0.1326
# reliability_binary_z                               0.1786
# attend_binary_z                                    0.1843
# v2_ltm_z                                           0.4817
# v2_ltm_sq_z                                        0.2825
# tested_binary_z                                    <2e-16 ***
# it_ltm_z:reliability_binary_z                      0.5642
# it_ltm_sq_z:reliability_binary_z                   0.5417
# it_ltm_z:attend_binary_z                           0.2925
# it_ltm_sq_z:attend_binary_z                        0.3408
# reliability_binary_z:attend_binary_z               0.7662
# reliability_binary_z:v2_ltm_z                      0.0399 *
# reliability_binary_z:v2_ltm_sq_z                   0.0122 *
# attend_binary_z:v2_ltm_z                           0.1024
# attend_binary_z:v2_ltm_sq_z                        0.1750
# it_ltm_z:reliability_binary_z:attend_binary_z      0.7780
# it_ltm_sq_z:reliability_binary_z:attend_binary_z   0.6294
# reliability_binary_z:attend_binary_z:v2_ltm_z      0.9535
# reliability_binary_z:attend_binary_z:v2_ltm_sq_z   0.5172
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_ltm_diff_z + it_ltm_diff_sq_z)  * reliability_binary_z *  
                  attend_binary_z + (v2_ltm_diff_z + v2_ltm_diff_sq_z) * reliability_binary_z *  
                  attend_binary_z + tested_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_ltm_diff_z + it_ltm_diff_sq_z) * reliability_binary_z *
#     attend_binary_z + (v2_ltm_diff_z + v2_ltm_diff_sq_z) * reliability_binary_z *
#     attend_binary_z + tested_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   6855.3   7006.8  -3405.7   6811.3     7208
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.3494  0.2152  0.3542  0.5476  1.7577
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5763   0.7592
# Number of obs: 7230, groups:  participant, 133
#
# Fixed effects:
#                                                         Estimate Std. Error
# (Intercept)                                            1.4724243  0.0739914
# it_ltm_diff_z                                         -0.0122572  0.0328578
# it_ltm_diff_sq_z                                       0.0428786  0.0319479
# reliability_binary_z                                   0.0447569  0.0316635
# attend_binary_z                                       -0.0507767  0.0374315
# v2_ltm_diff_z                                          0.0161214  0.0337797
# v2_ltm_diff_sq_z                                       0.0140539  0.0320485
# tested_binary_z                                       -0.5975480  0.0394102
# it_ltm_diff_z:reliability_binary_z                    -0.0045502  0.0329612
# it_ltm_diff_sq_z:reliability_binary_z                 -0.0311047  0.0318840
# it_ltm_diff_z:attend_binary_z                          0.0004733  0.0330464
# it_ltm_diff_sq_z:attend_binary_z                       0.0630703  0.0318061
# reliability_binary_z:attend_binary_z                   0.0139665  0.0322580
# reliability_binary_z:v2_ltm_diff_z                    -0.0027739  0.0337199
# reliability_binary_z:v2_ltm_diff_sq_z                 -0.0967245  0.0322115
# attend_binary_z:v2_ltm_diff_z                          0.0220106  0.0338235
# attend_binary_z:v2_ltm_diff_sq_z                      -0.0580244  0.0320749
# it_ltm_diff_z:reliability_binary_z:attend_binary_z    -0.0201229  0.0330933
# it_ltm_diff_sq_z:reliability_binary_z:attend_binary_z  0.0455937  0.0319120
# reliability_binary_z:attend_binary_z:v2_ltm_diff_z     0.0429573  0.0338081
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sq_z  0.0321036  0.0321122
#                                                       z value Pr(>|z|)
# (Intercept)                                            19.900  < 2e-16 ***
# it_ltm_diff_z                                          -0.373  0.70912
# it_ltm_diff_sq_z                                        1.342  0.17955
# reliability_binary_z                                    1.414  0.15750
# attend_binary_z                                        -1.357  0.17493
# v2_ltm_diff_z                                           0.477  0.63318
# v2_ltm_diff_sq_z                                        0.439  0.66101
# tested_binary_z                                       -15.162  < 2e-16 ***
# it_ltm_diff_z:reliability_binary_z                     -0.138  0.89020
# it_ltm_diff_sq_z:reliability_binary_z                  -0.976  0.32928
# it_ltm_diff_z:attend_binary_z                           0.014  0.98857
# it_ltm_diff_sq_z:attend_binary_z                        1.983  0.04737 *
# reliability_binary_z:attend_binary_z                    0.433  0.66504
# reliability_binary_z:v2_ltm_diff_z                     -0.082  0.93444
# reliability_binary_z:v2_ltm_diff_sq_z                  -3.003  0.00268 **
# attend_binary_z:v2_ltm_diff_z                           0.651  0.51521
# attend_binary_z:v2_ltm_diff_sq_z                       -1.809  0.07045 .
# it_ltm_diff_z:reliability_binary_z:attend_binary_z     -0.608  0.54314
# it_ltm_diff_sq_z:reliability_binary_z:attend_binary_z   1.429  0.15308
# reliability_binary_z:attend_binary_z:v2_ltm_diff_z      1.271  0.20386
# reliability_binary_z:attend_binary_z:v2_ltm_diff_sq_z   1.000  0.31744
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
