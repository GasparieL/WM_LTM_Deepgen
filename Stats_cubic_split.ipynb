# %%
library(lme4)
library(simr)
library(dplyr)
library(lme4)
library(simr)
library(dplyr)
library(broom)
install.packages("sjPlot")
library(sjPlot)
install.packages("broom.mixed")
library(broom.mixed)
library(htmlTable)
library(dplyr)
library(stringr)
# library(gt)
library(car)
install.packages("stargazer")
library(stargazer)
# install.packages("car")
library(car)
library(lmerTest)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpeRUFBY/downloaded_packages
# Install package "strengejacke" from GitHub (`devtools::install_github("strengejacke/strengejacke")`) to load all sj-packages at once!
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpeRUFBY/downloaded_packages
# Attaching package: ‘stringr’
#
#
# The following object is masked from ‘package:simr’:
#
#     fixed
#
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpeRUFBY/downloaded_packages
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer
#
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
file_path1 <- "pilot5_cubic_n_split.csv"
file_path2 <- "pilot6_cubic_n_split.csv"
file_path3 <- "pilot_total.csv"
df5 <- read.csv(file_path1) %>%
    select(it_sim_dis_test, v2_sim_dis_test, it_sim_dis_diff_test, v2_sim_dis_diff_test, it_sim_dis_diff_test_sign, v2_sim_dis_diff_test_sign, it_sim_dis_test, v2_sim_dis_test, it_sim_dis_diff_test_sign, v2_sim_dis_diff_test_sign, it_sim_dis_test_cube_z, v2_sim_dis_test_cube_z, it_sim_dis_diff_test_cube_z, v2_sim_dis_diff_test_cube_z, it_sim_dis_test_sign_cube_z, it_sim_dis_diff_test_sign_cube_z, v2_sim_dis_test_sign_cube_z, v2_sim_dis_diff_test_sign_cube_z, it_sim_dis_diff, it_sim_dis_diff_sq, validity_reliability_z, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z, rt,tested_memorability_resmem_z, it_pos_neg_z, v2_pos_neg_z, it_sim_dis_diff_test_sign_z, it_sim_dis_diff_test_sign_sq_z,v2_sim_dis_diff_test_sign_z, v2_sim_dis_diff_test_sign_sq_z, it_sim_dis_test_sign_z, it_sim_dis_test_sign_sq_z,v2_sim_dis_test_sign_z, v2_sim_dis_test_sign_sq_z,  it_int_rel, v2_int_rel, it_int_rel_sq, v2_int_rel_sq,  it_pos_neg, v2_pos_neg)
df6 <- read.csv(file_path2) %>%
    select(it_sim_dis_test, v2_sim_dis_test, it_sim_dis_diff_test, v2_sim_dis_diff_test, it_sim_dis_diff_test_sign, v2_sim_dis_diff_test_sign, it_sim_dis_test, v2_sim_dis_test, it_sim_dis_diff_test_sign, v2_sim_dis_diff_test_sign, it_sim_dis_test_cube_z, v2_sim_dis_test_cube_z, it_sim_dis_diff_test_cube_z, v2_sim_dis_diff_test_cube_z, it_sim_dis_test_sign_cube_z, it_sim_dis_diff_test_sign_cube_z, v2_sim_dis_test_sign_cube_z, v2_sim_dis_diff_test_sign_cube_z, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z, rt,tested_memorability_resmem_z, it_pos_neg_z, v2_pos_neg_z, it_sim_dis_diff_test_sign_z, it_sim_dis_diff_test_sign_sq_z,v2_sim_dis_diff_test_sign_z, v2_sim_dis_diff_test_sign_sq_z, it_sim_dis_test_sign_z, it_sim_dis_test_sign_sq_z,v2_sim_dis_test_sign_z, v2_sim_dis_test_sign_sq_z, it_int_rel, v2_int_rel, it_int_rel_sq, v2_int_rel_sq,  it_pos_neg, v2_pos_neg)
df_total <- read.csv(file_path3) %>%
    select(it_sim_dis_test, v2_sim_dis_test, it_sim_dis_diff_test, v2_sim_dis_diff_test, it_sim_dis_diff_test_sign, v2_sim_dis_diff_test_sign, it_sim_dis_test, v2_sim_dis_test, it_sim_dis_diff_test_sign, v2_sim_dis_diff_test_sign, it_sim_dis_test_cube_z, v2_sim_dis_test_cube_z, it_sim_dis_diff_test_cube_z, v2_sim_dis_diff_test_cube_z, it_sim_dis_test_sign_cube_z, it_sim_dis_diff_test_sign_cube_z, v2_sim_dis_test_sign_cube_z, v2_sim_dis_diff_test_sign_cube_z, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z, rt,tested_memorability_resmem_z, it_pos_neg_z, v2_pos_neg_z, it_sim_dis_diff_test_sign_z, it_sim_dis_diff_test_sign_sq_z,v2_sim_dis_diff_test_sign_z, v2_sim_dis_diff_test_sign_sq_z, it_sim_dis_test_sign_z, it_sim_dis_test_sign_sq_z,v2_sim_dis_test_sign_z, v2_sim_dis_test_sign_sq_z, it_int_rel, v2_int_rel, it_int_rel_sq, v2_int_rel_sq, it_pos_neg, v2_pos_neg)

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
class(df5$rt)
typeof(df5$rt)
str(df5$rt)
summary(df5$rt)
# Out:
# [1] "numeric"
# [1] "double"
#  num [1:39933] 1.695 1.631 0.895 2.096 2.894 ...
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#  0.3143  1.2045  1.5297  1.6161  1.9623  2.9895    1205

# %%
run_models <- function(df) {
    
    # it_third_test <- poly(df$it_sim_dis_test, 3, raw = FALSE)
    # v2_third_test <- poly(df$v2_sim_dis_test, 3, raw = FALSE)

    # it_lin_test  <- it_third_test[, 1]
    # it_sq_test   <- it_third_test[, 2]
    # it_cube_test <- it_third_test[, 3]

    # v2_lin_test  <- v2_third_test[, 1]
    # v2_sq_test   <- v2_third_test[, 2]
    # v2_cube_test <- v2_third_test[, 3]

    # it_third_test_sign <- poly(df$it_sim_dis_diff_test_sign, 3, raw = FALSE)
    # v2_third_test_sign <- poly(df$v2_sim_dis_diff_test_sign, 3, raw = FALSE)

    # it_lin_test_sign  <- it_third_test_sign[, 1]
    # it_sq_test_sign   <- it_third_test_sign[, 2]
    # it_cube_test_sign <- it_third_test_sign[, 3]

    # v2_lin_test_sign  <- v2_third_test_sign[, 1]
    # v2_sq_test_sign   <- v2_third_test_sign[, 2]
    # v2_cube_test_sign <- v2_third_test_sign[, 3]

    # acc_abs <- glmer(resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z + it_sim_dis_test_cube_z) 
    #             + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z + v2_sim_dis_test_cube_z) 
    #                  + validity_binary_z * reliability_binary_z +  (1 | participant), 
    #               data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

    # acc_rel <- glmer(resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z + it_sim_dis_diff_test_cube_z) 
    #                  + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z + v2_sim_dis_diff_test_cube_z) 
    #                  + validity_binary_z * reliability_binary_z
    #                  + (1 | participant), 
    #                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
    
    # acc_rel <- glmer(resp_correct ~ (it_lin_test + it_sq_test + it_cube_test) 
    #                  + (v2_lin_test + v2_sq_test + v2_cube_test) 
    #                  + validity_binary_z * reliability_binary_z
    #                  + (1 | participant), 
    #                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

    # acc_rel_split <- glmer(resp_correct ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z + it_sim_dis_diff_test_sign_cube_z) * it_pos_neg 
    #                        + (v2_sim_dis_diff_test_sign_z + v2_sim_dis_diff_test_sign_sq_z + v2_sim_dis_diff_test_sign_cube_z) * v2_pos_neg 
    #                        + validity_binary_z * reliability_binary_z
    #                        + (1 | participant), 
    #               data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
    #                                     optCtrl = list(maxfun = 500000),
    #                                     calc.derivs = FALSE))

    # acc_rel_split <- glmer(resp_correct ~ (it_lin_test_sign + it_sq_test_sign + it_cube_test_sign) * it_pos_neg 
    #                        + (v2_lin_test_sign + v2_sq_test_sign + v2_cube_test_sign) * v2_pos_neg 
    #                        + validity_binary_z * reliability_binary_z
    #                        + (1 | participant), 
    #               data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
    #                                     optCtrl = list(maxfun = 500000),
    #                                     calc.derivs = FALSE))

    
    df_correct <- subset(df, resp_correct == 1)
    it_third_test_rt <- poly(df_correct$it_sim_dis_test, 3, raw = FALSE)
    v2_third_test_rt <- poly(df_correct$v2_sim_dis_test, 3, raw = FALSE)
    
    it_sim_dis_diff_test_rt <- poly(df_correct$it_sim_dis_diff_test, 3, raw = FALSE)
    v2_sim_dis_diff_test_rt <- poly(df_correct$v2_sim_dis_diff_test, 3, raw = FALSE)

    
    it_sim_dis_diff_test_sign_rt <- poly(df_correct$it_sim_dis_diff_test_sign, 3, raw = FALSE)
    v2_sim_dis_diff_test_sign_rt <- poly(df_correct$v2_sim_dis_diff_test_sign, 3, raw = FALSE)

    df_correct$it_sim_dis_test_z_new  <- it_third_test_rt[, 1]
    df_correct$it_sim_dis_test_sq_z_new   <- it_third_test_rt[, 2]
    df_correct$it_sim_dis_test_cube_z_new <- it_third_test_rt[, 3]

    df_correct$v2_sim_dis_test_z_new  <- v2_third_test_rt[, 1]
    df_correct$v2_sim_dis_test_sq_z_new   <- v2_third_test_rt[, 2]
    df_correct$v2_sim_dis_test_cube_z_new <- v2_third_test_rt[, 3]

    df_correct$it_sim_dis_diff_test_z_new  <- it_sim_dis_diff_test_rt[, 1]
    df_correct$it_sim_dis_diff_test_sq_z_new   <- it_sim_dis_diff_test_rt[, 2]
    df_correct$it_sim_dis_diff_test_cube_z_new <- it_sim_dis_diff_test_rt[, 3]

    df_correct$v2_sim_dis_diff_test_z_new  <- v2_sim_dis_diff_test_rt[, 1]
    df_correct$v2_sim_dis_diff_test_sq_z_new   <- v2_sim_dis_diff_test_rt[, 2]
    df_correct$v2_sim_dis_diff_test_cube_z_new <- v2_sim_dis_diff_test_rt[, 3]

    
    df_correct$it_sim_dis_diff_test_sign_z_new  <- it_sim_dis_diff_test_sign_rt[, 1]
    df_correct$it_sim_dis_diff_test_sign_sq_z_new   <- it_sim_dis_diff_test_sign_rt[, 2]
    df_correct$it_sim_dis_diff_test_sign_cube_z_new <- it_sim_dis_diff_test_sign_rt[, 3]

    df_correct$v2_sim_dis_diff_test_sign_z_new  <- v2_sim_dis_diff_test_sign_rt[, 1]
    df_correct$v2_sim_dis_diff_test_sign_sq_z_new   <- v2_sim_dis_diff_test_sign_rt[, 2]
    df_correct$v2_sim_dis_diff_test_sign_cube_z_new <- v2_sim_dis_diff_test_sign_rt[, 3]
    
    
    # df_correct$it_sim_dis_test_z_new <- scale(df_correct$it_sim_dis_test_z)
    # df_correct$it_sim_dis_test_sq_z_new <- scale(df_correct$it_sim_dis_test_sq_z)
    # df_correct$it_sim_dis_test_cube_z_new <- scale(df_correct$it_sim_dis_test_cube_z)
    # df_correct$it_sim_dis_diff_test_z_new <- scale(df_correct$it_sim_dis_diff_test_z)
    # df_correct$it_sim_dis_diff_test_sq_z_new <- scale(df_correct$it_sim_dis_diff_test_sq_z)
    # df_correct$it_sim_dis_diff_test_cube_z_new <- scale(df_correct$it_sim_dis_diff_test_cube_z)
    
    df_correct$validity_binary_z_new <- scale(df_correct$validity_binary_z)
    df_correct$reliability_binary_z_new <- scale(df_correct$reliability_binary_z)
    
    # df_correct$v2_sim_dis_test_z_new <- scale(df_correct$v2_sim_dis_test_z)
    # df_correct$v2_sim_dis_test_sq_z_new <- scale(df_correct$v2_sim_dis_test_sq_z)
    # df_correct$v2_sim_dis_test_cube_z_new <- scale(df_correct$v2_sim_dis_test_cube_z)
    # df_correct$v2_sim_dis_diff_test_z_new <- scale(df_correct$v2_sim_dis_diff_test_z)
    # df_correct$v2_sim_dis_diff_test_sq_z_new <- scale(df_correct$v2_sim_dis_diff_test_sq_z)
    # df_correct$v2_sim_dis_diff_test_cube_z_new <- scale(df_correct$v2_sim_dis_diff_test_cube_z)

    # df_correct$it_sim_dis_diff_test_sign_z_new <- scale(df_correct$it_sim_dis_diff_test_sign_z)
    # df_correct$it_sim_dis_diff_test_sign_sq_z_new <- scale(df_correct$it_sim_dis_diff_test_sign_sq_z)
    # df_correct$it_sim_dis_diff_test_sign_cube_z_new <- scale(df_correct$it_sim_dis_diff_test_sign_cube_z)
    # df_correct$v2_sim_dis_diff_test_sign_z_new <- scale(df_correct$v2_sim_dis_diff_test_sign_z)
    # df_correct$v2_sim_dis_diff_test_sign_sq_z_new <- scale(df_correct$v2_sim_dis_diff_test_sign_sq_z)
    # df_correct$v2_sim_dis_diff_test_sign_cube_z_new <- scale(df_correct$v2_sim_dis_diff_test_sign_cube_z)
    
    df_correct$log_rt <- log(df_correct$rt)

    rt_abs <- lmer(log_rt ~ (it_sim_dis_test_z_new + it_sim_dis_test_sq_z_new + it_sim_dis_test_cube_z_new) 
                   + (v2_sim_dis_test_z_new + v2_sim_dis_test_sq_z_new + v2_sim_dis_test_cube_z_new) 
                   + validity_binary_z_new * reliability_binary_z_new
                   +  (1 | participant), 
                    data = df_correct, control = lmerControl(optimizer = "bobyqa"))
    rt_rel <- lmer(log_rt ~ (it_sim_dis_diff_test_z_new + it_sim_dis_diff_test_sq_z_new + it_sim_dis_diff_test_cube_z_new) 
                   + (v2_sim_dis_diff_test_z_new + v2_sim_dis_diff_test_sq_z_new + v2_sim_dis_diff_test_cube_z_new) 
                   + validity_binary_z_new * reliability_binary_z_new
                   + (1 | participant), 
                      data = df_correct, control = lmerControl(optimizer = "bobyqa"))
    rt_rel_split <- lmer(log_rt ~ (it_sim_dis_diff_test_sign_z_new + it_sim_dis_diff_test_sign_sq_z_new + it_sim_dis_diff_test_sign_cube_z_new) * it_pos_neg 
                         + (v2_sim_dis_diff_test_sign_z_new + v2_sim_dis_diff_test_sign_sq_z_new + v2_sim_dis_diff_test_sign_cube_z_new) * v2_pos_neg  
                         + validity_binary_z_new * reliability_binary_z_new
                         + (1 | participant), 
                  data = df_correct, control =lmerControl(optimizer = "bobyqa"))



return(list(
    # acc_abs = acc_abs,
    # acc_rel = acc_rel,
    # acc_rel_split = acc_rel_split, 
    rt_abs       = rt_abs,
    rt_rel       = rt_rel,
    rt_rel_split = rt_rel_split
  ))
}

# %%
results_old_stims <- run_models(df6)
results_new_stims <- run_models(df5)
results_total <- run_models(df_total)

# %%
extract_significance <- function(model_summary) {
  # For glmer models
  if ("coefficients" %in% names(model_summary)) {
    # Check more carefully for z value vs t value columns
    coef_table <- model_summary$coefficients
    var_names <- rownames(coef_table)
    
    # Check which p-value column exists
    if ("Pr(>|z|)" %in% colnames(coef_table)) {
      p_values <- coef_table[, "Pr(>|z|)"]
    } else if ("Pr(>|t|)" %in% colnames(coef_table)) {
      p_values <- coef_table[, "Pr(>|t|)"]
    } else {
      # If there's a z or t value, calculate p-values manually
      if ("z value" %in% colnames(coef_table)) {
        z_values <- coef_table[, "z value"]
        p_values <- 2 * pnorm(abs(z_values), lower.tail = FALSE)
      } else if ("t value" %in% colnames(coef_table)) {
        t_values <- coef_table[, "t value"]
        # Using a large df for approximation
        p_values <- 2 * pt(abs(t_values), df = 100, lower.tail = FALSE)
      } else {
        stop("Cannot find p-values or z/t values in coefficients table")
      }
    }
  } else {
    # More detailed debug info
    cat("Available names in model summary:\n")
    print(names(model_summary))
    
    # Try to access fixed effects via other means
    if ("fixed.effects" %in% names(model_summary)) {
      var_names <- names(model_summary$fixed.effects)
      # Manually calculate p-values using fixed effects and std errors
      # This is just a placeholder - would need to be adapted to actual structure
      stop("Found fixed.effects but need appropriate calculation of p-values")
    } else {
      stop("Could not extract coefficients from model summary")
    }
  }
  
  # Calculate significance stars
  significance <- sapply(p_values, function(p) {
    if (is.na(p)) return("")
    if (p < 0.001) return("***")
    if (p < 0.01) return("**")
    if (p < 0.05) return("*")
    if (p < 0.1) return(".")
    return("")
  })
  
  return(data.frame(
    variable = var_names,
    p_value = p_values,
    significance = significance,
    stringsAsFactors = FALSE
  ))
}

# %%
compare_models <- function(model_list, model_names, 
                          include_p_values = FALSE,
                          only_significant = TRUE,
                          significance_level = 0.1) {
  
  sig_list <- lapply(model_list, extract_significance)
  names(sig_list) <- model_names
  
  all_vars <- unique(unlist(lapply(sig_list, function(x) x$variable)))
  
  result_df <- data.frame(Variable = all_vars, stringsAsFactors = FALSE)
  
  # First, determine which rows have significance in any model
  has_significance_by_var <- sapply(all_vars, function(var) {
    any_significant <- FALSE
    for(model_name in model_names) {
      model_sig <- sig_list[[model_name]]
      idx <- which(model_sig$variable == var)
      if(length(idx) > 0) {
        stars <- model_sig$significance[idx]
        if(stars != "") {
          any_significant <- TRUE
          break
        }
      }
    }
    return(any_significant)
  })
  
  # Now populate the data frame with all p-values for rows with any significance
  for(model_name in model_names) {
    model_sig <- sig_list[[model_name]]
    result_df[[model_name]] <- sapply(all_vars, function(var) {
      idx <- which(model_sig$variable == var)
      if(length(idx) == 0) return("")
      
      p_val <- model_sig$p_value[idx]
      stars <- model_sig$significance[idx]
      
      # Always show p-value if this variable has significance in any model
      if(has_significance_by_var[var] || !only_significant) {
        return(paste0(stars, " (p=", sprintf("%.4f", p_val), ")"))
      } else if(stars != "") {
        # Show significance stars with p-value for significant results
        return(paste0(stars, " (p=", sprintf("%.4f", p_val), ")"))
      } else {
        # For non-significant results in rows without any significance
        return("")
      }
    })
  }
  
  # Filter rows if only_significant is TRUE
  if(only_significant) {
    result_df <- result_df[has_significance_by_var, ]
  }
  
  # Adjust HTML table styling to make first column wider
  html_table <- htmlTable(
    result_df,
    caption = "Significance Comparison Across Models",
    rnames = FALSE,
    css.cell = "padding: 8px;",
    css.table = "border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;",
    css.header = "background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd;",
    css.rgroup = "border-bottom: 1px solid #dddddd;",
    css.tspanner = "font-weight: bold; text-align: center; border-bottom: 2px solid #dddddd;",
    css.class = "table-hover"
  )
  
  # Add additional CSS to make the first column wider
  html_table <- gsub("<table", "<style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table", html_table)
  
  return(html_table)
}

# %%
# Create tables for the three accuracy models
# acc_abs_old <- summary(results_old_stims$acc_abs)
# acc_abs_new <- summary(results_new_stims$acc_abs)
# acc_abs_total <- summary(results_total$acc_abs)

# comparison_table_acc_abs <- compare_models(
#   model_list = list(acc_abs_old, acc_abs_new, acc_abs_total),
#   model_names = c("Old Stimuli", "New Stimuli", "Total"),
#   include_p_values = TRUE,
#   only_significant = TRUE
# )
# writeLines(comparison_table_acc_abs, "comparison_table_wm_acc_abs.html")

# acc_rel_old <- summary(results_old_stims$acc_rel)
# acc_rel_new <- summary(results_new_stims$acc_rel)
# acc_rel_total <- summary(results_total$acc_rel)

# comparison_table_acc_rel <- compare_models(
#   model_list = list(acc_rel_old, acc_rel_new, acc_rel_total),
#   model_names = c("Old Stimuli", "New Stimuli", "Total"),
#   include_p_values = TRUE,
#   only_significant = TRUE
# )
# writeLines(comparison_table_acc_rel, "comparison_table_wm_acc_rel.html")

# acc_rel_split_old <- summary(results_old_stims$acc_rel_split)
# acc_rel_split_new <- summary(results_new_stims$acc_rel_split)
# acc_rel_split_total <- summary(results_total$acc_rel_split)

# comparison_table_acc_rel_split <- compare_models(
#   model_list = list(acc_rel_split_old, acc_rel_split_new, acc_rel_split_total),
#   model_names = c("Old Stimuli", "New Stimuli", "Total"),
#   include_p_values = TRUE,
#   only_significant = TRUE
# )
# writeLines(comparison_table_acc_rel_split, "comparison_table_wm_acc_rel_split.html")

# Create tables for the three RT models
rt_abs_old <- summary(results_old_stims$rt_abs)
rt_abs_new <- summary(results_new_stims$rt_abs)
rt_abs_total <- summary(results_total$rt_abs)

comparison_table_rt_abs <- compare_models(
  model_list = list(rt_abs_old, rt_abs_new, rt_abs_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_rt_abs, "comparison_table_wm_rt_abs.html")

rt_rel_old <- summary(results_old_stims$rt_rel)
rt_rel_new <- summary(results_new_stims$rt_rel)
rt_rel_total <- summary(results_total$rt_rel)

comparison_table_rt_rel <- compare_models(
  model_list = list(rt_rel_old, rt_rel_new, rt_rel_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_rt_rel, "comparison_table_wm_rt_rel.html")

rt_rel_split_old <- summary(results_old_stims$rt_rel_split)
rt_rel_split_new <- summary(results_new_stims$rt_rel_split)
rt_rel_split_total <- summary(results_total$rt_rel_split)

comparison_table_rt_rel_split <- compare_models(
  model_list = list(rt_rel_split_old, rt_rel_split_new, rt_rel_split_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_rt_rel_split, "comparison_table_wm_rt_rel_split.html")

# Display all tables
# IRdisplay::display_html(comparison_table_acc_abs)
# IRdisplay::display_html(comparison_table_acc_rel)
# IRdisplay::display_html(comparison_table_acc_rel_split)
IRdisplay::display_html(comparison_table_rt_abs)
IRdisplay::display_html(comparison_table_rt_rel)
IRdisplay::display_html(comparison_table_rt_rel_split)
# Out:
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0003)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_sq_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0026)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0002)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_sq_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.8927)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0575)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4799)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0630)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0182)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>validity_binary_z_new:reliability_binary_z_new</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# </tbody>
# </table>
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>x</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0001)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>y</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0065)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>z</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0072)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0253)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0001)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_z_new</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0023)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sq_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0006)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0739)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0004)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3903)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0001)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1128)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>validity_binary_z_new:reliability_binary_z_new</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# </tbody>
# </table>
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0160)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2762)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0383)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0221)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0042)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_z_new</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0045)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1715)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0043)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_sq_z_new</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0027)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1147)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0020)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2397)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0783)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.6797)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0003)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_z_new:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3161)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0030)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0326)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_sq_z_new:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1610)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0002)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_cube_z_new:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3029)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1645)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0039)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.6753)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1207)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0730)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_sq_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4036)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0425)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1300)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_cube_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0005)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7214)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0081)</td>
# </tr>
# <tr>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>validity_binary_z_new:reliability_binary_z_new</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# </tbody>
# </table>

# %%
# acc_rel_split_old <- summary(results_old_stims$acc_rel_split)
# acc_rel_split_new <- summary(results_new_stims$acc_rel_split)
# acc_rel_split_total <- summary(results_total$acc_rel_split)

# %%
# acc_rel_split_total

# %%
####p > 0.1 or < 0.01; z value with 1 sig point ;beta = 
##learn to get confidence interval of 95%

# %%
# acc_rel_split_total <- summary(results_total$acc_rel_split)

# coef_table <- coef(acc_rel_split_total)
# print(coef_table)

# ci_wald <- confint(results_total$acc_rel_split, method = "Wald", level = 0.95)

# %%
# acc_rel_split_total <- summary(results_total$acc_rel_split)

# coef_table <- coef(acc_rel_split_total)
# print(coef_table)

# ci_wald <- confint(results_total$acc_rel_split, method = "Wald", level = 0.95)

# results_combined <- cbind(
#   Beta = coef_table[, "Estimate"],
#   SE = coef_table[, "Std. Error"],
#   z_value = coef_table[, "z value"],
#   p_value = coef_table[, "Pr(>|z|)"],
#   CI_lower = ci_wald[rownames(coef_table), 1],
#   CI_upper = ci_wald[rownames(coef_table), 2]
# )

# print(results_combined)

# results_df <- as.data.frame(results_combined)
# results_df$predictor <- rownames(results_df)

# results_df <- results_df[, c("predictor", "Beta", "SE", "z_value", "p_value", "CI_lower", "CI_upper")]

# print(results_df)

# write.csv(results_df, "acc_rel_split_total_results.csv", row.names = FALSE)

# %%
extract_model_results <- function(model, method = "Wald") {
  coef_table <- coef(summary(model))
  ci <- confint(model, method = method, level = 0.95, quiet = TRUE)
  
  results <- cbind(
    Beta = coef_table[, "Estimate"],
    SE = coef_table[, "Std. Error"],
    z_value = coef_table[, "z value"],
    p_value = coef_table[, "Pr(>|z|)"],
    CI_lower = ci[rownames(coef_table), 1],
    CI_upper = ci[rownames(coef_table), 2]
  )
  
  return(as.data.frame(results))
}

acc_rel_split_total_results <- extract_model_results(results_total$acc_rel_split)
print(acc_rel_split_total_results)
# Out:
# Error in object$coefficients: $ operator is invalid for atomic vectors
# Traceback:
#
# 1. extract_model_results(results_total$acc_rel_split)
# 2. coef(summary(model))   # at line 2 of file <text>
# 3. coef.default(summary(model))

# %%
library(knitr)
library(kableExtra)
library(IRdisplay)

# Function to create combined results table with colors
create_combined_results_table <- function(model_old, model_new, model_total, 
                                          model_name = "Combined Model Results",
                                          save_file = NULL) {
  
  # Function to clean predictor names
  clean_names <- function(names) {
    names <- gsub("validity_binary_z", "validity", names)
    names <- gsub("reliability_binary_z", "reliability", names)
    # Order matters! Do cube and square before the base term
    names <- gsub("it_cube_test_sign", "IT_cubic", names)
    names <- gsub("it_sq_test_sign", "IT_quadratic", names)
    names <- gsub("it_lin_test_sign", "IT_linear", names)
    names <- gsub("v2_cube_test_sign", "V2_cubic", names)
    names <- gsub("v2_sq_test_sign", "V2_quadratic", names)
    names <- gsub("v2_lin_test_sign", "V2_linear", names)
    names <- gsub("it_pos_neg", "IT_sign", names)
    names <- gsub("v2_pos_neg", "V2_sign", names)
    return(names)
  }
  
  # Function to format p-value (vectorized, no leading zero)
  format_p <- function(p_vec) {
    sapply(p_vec, function(p) {
      if (p < 0.001) {
        return("&lt;.001")
      } else {
        formatted <- sprintf("%.3f", p)
        # Remove leading zero
        formatted <- sub("^0\\.", ".", formatted)
        return(formatted)
      }
    })
  }
  
  # Function to format to n significant figures
  format_sig_figs <- function(x, n = 2) {
    formatted <- signif(x, n)
    # Convert to character, preserving the significant figures
    as.character(formatted)
  }
  
  # Function to combine values with color formatting
  combine_colored <- function(old_val, new_val, total_val) {
    paste0(
      '<span style="color: purple;">', old_val, '</span>',
      ' / ',
      '<span style="color: blue;">', new_val, '</span>',
      ' / ',
      '<span style="color: black; font-weight: bold;">', total_val, '</span>'
    )
  }
  
  # Get coefficients for all three models
  coef_old <- coef(summary(model_old))
  coef_new <- coef(summary(model_new))
  coef_total <- coef(summary(model_total))
  
  # Get confidence intervals
  ci_old <- confint(model_old, method = "Wald", quiet = TRUE)
  ci_new <- confint(model_new, method = "Wald", quiet = TRUE)
  ci_total <- confint(model_total, method = "Wald", quiet = TRUE)
  
  # Get predictor names
  predictors <- clean_names(rownames(coef_total))
  
  # Check which predictors are significant in all three models (p < .05)
  sig_in_all <- (coef_old[, "Pr(>|z|)"] < 0.05) & 
                (coef_new[, "Pr(>|z|)"] < 0.05) & 
                (coef_total[, "Pr(>|z|)"] < 0.05)
  
  # Bold predictor names that are significant in all three
  predictors_formatted <- ifelse(sig_in_all, 
                                 paste0("<strong>", predictors, "</strong>"), 
                                 predictors)
  
  # Combine values with color formatting
  results <- data.frame(
    Predictor = predictors_formatted,
    Beta = combine_colored(
      format_sig_figs(coef_old[, "Estimate"], 2),
      format_sig_figs(coef_new[, "Estimate"], 2),
      format_sig_figs(coef_total[, "Estimate"], 2)
    ),
    SE = combine_colored(
      format_sig_figs(coef_old[, "Std. Error"], 2),
      format_sig_figs(coef_new[, "Std. Error"], 2),
      format_sig_figs(coef_total[, "Std. Error"], 2)
    ),
    z = combine_colored(
      format_sig_figs(coef_old[, "z value"], 2),
      format_sig_figs(coef_new[, "z value"], 2),
      format_sig_figs(coef_total[, "z value"], 2)
    ),
    p = combine_colored(
      format_p(coef_old[, "Pr(>|z|)"]),
      format_p(coef_new[, "Pr(>|z|)"]),
      format_p(coef_total[, "Pr(>|z|)"])
    ),
    CI_Lower = combine_colored(
      format_sig_figs(ci_old[rownames(coef_old), 1], 2),
      format_sig_figs(ci_new[rownames(coef_new), 1], 2),
      format_sig_figs(ci_total[rownames(coef_total), 1], 2)
    ),
    CI_Upper = combine_colored(
      format_sig_figs(ci_old[rownames(coef_old), 2], 2),
      format_sig_figs(ci_new[rownames(coef_new), 2], 2),
      format_sig_figs(ci_total[rownames(coef_total), 2], 2)
    ),
    stringsAsFactors = FALSE
  )
  
  # Create formatted table with borders
  table <- kable(results, row.names = FALSE, align = c("l", "r", "r", "r", "r", "r", "r"),
                 escape = FALSE, format = "html") %>%
    kable_styling(bootstrap_options = c("striped", "hover", "condensed", "bordered"),
                  full_width = FALSE) %>%
    add_header_above(c(" " = 1, 
                       "Study 1 / Study 2 / Combined" = 6))
  
  # Create header
  header_html <- paste0(
    '<h3>', model_name, '</h3>',
    '<p style="font-size: 12px;">',
    '<span style="color: purple;">■</span> Study 1 &nbsp;&nbsp; ',
    '<span style="color: blue;">■</span> Study 2 &nbsp;&nbsp; ',
    '<span style="color: black; font-weight: bold;">■</span> Combined',
    '<br><strong>Bold predictors</strong> are significant (p &lt; .05) in all three studies.',
    '</p>'
  )
  
  # Add custom CSS for clear borders
  css_style <- '
  <style>
    table {
      border-collapse: collapse !important;
      border: 2px solid #333 !important;
    }
    th, td {
      border: 1px solid #666 !important;
      padding: 8px !important;
    }
    th {
      background-color: #f0f0f0 !important;
      font-weight: bold !important;
    }
  </style>
  '
  
  # Combine HTML
  full_html <- paste0(css_style, header_html, as.character(table))
  
  # Display in notebook
  display_html(full_html)
  
  # Save to file if requested
  if (!is.null(save_file)) {
    complete_html <- paste0(
      '<!DOCTYPE html>
      <html>
      <head>
        <meta charset="utf-8">
        <title>', model_name, '</title>',
      css_style,
      '</head>
      <body>',
      full_html,
      '</body>
      </html>'
    )
    writeLines(complete_html, save_file)
    cat("\nTable saved to:", save_file, "\n")
  }
  
  return(results)
}

# Use it with your three models and save to HTML
acc_rel_split_combined <- create_combined_results_table(
  results_old_stims$acc_rel_split,
  results_new_stims$acc_rel_split,
  results_total$acc_rel_split,
  "Model Results: acc_rel_split",
  save_file = "acc_rel_split_results.html"
)

# %%
library(knitr)
library(kableExtra)
library(IRdisplay)
library(lmerTest)  # This package adds p-values to lmer models

# Function to create combined results table for LMER models
create_combined_results_table_rt <- function(model_old, model_new, model_total, 
                                             model_name = "Combined Model Results",
                                             save_file = NULL) {
  
  # Function to clean predictor names
  clean_names <- function(names) {
    names <- gsub("validity_binary_z_new", "validity", names)
    names <- gsub("reliability_binary_z_new", "reliability", names)
    # Order matters! Do cube and square before the base term
    names <- gsub("it_sim_dis_diff_test_sign_cube_z_new", "IT_cubic", names)
    names <- gsub("it_sim_dis_diff_test_sign_sq_z_new", "IT_quadratic", names)
    names <- gsub("it_sim_dis_diff_test_sign_z_new", "IT_linear", names)
    names <- gsub("v2_sim_dis_diff_test_sign_cube_z_new", "V2_cubic", names)
    names <- gsub("v2_sim_dis_diff_test_sign_sq_z_new", "V2_quadratic", names)
    names <- gsub("v2_sim_dis_diff_test_sign_z_new", "V2_linear", names)
    names <- gsub("it_pos_neg", "IT_sign", names)
    names <- gsub("v2_pos_neg", "V2_sign", names)
    return(names)
  }
  
  # Function to format p-value (vectorized, no leading zero)
  format_p <- function(p_vec) {
    sapply(p_vec, function(p) {
      if (p < 0.001) {
        return("&lt;.001")
      } else {
        formatted <- sprintf("%.3f", p)
        # Remove leading zero
        formatted <- sub("^0\\.", ".", formatted)
        return(formatted)
      }
    })
  }
  
  # Function to format to n significant figures
  format_sig_figs <- function(x, n = 2) {
    formatted <- signif(x, n)
    # Convert to character, preserving the significant figures
    as.character(formatted)
  }
  
  # Function to combine values with color formatting
  combine_colored <- function(old_val, new_val, total_val) {
    paste0(
      '<span style="color: purple;">', old_val, '</span>',
      ' / ',
      '<span style="color: blue;">', new_val, '</span>',
      ' / ',
      '<span style="color: black; font-weight: bold;">', total_val, '</span>'
    )
  }
  
  # Get coefficients for all three models (lmerTest gives us t-values and p-values)
  coef_old <- coef(summary(model_old))
  coef_new <- coef(summary(model_new))
  coef_total <- coef(summary(model_total))
  
  # Get confidence intervals
  ci_old <- confint(model_old, method = "Wald", quiet = TRUE)
  ci_new <- confint(model_new, method = "Wald", quiet = TRUE)
  ci_total <- confint(model_total, method = "Wald", quiet = TRUE)
  
  # Get predictor names (from fixed effects only)
  predictors <- clean_names(rownames(coef_total))
  
  # Check which predictors are significant in all three models (p < .05)
  sig_in_all <- (coef_old[, "Pr(>|t|)"] < 0.05) & 
                (coef_new[, "Pr(>|t|)"] < 0.05) & 
                (coef_total[, "Pr(>|t|)"] < 0.05)
  
  # Bold predictor names that are significant in all three
  predictors_formatted <- ifelse(sig_in_all, 
                                 paste0("<strong>", predictors, "</strong>"), 
                                 predictors)
  
  # Combine values with color formatting
  results <- data.frame(
    Predictor = predictors_formatted,
    Beta = combine_colored(
      format_sig_figs(coef_old[, "Estimate"], 2),
      format_sig_figs(coef_new[, "Estimate"], 2),
      format_sig_figs(coef_total[, "Estimate"], 2)
    ),
    SE = combine_colored(
      format_sig_figs(coef_old[, "Std. Error"], 2),
      format_sig_figs(coef_new[, "Std. Error"], 2),
      format_sig_figs(coef_total[, "Std. Error"], 2)
    ),
    t = combine_colored(
      format_sig_figs(coef_old[, "t value"], 2),
      format_sig_figs(coef_new[, "t value"], 2),
      format_sig_figs(coef_total[, "t value"], 2)
    ),
    p = combine_colored(
      format_p(coef_old[, "Pr(>|t|)"]),
      format_p(coef_new[, "Pr(>|t|)"]),
      format_p(coef_total[, "Pr(>|t|)"])
    ),
    CI_Lower = combine_colored(
      format_sig_figs(ci_old[rownames(coef_old), 1], 2),
      format_sig_figs(ci_new[rownames(coef_new), 1], 2),
      format_sig_figs(ci_total[rownames(coef_total), 1], 2)
    ),
    CI_Upper = combine_colored(
      format_sig_figs(ci_old[rownames(coef_old), 2], 2),
      format_sig_figs(ci_new[rownames(coef_new), 2], 2),
      format_sig_figs(ci_total[rownames(coef_total), 2], 2)
    ),
    stringsAsFactors = FALSE
  )
  
  # Create formatted table with borders
  table <- kable(results, row.names = FALSE, align = c("l", "r", "r", "r", "r", "r", "r"),
                 escape = FALSE, format = "html") %>%
    kable_styling(bootstrap_options = c("striped", "hover", "condensed", "bordered"),
                  full_width = FALSE) %>%
    add_header_above(c(" " = 1, 
                       "Study 1 / Study 2 / Combined" = 6))
  
  # Create header
  header_html <- paste0(
    '<h3>', model_name, '</h3>',
    '<p style="font-size: 12px;">',
    '<span style="color: purple;">■</span> Study 1 &nbsp;&nbsp; ',
    '<span style="color: blue;">■</span> Study 2 &nbsp;&nbsp; ',
    '<span style="color: black; font-weight: bold;">■</span> Combined',
    '<br><strong>Bold predictors</strong> are significant (p &lt; .05) in all three studies.',
    '</p>'
  )
  
  # Add custom CSS for clear borders
  css_style <- '
  <style>
    table {
      border-collapse: collapse !important;
      border: 2px solid #333 !important;
    }
    th, td {
      border: 1px solid #666 !important;
      padding: 8px !important;
    }
    th {
      background-color: #f0f0f0 !important;
      font-weight: bold !important;
    }
  </style>
  '
  
  # Combine HTML
  full_html <- paste0(css_style, header_html, as.character(table))
  
  # Display in notebook
  display_html(full_html)
  
  # Save to file if requested
  if (!is.null(save_file)) {
    complete_html <- paste0(
      '<!DOCTYPE html>
      <html>
      <head>
        <meta charset="utf-8">
        <title>', model_name, '</title>',
      css_style,
      '</head>
      <body>',
      full_html,
      '</body>
      </html>'
    )
    writeLines(complete_html, save_file)
    cat("\nTable saved to:", save_file, "\n")
  }
  
  return(results)
}

# Use it with your rt_rel_split models
rt_rel_split_combined <- create_combined_results_table_rt(
  results_old_stims$rt_rel_split,
  results_new_stims$rt_rel_split,
  results_total$rt_rel_split,
  "Model Results: rt_rel_split",
  save_file = "rt_rel_split_results.html"
)

# %%
R.version.string

# %%
# bolding the predictor names that are significant in all three (study 1, study 2, combined)?
