# %%
library(lme4)
library(simr)
library(dplyr)

library(reticulate)

# %%
# install.packages("reticulate")
# Out:
# also installing the dependencies ‘RcppTOML’, ‘here’
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmptJGP1l/downloaded_packages

# %%
# install.packages("car")
library(car)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode

# %%
pd <- import("pandas")  # Import Python pandas

# %%
# df <- pd$read_pickle("pilot6_TEST.pkl")
# Out:
# Error in eval(expr, envir, enclos): Not compatible with STRSXP: [type=environment].
# Traceback:
#
# 1. pd$read_pickle("pilot6_TEST.pkl")
# 2. py_to_r(result)
# 3. py_to_r.pandas.core.frame.DataFrame(result)
# 4. py_convert_pandas_df(x)

# %%
file_path <- "pilot6_TEST.csv"

df <- read.csv(file_path) %>%
    select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z )

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
# head(df$reliability_binary)
#

# %%
# names(df)

# %%
# mean(df$it_sim_dis_diff)

# %%
# model <- glm(
#   resp_correct ~ it_sim_dis_diff_test_z * reliability_binary * validity_binary + 
#              v2_sim_dis_diff_test_z * reliability_binary * validity_binary,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # head(df$v2_sim_dis_test_z)



# formula1 <- glmer(resp_correct ~  v2_sim_dis_test_z * reliability_binary * validity_binary +  
#                    it_sim_dis_test_z * reliability_binary * validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# model <- glm(
#   resp_correct ~ reliability_binary * validity_binary + (1 | participant),
#              y,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # IT*V2*reliability*validity + itsq+v2sq



# formula1 <- glmer(resp_correct ~ it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z * reliability_binary * validity_binary +  
#                    v2_sim_dis_diff_test_sq_z + it_sim_dis_diff_test_sq_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  45009.3  45190.9 -22483.7  44967.3    41979
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9937 -0.8386  0.4565  0.5919  1.5750
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4364   0.6606
# Number of obs: 42000, groups:  participant, 137
#
# Fixed effects:
#                                                               Estimate
# (Intercept)                                                  1.1342479
# it_sim_dis_test_z                                            0.0415843
# it_sim_dis_test_sq_z                                        -0.0456980
# reliability_binary_z                                         0.0275394
# validity_binary_z                                            0.2382289
# v2_sim_dis_test_z                                           -0.0150547
# v2_sim_dis_test_sq_z                                        -0.0422229
# it_sim_dis_test_z:reliability_binary_z                      -0.0146617
# it_sim_dis_test_sq_z:reliability_binary_z                    0.0058509
# it_sim_dis_test_z:validity_binary_z                          0.0216210
# it_sim_dis_test_sq_z:validity_binary_z                      -0.0174402
# reliability_binary_z:validity_binary_z                       0.0832680
# reliability_binary_z:v2_sim_dis_test_z                      -0.0007804
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.0102008
# validity_binary_z:v2_sim_dis_test_z                          0.0039851
# validity_binary_z:v2_sim_dis_test_sq_z                      -0.0084064
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    -0.0123173
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.0020533
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z    -0.0099049
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.0086292
#                                                             Std. Error z value
# (Intercept)                                                  0.0578102  19.620
# it_sim_dis_test_z                                            0.0121453   3.424
# it_sim_dis_test_sq_z                                         0.0118937  -3.842
# reliability_binary_z                                         0.0118386   2.326
# validity_binary_z                                            0.0115685  20.593
# v2_sim_dis_test_z                                            0.0129431  -1.163
# v2_sim_dis_test_sq_z                                         0.0127767  -3.305
# it_sim_dis_test_z:reliability_binary_z                       0.0121482  -1.207
# it_sim_dis_test_sq_z:reliability_binary_z                    0.0119083   0.491
# it_sim_dis_test_z:validity_binary_z                          0.0119108   1.815
# it_sim_dis_test_sq_z:validity_binary_z                       0.0116603  -1.496
# reliability_binary_z:validity_binary_z                       0.0115504   7.209
# reliability_binary_z:v2_sim_dis_test_z                       0.0129495  -0.060
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.0127867   0.798
# validity_binary_z:v2_sim_dis_test_z                          0.0128794   0.309
# validity_binary_z:v2_sim_dis_test_sq_z                       0.0122180  -0.688
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.0119088  -1.034
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.0116645   0.176
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.0128824  -0.769
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.0122134   0.707
#                                                             Pr(>|z|)
# (Intercept)                                                  < 2e-16 ***
# it_sim_dis_test_z                                           0.000617 ***
# it_sim_dis_test_sq_z                                        0.000122 ***
# reliability_binary_z                                        0.020006 *
# validity_binary_z                                            < 2e-16 ***
# v2_sim_dis_test_z                                           0.244771
# v2_sim_dis_test_sq_z                                        0.000951 ***
# it_sim_dis_test_z:reliability_binary_z                      0.227468
# it_sim_dis_test_sq_z:reliability_binary_z                   0.623190
# it_sim_dis_test_z:validity_binary_z                         0.069486 .
# it_sim_dis_test_sq_z:validity_binary_z                      0.134734
# reliability_binary_z:validity_binary_z                      5.63e-13 ***
# reliability_binary_z:v2_sim_dis_test_z                      0.951945
# reliability_binary_z:v2_sim_dis_test_sq_z                   0.425008
# validity_binary_z:v2_sim_dis_test_z                         0.757007
# validity_binary_z:v2_sim_dis_test_sq_z                      0.491430
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    0.300994
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z 0.860273
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z    0.441971
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z 0.479856
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_z +
#     v2_sim_dis_diff_test_sq_z) * reliability_binary_z * validity_binary_z +
#     it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  45005.7  45195.9 -22480.8  44961.7    41978
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0125 -0.8386  0.4562  0.5917  1.6071
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4357   0.6601
# Number of obs: 42000, groups:  participant, 137
#
# Fixed effects:
#                                                                   Estimate
# (Intercept)                                                       1.134369
# it_sim_dis_diff_test_z                                            0.041031
# it_sim_dis_diff_test_sq_z                                        -0.050949
# reliability_binary_z                                              0.027618
# validity_binary_z                                                 0.238362
# v2_sim_dis_diff_test_z                                           -0.019252
# v2_sim_dis_diff_test_sq_z                                        -0.046244
# it_sim_dis_diff_test_z:reliability_binary_z                      -0.011778
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.001548
# it_sim_dis_diff_test_z:validity_binary_z                          0.014650
# it_sim_dis_diff_test_sq_z:validity_binary_z                      -0.009639
# reliability_binary_z:validity_binary_z                            0.082030
# reliability_binary_z:v2_sim_dis_diff_test_z                      -0.002388
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    0.011103
# validity_binary_z:v2_sim_dis_diff_test_z                          0.002835
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       0.006361
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     0.002679
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    -0.008309
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z -0.004168
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.005662
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z -0.003440
#                                                                  Std. Error
# (Intercept)                                                        0.057795
# it_sim_dis_diff_test_z                                             0.011872
# it_sim_dis_diff_test_sq_z                                          0.012268
# reliability_binary_z                                               0.011842
# validity_binary_z                                                  0.011571
# v2_sim_dis_diff_test_z                                             0.011893
# v2_sim_dis_diff_test_sq_z                                          0.012268
# it_sim_dis_diff_test_z:reliability_binary_z                        0.011877
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.011752
# it_sim_dis_diff_test_z:validity_binary_z                           0.011666
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.011407
# reliability_binary_z:validity_binary_z                             0.011552
# reliability_binary_z:v2_sim_dis_diff_test_z                        0.011892
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.011770
# validity_binary_z:v2_sim_dis_diff_test_z                           0.011604
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.011335
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      0.012601
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z      0.011662
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.011411
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      0.011610
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.011338
#                                                                  z value
# (Intercept)                                                       19.627
# it_sim_dis_diff_test_z                                             3.456
# it_sim_dis_diff_test_sq_z                                         -4.153
# reliability_binary_z                                               2.332
# validity_binary_z                                                 20.601
# v2_sim_dis_diff_test_z                                            -1.619
# v2_sim_dis_diff_test_sq_z                                         -3.769
# it_sim_dis_diff_test_z:reliability_binary_z                       -0.992
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.132
# it_sim_dis_diff_test_z:validity_binary_z                           1.256
# it_sim_dis_diff_test_sq_z:validity_binary_z                       -0.845
# reliability_binary_z:validity_binary_z                             7.101
# reliability_binary_z:v2_sim_dis_diff_test_z                       -0.201
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.943
# validity_binary_z:v2_sim_dis_diff_test_z                           0.244
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.561
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      0.213
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     -0.713
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  -0.365
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      0.488
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  -0.303
#                                                                  Pr(>|z|)
# (Intercept)                                                       < 2e-16 ***
# it_sim_dis_diff_test_z                                           0.000548 ***
# it_sim_dis_diff_test_sq_z                                        3.28e-05 ***
# reliability_binary_z                                             0.019695 *
# validity_binary_z                                                 < 2e-16 ***
# v2_sim_dis_diff_test_z                                           0.105487
# v2_sim_dis_diff_test_sq_z                                        0.000164 ***
# it_sim_dis_diff_test_z:reliability_binary_z                      0.321376
# it_sim_dis_diff_test_sq_z:reliability_binary_z                   0.895233
# it_sim_dis_diff_test_z:validity_binary_z                         0.209221
# it_sim_dis_diff_test_sq_z:validity_binary_z                      0.398108
# reliability_binary_z:validity_binary_z                           1.24e-12 ***
# reliability_binary_z:v2_sim_dis_diff_test_z                      0.840823
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   0.345550
# validity_binary_z:v2_sim_dis_diff_test_z                         0.807007
# validity_binary_z:v2_sim_dis_diff_test_sq_z                      0.574655
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                    0.831659
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    0.476152
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z 0.714891
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    0.625814
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z 0.761558
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula11 <- glmer(resp_correct ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_attend_z + v2_sim_dis_attend_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula11)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: resp_correct ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_attend_z +
#     v2_sim_dis_attend_sq_z) * reliability_binary_z * validity_binary_z +
#     it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  45004.1  45194.3 -22480.1  44960.1    41978
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9690 -0.8352  0.4562  0.5917  1.6852
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4362   0.6605
# Number of obs: 42000, groups:  participant, 137
#
# Fixed effects:
#                                                                 Estimate
# (Intercept)                                                    1.1357559
# it_sim_dis_attend_z                                            0.0343250
# it_sim_dis_attend_sq_z                                        -0.0539997
# reliability_binary_z                                           0.0276449
# validity_binary_z                                              0.2382314
# v2_sim_dis_attend_z                                           -0.0009666
# v2_sim_dis_attend_sq_z                                        -0.0402953
# it_sim_dis_attend_z:reliability_binary_z                      -0.0163926
# it_sim_dis_attend_sq_z:reliability_binary_z                    0.0009821
# it_sim_dis_attend_z:validity_binary_z                          0.0325711
# it_sim_dis_attend_sq_z:validity_binary_z                       0.0003738
# reliability_binary_z:validity_binary_z                         0.0830307
# reliability_binary_z:v2_sim_dis_attend_z                       0.0020639
# reliability_binary_z:v2_sim_dis_attend_sq_z                    0.0157262
# validity_binary_z:v2_sim_dis_attend_z                         -0.0179741
# validity_binary_z:v2_sim_dis_attend_sq_z                      -0.0069866
# it_sim_dis_attend_z:v2_sim_dis_attend_z                       -0.0067881
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z    -0.0087858
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z  0.0104698
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z    -0.0154135
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z -0.0014184
#                                                               Std. Error
# (Intercept)                                                    0.0578423
# it_sim_dis_attend_z                                            0.0121208
# it_sim_dis_attend_sq_z                                         0.0124437
# reliability_binary_z                                           0.0118356
# validity_binary_z                                              0.0115570
# v2_sim_dis_attend_z                                            0.0130231
# v2_sim_dis_attend_sq_z                                         0.0132829
# it_sim_dis_attend_z:reliability_binary_z                       0.0121197
# it_sim_dis_attend_sq_z:reliability_binary_z                    0.0118587
# it_sim_dis_attend_z:validity_binary_z                          0.0118374
# it_sim_dis_attend_sq_z:validity_binary_z                       0.0114667
# reliability_binary_z:validity_binary_z                         0.0115388
# reliability_binary_z:v2_sim_dis_attend_z                       0.0129409
# reliability_binary_z:v2_sim_dis_attend_sq_z                    0.0128093
# validity_binary_z:v2_sim_dis_attend_z                          0.0126461
# validity_binary_z:v2_sim_dis_attend_sq_z                       0.0126988
# it_sim_dis_attend_z:v2_sim_dis_attend_z                        0.0126634
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z     0.0118473
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z  0.0114595
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z     0.0126547
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z  0.0126876
#                                                               z value Pr(>|z|)
# (Intercept)                                                    19.635  < 2e-16
# it_sim_dis_attend_z                                             2.832  0.00463
# it_sim_dis_attend_sq_z                                         -4.340 1.43e-05
# reliability_binary_z                                            2.336  0.01951
# validity_binary_z                                              20.614  < 2e-16
# v2_sim_dis_attend_z                                            -0.074  0.94084
# v2_sim_dis_attend_sq_z                                         -3.034  0.00242
# it_sim_dis_attend_z:reliability_binary_z                       -1.353  0.17620
# it_sim_dis_attend_sq_z:reliability_binary_z                     0.083  0.93400
# it_sim_dis_attend_z:validity_binary_z                           2.752  0.00593
# it_sim_dis_attend_sq_z:validity_binary_z                        0.033  0.97399
# reliability_binary_z:validity_binary_z                          7.196 6.21e-13
# reliability_binary_z:v2_sim_dis_attend_z                        0.159  0.87328
# reliability_binary_z:v2_sim_dis_attend_sq_z                     1.228  0.21955
# validity_binary_z:v2_sim_dis_attend_z                          -1.421  0.15522
# validity_binary_z:v2_sim_dis_attend_sq_z                       -0.550  0.58219
# it_sim_dis_attend_z:v2_sim_dis_attend_z                        -0.536  0.59193
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z     -0.742  0.45834
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z   0.914  0.36091
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z     -1.218  0.22322
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z  -0.112  0.91099
#
# (Intercept)                                                   ***
# it_sim_dis_attend_z                                           **
# it_sim_dis_attend_sq_z                                        ***
# reliability_binary_z                                          *
# validity_binary_z                                             ***
# v2_sim_dis_attend_z
# v2_sim_dis_attend_sq_z                                        **
# it_sim_dis_attend_z:reliability_binary_z
# it_sim_dis_attend_sq_z:reliability_binary_z
# it_sim_dis_attend_z:validity_binary_z                         **
# it_sim_dis_attend_sq_z:validity_binary_z
# reliability_binary_z:validity_binary_z                        ***
# reliability_binary_z:v2_sim_dis_attend_z
# reliability_binary_z:v2_sim_dis_attend_sq_z
# validity_binary_z:v2_sim_dis_attend_z
# validity_binary_z:v2_sim_dis_attend_sq_z
# it_sim_dis_attend_z:v2_sim_dis_attend_z
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula10 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_z * v2_sim_dis_diff_z +  (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula10)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) *
#     reliability_binary_z * validity_binary_z + it_sim_dis_diff_z *
#     v2_sim_dis_diff_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  45005.7  45195.9 -22480.8  44961.7    41978
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0125 -0.8386  0.4562  0.5917  1.6071
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4357   0.6601
# Number of obs: 42000, groups:  participant, 137
#
# Fixed effects:
#                                                              Estimate
# (Intercept)                                                  1.134579
# it_sim_dis_diff_z                                            0.032663
# it_sim_dis_diff_sq_z                                        -0.050951
# reliability_binary_z                                         0.027399
# validity_binary_z                                            0.239001
# v2_sim_dis_diff_z                                           -0.004939
# v2_sim_dis_diff_sq_z                                        -0.046266
# it_sim_dis_diff_z:reliability_binary_z                      -0.013171
# it_sim_dis_diff_sq_z:reliability_binary_z                    0.001547
# it_sim_dis_diff_z:validity_binary_z                          0.027303
# it_sim_dis_diff_sq_z:validity_binary_z                      -0.009639
# reliability_binary_z:validity_binary_z                       0.082164
# reliability_binary_z:v2_sim_dis_diff_z                       0.003113
# reliability_binary_z:v2_sim_dis_diff_sq_z                    0.011108
# validity_binary_z:v2_sim_dis_diff_z                         -0.020099
# validity_binary_z:v2_sim_dis_diff_sq_z                       0.006364
# it_sim_dis_diff_z:v2_sim_dis_diff_z                          0.002678
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z    -0.005926
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z -0.004169
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z    -0.004253
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z -0.003442
#                                                             Std. Error z value
# (Intercept)                                                   0.057790  19.633
# it_sim_dis_diff_z                                             0.011874   2.751
# it_sim_dis_diff_sq_z                                          0.012268  -4.153
# reliability_binary_z                                          0.011841   2.314
# validity_binary_z                                             0.011561  20.673
# v2_sim_dis_diff_z                                             0.011896  -0.415
# v2_sim_dis_diff_sq_z                                          0.012274  -3.770
# it_sim_dis_diff_z:reliability_binary_z                        0.011874  -1.109
# it_sim_dis_diff_sq_z:reliability_binary_z                     0.011753   0.132
# it_sim_dis_diff_z:validity_binary_z                           0.011664   2.341
# it_sim_dis_diff_sq_z:validity_binary_z                        0.011408  -0.845
# reliability_binary_z:validity_binary_z                        0.011543   7.118
# reliability_binary_z:v2_sim_dis_diff_z                        0.011899   0.262
# reliability_binary_z:v2_sim_dis_diff_sq_z                     0.011776   0.943
# validity_binary_z:v2_sim_dis_diff_z                           0.011603  -1.732
# validity_binary_z:v2_sim_dis_diff_sq_z                        0.011341   0.561
# it_sim_dis_diff_z:v2_sim_dis_diff_z                           0.012598   0.213
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z      0.011669  -0.508
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z   0.011412  -0.365
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z      0.011605  -0.366
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z   0.011343  -0.303
#                                                             Pr(>|z|)
# (Intercept)                                                  < 2e-16 ***
# it_sim_dis_diff_z                                           0.005947 **
# it_sim_dis_diff_sq_z                                        3.28e-05 ***
# reliability_binary_z                                        0.020671 *
# validity_binary_z                                            < 2e-16 ***
# v2_sim_dis_diff_z                                           0.677991
# v2_sim_dis_diff_sq_z                                        0.000164 ***
# it_sim_dis_diff_z:reliability_binary_z                      0.267345
# it_sim_dis_diff_sq_z:reliability_binary_z                   0.895245
# it_sim_dis_diff_z:validity_binary_z                         0.019236 *
# it_sim_dis_diff_sq_z:validity_binary_z                      0.398111
# reliability_binary_z:validity_binary_z                      1.09e-12 ***
# reliability_binary_z:v2_sim_dis_diff_z                      0.793653
# reliability_binary_z:v2_sim_dis_diff_sq_z                   0.345552
# validity_binary_z:v2_sim_dis_diff_z                         0.083246 .
# validity_binary_z:v2_sim_dis_diff_sq_z                      0.574657
# it_sim_dis_diff_z:v2_sim_dis_diff_z                         0.831658
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z    0.611564
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z 0.714868
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z    0.714002
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z 0.761562
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# formula1 <- glmer(resp_correct ~ (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary *  
#                   validity_binary + (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_attend * reliability_binary *  
#                   validity_binary + v2_sim_dis_attend * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# formula2 <- glmer(resp_correct ~ it_sim_dis_unattend * reliability_binary *  
#                   validity_binary + v2_sim_dis_unattend * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula2)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# head(df$reliability_binary)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))


# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula10 <- glmer(resp_correct ~ (it_sim_dis_unattend_z + it_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_unattend_z + v2_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula10)
