# %%
library(lme4)
library(simr)
library(dplyr)

# %%
# install.packages("car")
library(car)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode

# %%
file_path <- "pilot3x_nonresp_inc_stats.csv"
df <- read.csv(file_path) %>%
    select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, reliability_binary, validity_binary, Accuracy, v2_sim_dis_attend, it_sim_dis_attend, v2_sim_dis_unattend, it_sim_dis_unattend, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z )

# %%
head(df$v2_sim_dis_attend)
# df$v2_sim_dis_attend_cat <- factor(df$v2_sim_dis_attend_cat)

# # Verify the change
# str(df$v2_sim_dis_attend_cat)
# Out:
# [1] -0.026005576 -0.005751650 -0.034835014 -0.031510057  0.004823995
# [6] -0.027097704

# %%
# unique_entries <- unique(df$v2_sim_dis_attend_cat)
# unique_count <- length(unique_entries)

# Display the first few entries of `v2_sim_dis_attend_cat` and the count of unique entries
# head_entries <- head(df$v2_sim_dis_attend_cat)

list(unique_entries = unique_entries, unique_count = unique_count, head_entries = head_entries)
# Out:
# $unique_entries
# [1]                             Least Similar Most Similar
# Levels:        Least Similar Most Similar
#
# $unique_count
# [1] 5
#
# $head_entries
# [1]
# Levels:        Least Similar Most Similar

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
head(df$it_sim_dis_diff)
# Out:
# [1] -0.6958305  0.2761139 -0.4504228  0.1582699 -0.3358218  0.2649858

# %%
model <- glm(
  resp_correct ~ it_sim_dis_diff * reliability_binary * validity_binary + 
             v2_sim_dis_diff * reliability_binary * validity_binary,
  data = df,
  family = binomial(link = "logit")
)

# View the model summary
summary(model)
# Out:
# Call:
# glm(formula = resp_correct ~ it_sim_dis_diff * reliability_binary *
#     validity_binary + v2_sim_dis_diff * reliability_binary *
#     validity_binary, family = binomial(link = "logit"), data = df)
#
# Coefficients:
#                                                      Estimate Std. Error
# (Intercept)                                         0.8791065  0.0128836
# it_sim_dis_diff                                    -0.0061803  0.0167487
# reliability_binary                                 -0.0414778  0.0128836
# validity_binary                                     0.1579241  0.0128836
# v2_sim_dis_diff                                     0.1512535  0.1403452
# it_sim_dis_diff:reliability_binary                 -0.0382411  0.0167487
# it_sim_dis_diff:validity_binary                     0.0247683  0.0167487
# reliability_binary:validity_binary                  0.1071734  0.0128836
# reliability_binary:v2_sim_dis_diff                  0.0516794  0.1403452
# ...

# %%
head(df$validity_binary)
# Out:
# [1]  1  1 -1  1 -1  1

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_diff + it_sim_dis_diff_sq) * reliability_binary *  
                  validity_binary + (v2_sim_dis_diff + v2_sim_dis_diff_sq) * reliability_binary *  
                  validity_binary + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# Out:
# Warning message in optwrap(optimizer, devfun, start, rho$lower, control = control, :
# “convergence code 1 from bobyqa: bobyqa -- maximum number of function evaluations exceeded”
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.00856598 (tol = 0.002, component 1)”

# %%
summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_diff + it_sim_dis_diff_sq) * reliability_binary *
#     validity_binary + (v2_sim_dis_diff + v2_sim_dis_diff_sq) *
#     reliability_binary * validity_binary + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  46163.4  46344.8 -23060.7  46121.4    41679
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6013 -0.9757  0.4671  0.6310  1.6154
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4194   0.6476
# Number of obs: 41700, groups:  participant, 139
#
# Fixed effects:
#                                                         Estimate Std. Error
# ...

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *  
                  validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary *  
                  validity_binary + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *
#     validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) *
#     reliability_binary * validity_binary + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  46163.4  46344.8 -23060.7  46121.4    41679
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6012 -0.9757  0.4671  0.6310  1.6157
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4194   0.6476
# Number of obs: 41700, groups:  participant, 139
#
# Fixed effects:
# ...

# %%
formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula1)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ reliability_binary * validity_binary + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  46308.9  46352.1 -23149.4  46298.9    41695
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6270 -0.9958  0.4727  0.6273  1.3416
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4156   0.6447
# Number of obs: 41700, groups:  participant, 139
#
# Fixed effects:
#                                    Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         0.95605    0.05633  16.972   <2e-16 ***
# reliability_binary                 -0.04329    0.01326  -3.264   0.0011 **
# validity_binary                     0.17293    0.01327  13.030   <2e-16 ***
# ...

# %%
formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula1)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ reliability_binary * validity_binary + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  46308.9  46352.1 -23149.4  46298.9    41695
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6270 -0.9958  0.4727  0.6273  1.3416
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4156   0.6447
# Number of obs: 41700, groups:  participant, 139
#
# Fixed effects:
#                                    Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         0.95605    0.05633  16.972   <2e-16 ***
# reliability_binary                 -0.04329    0.01326  -3.264   0.0011 **
# validity_binary                     0.17293    0.01327  13.030   <2e-16 ***
# ...

# %%
formula1 <- glmer(resp_correct ~ v2_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula1)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ v2_sim_dis_attend * reliability_binary * validity_binary +
#     (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  46296.0  46373.7 -23139.0  46278.0    41691
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.8210 -0.9933  0.4689  0.6303  1.3823
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4161   0.645
# Number of obs: 41700, groups:  participant, 139
#
# Fixed effects:
#                                                      Estimate Std. Error
# (Intercept)                                           0.95906    0.05644
# v2_sim_dis_attend                                    -0.36966    0.26837
# reliability_binary                                   -0.04591    0.01344
# ...

# %%
formula1 <- glmer(resp_correct ~ it_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula1)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ it_sim_dis_attend * reliability_binary * validity_binary +
#     (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  46306.9  46384.6 -23144.4  46288.9    41691
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6663 -0.9945  0.4715  0.6299  1.4433
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4159   0.6449
# Number of obs: 41700, groups:  participant, 139
#
# Fixed effects:
#                                                      Estimate Std. Error
# (Intercept)                                           0.95580    0.05639
# it_sim_dis_attend                                    -0.04901    0.03277
# reliability_binary                                   -0.04427    0.01328
# ...

# %%
formula1 <- glmer(resp_correct ~ v2_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula1)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ v2_sim_dis_diff * reliability_binary * validity_binary +
#     (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  46311.6  46389.3 -23146.8  46293.6    41691
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6480 -0.9991  0.4734  0.6301  1.3748
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4157   0.6448
# Number of obs: 41700, groups:  participant, 139
#
# Fixed effects:
#                                                    Estimate Std. Error z value
# (Intercept)                                         0.95849    0.05640  16.995
# v2_sim_dis_diff                                     0.18720    0.14506   1.290
# ...

# %%
formula1 <- glmer(resp_correct ~ it_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula1)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ it_sim_dis_diff * reliability_binary * validity_binary +
#     (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  46309.5  46387.3 -23145.8  46291.5    41691
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6709 -0.9947  0.4729  0.6305  1.3984
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4158   0.6448
# Number of obs: 41700, groups:  participant, 139
#
# Fixed effects:
#                                                    Estimate Std. Error z value
# (Intercept)                                         0.95813    0.05639  16.990
# it_sim_dis_diff                                    -0.01051    0.01727  -0.609
# ...
