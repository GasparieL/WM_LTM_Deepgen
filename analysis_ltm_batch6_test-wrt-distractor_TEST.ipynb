# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os.path as op
import glob
import matplotlib.pyplot as plt
import ast
# import moss
import csv
import random
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning
import scipy
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning
import os
from pandas import Timestamp
from datetime import timedelta
from sklearn.preprocessing import StandardScaler

# %%
home_dir = op.abspath('./')

data_files = glob.glob(op.join(home_dir,
                        'data',
                        '*.csv'))
sns.set_context('talk')

# %%
df_orig = pd.read_csv('pilot6_TEST.csv')

participant_set = set(df_orig['participant'])

# %%
df_orig['validity_binary']
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 41995    0
# 41996    1
# 41997    1
# 41998    1
# 41999    1
# Name: validity_binary, Length: 42000, dtype: int64

# %%
df = []
for sub in data_files:
    try:
        sub_df = pd.read_csv(sub)
        
        # Filter for participants in participant_set
        if any(sub_df['participant'].isin(participant_set)):
            # Filter for non-empty 'image_recall_response.keys' and reset the index
            data = sub_df.loc[sub_df['image_recall_response.keys'].notna()].reset_index(drop=True)
            df.append(data.copy())
    except Exception as e:
        print(f"Error processing file {sub}: {e}")
        
# Concatenate all filtered data into a single DataFrame
df = pd.concat(df, ignore_index=True)

# Get the count of unique participants
unique_participants_count = len(set(df['participant']))
print(unique_participants_count)
# Out:
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-09_12h13.56.688.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_22h11.53.949.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-28_19h01.07.543.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-04_02h15.32.256.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_21h17.51.789.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-21_13h00.30.594.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-29_23h04.21.655.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_02h32.13.085.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-28_12h44.18.259.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_11h52.52.395.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-09_19h37.43.100.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_19h48.18.024.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_20h42.16.677.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-14_19h14.38.679.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_18h18.55.314.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-14_14h40.54.780.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-16_23h35.02.962.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-30_14h49.26.820.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_18h56.42.695.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-12_20h46.26.381.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-30_21h16.44.784.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-12_16h09.42.629.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/164524_WM_Deepgen_2024-10-14_17h11.03.478.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-10_18h21.45.132.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167176_WM_Deepgen_2024-12-02_13h26.05.295.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_12h07.40.919.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-13_01h27.45.964.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-22_09h51.29.724.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-12-02_12h39.21.836.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-17_18h30.20.350.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-22_12h57.52.812.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/130429_WM_Deepgen_2024-11-01_13h38.54.390.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-17_15h46.49.532.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_16h06.28.846.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_01h18.35.242.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-26_18h04.50.603.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-12_16h31.26.231.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-20_16h32.20.504.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_21h01.10.267.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-11_23h32.50.357.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-03_21h00.02.012.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-23_16h21.58.814.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-21_11h46.20.213.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-04_10h26.05.218.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167176_WM_Deepgen_2024-12-02_13h24.12.117.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_21h02.34.311.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-23_23h21.01.040.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_17h24.36.964.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/138046_WM_Deepgen_2024-10-24_13h16.59.701.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-10_11h49.39.843.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/165658_WM_Deepgen_2024-11-24_14h47.59.584.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_02h52.58.478.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-14_19h06.22.729.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-29_19h13.31.303.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-22_18h51.55.974.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/168889_WM_Deepgen_2024-12-02_14h03.28.335.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_16h37.45.390.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_20h31.43.754.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-20_22h16.55.250.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167041_WM_Deepgen_2024-10-28_15h07.19.888.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-22_22h32.08.465.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-22_11h24.36.271.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_16h47.14.580.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-18_09h47.19.365.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_13h46.08.948.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-14_15h57.31.348.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-28_10h00.52.918.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/150652_WM_Deepgen_2023-08-02_11h33.40.328.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/128059_WM_Deepgen_2023-08-02_11h24.49.429.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-12-03_18h34.15.199.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/168940_WM_Deepgen_2024-12-02_20h05.57.476.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_17h43.21.962.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-04_01h27.31.136.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/130429_WM_Deepgen_2024-10-17_17h08.37.711.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_17h31.41.758.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_23h32.03.969.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-20_17h26.02.664.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/168073_WM_Deepgen_2024-11-28_07h51.23.108.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_12h35.50.036.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-16_17h10.26.841.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_16h32.06.541.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-09_16h58.03.048.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-21_11h55.13.143.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-19_16h15.18.134.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-02_09h05.05.475.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_15h29.32.135.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-30_22h49.57.057.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-18_17h51.19.823.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_02h48.37.435.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-24_20h33.20.061.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-04_08h06.43.126.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_10h56.48.846.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-02_06h10.29.129.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_20h03.50.529.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-22_14h46.29.729.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-01_09h02.01.831.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-20_13h27.19.817.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-27_22h53.58.512.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-25_00h52.48.838.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-24_13h05.30.324.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-01_16h08.20.438.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-27_21h57.51.019.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-28_14h24.23.937.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-19_21h51.18.593.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-19_15h47.14.202.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-24_20h03.32.661.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167176_WM_Deepgen_2024-12-02_13h24.23.334.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_18h47.43.554.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_11h51.32.574.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/166894_WM_Deepgen_2024-11-24_12h48.57.508.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-31_12h03.04.245.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_11h51.32.313.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-23_16h03.06.466.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_16h25.08.428.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-16_19h20.33.024.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-30_11h37.42.210.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-02_18h32.50.236.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-02_09h39.55.699.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_16h30.40.812.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-21_23h30.35.955.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_11h53.16.558.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-29_21h00.51.587.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-14_17h20.02.635.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-12_01h02.06.878.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-14_19h38.28.940.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_23h34.43.802.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-14_17h22.57.649.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_18h33.44.229.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-12_13h45.10.433.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-28_10h00.34.500.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-31_12h04.00.597.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-05_09h03.33.757.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-03_22h35.27.913.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_14h56.55.268.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-09_13h15.03.597.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-30_00h07.15.739.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_21h51.16.277.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-29_17h43.05.547.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-09_16h03.42.525.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-28_22h15.35.499.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_11h57.49.262.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-25_08h40.25.421.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-21_13h00.19.020.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-20_20h29.12.046.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/128059_WM_Deepgen_2023-08-02_11h24.29.083.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-01_00h27.12.712.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/169006_WM_Deepgen_2024-12-03_18h46.35.480.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_13h38.39.652.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-01_06h21.02.883.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167176_WM_Deepgen_2024-12-02_13h23.55.034.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-14_21h29.30.331.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-26_11h13.35.531.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-30_11h37.06.383.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-05_09h48.02.953.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_09h47.53.012.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-12-02_12h47.02.088.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-10_15h19.55.953.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-14_17h17.18.922.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_21h50.44.908.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-28_09h22.13.859.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-22_10h40.25.052.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/140848_WM_Deepgen_2024-05-20_12h31.01.314.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-18_09h45.18.533.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/130429_WM_Deepgen_2025-01-23_16h02.56.758.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_09h54.08.716.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_22h08.15.368.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-26_10h12.09.906.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_11h53.04.091.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-03_15h18.28.526.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_00h10.44.014.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-09_19h21.05.445.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/169006_WM_Deepgen_2024-12-03_18h45.05.630.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-30_11h24.42.787.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-16_22h50.37.046.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-01_13h33.32.309.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-04_11h46.46.923.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/131596_WM_Deepgen_2024-09-02_03h37.15.848.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-09_19h28.09.644.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-21_19h23.23.574.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-04_07h43.46.335.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-30_24h08.51.603.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-03_16h48.47.894.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-01_13h46.29.760.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-12_23h08.40.152.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167176_WM_Deepgen_2024-12-02_13h24.03.783.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_11h53.28.226.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-21_21h45.14.516.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_18h27.14.124.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-26_18h15.45.249.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-12-02_17h16.45.464.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-12_17h55.23.085.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167176_WM_Deepgen_2024-12-02_13h25.37.548.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/131596_WM_Deepgen_2024-09-03_00h37.10.362.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-12-02_20h36.39.111.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-10_02h30.30.631.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/163060_WM_Deepgen_2024-06-04_16h55.26.436.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-20_16h34.58.364.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-15_10h35.15.992.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-30_11h23.44.306.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-22_20h09.02.051.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-21_12h08.34.114.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-01_11h11.38.756.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-18_10h09.54.124.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-12-03_19h03.56.236.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-21_21h32.35.984.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-14_13h11.21.822.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/140848_WM_Deepgen_2024-05-20_12h30.47.784.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/168718_WM_Deepgen_2024-11-26_21h43.49.268.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_19h49.51.204.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-24_11h57.40.793.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-28_21h51.57.997.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-09_21h22.52.325.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-20_13h45.30.592.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-28_15h08.13.751.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/168940_WM_Deepgen_2024-12-02_20h06.12.417.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-12-02_12h38.52.476.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-03_21h57.41.765.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-10_15h30.07.691.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_19h00.38.301.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-30_22h56.36.872.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-29_22h18.28.594.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-29_22h54.06.052.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/150652_WM_Deepgen_2023-08-02_11h33.24.258.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-18_16h22.36.702.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-18_10h23.17.915.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/164842_WM_Deepgen_2025-01-22_12h23.44.790.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_16h33.05.173.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_11h51.59.687.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-23_12h13.36.621.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-26_21h27.41.156.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/163060_WM_Deepgen_2024-06-04_16h54.59.554.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/155275_WM_Deepgen_2024-11-28_11h51.49.254.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-01_15h57.57.412.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-16_17h57.59.352.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-03-12_10h40.43.606.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2025-01-23_13h22.27.962.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-02_19h09.08.042.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-04-30_22h39.40.712.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-05-15_18h08.37.098.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/131596_WM_Deepgen_2024-09-02_03h37.35.461.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167176_WM_Deepgen_2024-12-02_13h25.51.497.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-16_16h03.30.145.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-24_20h47.50.999.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-12-02_12h29.11.787.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-15_00h58.04.328.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-21_13h08.46.651.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-25_14h00.08.583.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_20h26.26.971.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-08-28_19h44.55.758.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167176_WM_Deepgen_2024-12-02_13h24.34.452.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_17h51.15.807.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-26_16h21.46.183.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/150043_WM_Deepgen_2024-11-26_11h32.48.617.csv: 'image_recall_response.keys'
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-21_10h34.11.979.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-24_23h00.44.636.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/168940_WM_Deepgen_2024-12-02_20h01.18.986.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-14_00h31.41.347.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-10-18_10h54.29.612.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/167041_WM_Deepgen_2024-10-28_15h07.31.988.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-09-02_19h08.42.722.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-06-04_16h23.46.763.csv: No columns to parse from file
# Error processing file /Users/lana/Desktop/psychoPyExperiments/wm_deepgen/data/PARTICIPANT_WM_Deepgen_2024-11-24_12h19.02.598.csv: No columns to parse from file
# 135

# %%
df_orig['Prioritized - Deprioritized IT Distractor Similarity']
# Out:
# 0       -0.799222
# 1       -0.629416
# 2        0.177236
# 3        0.171813
# 4       -0.628796
#            ...
# 41995   -0.169682
# 41996    0.483480
# 41997    1.444772
# 41998    1.121865
# 41999    1.452036
# Name: Prioritized - Deprioritized IT Distractor Similarity, Length: 42000, dtype: float64

# %%
# df['it_sim_dis_unattend']

# %%
len(set(df['participant']))
# Out:
# 135

# %%
df
# Out:
#        setup_js.started  setup_js.stopped  participant  \
# 0                   NaN               NaN       165862
# 1                   NaN               NaN       165862
# 2                   NaN               NaN       165862
# 3                   NaN               NaN       165862
# 4                   NaN               NaN       165862
# ...                 ...               ...          ...
# 32773               NaN               NaN       167431
# 32774               NaN               NaN       167431
# 32775               NaN               NaN       167431
# 32776               NaN               NaN       167431
# 32777               NaN               NaN       167431
#
#                           date     expName psychopyVersion        OS  \
# 0      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# 1      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# 2      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# 3      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# 4      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# ...                        ...         ...             ...       ...
# 32773  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
# 32774  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
# 32775  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
# 32776  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
# 32777  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
#
#        frameRate  Instructions1.started  Instructions1.stopped  ...  \
# 0       59.88024                    NaN                    NaN  ...
# 1       59.88024                    NaN                    NaN  ...
# 2       59.88024                    NaN                    NaN  ...
# 3       59.88024                    NaN                    NaN  ...
# 4       59.88024                    NaN                    NaN  ...
# ...          ...                    ...                    ...  ...
# 32773   62.50000                    NaN                    NaN  ...
# 32774   62.50000                    NaN                    NaN  ...
# 32775   62.50000                    NaN                    NaN  ...
# 32776   62.50000                    NaN                    NaN  ...
# 32777   62.50000                    NaN                    NaN  ...
#
#                                          ImagePath  key_resp_18.rt  \
# 0        ./stimuli/new_foil_stims/broccoli_01b.jpg             NaN
# 1      ./stimuli/new_foil_stims/windowsill_07s.jpg             NaN
# 2        ./stimuli/new_foil_stims/bolo_tie_08s.jpg             NaN
# 3                              ./stimuli/216_3.jpg             NaN
# 4          ./stimuli/new_foil_stims/oilcan_08s.jpg             NaN
# ...                                            ...             ...
# 32773                          ./stimuli/141_2.jpg             NaN
# 32774   ./stimuli/new_foil_stims/speedboat_09s.jpg             NaN
# 32775                          ./stimuli/274_1.jpg             NaN
# 32776   ./stimuli/new_foil_stims/mannequin_02s.jpg             NaN
# 32777                           ./stimuli/67_2.jpg             NaN
#
#        key_resp_18.duration  end_exp.started  end_exp.stopped key_resp_14.rt  \
# 0                       NaN              NaN              NaN            NaN
# 1                       NaN              NaN              NaN            NaN
# 2                       NaN              NaN              NaN            NaN
# 3                       NaN              NaN              NaN            NaN
# 4                       NaN              NaN              NaN            NaN
# ...                     ...              ...              ...            ...
# 32773                   NaN              NaN              NaN            NaN
# 32774                   NaN              NaN              NaN            NaN
# 32775                   NaN              NaN              NaN            NaN
# 32776                   NaN              NaN              NaN            NaN
# 32777                   NaN              NaN              NaN            NaN
#
#        key_resp_14.duration  key_resp_12.rt  key_resp_12.duration  \
# 0                       NaN             NaN                   NaN
# 1                       NaN             NaN                   NaN
# 2                       NaN             NaN                   NaN
# 3                       NaN             NaN                   NaN
# 4                       NaN             NaN                   NaN
# ...                     ...             ...                   ...
# 32773                   NaN             NaN                   NaN
# 32774                   NaN             NaN                   NaN
# 32775                   NaN             NaN                   NaN
# 32776                   NaN             NaN                   NaN
# 32777                   NaN             NaN                   NaN
#
#        trials_2.order
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 32773             NaN
# 32774             NaN
# 32775             NaN
# 32776             NaN
# 32777             NaN
#
# [32778 rows x 256 columns]

# %%
df_orig
# Out:
#        setup_js.started  setup_js.stopped  participant  \
# 0                   NaN               NaN       123985
# 1                   NaN               NaN       123985
# 2                   NaN               NaN       123985
# 3                   NaN               NaN       123985
# 4                   NaN               NaN       123985
# ...                 ...               ...          ...
# 41995               NaN               NaN       171304
# 41996               NaN               NaN       171304
# 41997               NaN               NaN       171304
# 41998               NaN               NaN       171304
# 41999               NaN               NaN       171304
#
#                           date     expName psychopyVersion        OS  \
# 0      2025-01-28 21:25:50.434  WM_Deepgen        2023.2.1  MacIntel
# 1      2025-01-28 21:25:50.434  WM_Deepgen        2023.2.1  MacIntel
# 2      2025-01-28 21:25:50.434  WM_Deepgen        2023.2.1  MacIntel
# 3      2025-01-28 21:25:50.434  WM_Deepgen        2023.2.1  MacIntel
# 4      2025-01-28 21:25:50.434  WM_Deepgen        2023.2.1  MacIntel
# ...                        ...         ...             ...       ...
# 41995  2025-01-29 19:25:41.828  WM_Deepgen        2023.2.1  MacIntel
# 41996  2025-01-29 19:25:41.828  WM_Deepgen        2023.2.1  MacIntel
# 41997  2025-01-29 19:25:41.828  WM_Deepgen        2023.2.1  MacIntel
# 41998  2025-01-29 19:25:41.828  WM_Deepgen        2023.2.1  MacIntel
# 41999  2025-01-29 19:25:41.828  WM_Deepgen        2023.2.1  MacIntel
#
#        frameRate  Instructions1.started  Instructions1.stopped  ...  \
# 0      61.349693                    NaN                    NaN  ...
# 1      61.349693                    NaN                    NaN  ...
# 2      61.349693                    NaN                    NaN  ...
# 3      61.349693                    NaN                    NaN  ...
# 4      61.349693                    NaN                    NaN  ...
# ...          ...                    ...                    ...  ...
# 41995  59.880240                    NaN                    NaN  ...
# 41996  59.880240                    NaN                    NaN  ...
# 41997  59.880240                    NaN                    NaN  ...
# 41998  59.880240                    NaN                    NaN  ...
# 41999  59.880240                    NaN                    NaN  ...
#
#        processed_mouse.click  mouse.time_length  mouse.time_first  \
# 0       ['"memoranda_stim"']                  1            1.8312
# 1       ['"memoranda_stim"']                  1            1.8784
# 2      ['"distractor_im_1"']                  1            1.8978
# 3       ['"memoranda_stim"']                  1            1.3462
# 4       ['"memoranda_stim"']                  1            1.9802
# ...                      ...                ...               ...
# 41995   ['"memoranda_stim"']                  1            1.4795
# 41996   ['"memoranda_stim"']                  1            2.1293
# 41997  ['"distractor_im_2"']                  1            1.2625
# 41998   ['"memoranda_stim"']                  1            1.4625
# 41999   ['"memoranda_stim"']                  1            1.4123
#
#        mouse.time_last  mouse.clicked_name_first  mouse.clicked_name_last  \
# 0               1.8312          "memoranda_stim"         "memoranda_stim"
# 1               1.8784          "memoranda_stim"         "memoranda_stim"
# 2               1.8978         "distractor_im_1"        "distractor_im_1"
# 3               1.3462          "memoranda_stim"         "memoranda_stim"
# 4               1.9802          "memoranda_stim"         "memoranda_stim"
# ...                ...                       ...                      ...
# 41995           1.4795          "memoranda_stim"         "memoranda_stim"
# 41996           2.1293          "memoranda_stim"         "memoranda_stim"
# 41997           1.2625         "distractor_im_2"        "distractor_im_2"
# 41998           1.4625          "memoranda_stim"         "memoranda_stim"
# 41999           1.4123          "memoranda_stim"         "memoranda_stim"
#
#        resp_correct_within  Accuracy  mouse.time_last_within  analysis_rt
# 0                 1.190548  1.190548                1.987624     1.987624
# 1                 1.190548  1.190548                2.034824     2.034824
# 2                 0.190548  0.190548                2.054224     2.054224
# 3                 1.190548  1.190548                1.502624     1.502624
# 4                 1.190548  1.190548                2.136624     2.136624
# ...                    ...       ...                     ...          ...
# 41995             0.907214  0.907214                1.558988     1.558988
# 41996             0.907214  0.907214                2.208788     2.208788
# 41997            -0.092786 -0.092786                1.341988     1.341988
# 41998             0.907214  0.907214                1.541988     1.541988
# 41999             0.907214  0.907214                1.491788     1.491788
#
# [42000 rows x 410 columns]

# %%
# df_orig['image_recall_response_count']

# %%
combined_df = pd.concat([df, df_orig], ignore_index=True)

# %%
response_counts = combined_df.groupby('participant')['image_recall_response.keys'].count().reset_index()

response_counts = response_counts.rename(columns={'image_recall_response.keys': 'image_recall_response_count'})

print(response_counts)
# Out:
#      participant  image_recall_response_count
# 0         123985                          240
# 1         124081                          240
# 2         124180                          240
# 3         124750                          240
# 4         124819                          240
# ..           ...                          ...
# 132       170536                          238
# 133       170665                          240
# 134       171031                          239
# 135       171253                          238
# 136       171304                          240
#
# [137 rows x 2 columns]

# %%
min_response_count = response_counts['image_recall_response_count'].min()
min_response_count
# Out:
# 0

# %%
threshold = 250 * (2 / 3)

below_threshold_count = (response_counts['image_recall_response_count'] < threshold).sum()

print(f"The number of participants with image_recall_response.keys count below {threshold} is: {below_threshold_count}")
# Out:
# The number of participants with image_recall_response.keys count below 166.66666666666666 is: 2

# %%
combined_df['acc_recall'] = np.where(combined_df['ImagePath'].str.contains("foil", case=False, na=False), 0, 1)
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1974338098.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df['acc_recall'] = np.where(combined_df['ImagePath'].str.contains("foil", case=False, na=False), 0, 1)

# %%
# combined_df['acc_recall']

# %%
combined_df['mem_answ'] = np.where(combined_df['image_recall_response.keys'].isin([1, 2]), 0,
                                   np.where(combined_df['image_recall_response.keys'].isin([3, 4]), 1, np.nan))
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/2647953418.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df['mem_answ'] = np.where(combined_df['image_recall_response.keys'].isin([1, 2]), 0,

# %%
combined_df['mem_answ']
# Out:
# 0        0.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        1.0
#         ...
# 74773    NaN
# 74774    NaN
# 74775    NaN
# 74776    NaN
# 74777    NaN
# Name: mem_answ, Length: 74778, dtype: float64

# %%
combined_df['recall_answ'] = np.where(
    combined_df['mem_answ'].isna() | combined_df['acc_recall'].isna(), np.nan,
    np.where(
        (combined_df['mem_answ'] == 0) & (combined_df['acc_recall'] == 0) | 
        (combined_df['mem_answ'] == 1) & (combined_df['acc_recall'] == 1), 1, 0)
)
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1958824526.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df['recall_answ'] = np.where(

# %%
combined_df['recall_answ']
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        0.0
#         ...
# 74773    NaN
# 74774    NaN
# 74775    NaN
# 74776    NaN
# 74777    NaN
# Name: recall_answ, Length: 74778, dtype: float64

# %%
# count_gt_120 = combined_df[combined_df['image_recall_response.rt'] > 10].shape[0]
# count_gt_120

# %%
combined_df = combined_df[combined_df['image_recall_response.rt'] <= 4]

# %%
recall_count_per_participant = combined_df.groupby('participant')['recall_answ'].sum().reset_index()

recall_count_per_participant = recall_count_per_participant.rename(columns={'recall_answ': 'recall_answ_count'})

print(recall_count_per_participant)
# Out:
#      participant  recall_answ_count
# 0         123985              150.0
# 1         124081              150.0
# 2         124180              123.0
# 3         124750              144.0
# 4         124819              170.0
# ..           ...                ...
# 130       170536              123.0
# 131       170665              156.0
# 132       171031              172.0
# 133       171253              133.0
# 134       171304              159.0
#
# [135 rows x 2 columns]

# %%
recall_counts = combined_df['recall_answ'].value_counts()

plt.figure(figsize=(6, 4))
recall_counts.plot(kind='bar', color=['lightblue', 'salmon'])
# plt.title('Counts of Recall Ans = 1 vs 0')
plt.xlabel('Correct vs incorrect answer distribution')
plt.ylabel('Count')
plt.xticks(rotation=0)  # Rotate x labels if necessary
plt.tight_layout()
plt.show()

# %%
answer_mapping = {1: 'Definitely not seen', 2: 'Probably not seen',
                  3: 'Probably seen', 4: 'Definitely seen'}

combined_df['Answer Labels'] = combined_df['image_recall_response.keys'].map(answer_mapping)

# %%
label_order = [
    'Definitely not seen', 
    'Probably not seen', 
    'Probably seen', 
    'Definitely seen'
]

# Count occurrences and sort by the defined order
answer_counts = combined_df['Answer Labels'].value_counts()
answer_counts = answer_counts.reindex(label_order)

plt.figure(figsize=(8, 5))
answer_counts.plot(kind='bar', color='lightcoral')
plt.title('Distribution of Answer Labels')
plt.xlabel('Answer Labels')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.tight_layout()
plt.show()

# %%
df = combined_df

# %%
correctLTM_df = df[df['recall_answ'] == 1]

correctLTM_df['Answer Labels'] = correctLTM_df['image_recall_response.keys'].map(answer_mapping)
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/2467276519.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   correctLTM_df['Answer Labels'] = correctLTM_df['image_recall_response.keys'].map(answer_mapping)

# %%
answer_counts_corr = correctLTM_df['Answer Labels'].value_counts()
answer_counts_corr = answer_counts_corr.reindex(label_order)

# %%
plt.figure(figsize=(8, 5))
answer_counts_corr.plot(kind='bar', color='lightcoral')
plt.title('Distribution of Answer Labels when response is correct')
plt.xlabel('Answer Labels')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.tight_layout()
plt.show()

# %%
correctLTM_df['Answer Labels']
# Out:
# 1        Definitely not seen
# 2          Probably not seen
# 3            Definitely seen
# 5          Probably not seen
# 6            Definitely seen
#                 ...
# 32768    Definitely not seen
# 32769    Definitely not seen
# 32772          Probably seen
# 32773          Probably seen
# 32777        Definitely seen
# Name: Answer Labels, Length: 20137, dtype: object

# %%
wrongLTM_df = df[df['recall_answ'] == 0]

wrongLTM_df['Answer Labels'] = wrongLTM_df['image_recall_response.keys'].map(answer_mapping)
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1338151430.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wrongLTM_df['Answer Labels'] = wrongLTM_df['image_recall_response.keys'].map(answer_mapping)

# %%
answer_counts_incorr = wrongLTM_df['Answer Labels'].value_counts()
answer_counts_incorr = answer_counts_incorr.reindex(label_order)

# %%
plt.figure(figsize=(8, 5))
answer_counts_incorr.plot(kind='bar', color='lightcoral')
plt.title('Distribution of Answer Labels when response is incorrect')
plt.xlabel('Answer Labels')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.tight_layout()
plt.show()



###for each of the categories plot the accuracy

# %%
# df = df[df['image_recall_response.rt'] <= 4]

# %%
df['recall_category'] = df['image_recall_response.keys'].map({
    1: 'Definitely not seen',
    2: 'Probably not seen',
    3: 'Probably seen',
    4: 'Definitely seen'
})

df['correct_recall'] = ((df['acc_recall'] == 1) & 
                              (df['Answer Labels'].isin(['Probably seen', 'Definitely seen']))) | \
                             ((df['acc_recall'] == 0) & 
                              (df['Answer Labels'].isin(['Definitely not seen', 'Probably not seen'])))



response_time_column = 'image_recall_response.rt'
correct_response_times = df[df['recall_answ'] == 1][response_time_column].dropna()
incorrect_response_times = df[df['recall_answ'] == 0][response_time_column].dropna()

# Get summary statistics for response times
response_time_stats = df[response_time_column].describe()

# Plotting the response times distribution
plt.figure(figsize=(12, 6))
sns.histplot(correct_response_times, color='green', kde=True, label='Correct Responses', binwidth=0.5)
sns.histplot(incorrect_response_times, color='red', kde=True, label='Incorrect Responses', binwidth=0.5)

plt.title('Response Times Distribution', fontsize=14)
plt.xlabel('Response Time (seconds)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# Displaying summary statistics for response times
print(response_time_stats)


#####more fine graned bins
# Out:
# count    31308.000000
# mean         1.583873
# std          0.706200
# min          0.000500
# 25%          1.067900
# 50%          1.405050
# 75%          1.961675
# max          3.999800
# Name: image_recall_response.rt, dtype: float64

# %%
df['correct_recall']
# Out:
# 1         True
# 2         True
# 3         True
# 4        False
# 5         True
#          ...
# 32770    False
# 32771    False
# 32772     True
# 32773     True
# 32777     True
# Name: correct_recall, Length: 31308, dtype: bool

# %%
confidence_order = ['Definitely not seen', 'Probably not seen', 'Probably seen', 'Definitely seen']

confidence_mapping = {1: 'Definitely not seen', 2: 'Probably not seen', 
                                  3: 'Probably seen', 4: 'Definitely seen'}
df['confidence_level'] = df['image_recall_response.keys'].map(confidence_mapping)

confidence_correctness = pd.crosstab(df['confidence_level'], df['correct_recall'], normalize='index').reindex(index=confidence_order)

plt.figure(figsize=(10, 6))
sns.heatmap(confidence_correctness, annot=True, cmap='Blues')
plt.title('Correctness Proportion by Confidence Level')
plt.xlabel('Is Recall Correct')
plt.ylabel('Confidence Level')
plt.show()

# %%
correctness_order = [False, True]  # Assuming 0 is 'not correct' and 1 is 'correct'

confidence_correctness_reversed = pd.crosstab(
    df['correct_recall'],
    df['confidence_level'],
    normalize='index'
).reindex(index=correctness_order, columns=confidence_order)

plt.figure(figsize=(10, 6))
sns.heatmap(confidence_correctness_reversed, annot=True, cmap='Blues', cbar_kws={'label': 'Proportion'})
plt.title('Confidence Level Proportion by Correctness')
plt.xlabel('Confidence Level')
plt.ylabel('Is Recall Correct')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Convert 'resp_correct' to numeric, coercing errors to NaN (non-numeric to NaN)
df['recall_answ'] = pd.to_numeric(df['recall_answ'], errors='coerce')

# Now, calculate the mean 'resp_correct' for each participant
mean_resp_correct = df.groupby('participant')['recall_answ'].mean().reset_index()

# Create the swarm plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as necessary
sns.swarmplot(y='recall_answ', data=mean_resp_correct)

plt.title('Mean Correct Responses by Participant -  for images definitely seen')
plt.xlabel('Participant')
plt.ylabel('Mean Correct Response')

# Show the plot
plt.show()

# %%
df
# Out:
#        setup_js.started  setup_js.stopped  participant  \
# 1                   NaN               NaN       165862
# 2                   NaN               NaN       165862
# 3                   NaN               NaN       165862
# 4                   NaN               NaN       165862
# 5                   NaN               NaN       165862
# ...                 ...               ...          ...
# 32770               NaN               NaN       167431
# 32771               NaN               NaN       167431
# 32772               NaN               NaN       167431
# 32773               NaN               NaN       167431
# 32777               NaN               NaN       167431
#
#                           date     expName psychopyVersion        OS  \
# 1      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# 2      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# 3      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# 4      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# 5      2024-11-27_10h29.27.557  WM_Deepgen        2023.2.1     Win32
# ...                        ...         ...             ...       ...
# 32770  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
# 32771  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
# 32772  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
# 32773  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
# 32777  2024-11-24_14h54.08.781  WM_Deepgen        2023.2.1  MacIntel
#
#        frameRate  Instructions1.started  Instructions1.stopped  ... Accuracy  \
# 1       59.88024                    NaN                    NaN  ...      NaN
# 2       59.88024                    NaN                    NaN  ...      NaN
# 3       59.88024                    NaN                    NaN  ...      NaN
# 4       59.88024                    NaN                    NaN  ...      NaN
# 5       59.88024                    NaN                    NaN  ...      NaN
# ...          ...                    ...                    ...  ...      ...
# 32770   62.50000                    NaN                    NaN  ...      NaN
# 32771   62.50000                    NaN                    NaN  ...      NaN
# 32772   62.50000                    NaN                    NaN  ...      NaN
# 32773   62.50000                    NaN                    NaN  ...      NaN
# 32777   62.50000                    NaN                    NaN  ...      NaN
#
#        mouse.time_last_within  analysis_rt  acc_recall  mem_answ recall_answ  \
# 1                         NaN          NaN           0       0.0         1.0
# 2                         NaN          NaN           0       0.0         1.0
# 3                         NaN          NaN           1       1.0         1.0
# 4                         NaN          NaN           0       1.0         0.0
# 5                         NaN          NaN           0       0.0         1.0
# ...                       ...          ...         ...       ...         ...
# 32770                     NaN          NaN           0       1.0         0.0
# 32771                     NaN          NaN           0       1.0         0.0
# 32772                     NaN          NaN           1       1.0         1.0
# 32773                     NaN          NaN           1       1.0         1.0
# 32777                     NaN          NaN           1       1.0         1.0
#
#              Answer Labels      recall_category  correct_recall  \
# 1      Definitely not seen  Definitely not seen            True
# 2        Probably not seen    Probably not seen            True
# 3          Definitely seen      Definitely seen            True
# 4            Probably seen        Probably seen           False
# 5        Probably not seen    Probably not seen            True
# ...                    ...                  ...             ...
# 32770      Definitely seen      Definitely seen           False
# 32771        Probably seen        Probably seen           False
# 32772        Probably seen        Probably seen            True
# 32773        Probably seen        Probably seen            True
# 32777      Definitely seen      Definitely seen            True
#
#           confidence_level
# 1      Definitely not seen
# 2        Probably not seen
# 3          Definitely seen
# 4            Probably seen
# 5        Probably not seen
# ...                    ...
# 32770      Definitely seen
# 32771        Probably seen
# 32772        Probably seen
# 32773        Probably seen
# 32777      Definitely seen
#
# [31308 rows x 417 columns]

# %%
##acc_recall is 1 if the image was actually seen
##mem_answ is 1 if the said seen or probably seen
###recall_answ is 1 if these two are both 1 or both 0


### now I want, for the images where acc_recall == 1 to assign it, v2, etc
cols_to_copy = ['attend', 'reliability', 'validity', 'test_item']

# # Define the condition to match both `participant` and `ImagePath`
# condition = (df['acc_recall'] == 1) & (
#     ((df['participant'] == df_orig['participant']) & (df['ImagePath'] == df_orig['img1'])) |
#     ((df['participant'] == df_orig['participant']) & (df['ImagePath'] == df_orig['img2'])) |
#     ((df['participant'] == df_orig['participant']) & (df['ImagePath'] == df_orig['ping_im']))
# )

# # Apply the condition and copy values from `df_orig` to `df`
# df.loc[condition, cols_to_copy] = df_orig.loc[
#     ((df_orig['participant'] == df['participant']) & (df_orig['img1'] == df['ImagePath'])) |
#     ((df_orig['participant'] == df['participant']) & (df_orig['img2'] == df['ImagePath'])) |
#     ((df_orig['participant'] == df['participant']) & (df_orig['ping_im'] == df['ImagePath'])),
#     cols_to_copy
# ].values

# %%
df['participant']
# Out:
# 1        165862
# 2        165862
# 3        165862
# 4        165862
# 5        165862
#           ...
# 32770    167431
# 32771    167431
# 32772    167431
# 32773    167431
# 32777    167431
# Name: participant, Length: 31308, dtype: int64

# %%
df_orig['it_sim_dis_unattend']
# Out:
# 0        0.466768
# 1        0.003009
# 2       -0.209605
# 3       -0.240997
# 4        0.241943
#            ...
# 41995    0.005654
# 41996   -0.044433
# 41997   -0.519718
# 41998   -0.460473
# 41999   -0.428987
# Name: it_sim_dis_unattend, Length: 42000, dtype: float64

# %%
prc = []
for a in df['acc_recall']:
    if a == 1:
        prc.append('Correct')
    else:
        prc.append('Wrong')
df['Past Response Correctness'] = prc

# %%
df_orig['validity_binary']
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 41995    0
# 41996    1
# 41997    1
# 41998    1
# 41999    1
# Name: validity_binary, Length: 42000, dtype: int64

# %%
def fill_non_nan_columns(row):
    # Locate matching rows in df_orig based on participant and image conditions
    matching_rows = df_orig[
        (df_orig['participant'] == row['participant']) &
        ((df_orig['img1'] == row['ImagePath']) | 
         (df_orig['img2'] == row['ImagePath']) | 
         (df_orig['ping_img'] == row['ImagePath']))
    ]
    
    # Copy non-NaN columns from the first matching row in df_orig if there's a match
    if not matching_rows.empty:
        match = matching_rows.iloc[0]
        for col in match.index:
            # Skip columns that identify rows (not to be copied over) and only copy non-NaN values
            if col not in ['participant'] and pd.notna(match[col]):
                row[col] = match[col]
    return row

# Apply the function to each row in df, only where 'acc_recall' == 1
df = df.apply(lambda row: fill_non_nan_columns(row) if row['acc_recall'] == 1 else row, axis=1)

# %%
# # Initialize an empty dataframe for df_ltm
# df_ltm = pd.DataFrame()

# def fill_non_nan_columns(row):
#     global df_ltm  # Use the global variable df_ltm
    
#     # Locate matching rows in df_orig based on participant and image conditions
#     matching_rows = df_orig[
#         (df_orig['participant'] == row['participant']) &
#         ((df_orig['img1'] == row['ImagePath']) | 
#          (df_orig['img2'] == row['ImagePath']) | 
#          (df_orig['ping_img'] == row['ImagePath']))
#     ]
    
# #     # Copy non-NaN columns from the first matching row in df_orig if there's a match
#     if not matching_rows.empty:
#         match = matching_rows.iloc[0]
# #         for col in match.index:
# #             # Skip columns that identify rows (not to be copied over) and only copy non-NaN values
# #             if col not in ['participant'] and pd.notna(match[col]):
# #                 row[col] = match[col]
        
#         # Add the matching row to df_ltm and create an additional column
#         matching_row = match.copy()
#         matching_row['image_recall_response.keys'] = row['image_recall_response.keys']  # Replace 'some_value' with the desired logic
#         matching_row['acc_recall'] = row['acc_recall']  # Replace 'some_value' with the desired logic
#         matching_row['recall_answ'] = row['recall_answ']  # Replace 'some_value' with the desired logic
#         matching_row['mem_answ'] = row['mem_answ']  # Replace 'some_value' with the desired logic
#         matching_row['Answer Labels'] = row['Answer Labels']  # Replace 'some_value' with the desired logic
#         df_ltm = pd.concat([df_ltm, matching_row.to_frame().T], ignore_index=True)
#     'Answer Labels'
#     return row

# # Apply the function to each row in df, only where 'acc_recall' == 1
# df = df.apply(lambda row: fill_non_nan_columns(row) if row['acc_recall'] == 1 else row, axis=1)

# %%
# df_ltm.to_csv("df_ltm.csv", index=False)

# %%
df['validity_binary']
# Out:
# 1        NaN
# 2        NaN
# 3        1.0
# 4        NaN
# 5        NaN
#         ...
# 32770    NaN
# 32771    NaN
# 32772    1.0
# 32773    0.0
# 32777    0.0
# Name: validity_binary, Length: 31308, dtype: float64

# %%
def remove_unit_variance(df, col, unit, group=None, suffix="_within"):
    """Remove variance between sampling units.

    This is useful for plotting repeated-measures data using within-unit
    error bars.

    Parameters
    ----------
    df : DataFrame
        Input data. Will have a new column added.
    col : column name
        Column in dataframe with quantitative measure to modify.
    unit : column name
        Column in dataframe defining sampling units (e.g., subjects).
    group : column name(s), optional
        Columns defining groups to remove unit variance within.
    suffix : string, optional
        Suffix appended to ``col`` name to create new column.

    Returns
    -------
    df : DataFrame
        Returns modified dataframe.

    """
    new_col = col + suffix

    def demean(x):
        return x - x.mean()

    if group is None:
        new = df.groupby(unit)[col].transform(demean)
        new += df[col].mean()
        df.loc[:, new_col] = new
    else:
        df.loc[:, new_col] = np.nan
        for level, df_level in df.groupby(group):
            new = df_level.groupby(unit)[col].transform(demean)
            new += df_level[col].mean()
            df.loc[new.index, new_col] = new

    return df

# %%
df = remove_unit_variance(df,'mouse.time_last','participant')
df['analysis_rt'] = df['mouse.time_last_within']

# %%
palette = sns.color_palette("husl", n_colors=2)[::-1]  # Reverse the color order

# %%
df['Distractor V2 Similarity Preference'] = df['v2_prefers'] 
df['Distractor IT Similarity Preference'] = df['it_prefers']

column_params = {
    'v2': {'n_cats': 5, 'labels': ['Least Similar', '', ' ', '   ', 'Most Similar']},
    'it': {'n_cats': 5, 'labels': ['Least Similar', '', ' ', '   ', 'Most Similar']}
}

for label in ['it_sim_dis_attend', 'v2_sim_dis_attend', 'it_sim_dis_unattend', 'v2_sim_dis_unattend', 'it_sim_dis_diff', 'v2_sim_dis_diff', 'it_im1_im2', 'v2_im1_im2', 'it_sim_dis_test', 'v2_sim_dis_test', 'it_sim_dis_untest', 'v2_sim_dis_untest', 'it_sim_dis_diff_test', 'v2_sim_dis_diff_test', 'v2_sim_dis_diff_sq', 'it_sim_dis_diff_sq', 'v2_sim_dis_diff_test_sq','it_sim_dis_diff_test_sq']:
    
    if 'v2' in label:
        n_cats = column_params['v2']['n_cats']
        labels = column_params['v2']['labels']
    else:
        n_cats = column_params['it']['n_cats']
        labels = column_params['it']['labels']
    
    df[label + '_cat'] = pd.qcut(df[label], q=n_cats, labels=labels, duplicates='drop')


df['V2 Distractor Similarity\nto Prioritized Item'] = df['v2_sim_dis_attend_cat']
df['IT Distractor Similarity\nto Prioritized Item'] = df['it_sim_dis_attend_cat']
df['V2 Distractor Similarity\nto Deprioritized Item'] = df['v2_sim_dis_unattend_cat']
df['IT Distractor Similarity\nto Deprioritized Item'] = df['it_sim_dis_unattend_cat']
df['Prioritized - Deprioritized IT Distractor Similarity'] = df['it_sim_dis_diff_cat'] 
df['Prioritized - Deprioritized V2 Distractor Similarity'] = df['v2_sim_dis_diff_cat'] 
df['Prioritized - Deprioritized IT Distractor Similarity Squared'] = df['v2_sim_dis_diff_sq_cat'] 
df['Prioritized - Deprioritized V2 Distractor Similarity Squared'] = df['it_sim_dis_diff_sq_cat'] 


df['V2 Distractor Similarity\nto Tested Item'] = df['v2_sim_dis_test_cat']
df['IT Distractor Similarity\nto Tested Item'] = df['it_sim_dis_test_cat']
df['V2 Distractor Similarity\nto Untested Item'] = df['v2_sim_dis_untest_cat']
df['IT Distractor Similarity\nto Untested Item'] = df['it_sim_dis_untest_cat']
df['Tested - Untested IT Distractor Similarity'] = df['it_sim_dis_diff_test_cat'] 
df['Tested - Untested V2 Distractor Similarity'] = df['v2_sim_dis_diff_test_cat'] 
df['Tested - Untested IT Distractor Similarity Squared'] = df['v2_sim_dis_diff_test_sq_cat'] 
df['Tested - Untested V2 Distractor Similarity Squared'] = df['it_sim_dis_diff_test_sq_cat']

# %%
df['tested_item'] = df['Tested Item']
df['ret_rel'] = df['Retrocue Reliability']

# %%
# df_correct = df[df['resp_correct'] == 1]

# %%
df['it_sim_dis_diff'] = df['it_sim_dis_diff'] - np.mean(df['it_sim_dis_diff'])
df['v2_sim_dis_diff'] = df['v2_sim_dis_diff'] - np.mean(df['v2_sim_dis_diff'])

df['it_sim_dis_diff_test'] = df['it_sim_dis_diff_test'] - np.mean(df['it_sim_dis_diff_test'])
df['v2_sim_dis_diff_test'] = df['v2_sim_dis_diff_test'] - np.mean(df['v2_sim_dis_diff_test'])

df['it_sim_dis_diff_test_sq'] = [x**2 for x in df['it_sim_dis_diff_test']]
df['v2_sim_dis_diff_test_sq'] = [x**2 for x in df['v2_sim_dis_diff_test']]

df['it_sim_dis_diff_sq'] = [x**2 for x in df['it_sim_dis_diff']]
df['v2_sim_dis_diff_sq'] = [x**2 for x in df['v2_sim_dis_diff']]


df['it_sim_dis_diff_sq'] = df['it_sim_dis_diff_sq'] - np.mean(df['it_sim_dis_diff_sq'])
df['v2_sim_dis_diff_sq'] = df['v2_sim_dis_diff_sq'] - np.mean(df['v2_sim_dis_diff_sq'])

df['it_sim_dis_diff_test_sq'] = df['it_sim_dis_diff_test_sq'] - np.mean(df['it_sim_dis_diff_test_sq'])
df['v2_sim_dis_diff_test_sq'] = df['v2_sim_dis_diff_test_sq'] - np.mean(df['v2_sim_dis_diff_test_sq'])


df['IT_diff_binned'] = pd.qcut(df['it_sim_dis_diff'], 5, duplicates='drop')
df['V2_diff_binned'] = pd.qcut(df['v2_sim_dis_diff'], 5, duplicates='drop')
df['IT_diff_binned_sq'] = pd.qcut(df['it_sim_dis_diff_sq'], 5, duplicates='drop')
df['V2_diff_binned_sq'] = pd.qcut(df['v2_sim_dis_diff_sq'], 5, duplicates='drop')


df['IT_diff_binned_test'] = pd.qcut(df['it_sim_dis_diff_test'], 5, duplicates='drop')
df['V2_diff_binned_test'] = pd.qcut(df['v2_sim_dis_diff_test'], 5, duplicates='drop')
df['IT_diff_binned_test_sq'] = pd.qcut(df['it_sim_dis_diff_test_sq'], 5, duplicates='drop')
df['V2_diff_binned_test_sq'] = pd.qcut(df['v2_sim_dis_diff_test_sq'], 5, duplicates='drop')

def round_to_significant_figures(x, sig_figs=2):
    if x == 0:
        return 0
    else:
        return round(x, sig_figs - int(np.floor(np.log10(abs(x)))) - 1)


def process_interval(interval):
    # Round both bounds
    lower_rounded = round_to_significant_figures(interval.left)
    upper_rounded = round_to_significant_figures(interval.right)
    # Return a new interval with the rounded bounds
    return pd.Interval(lower_rounded, upper_rounded)

df['IT_diff_binned'] = df['IT_diff_binned'].apply(process_interval)
df['V2_diff_binned'] = df['V2_diff_binned'].apply(process_interval)
df['IT_diff_binned_sq'] = df['IT_diff_binned_sq'].apply(process_interval)
df['V2_diff_binned_sq'] = df['V2_diff_binned_sq'].apply(process_interval)

df['IT_diff_binned_test'] = df['IT_diff_binned_test'].apply(process_interval)
df['V2_diff_binned_test'] = df['V2_diff_binned_test'].apply(process_interval)
df['IT_diff_binned_test_sq'] = df['IT_diff_binned_test_sq'].apply(process_interval)
df['V2_diff_binned_test_sq'] = df['V2_diff_binned_test_sq'].apply(process_interval)

df['Prioritized - Deprioritized V2 Distractor Similarity Ranges'] = df['V2_diff_binned']
df['Prioritized - Deprioritized IT Distractor Similarity Ranges'] = df['IT_diff_binned']
df['Prioritized - Deprioritized V2 Distractor Similarity Squared Ranges'] = df['V2_diff_binned_sq']
df['Prioritized - Deprioritized IT Distractor Similarity Squared Ranges'] = df['IT_diff_binned_sq']

df['Tested - Untested V2 Distractor Similarity Ranges'] = df['V2_diff_binned_test']
df['Tested - Untested IT Distractor Similarity Ranges'] = df['IT_diff_binned_test']
df['Tested - Untested V2 Distractor Similarity Squared Ranges'] = df['V2_diff_binned_test_sq']
df['Tested - Untested IT Distractor Similarity Squared Ranges'] = df['IT_diff_binned_test_sq']

# %%
df['V2 Distractor Similarity to Tested Item'] = df['v2_sim_dis_test_z']
df['IT Distractor Similarity to Tested Item'] = df['it_sim_dis_test_z']
df['Tested - Untested V2 Distractor Similarity'] = df['v2_sim_dis_diff_test_z']
df['Tested - Untested IT Distractor Similarity'] = df['it_sim_dis_diff_test_z']


# df['V2 Distractor Similarity to LTM Item'] = df['v2_sim_dis_test_z']
# df['IT Distractor Similarity to LTM Item'] = df['it_sim_dis_test_z']
# df['LTM - NonLTM V2 Distractor Similarity'] = df['v2_sim_dis_diff_test_z']
# df['LTM - NonLTM IT Distractor Similarity'] = df['it_sim_dis_diff_test_z']

# %%
# Add a new column 'category' to df with all conditions
df['category'] = df.apply(
    lambda row: 'distractor' if row['ImagePath'] == row['ping_img']
    else ('foil' if 'foil' in str(row['ImagePath']).lower()
          else ('tested' if ((row['ImagePath'] == row['img1'] and row['test_item'] == 'img1') or 
                             (row['ImagePath'] == row['img2'] and row['test_item'] == 'img2'))
                else 'not tested')),
    axis=1
)

# %%
# df_filtered['category']

# %%
df['mem_stim_type'] = df.apply(
    lambda row: 'distractor' if row['ImagePath'] == row['ping_img']
    else  (('tested' if ((row['ImagePath'] == row['img1'] and row['test_item'] == 'img1') or 
                             (row['ImagePath'] == row['img2'] and row['test_item'] == 'img2'))
                else 'not tested')),
    axis=1
)

# %%
df['Tested'] = df['mem_stim_type']

# %%
df['Attend'] = df.apply(
    lambda row: 'distractor' if row['ImagePath'] == row['ping_img']
    else 'foil' if (row['category']== 'foil')
    else 'attended' if ((row['ImagePath'] == row['img1'] and row['attend'] == 'img1') or 
                             (row['ImagePath'] == row['img2'] and row['attend'] == 'img2'))
    else 'not attended',
    axis=1
)

# %%
def calculate_ltm_reliability(row):
    if (row['category']== 'foil'):
        return 'foil'
    elif row['reliability'] > 0.7:
        return 'high'
    elif row['reliability'] < 0.7:
        return 'low'
    
    else:
        return None  # Optional: Default case, if needed

# Apply the function to the dataframe
df['Reliability'] = df.apply(calculate_ltm_reliability, axis=1)

# %%
scaler = StandardScaler()

df['reliability_binary'] = np.where(df['Reliability'] == 'low', -1 , 1)
df['tested_binary'] =  np.where(df['Tested'] == 'tested', -1 , 1)
df['priority_binary'] =  np.where(df['Tested Item'] == 'prioritized', -1 , 1)
df['reliability_binary_z'] = scaler.fit_transform(df[['reliability_binary']])
df['tested_binary_z'] = scaler.fit_transform(df[['tested_binary']])
df['priority_binary_z'] = scaler.fit_transform(df[['priority_binary']])

# %%
df_distractor = df[df['category'] == 'distractor']

# %%
df['attend_binary'] = np.where(df['Attend'] == 'attended', -1 , 1)
df['attend_binary_z'] = scaler.fit_transform(df[['attend_binary']])

# %%
df_filtered = df[(df['category'] == 'tested') | (df['category'] == 'not tested')]

# %%
df_filtered['Tested Item'] #just wm testedness
# Out:
# 3          prioritized
# 10         prioritized
# 16         prioritized
# 18       deprioritized
# 26         prioritized
#              ...
# 32760      prioritized
# 32763    deprioritized
# 32765      prioritized
# 32773    deprioritized
# 32777    deprioritized
# Name: Tested Item, Length: 10489, dtype: object

# %%
df_filtered['Attend'] # if ltm was attended in wm
# Out:
# 3        not attended
# 10       not attended
# 16           attended
# 18       not attended
# 26       not attended
#              ...
# 32760    not attended
# 32763        attended
# 32765        attended
# 32773    not attended
# 32777    not attended
# Name: Attend, Length: 10489, dtype: object

# %%
df_filtered['Tested'] # if ltm was tested in wm
# Out:
# 3        not tested
# 10       not tested
# 16           tested
# 18           tested
# 26       not tested
#             ...
# 32760    not tested
# 32763    not tested
# 32765        tested
# 32773        tested
# 32777        tested
# Name: Tested, Length: 10489, dtype: object

# %%
#if ltm item was not tested in wm we need to update it and v2
#'V2 Distractor Similarity to LTM Item'
#'IT Distractor Similarity to LTM Item'
#'LTM - NonLTM V2 Distractor Similarity'
#'LTM - NonLTM IT Distractor Similarity'

# %%
df_filtered['ImagePath']
# Out:
# 3        ./stimuli/216_3.jpg
# 10        ./stimuli/83_3.jpg
# 16        ./stimuli/30_2.jpg
# 18        ./stimuli/73_2.jpg
# 26        ./stimuli/55_2.jpg
#                 ...
# 32760    ./stimuli/294_2.jpg
# 32763      ./stimuli/1_3.jpg
# 32765    ./stimuli/195_2.jpg
# 32773    ./stimuli/141_2.jpg
# 32777     ./stimuli/67_2.jpg
# Name: ImagePath, Length: 10489, dtype: object

# %%
# if df_filtered['Tested'] == 'not tested':
#     df_filtered['it_sim_dis_test'] = np.where(df_filtered['test_item'] == 'img1', df_filtered['IT_root_im1'], dataframe['IT_root_im2'])
#     df_filtered['v2_sim_dis_test'] = np.where(df_filtered['test_item'] == 'img1', df_filtered['V2_root_im1'], dataframe['V2_root_im2'])

    
    
df_filtered['it_ltm'] = df_filtered.apply(
    lambda row: 'distractor' if row['ImagePath'] == row['ping_img'] else (
        row['IT_root_im1'] if (row['ImagePath'] == row['img1']) else (
            row['IT_root_im2'] if (row['ImagePath'] == row['img2'] ) else 
            'not tested'
        )
    ),
    axis=1
)
    
df_filtered['v2_ltm'] = df_filtered.apply(
    lambda row: 'distractor' if row['ImagePath'] == row['ping_img'] else (
        row['V2_root_im1'] if (row['ImagePath'] == row['img1']) else (
            row['V2_root_im2'] if (row['ImagePath'] == row['img2'] ) else 
            'not tested'
        )
    ),
    axis=1
)
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3728465708.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm'] = df_filtered.apply(
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3728465708.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm'] = df_filtered.apply(

# %%
    
df_filtered['it_ltm_diff'] = df_filtered.apply(
    lambda row: 'distractor' if row['ImagePath'] == row['ping_img'] else (
        (row['IT_root_im1'] - row['IT_root_im2']) if (row['ImagePath'] == row['img1']) else (
        (row['IT_root_im2'] - row['IT_root_im1']) if (row['ImagePath'] == row['img2'] ) else 
            'not tested'
        )
    ),
    axis=1
)

    
df_filtered['v2_ltm_diff'] = df_filtered.apply(
    lambda row: 'distractor' if row['ImagePath'] == row['ping_img'] else (
        (row['V2_root_im1'] - row['V2_root_im2']) if (row['ImagePath'] == row['img1']) else (
        (row['V2_root_im2'] - row['V2_root_im1']) if (row['ImagePath'] == row['img2'] ) else 
            'not tested'
        )
    ),
    axis=1
)
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1284417044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_diff'] = df_filtered.apply(
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1284417044.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_diff'] = df_filtered.apply(

# %%
# Ensure the column is numeric
df_filtered[label] = pd.to_numeric(df_filtered[label], errors='coerce')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/777402126.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[label] = pd.to_numeric(df_filtered[label], errors='coerce')

# %%
column_params = {
    'v2': {'n_cats': 5, 'labels': ['Least Similar', '', ' ', '   ', 'Most Similar']},
    'it': {'n_cats': 5, 'labels': ['Least Similar', '', ' ', '   ', 'Most Similar']}
}

for label in ['it_ltm', 'v2_ltm', 'it_ltm_diff', 'v2_ltm_diff']:
    
    if 'v2' in label:
        n_cats = column_params['v2']['n_cats']
        labels = column_params['v2']['labels']
    else:
        n_cats = column_params['it']['n_cats']
        labels = column_params['it']['labels']
    
    df_filtered[label + '_cat'] = pd.qcut(df_filtered[label], q=n_cats, labels=labels, duplicates='drop')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3918125177.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[label + '_cat'] = pd.qcut(df_filtered[label], q=n_cats, labels=labels, duplicates='drop')
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3918125177.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[label + '_cat'] = pd.qcut(df_filtered[label], q=n_cats, labels=labels, duplicates='drop')
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3918125177.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[label + '_cat'] = pd.qcut(df_filtered[label], q=n_cats, labels=labels, duplicates='drop')
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3918125177.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[label + '_cat'] = pd.qcut(df_filtered[label], q=n_cats, labels=labels, duplicates='drop')

# %%
# print(df_filtered['it_ltm_diff'].isna())
# print("Column type:", df_filtered['it_ltm_diff'].dtype)
# print("Column values (sample):", df_filtered['it_ltm_diff'].head())
# df_filtered[df_filtered['it_ltm'].isna()== True]
# 168889

# %%
df_filtered['V2 Distractor Similarity\nto LTM Item'] = df_filtered['v2_ltm_cat']
df_filtered['IT Distractor Similarity\nto LTM Item'] = df_filtered['it_ltm_cat']
df_filtered['LTM - NonLTM V2 Distractor Similarity Ranges'] = df_filtered['v2_ltm_diff_cat']
df_filtered['LTM - NonLTM IT Distractor Similarity Ranges'] = df_filtered['it_ltm_diff_cat']



df_filtered['v2_ltm'] = df_filtered['v2_ltm'] - np.mean(df_filtered['v2_ltm'])
df_filtered['it_ltm'] = df_filtered['it_ltm'] - np.mean(df_filtered['it_ltm'])
df_filtered['v2_ltm_diff'] = df_filtered['v2_ltm_diff'] - np.mean(df_filtered['v2_ltm_diff'])
df_filtered['it_ltm_diff'] = df_filtered['it_ltm_diff'] - np.mean(df_filtered['it_ltm_diff'])



df_filtered['v2_ltm_sq'] = [x**2 for x in df_filtered['v2_ltm']]
df_filtered['it_ltm_sq'] = [x**2 for x in df_filtered['it_ltm']]
df_filtered['v2_ltm_diff_sq'] = [x**2 for x in df_filtered['v2_ltm_diff']]
df_filtered['it_ltm_diff_sq'] = [x**2 for x in df_filtered['it_ltm_diff']]

df_filtered['v2_ltm_sq'] = df_filtered['v2_ltm_sq'] - np.mean(df_filtered['v2_ltm_sq'])
df_filtered['it_ltm_sq'] = df_filtered['it_ltm_sq'] - np.mean(df_filtered['it_ltm_sq'])
df_filtered['v2_ltm_diff_sq'] = df_filtered['v2_ltm_diff_sq'] - np.mean(df_filtered['v2_ltm_diff_sq'])
df_filtered['it_ltm_diff_sq'] = df_filtered['it_ltm_diff_sq'] - np.mean(df_filtered['it_ltm_diff_sq'])

scaler = StandardScaler()

df_filtered['v2_ltm_z'] = scaler.fit_transform(df_filtered[['v2_ltm']])
df_filtered['it_ltm_z'] = scaler.fit_transform(df_filtered[['it_ltm']])
df_filtered['v2_ltm_diff_z'] = scaler.fit_transform(df_filtered[['v2_ltm_diff']])
df_filtered['it_ltm_diff_z'] = scaler.fit_transform(df_filtered[['it_ltm_diff']])
df_filtered['v2_ltm_sq_z'] = scaler.fit_transform(df_filtered[['v2_ltm_sq']])
df_filtered['it_ltm_sq_z'] = scaler.fit_transform(df_filtered[['it_ltm_sq']])
df_filtered['v2_ltm_diff_sq_z'] = scaler.fit_transform(df_filtered[['v2_ltm_diff_sq']])
df_filtered['it_ltm_diff_sq_z'] = scaler.fit_transform(df_filtered[['it_ltm_diff_sq']])
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['V2 Distractor Similarity\nto LTM Item'] = df_filtered['v2_ltm_cat']
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['IT Distractor Similarity\nto LTM Item'] = df_filtered['it_ltm_cat']
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['LTM - NonLTM V2 Distractor Similarity Ranges'] = df_filtered['v2_ltm_diff_cat']
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['LTM - NonLTM IT Distractor Similarity Ranges'] = df_filtered['it_ltm_diff_cat']
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm'] = df_filtered['v2_ltm'] - np.mean(df_filtered['v2_ltm'])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm'] = df_filtered['it_ltm'] - np.mean(df_filtered['it_ltm'])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_diff'] = df_filtered['v2_ltm_diff'] - np.mean(df_filtered['v2_ltm_diff'])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_diff'] = df_filtered['it_ltm_diff'] - np.mean(df_filtered['it_ltm_diff'])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_sq'] = [x**2 for x in df_filtered['v2_ltm']]
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_sq'] = [x**2 for x in df_filtered['it_ltm']]
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_diff_sq'] = [x**2 for x in df_filtered['v2_ltm_diff']]
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_diff_sq'] = [x**2 for x in df_filtered['it_ltm_diff']]
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_sq'] = df_filtered['v2_ltm_sq'] - np.mean(df_filtered['v2_ltm_sq'])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_sq'] = df_filtered['it_ltm_sq'] - np.mean(df_filtered['it_ltm_sq'])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_diff_sq'] = df_filtered['v2_ltm_diff_sq'] - np.mean(df_filtered['v2_ltm_diff_sq'])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_diff_sq'] = df_filtered['it_ltm_diff_sq'] - np.mean(df_filtered['it_ltm_diff_sq'])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_z'] = scaler.fit_transform(df_filtered[['v2_ltm']])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_z'] = scaler.fit_transform(df_filtered[['it_ltm']])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_diff_z'] = scaler.fit_transform(df_filtered[['v2_ltm_diff']])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_diff_z'] = scaler.fit_transform(df_filtered[['it_ltm_diff']])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_sq_z'] = scaler.fit_transform(df_filtered[['v2_ltm_sq']])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_sq_z'] = scaler.fit_transform(df_filtered[['it_ltm_sq']])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['v2_ltm_diff_sq_z'] = scaler.fit_transform(df_filtered[['v2_ltm_diff_sq']])
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3733209217.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['it_ltm_diff_sq_z'] = scaler.fit_transform(df_filtered[['it_ltm_diff_sq']])

# %%
df_filtered['LTM - NonLTM V2 Distractor Similarity'] = df_filtered['v2_ltm_diff_z']
df_filtered['LTM - NonLTM IT Distractor Similarity'] = df_filtered['it_ltm_diff_z']
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/339811994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['LTM - NonLTM V2 Distractor Similarity'] = df_filtered['v2_ltm_diff_z']
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/339811994.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['LTM - NonLTM IT Distractor Similarity'] = df_filtered['it_ltm_diff_z']

# %%
df_filtered['it_ltm_diff_sq_z']
# Out:
# 3       -1.021010
# 10       1.402818
# 16      -0.798559
# 18       0.529467
# 26      -0.257535
#            ...
# 32760    1.550982
# 32763   -1.131468
# 32765    1.592172
# 32773   -0.519390
# 32777    0.142533
# Name: it_ltm_diff_sq_z, Length: 10489, dtype: float64

# %%
df_filtered['V2_root_im2']
# Out:
# 3        0.003851
# 10       0.098467
# 16       0.051605
# 18       0.056941
# 26       0.079077
#            ...
# 32760    0.098212
# 32763    0.059349
# 32765    0.145103
# 32773    0.067509
# 32777    0.004508
# Name: V2_root_im2, Length: 10489, dtype: float64

# %%
df_filtered['v2_ltm']
# Out:
# 3       -0.067490
# 10       0.027125
# 16      -0.037111
# 18       0.042885
# 26       0.094489
#            ...
# 32760   -0.045852
# 32763   -0.011993
# 32765   -0.025792
# 32773   -0.031388
# 32777    0.052973
# Name: v2_ltm, Length: 10489, dtype: float64

# %%
df_distractor = df[df['category'] == 'distractor']

# %%
palette = sns.color_palette("husl", n_colors=2)[::-1]  # Reverse the color order

# %%
df_filtered['V2 Distractor Similarity\nto Tested Item']
# Out:
# 3        Most Similar
# 10       Most Similar
# 16
# 18
# 26
#              ...
# 32760
# 32763
# 32765
# 32773
# 32777    Most Similar
# Name: V2 Distractor Similarity\nto Tested Item, Length: 10489, dtype: category
# Categories (5, object): ['Least Similar' < '' < ' ' < '   ' < 'Most Similar']

# %%
df_filtered['V2 Distractor Similarity\nto LTM Item']
# Out:
# 3        Least Similar
# 10
# 16
# 18
# 26        Most Similar
#              ...
# 32760
# 32763
# 32765
# 32773
# 32777     Most Similar
# Name: V2 Distractor Similarity\nto LTM Item, Length: 10489, dtype: category
# Categories (5, object): ['Least Similar' < '' < ' ' < '   ' < 'Most Similar']

# %%
g = sns.catplot(
            x = 'Retrocue Reliability',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
            # col = 'Retrocue Reliability',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
            palette = palette[::-1],  # Reverse the color order
            data = df_distractor)
g.set(ylim=(0, 0.85))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3175656336.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(96.08554487179485, 0.5, 'Accuracy')

# %%
df_filtered['V2 Distractor Similarity to LTM Item'] = df_filtered['v2_ltm_z']
df_filtered['IT Distractor Similarity to LTM Item'] = df_filtered['it_ltm_z']

df_filtered['V2 Distractor Similarity to LTM Item'] = df_filtered['v2_ltm_z']
df_filtered['IT Distractor Similarity to LTM Item'] = df_filtered['it_ltm_z']
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1239251767.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['V2 Distractor Similarity to LTM Item'] = df_filtered['v2_ltm_z']
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1239251767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['IT Distractor Similarity to LTM Item'] = df_filtered['it_ltm_z']
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1239251767.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['V2 Distractor Similarity to LTM Item'] = df_filtered['v2_ltm_z']
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1239251767.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['IT Distractor Similarity to LTM Item'] = df_filtered['it_ltm_z']

# %%
df_filtered_corr = df_filtered[df_filtered['resp_correct'] == 1.0]

# %%
g = sns.catplot(
            x = 'V2 Distractor Similarity\nto LTM Item',
            y = 'recall_answ',
            ci = 68,
#             hue = 'Tested Item',
            col = 'Retrocue Reliability',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_filtered_corr)
g.set(ylim=(0.55, 0.85))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/2867379924.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(681.5937500000001, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'V2 Distractor Similarity\nto LTM Item',
            y = 'recall_answ',
            ci = 68,
#             hue = 'Attend',
#             col = 'Tested',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_filtered_corr)
g.set(ylim=(0.7, 0.85))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/230173215.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(6.819444444444445, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'IT Distractor Similarity\nto LTM Item',
            y = 'recall_answ',
            ci = 68,
#             hue = 'Attend',
#             col = 'Tested',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_filtered_corr)
g.set(ylim=(0.7, 0.85))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1551066893.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(6.819444444444445, 0.5, 'Accuracy')

# %%
# plt.figure(figsize=(10, 6))
# sns.lmplot(
#     x='IT Distractor Similarity to LTM Item',
#     y='recall_answ',
#     hue = 'Tested Item',
#     row = 'Retrocue Reliability',
#     x_bins = 7,
#     order = 2,
#     ci = 68,
#     palette = palette[::-1],  # Reverse the color order
#     data=df_filtered_corr
# )
# plt.ylabel('Accuracy')

# %%
# plt.figure(figsize=(10, 6))
# sns.lmplot(
#     x='V2 Distractor Similarity to LTM Item',
#     y='recall_answ',
#     hue = 'Tested Item',
#     row = 'Retrocue Reliability',
#     x_bins = 7,
#     order = 2,
#     ci = 68,
#     palette = palette[::-1],  # Reverse the color order
#     data=df_filtered_corr
# )
# plt.ylabel('Accuracy')

# %%
# plt.figure(figsize=(10, 6))
# sns.lmplot(
#     x='LTM - NonLTM V2 Distractor Similarity',
#     y='recall_answ',
#     hue = 'Tested Item',
#     row = 'Retrocue Reliability',
#     x_bins = 7,
#     order = 2,
#     ci = 68,
#     palette = palette[::-1],  # Reverse the color order
#     data=df_filtered_corr
# )
# plt.ylabel('Accuracy')

# %%
# g = sns.lmplot(
#     x='LTM - NonLTM IT Distractor Similarity',
#     y='recall_answ',
#     hue='Tested Item',
# #     row='Retrocue Reliability', 
#     x_bins=20,  # Increase number of bins
#     height=4,   # Reduce height
#     aspect=1.5, # Control width/height ratio
#     order=2,
#     ci=68,
#     palette=palette[::-1],
#     data=df_filtered_corr
# )

# %%
df_distractor_correct_wm = df_distractor[
    ((df_distractor['resp_correct'] == 1))
]

# %%
g = sns.catplot(
            x = 'IT Distractor Similarity\nto Tested Item',
            y = 'recall_answ',
            ci = 68,
#             hue = 'Retrocue Reliability',
#             row_order = ['low', 'high'],
#             hue = 'Tested Item',
#             col = 'Attend',
        
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             palette = palette,  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/168137919.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(6.819444444444445, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x =  'Tested - Untested IT Distractor Similarity Ranges',
            y = 'recall_answ',
            ci = 68,
#             row = 'Retrocue Reliability',
#             row_order = ['low', 'high'],
#             hue = 'Tested Item',
#             col = 'Attend',
        
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             palette = palette,  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3728610853.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(-7.805555555555555, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'V2 Distractor Similarity\nto Tested Item',
            y = 'recall_answ',
            ci = 68,
#             row = 'Retrocue Reliability',
#             row_order = ['low', 'high'],
#             hue = 'Tested Item',        
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             palette = palette,  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/2762645344.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(6.819444444444445, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x =  'Tested - Untested V2 Distractor Similarity Ranges',
            y = 'recall_answ',
            ci = 68,
#             hue = 'Retrocue Reliability',
#             row_order = ['low', 'high'],
#             hue = 'Tested Item',
#             col = 'Attend',
        
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             palette = palette,  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/4206239782.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(6.819444444444445, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'IT Distractor Similarity\nto Prioritized Item',
            y = 'recall_answ',
            ci = 68,
            row = 'Retrocue Reliability',
            row_order = ['low', 'high'],
            hue = 'Tested Item',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
            palette = palette[::-1],  # Reverse the color order
#             palette = palette,  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/2050625006.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(96.08554487179485, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'Prioritized - Deprioritized IT Distractor Similarity Ranges',
            y = 'recall_answ',
            ci = 68,
            hue = 'Retrocue Reliability',
#             row_order = ['low', 'high'],
#             hue = 'Tested Item',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            palette = palette,  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/4291898301.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(102.55563034188033, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'V2 Distractor Similarity\nto Prioritized Item',
            y = 'recall_answ',
            ci = 68,
            hue = 'Retrocue Reliability',
#             row_order = ['low', 'high'],
#             hue = 'Tested Item',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            palette = palette,  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/14780931.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(102.55563034188033, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'Prioritized - Deprioritized V2 Distractor Similarity Ranges',
            y = 'recall_answ',
            ci = 68,
#             row = 'Retrocue Reliability',
#             row_order = ['low', 'high'],
            hue = 'Tested Item',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
            palette = palette[::-1],  # Reverse the color order
#             palette = palette,  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/2917089961.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(101.19585737179487, 0.5, 'Accuracy')

# %%
df_correct_wm = df_filtered[
    ((df_filtered['resp_correct'] == 1))
]

# %%
# g = sns.catplot(
#     x='IT Distractor Similarity\nto LTM Item',
#     y='recall_answ',
#     ci=68,
#     hue ='Tested',
#     row = 'Attend',
#     col_order = ['low', 'high'],
#     row_order = ['not attended', 'attended'],
#     col='Retrocue Reliability',
#     aspect=1.3,
#     dodge=0.1,
#     kind='point',
#     palette=palette,  # Reverse the color order
#     data=df_correct_wm,

# )

# g.set(ylim=(0.45, 1))
# g.set_ylabels('Accuracy')
# g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing
# plt.show()

g = sns.catplot(
    x='IT Distractor Similarity\nto LTM Item',
    y='recall_answ',
    ci=68,
    row ='Tested',
    hue = 'Attend',
#     col_order = ['low', 'high'],
#     row_order = ['not tested', 'tested'],
    
#     col='Retrocue Reliability',
    aspect=1.3,
    dodge=0.1,
    kind='point',
    palette=palette,  # Reverse the color order
    data=df_correct_wm,

)

g.set(ylim=(0.6, 0.9))
g.set_ylabels('Accuracy')
g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing
plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1204743583.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
g = sns.catplot(
    x='LTM - NonLTM IT Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    row ='Tested',
    hue = 'Attend',
    col_order = ['low', 'high'],
    row_order = ['not tested', 'tested'],
    col='Retrocue Reliability',
    
    aspect=1.3,
    dodge=0.1,
    kind='point',
    palette=palette,  # Reverse the color order
    data=df_correct_wm,

)

g.set(ylim=(0.45, 1))
g.set_ylabels('Accuracy')
g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing
plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/595050120.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
g = sns.catplot(
    x='V2 Distractor Similarity\nto LTM Item',
    y='recall_answ',
    ci=68,
    row ='Tested',
    hue = 'Attend',
    col_order = ['low', 'high'],
    row_order = ['not tested', 'tested'],
    col='Retrocue Reliability',
    
    aspect=1.3,
    dodge=0.1,
    kind='point',
    palette=palette,  # Reverse the color order
    data=df_correct_wm,

)

g.set(ylim=(0.45, 1))
g.set_ylabels('Accuracy')
g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing
plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3787133267.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
g = sns.catplot(
    x='LTM - NonLTM V2 Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    row ='Tested',
    hue = 'Attend',
    col_order = ['low', 'high'],
    row_order = ['not tested', 'tested'],
    col='Retrocue Reliability',
    aspect=1.3,
    dodge=0.1,
    kind='point',
    palette=palette,  # Reverse the color order
    data=df_correct_wm,

)

g.set(ylim=(0.45, 1))
g.set_ylabels('Accuracy')
g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing
plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/4248248327.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
### When the seen image was validly tested

# %%
# df['attend']

# %%
# df['Attend']

# %%
# df['Attend Inc'] = df.apply(
#     lambda row: 'distractor' if row['ImagePath'] == row['ping_img']
#     else 'foil' if (row['category']== 'not attended')
#     else 'attended' if ((row['ImagePath'] == row['img1'] and row['attend'] == 'img1') or 
#                              (row['ImagePath'] == row['img2'] and row['attend'] == 'img2'))
#     else 'not attended',
#     axis=1
# )

# %%
unique_values = df['Attend'].unique()
unique_values
# Out:
# array(['foil', 'not attended', 'distractor', 'attended'], dtype=object)

# %%
# df['Reliability']

# %%
unique_values = df_filtered['Reliability'].unique()
print(unique_values)
# Out:
# ['high' 'low']

# %%
df_correct_wm = df_filtered[
    ((df_filtered['resp_correct'] == 1))
]

# df_correct_wm = df[
#     ((df['resp_correct'] == 1) | (df['category'] == 'foil') | (df['category'] == 'distractor'))
# ]

df_incorrect_wm = df_filtered[
    ((df_filtered['resp_correct'] == 0))
]

# %%
df_incorrect_wm
# Out:
#        setup_js.started  setup_js.stopped  participant  \
# 16                  NaN               NaN       165862
# 29                  NaN               NaN       165862
# 77                  NaN               NaN       165862
# 80                  NaN               NaN       165862
# 81                  NaN               NaN       165862
# ...                 ...               ...          ...
# 32681               NaN               NaN       167431
# 32690               NaN               NaN       167431
# 32698               NaN               NaN       167431
# 32701               NaN               NaN       167431
# 32734               NaN               NaN       167431
#
#                           date     expName psychopyVersion        OS  \
# 16     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 29     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 77     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 80     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 81     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# ...                        ...         ...             ...       ...
# 32681  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32690  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32698  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32701  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32734  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
#
#        frameRate  Instructions1.started  Instructions1.stopped  ...  \
# 16      59.88024                    NaN                    NaN  ...
# 29      59.88024                    NaN                    NaN  ...
# 77      59.88024                    NaN                    NaN  ...
# 80      59.88024                    NaN                    NaN  ...
# 81      59.88024                    NaN                    NaN  ...
# ...          ...                    ...                    ...  ...
# 32681   62.50000                    NaN                    NaN  ...
# 32690   62.50000                    NaN                    NaN  ...
# 32698   62.50000                    NaN                    NaN  ...
# 32701   62.50000                    NaN                    NaN  ...
# 32734   62.50000                    NaN                    NaN  ...
#
#        v2_ltm_diff_z  it_ltm_diff_z  v2_ltm_sq_z  it_ltm_sq_z  \
# 16         -0.199773      -0.572157    -0.381412    -0.555444
# 29          0.744814      -0.113461    -0.663689     0.274825
# 77         -1.312477       1.007358     0.120157    -0.076905
# 80          1.596413       0.369870     3.879169    -0.814072
# 81          1.531099      -0.430040    -0.374504    -1.124548
# ...              ...            ...          ...          ...
# 32681      -0.931494       0.988249    -0.725158     2.160208
# 32690       1.464703       0.999918     1.868445    -0.206522
# 32698       1.133781       1.461569    -0.516539     1.558815
# 32701       1.597935       1.469843     0.791826     2.209473
# 32734      -0.118932       0.513686    -0.550230    -0.490528
#
#        v2_ltm_diff_sq_z  it_ltm_diff_sq_z  \
# 16            -1.137880         -0.798559
# 29            -0.527703         -1.171925
# 77             0.856405          0.017535
# 80             1.835291         -1.024793
# 81             1.593193         -0.967653
# ...                 ...               ...
# 32681         -0.156822         -0.027738
# 32690          1.357450         -0.000195
# 32698          0.338320          1.348886
# 32701          1.841054          1.377681
# 32734         -1.168415         -0.873935
#
#        LTM - NonLTM V2 Distractor Similarity  \
# 16                                 -0.199773
# 29                                  0.744814
# 77                                 -1.312477
# 80                                  1.596413
# 81                                  1.531099
# ...                                      ...
# 32681                              -0.931494
# 32690                               1.464703
# 32698                               1.133781
# 32701                               1.597935
# 32734                              -0.118932
#
#        LTM - NonLTM IT Distractor Similarity  \
# 16                                 -0.572157
# 29                                 -0.113461
# 77                                  1.007358
# 80                                  0.369870
# 81                                 -0.430040
# ...                                      ...
# 32681                               0.988249
# 32690                               0.999918
# 32698                               1.461569
# 32701                               1.469843
# 32734                               0.513686
#
#        V2 Distractor Similarity to LTM Item  \
# 16                                -0.696502
# 29                                 0.322577
# 77                                -1.078056
# 80                                 2.497332
# 81                                 0.703165
# ...                                     ...
# 32681                              0.145176
# 32690                              1.876779
# 32698                              0.550182
# 32701                              1.438375
# 32734                             -0.507168
#
#        IT Distractor Similarity to LTM Item
# 16                                -0.730147
# 29                                -1.109508
# 77                                 0.967139
# 80                                 0.561892
# 81                                -0.233985
# ...                                     ...
# 32681                              1.678030
# 32690                              0.909069
# 32698                              1.519960
# 32701                              1.690324
# 32734                              0.766604
#
# [2653 rows x 457 columns]

# %%
# df_filtered_correct_wm = df_correct_wm[df_correct_wm['category'].isin(['tested', 'not tested'])]

# # Create the catplot
# g = sns.catplot(
#     x='category',
#     y='recall_answ',
#     ci=68,
#     hue='Attend',
# #     col='Reliability',
#     aspect=1.3,
# #     dodge=0.1,
#     kind='bar',
# #     palette=palette,  # Reverse the color order
#     data=df,
#     order=['tested', 'not tested', 'foil', 'distractor'],  # Ensure correct x-axis order
#     hue_order=['attended', 'not attended', 'distractor', 'foil']  # Prioritize Tested Item categories
# )
# g.set_ylabels('Accuracy')

# # Set y-axis limits
# g.set(ylim=(0, 0.9))

# # Set y-axis label
# g

# %%
df_filtered_correct_wm = df_correct_wm[df_correct_wm['category'].isin(['tested', 'not tested'])]

# Create the catplot
g = sns.catplot(
    x='category',
    y='recall_answ',
    ci=68,
    hue='Attend',
    col='Reliability',
    aspect=1.3,
    dodge=0.1,
    kind='point',
    palette=palette,  # Reverse the color order
    data=df_correct_wm,
    order=['tested', 'not tested'],  # Ensure correct x-axis order
#     hue_order=tested_item_order  # Prioritize Tested Item categories
)
g.set_ylabels('Accuracy')

# Set y-axis limits
g.set(ylim=(0.4, 0.9))
g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing

# Set y-axis label
g
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/567762635.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
category_order = ['tested', 'not tested', 'foil', 'distractor']
df_filtered_incorrect_wm = df_incorrect_wm[df_incorrect_wm['category'].isin(['tested', 'not tested'])]

# Create the catplot
g = sns.catplot(
    x='category',
    y='recall_answ',
    ci=68,
    hue='Attend',
    col='Reliability',
    aspect=1.3,
    dodge=0.1,
    kind='point',
    palette=palette,  # Reverse the color order
    data=df_incorrect_wm,
    order=['tested', 'not tested']  # Ensure correct x-axis order
#     hue_order=tested_item_order  # Prioritize Tested Item categories
)

# Set y-axis limits
g.set(ylim=(0.35, 0.9))
g.fig.suptitle("Incorrect WM", y=1.05, fontsize=16)  # Adjust y for spacing

# Set y-axis label
g
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/305746289.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
# df_correct_tested = df_correct_wm[
#     ((df_correct_wm['category'] == 'tested')|(df_correct_wm['category'] == 'distractor'))
# ]

# df_correct_untested = df_correct_wm[
#     ((df_correct_wm['category'] == 'not tested')|(df_correct_wm['category'] == 'distractor'))

# ]

# df_incorrect_tested = df_incorrect_wm[
#     ((df_incorrect_wm['category'] == 'tested')|(df_incorrect_wm['category'] == 'distractor'))
# ]

# df_incorrect_untested = df_incorrect_wm[
#     ((df_incorrect_wm['category'] == 'not tested')|(df_incorrect_wm['category'] == 'distractor'))
# ]

# %%
# df_correct_tested['Prioritized - Deprioritized V2 Distractor Similarity Ranges']

# %%
# print(df_correct_tested['category'].unique())

# %%
attend_palette = {
    'distractor': '#FFC0CB',  # Blue
    'not attended': '#90D5FF',  # Orange
    'attended': '#301934',  # Green
}

# %%
# df_correct_tested

# %%
g = sns.catplot(
    x='LTM - NonLTM V2 Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    hue='Tested Item',
    col='Tested',
#     col='Retrocue Reliability',
    aspect=1.3,
#     dodge=0.1,
    kind='point',
#     palette=attend_palette,  # Reverse the color order
    data=df_correct_wm,

)

g.set(ylim=(0.25, 1))
g.set_ylabels('Accuracy')
g.set_xlabels('V2 Distractor Similarity Ranges')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')  # Adjust the angle and alignment of the labels

# Add a title
g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing

plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/373585094.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
g = sns.catplot(
    x='LTM - NonLTM V2 Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    hue='Attend',
    col='Tested',
#     col='Retrocue Reliability',
    aspect=1.3,
    dodge=0.1,
    kind='point',
#     palette=attend_palette,  # Reverse the color order
    data=df_correct_wm,
#     order=category_order,
#     hue_order=tested_item_order  # Prioritize Tested Item categories
    # Set the order of x-axis categories
)

g.set(ylim=(0.25, 1))
g.set_ylabels('Accuracy')
g.set_xlabels('V2 Distractor Similarity Ranges')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')  # Adjust the angle and alignment of the labels

# Add a title
g.fig.suptitle("Correct WM - Tested", y=1.05, fontsize=16)  # Adjust y for spacing

plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/981867469.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
g = sns.catplot(
    x='LTM - NonLTM IT Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    hue='Tested Item',
    col='Tested',
#     col='Retrocue Reliability',
    aspect=1.3,
    dodge=0.1,
    kind='point',
#     palette=attend_palette,  # Reverse the color order
    data=df_correct_wm,
#     order=category_order,
#     hue_order=tested_item_order  # Prioritize Tested Item categories
    # Set the order of x-axis categories
)

g.set(ylim=(0.25, 1))
g.set_ylabels('Accuracy')
g.set_xlabels('IT Distractor Similarity Ranges')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')  # Adjust the angle and alignment of the labels

# Add a title
g.fig.suptitle("Correct WM - Tested", y=1.05, fontsize=16)  # Adjust y for spacing

plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3600274909.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
g = sns.catplot(
    x='LTM - NonLTM IT Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    hue='Attend',
    col='Tested',
#     col='Retrocue Reliability',
    aspect=1.3,
    dodge=0.1,
    kind='point',
#     palette=attend_palette,  # Reverse the color order
    data=df_correct_wm,
#     order=category_order,
#     hue_order=tested_item_order  # Prioritize Tested Item categories
    # Set the order of x-axis categories
)

g.set(ylim=(0.25, 1))
g.set_ylabels('Accuracy')
g.set_xlabels('IT Distractor Similarity Ranges')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')  # Adjust the angle and alignment of the labels

# Add a title
g.fig.suptitle("Correct WM - Tested", y=1.05, fontsize=16)  # Adjust y for spacing

plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1821993159.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
df['resp_correct_within'].min()
# Out:
# -0.2227857142857143

# %%
g = sns.catplot(
    x='LTM - NonLTM V2 Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    hue='Attend',
#     col='Reliability',
#     col_order=['low', 'high'],
    aspect=1.3,
    dodge=0.1,
    kind='point',
    palette=attend_palette,  # Reverse the color order
    data=df_correct_wm,
#     order=category_order,
#     hue_order=tested_item_order  # Prioritize Tested Item categories
    # Set the order of x-axis categories
)

g.set(ylim=(0.25, 1))
g.set_ylabels('Accuracy')
g.set_xlabels('V2 Distractor Similarity Ranges')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')  # Adjust the angle and alignment of the labels

# Add a title
# g.fig.suptitle("Correct WM - Untested", y=1.05, fontsize=16)  # Adjust y for spacing

plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3906377813.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
# !pip install stargazer

# %%
g = sns.catplot(
    x='LTM - NonLTM V2 Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    hue='Attend',
#     col='Reliability',
#     col_order=['low', 'high'],
    aspect=1.3,
#     dodge=0.1,
    kind='point',
    palette=attend_palette,  # Reverse the color order
    data=df_incorrect_wm,
#     order=category_order,
#     hue_order=tested_item_order  # Prioritize Tested Item categories
    # Set the order of x-axis categories
)

g.set(ylim=(0.2, 1))
g.set_ylabels('Accuracy')
g.set_xlabels('V2 Distractor Similarity Ranges')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')  # Adjust the angle and alignment of the labels

# Add a title
# g.fig.suptitle("Incorrect WM - Tested", y=1.05, fontsize=16)  # Adjust y for spacing

plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3687212049.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
g = sns.catplot(
    x='LTM - NonLTM V2 Distractor Similarity Ranges',
    y='recall_answ',
    ci=68,
    hue='Attend',
#     col='Reliability',
#     col_order=['low', 'high'],
    
    aspect=1.3,
#     dodge=0.1,
    kind='point',
    palette=attend_palette,  # Reverse the color order
    data=df_incorrect_wm,
#     order=category_order,
#     hue_order=tested_item_order  # Prioritize Tested Item categories
    # Set the order of x-axis categories
)

g.set(ylim=(0.2, 1))
g.set_ylabels('Accuracy')
g.set_xlabels('V2 Distractor Similarity Ranges')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')  # Adjust the angle and alignment of the labels

# Add a title
# g.fig.suptitle("Incorrect WM - Untested", y=1.05, fontsize=16)  # Adjust y for spacing

plt.show()
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/1447149563.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(

# %%
# df_correct_wm['category']

# %%
# !pip install rpy2

# %%
# model = smf.glm(
#     formula="recall_answ ~ resp_correct + category * validity_binary * reliability_binary * it_sim_dis_diff_z * v2_sim_dis_diff_z",
#     data=df_correct_wm,
#     family=sm.families.Binomial()  # Binary outcomes
# )


# ### here recall_answ = 1 if ltm task correct, 0 if its wrong
# ### resp_correct = 1 if wm correct
# ### category : tested, not tested, distractor, foil?

# results = model.fit()

# print(results)

# %%
# print(results.summary())

# %%
# df_correct_wm_no_dist = df_correct_wm[
#     (df_correct_wm['category'] != 'distractor')
# ]

# df_incorrect_wm_no_dist = df_incorrect_wm[
#     (df_incorrect_wm['category'] != 'distractor')
# ]

# %%
# df_correct_wm_no_dist['Attend']

# %%
# df_correct_wm_no_dist['attend_binary'] = np.where(df_correct_wm_no_dist['Attend'] == 'attended', -1 , 1)

# %%
# df_correct_wm_no_dist['attend_binary']

# %%
### include if the ltm item that is in wm correct dataframe was tested or not in the wm

## tested vs untested in wm wrt to the wm item

# %%
# df_correct_wm_no_dist['test']

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()

# %%
# df_correct_wm_no_dist['mem_stim_type'] = np.where(df_correct_wm_no_dist['mem_stim_type'] == 'tested', -1 , 1)

# df_correct_wm_no_dist['mem_stim_type_z'] = scaler.fit_transform(df_correct_wm_no_dist[['mem_stim_type']])

# %%
df_filtered['Tested Item']
# Out:
# 3          prioritized
# 10         prioritized
# 16         prioritized
# 18       deprioritized
# 26         prioritized
#              ...
# 32760      prioritized
# 32763    deprioritized
# 32765      prioritized
# 32773    deprioritized
# 32777    deprioritized
# Name: Tested Item, Length: 10489, dtype: object

# %%
df_correct_wm.to_csv('pilot6_stats/correct_wm_ltm.csv', index=False)

# %%
df_incorrect_wm.to_csv('pilot6_stats/incorrect_wm_ltm.csv', index=False)

# %%
df_distractor_correct_wm = df_distractor[
    ((df_distractor['resp_correct'] == 1))
]

# %%
df_distractor_correct_wm
# Out:
#        setup_js.started  setup_js.stopped  participant  \
# 6                   NaN               NaN       165862
# 7                   NaN               NaN       165862
# 9                   NaN               NaN       165862
# 13                  NaN               NaN       165862
# 23                  NaN               NaN       165862
# ...                 ...               ...          ...
# 32720               NaN               NaN       167431
# 32726               NaN               NaN       167431
# 32733               NaN               NaN       167431
# 32752               NaN               NaN       167431
# 32767               NaN               NaN       167431
#
#                           date     expName psychopyVersion        OS  \
# 6      2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 7      2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 9      2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 13     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 23     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# ...                        ...         ...             ...       ...
# 32720  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32726  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32733  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32752  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32767  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
#
#        frameRate  Instructions1.started  Instructions1.stopped  ...  \
# 6       59.88024                    NaN                    NaN  ...
# 7       59.88024                    NaN                    NaN  ...
# 9       59.88024                    NaN                    NaN  ...
# 13      59.88024                    NaN                    NaN  ...
# 23      59.88024                    NaN                    NaN  ...
# ...          ...                    ...                    ...  ...
# 32720   62.50000                    NaN                    NaN  ...
# 32726   62.50000                    NaN                    NaN  ...
# 32733   62.50000                    NaN                    NaN  ...
# 32752   62.50000                    NaN                    NaN  ...
# 32767   62.50000                    NaN                    NaN  ...
#
#        mem_stim_type      Tested      Attend  Reliability  tested_binary  \
# 6         distractor  distractor  distractor         high              1
# 7         distractor  distractor  distractor          low              1
# 9         distractor  distractor  distractor          low              1
# 13        distractor  distractor  distractor          low              1
# 23        distractor  distractor  distractor         high              1
# ...              ...         ...         ...          ...            ...
# 32720     distractor  distractor  distractor          low              1
# 32726     distractor  distractor  distractor         high              1
# 32733     distractor  distractor  distractor          low              1
# 32752     distractor  distractor  distractor         high              1
# 32767     distractor  distractor  distractor          low              1
#
#        priority_binary  tested_binary_z  priority_binary_z  attend_binary  \
# 6                   -1         0.450398          -1.288053              1
# 7                    1         0.450398           0.776366              1
# 9                   -1         0.450398          -1.288053              1
# 13                  -1         0.450398          -1.288053              1
# 23                  -1         0.450398          -1.288053              1
# ...                ...              ...                ...            ...
# 32720                1         0.450398           0.776366              1
# 32726               -1         0.450398          -1.288053              1
# 32733               -1         0.450398          -1.288053              1
# 32752               -1         0.450398          -1.288053              1
# 32767               -1         0.450398          -1.288053              1
#
#        attend_binary_z
# 6             0.448036
# 7             0.448036
# 9             0.448036
# 13            0.448036
# 23            0.448036
# ...                ...
# 32720         0.448036
# 32726         0.448036
# 32733         0.448036
# 32752         0.448036
# 32767         0.448036
#
# [3842 rows x 429 columns]

# %%
df_distractor_correct_wm
# Out:
#        setup_js.started  setup_js.stopped  participant  \
# 6                   NaN               NaN       165862
# 7                   NaN               NaN       165862
# 9                   NaN               NaN       165862
# 13                  NaN               NaN       165862
# 23                  NaN               NaN       165862
# ...                 ...               ...          ...
# 32720               NaN               NaN       167431
# 32726               NaN               NaN       167431
# 32733               NaN               NaN       167431
# 32752               NaN               NaN       167431
# 32767               NaN               NaN       167431
#
#                           date     expName psychopyVersion        OS  \
# 6      2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 7      2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 9      2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 13     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 23     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# ...                        ...         ...             ...       ...
# 32720  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32726  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32733  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32752  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32767  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
#
#        frameRate  Instructions1.started  Instructions1.stopped  ...  \
# 6       59.88024                    NaN                    NaN  ...
# 7       59.88024                    NaN                    NaN  ...
# 9       59.88024                    NaN                    NaN  ...
# 13      59.88024                    NaN                    NaN  ...
# 23      59.88024                    NaN                    NaN  ...
# ...          ...                    ...                    ...  ...
# 32720   62.50000                    NaN                    NaN  ...
# 32726   62.50000                    NaN                    NaN  ...
# 32733   62.50000                    NaN                    NaN  ...
# 32752   62.50000                    NaN                    NaN  ...
# 32767   62.50000                    NaN                    NaN  ...
#
#        mem_stim_type      Tested      Attend  Reliability  tested_binary  \
# 6         distractor  distractor  distractor         high              1
# 7         distractor  distractor  distractor          low              1
# 9         distractor  distractor  distractor          low              1
# 13        distractor  distractor  distractor          low              1
# 23        distractor  distractor  distractor         high              1
# ...              ...         ...         ...          ...            ...
# 32720     distractor  distractor  distractor          low              1
# 32726     distractor  distractor  distractor         high              1
# 32733     distractor  distractor  distractor          low              1
# 32752     distractor  distractor  distractor         high              1
# 32767     distractor  distractor  distractor          low              1
#
#        priority_binary  tested_binary_z  priority_binary_z  attend_binary  \
# 6                   -1         0.450398          -1.288053              1
# 7                    1         0.450398           0.776366              1
# 9                   -1         0.450398          -1.288053              1
# 13                  -1         0.450398          -1.288053              1
# 23                  -1         0.450398          -1.288053              1
# ...                ...              ...                ...            ...
# 32720                1         0.450398           0.776366              1
# 32726               -1         0.450398          -1.288053              1
# 32733               -1         0.450398          -1.288053              1
# 32752               -1         0.450398          -1.288053              1
# 32767               -1         0.450398          -1.288053              1
#
#        attend_binary_z
# 6             0.448036
# 7             0.448036
# 9             0.448036
# 13            0.448036
# 23            0.448036
# ...                ...
# 32720         0.448036
# 32726         0.448036
# 32733         0.448036
# 32752         0.448036
# 32767         0.448036
#
# [3842 rows x 429 columns]

# %%
g = sns.catplot(
            x = 'IT Distractor Similarity\nto Tested Item',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
#             col = 'Attend',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3530530219.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(101.19585737179487, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'IT Distractor Similarity\nto Prioritized Item',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
#             col = 'Attend',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/4283528332.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(96.08554487179485, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'Tested - Untested IT Distractor Similarity Ranges',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
            col = 'Retrocue Reliability',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3135417499.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(827.2083358874199, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'Prioritized - Deprioritized IT Distractor Similarity Ranges',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
#             col = 'Attend',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/2358279215.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(101.19585737179487, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'V2 Distractor Similarity\nto Tested Item',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
#             col = 'Attend',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/620961927.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(96.08554487179485, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'V2 Distractor Similarity\nto Prioritized Item',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
#             col = 'Attend',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/4142676678.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(96.08554487179485, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'Tested - Untested V2 Distractor Similarity Ranges',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
#             col = 'Attend',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/919405323.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(96.08554487179485, 0.5, 'Accuracy')

# %%
g = sns.catplot(
            x = 'Prioritized - Deprioritized V2 Distractor Similarity Ranges',
            y = 'recall_answ',
            ci = 68,
            hue = 'Tested Item',
#             col = 'Attend',
            aspect = 1.3,
            dodge = 0.1,
            kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
            data = df_distractor_correct_wm)
g.set(ylim=(0.3, 0.6))
plt.ylabel('Accuracy')
# Out:
# /var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T/ipykernel_55897/3937887929.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   g = sns.catplot(
# Text(96.08554487179485, 0.5, 'Accuracy')

# %%
df_distractor_correct_wm.to_csv('pilot6_stats/distractor_wm_ltm.csv', index=False)

# %%
# df_incorrect_wm

# %%
df_wm = pd.concat([df_correct_wm, df_incorrect_wm], axis=0)
df_wm
# Out:
#        setup_js.started  setup_js.stopped  participant  \
# 3                   NaN               NaN       165862
# 10                  NaN               NaN       165862
# 18                  NaN               NaN       165862
# 26                  NaN               NaN       165862
# 27                  NaN               NaN       165862
# ...                 ...               ...          ...
# 32681               NaN               NaN       167431
# 32690               NaN               NaN       167431
# 32698               NaN               NaN       167431
# 32701               NaN               NaN       167431
# 32734               NaN               NaN       167431
#
#                           date     expName psychopyVersion        OS  \
# 3      2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 10     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 18     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 26     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# 27     2024-11-27 10:29:27.557  WM_Deepgen        2023.2.1     Win32
# ...                        ...         ...             ...       ...
# 32681  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32690  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32698  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32701  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
# 32734  2024-11-24 14:54:08.781  WM_Deepgen        2023.2.1  MacIntel
#
#        frameRate  Instructions1.started  Instructions1.stopped  ...  \
# 3       59.88024                    NaN                    NaN  ...
# 10      59.88024                    NaN                    NaN  ...
# 18      59.88024                    NaN                    NaN  ...
# 26      59.88024                    NaN                    NaN  ...
# 27      59.88024                    NaN                    NaN  ...
# ...          ...                    ...                    ...  ...
# 32681   62.50000                    NaN                    NaN  ...
# 32690   62.50000                    NaN                    NaN  ...
# 32698   62.50000                    NaN                    NaN  ...
# 32701   62.50000                    NaN                    NaN  ...
# 32734   62.50000                    NaN                    NaN  ...
#
#        v2_ltm_diff_z  it_ltm_diff_z  v2_ltm_sq_z  it_ltm_sq_z  \
# 3          -1.296496       0.374153     0.447754    -1.065699
# 10         -0.655215       1.477028    -0.548786     0.765164
# 18          0.587638      -1.202488    -0.260876     0.492780
# 26          0.898413      -0.884915     1.588847    -1.181845
# 27         -1.341677      -0.100322     1.189171    -0.781730
# ...              ...            ...          ...          ...
# 32681      -0.931494       0.988249    -0.725158     2.160208
# 32690       1.464703       0.999918     1.868445    -0.206522
# 32698       1.133781       1.461569    -0.516539     1.558815
# 32701       1.597935       1.469843     0.791826     2.209473
# 32734      -0.118932       0.513686    -0.550230    -0.490528
#
#        v2_ltm_diff_sq_z  it_ltm_diff_sq_z  \
# 3              0.806991         -1.021010
# 10            -0.676374          1.402818
# 18            -0.775915          0.529467
# 26            -0.228567         -0.257535
# 27             0.948258         -1.175259
# ...                 ...               ...
# 32681         -0.156822         -0.027738
# 32690          1.357450         -0.000195
# 32698          0.338320          1.348886
# 32701          1.841054          1.377681
# 32734         -1.168415         -0.873935
#
#        LTM - NonLTM V2 Distractor Similarity  \
# 3                                  -1.296496
# 10                                 -0.655215
# 18                                  0.587638
# 26                                  0.898413
# 27                                 -1.341677
# ...                                      ...
# 32681                              -0.931494
# 32690                               1.464703
# 32698                               1.133781
# 32701                               1.597935
# 32734                              -0.118932
#
#        LTM - NonLTM IT Distractor Similarity  \
# 3                                   0.374153
# 10                                  1.477028
# 18                                 -1.202488
# 26                                 -0.884915
# 27                                 -0.100322
# ...                                      ...
# 32681                               0.988249
# 32690                               0.999918
# 32698                               1.461569
# 32701                               1.469843
# 32734                               0.513686
#
#        V2 Distractor Similarity to LTM Item  \
# 3                                 -1.266667
# 10                                 0.509086
# 18                                 0.804879
# 26                                 1.773375
# 27                                -1.614099
# ...                                     ...
# 32681                              0.145176
# 32690                              1.876779
# 32698                              0.550182
# 32701                              1.438375
# 32734                             -0.507168
#
#        IT Distractor Similarity to LTM Item
# 3                                  0.322824
# 10                                 1.281861
# 18                                -1.189206
# 26                                -0.081162
# 27                                -0.585584
# ...                                     ...
# 32681                              1.678030
# 32690                              0.909069
# 32698                              1.519960
# 32701                              1.690324
# 32734                              0.766604
#
# [10489 rows x 457 columns]

# %%
df_wm_no_dist = df_wm[
    (df_wm['category'] != 'distractor')
]

# %%
# df_wm_no_dist.to_csv('pilot5_stats/wm_ltm_no_dist.csv')

# %%
# sub_df_valid = df[df.apply(lambda row: any((df['participant'] == row['participant']) & (df['img1'] == row['ImagePath'])), axis=1)]
df_valid_attend = df[
    ((df['ImagePath'] == df['img1']) & (df['validity'] == 'valid') & (df['attend'] == 'img1'))|
    ((df['ImagePath'] == df['img2']) & (df['validity'] == 'valid') & (df['attend'] == 'img2'))
]

df_valid_unattend = df[
    ((df['ImagePath'] == df['img1']) & (df['validity'] == 'valid') & (df['attend'] == 'img2'))|
    ((df['ImagePath'] == df['img2']) & (df['validity'] == 'valid') & (df['attend'] == 'img1'))
]

df_invalid_attend = df[
    ((df['ImagePath'] == df['img1']) & (df['validity'] == 'invalid') & (df['attend'] == 'img1'))|
    ((df['ImagePath'] == df['img2']) & (df['validity'] == 'invalid') & (df['attend'] == 'img2'))
]

df_invalid_unattend = df[
    ((df['ImagePath'] == df['img1']) & (df['validity'] == 'invalid') & (df['attend'] == 'img2'))|
    ((df['ImagePath'] == df['img2']) & (df['validity'] == 'invalid') & (df['attend'] == 'img1'))
]

# %%
print("No Problemo 2")
# Out:
# No Problemo 2

# %%
# df_attended = pd.concat([df_valid_attend, df_invalid_attend], ignore_index=True)

# %%
## wm accuracy by priority and tested item

##is being tested before showing any effect
## also split by correct and incorrect trials from wm task

# %%
### first categoriaze by wm task if they were correct or incorrect


### then memory for tested and untested items as a function of wherer they were prioritized or deprioritized

# %%
# df

# %%
# df['category_wm_ltm'] =

# %%
# df_correct_wm = df[
#     ((df['resp_correct'] == 1)) ]

# %%
# df_incorrect_wm = df[
#     ((df['resp_correct'] == 0)) ]

# %%
# g = sns.catplot(
#             x = 'Prioritized - Deprioritized V2 Distractor Similarity Ranges',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_correct_wm)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'Prioritized - Deprioritized V2 Distractor Similarity Ranges',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_correct_wm)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'Prioritized - Deprioritized V2 Distractor Similarity Ranges',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_correct_wm)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Correct WM", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'V2 Distractor Similarity\nto Prioritized Item',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_attended)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Seen and Attended images", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'V2 Distractor Similarity\nto Deprioritized Item',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_attended)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Seen and Attended images", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
##tested/untested and distractor and then split up by prioritized and deprioritized

# %%
# g = sns.catplot(
#             x = 'Prioritized - Deprioritized V2 Distractor Similarity Ranges',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_attended)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Seen and Attended images", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'IT Distractor Similarity\nto Prioritized Item',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_attended)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Seen and Attended images", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'IT Distractor Similarity\nto Deprioritized Item',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_attended)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Seen and Attended images", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'Prioritized - Deprioritized V2 Distractor Similarity Ranges',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_attended)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Seen and Attended images", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# import numpy as np

# # Define the conditions for each case
# conditions = [
#     ((df['ImagePath'] == df['img1']) & (df['validity'] == 'valid') & (df['attend'] == 'img1')) |
#     ((df['ImagePath'] == df['img2']) & (df['validity'] == 'valid') & (df['attend'] == 'img2')),

#     ((df['ImagePath'] == df['img1']) & (df['validity'] == 'valid') & (df['attend'] == 'img2')) |
#     ((df['ImagePath'] == df['img2']) & (df['validity'] == 'valid') & (df['attend'] == 'img1')),

#     ((df['ImagePath'] == df['img1']) & (df['validity'] == 'invalid') & (df['attend'] == 'img1')) |
#     ((df['ImagePath'] == df['img2']) & (df['validity'] == 'invalid') & (df['attend'] == 'img2')),

#     ((df['ImagePath'] == df['img1']) & (df['validity'] == 'invalid') & (df['attend'] == 'img2')) |
#     ((df['ImagePath'] == df['img2']) & (df['validity'] == 'invalid') & (df['attend'] == 'img1'))
# ]

# # Define the assignments for each case
# assignments = [
#     # Condition 1: Valid and attended image is the same
#     {
#         'seen_img': 'tested',
#         'IT_to_seen_image': df['it_sim_dis_attend'],
#         'V2_to_seen_image': df['v2_sim_dis_attend'],
#         'IT_relative': df['Prioritized - Deprioritized IT Distractor Similarity Ranges'],
#         'V2_relative': df['Prioritized - Deprioritized V2 Distractor Similarity Ranges']
#     },
#     # Condition 2: Valid but attended image is not the same, flipping certain fields
#     { 
# #         flip retrocue
#         'seen_img': 'not tested',
#         'IT_to_seen_image': df['it_sim_dis_unattend'],
#         'V2_to_seen_image': df['v2_sim_dis_unattend'],
#         'IT_relative': np.where(df['attend'] == 'img2', df['IT_root_im1'] - df['IT_root_im2'], df['IT_root_im2'] - df['IT_root_im1']),
#         'V2_relative': np.where(df['attend'] == 'img2', df['V2_root_im1'] - df['V2_root_im2'], df['V2_root_im2'] - df['V2_root_im1'])
#     },
#     # Condition 3: Invalid and attended image is the same
#     {
#         'seen_img': 'not tested',
#         'IT_to_seen_image': df['it_sim_dis_attend'],
#         'V2_to_seen_image': df['v2_sim_dis_attend'],
#         'IT_relative': df['Prioritized - Deprioritized IT Distractor Similarity Ranges'],
#         'V2_relative': df['Prioritized - Deprioritized V2 Distractor Similarity Ranges']
#     },
#     # Condition 4: Invalid and attended image is not the same
#     {#         flip retrocue

#         'seen_img': 'tested',
#         'IT_to_seen_image': df['it_sim_dis_unattend'],
#         'V2_to_seen_image': df['v2_sim_dis_unattend'],
#         'IT_relative': np.where(df['attend'] == 'img2', df['IT_root_im1'] - df['IT_root_im2'], df['IT_root_im2'] - df['IT_root_im1']),
#         'V2_relative': np.where(df['attend'] == 'img2', df['V2_root_im1'] - df['V2_root_im2'], df['V2_root_im2'] - df['V2_root_im1'])
#     }
# ]

# # Apply each condition to assign values
# for column, values in assignments[0].items():
#     df[column] = np.select(conditions, [assignment[column] for assignment in assignments], default=np.nan)

# # # Additional derived columns
# # df['it_sim_dis_diff'] = np.where(df['attend'] == 'img1', df['IT_root_im1'] - df['IT_root_im2'], df['IT_root_im2'] - df['IT_root_im1'])
# # df['v2_sim_dis_diff'] = np.where(df['attend'] == 'img1', df['V2_root_im1'] - df['V2_root_im2'], df['V2_root_im2'] - df['V2_root_im1'])

# # Normalize 'it_sim_dis_diff'
# df['it_sim_dis_diff'] = df['it_sim_dis_diff'] - df['it_sim_dis_diff'].mean(skipna=True)

# %%
# df['it_sim_dis_unattend']

# %%
# g = sns.catplot(
#             x = 'IT_relative',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = df_attended)

# g.set(ylim=(0.55, 0.85))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Seen and Attended images", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# sub_df = df[df.apply(lambda row: any((df['participant'] == row['participant']) & (df['ping_img'] == row['ImagePath'])), axis=1)]

# Display the resulting sub_df to the user
# tools.display_dataframe_to_user(name="Sub DF where ImagePath equals ping_im", dataframe=sub_df)

# %%
# sub_df

# %%
# g = sns.catplot(
#             x = 'V2 Distractor Similarity\nto Prioritized Item',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = sub_df)

# g.set(ylim=(0, 1))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Distractor images seen", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'IT Distractor Similarity\nto Prioritized Item',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = sub_df)

# g.set(ylim=(0, 1))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Distractor images seen", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'Prioritized - Deprioritized V2 Distractor Similarity Ranges',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = sub_df)

# g.set(ylim=(0, 1))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Distractor images seen", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# g = sns.catplot(
#             x = 'Prioritized - Deprioritized IT Distractor Similarity Ranges',
#             y = 'recall_answ',
#             ci = 68,
#             hue = 'Tested Item',
#             # col = 'Retrocue Reliability',
#             aspect = 1.3,
#             dodge = 0.1,
#             kind = 'point',
#             palette = palette[::-1],  # Reverse the color order
#             data = sub_df)

# g.set(ylim=(0, 1))
# g.set_ylabels('Accuracy')

# # Add a title
# g.fig.suptitle("Distractor images seen", y=1.05, fontsize=16)  # Adjust y for spacing

# plt.show()

# %%
# recalled_images = df[df['acc_recall'] == 1]

# def check_image_presence(row):
#     image_path = row['ImagePath']
#     participant = row['participant']
    
#     # Filter the original DataFrame for the same participant
#     participant_images = df[df['participant'] == participant]
#     if image_path in participant_images['ping_img'].values:
#             return True
# #     return is_present

# # Step 3: Apply the function and create a new column
# recalled_images.apply(check_image_presence, axis=1)

# # # Display the filtered DataFrame
# # print(recalled_images[['ImagePath', 'participant', 'image_present']==True])

# %%
# # Create a mapping for the answers
# answer_mapping = {1: 'Definitely not seen', 2: 'Probably not seen',
#                   3: 'Probably seen', 4: 'Definitely seen'}



# combined_df['Answer Labels'] = combined_df['image_recall_response.keys'].map(answer_mapping)

# # Plotting the distribution of answer labels for each participant
# plt.figure(figsize=(15, 8))
# sns.countplot(data=combined_df, x='participant', hue='Answer Labels', palette='viridis')
# plt.title('Distribution of Answers by Participant')
# plt.xlabel('Participant ID')
# plt.ylabel('Count')
# plt.xticks(rotation=90)  # Rotate the x-axis labels for better readability
# plt.legend(title='Answer Labels', bbox_to_anchor=(1, 1))  # Move the legend out of the plot
# plt.tight_layout()  # Adjust the plot to ensure everything fits without overlapping
# plt.show()

# %%
# new_data = combined_df

# %%
# new_data['image_seen'] = new_data['acc_recall']

# recall_response_column = 'image_recall_response.keys'

# new_data['recall_response'] = new_data[recall_response_column].map({1: 'not remembered', 2: 'not remembered', 3: 'remembered', 4: 'remembered'})
# recall_bias = new_data['recall_response'].value_counts(normalize=True)

# # 1. Overall recall response distribution
# recall_dist = new_data['recall_response'].value_counts()

# # Ensure 'image_seen' is boolean
# new_data['image_seen'] = new_data['acc_recall'].astype(bool)

# # Handle NaN values in 'recall_response'
# new_data['recall_response'] = new_data['recall_response'].fillna('unknown')
# accuracy_dist = new_data['image_seen'].value_counts()

# # Calculate recall response distribution for seen and not seen images
# seen_recall_dist = new_data[new_data['image_seen']]['recall_response'].value_counts()
# not_seen_recall_dist = new_data[~new_data['image_seen']]['recall_response'].value_counts()

# seen_recall_dist = seen_recall_dist[seen_recall_dist.index != 'unknown']
# not_seen_recall_dist = not_seen_recall_dist[not_seen_recall_dist.index != 'unknown']

# # Print the distributions for verification
# print("Recall Response Distribution for Seen Images:")
# print(seen_recall_dist)

# print("\nRecall Response Distribution for Not Seen Images:")
# print(not_seen_recall_dist)

# plt.figure(figsize=(12, 6))
# plt.figure(figsize=(18, 6)) 

# # Accuracy of Recall Plot
# plt.subplot(1, 3, 1)
# sns.barplot(x=accuracy_dist.index, y=accuracy_dist.values)
# plt.title('Accuracy of Recall', fontsize=14)  # Set title font size
# plt.xlabel('Is Recall Correct', fontsize=12)   # Set x-label font size
# plt.ylabel('Count', fontsize=12)              # Set y-label font size

# # Recall Bias Plot
# plt.subplot(1, 3, 2)
# sns.barplot(x=recall_bias.index, y=recall_bias.values)
# plt.title('Recall Bias', fontsize=14)
# plt.xlabel('Recall Response', fontsize=12)
# plt.ylabel('Proportion', fontsize=12)

# # Recall Response Distribution for Seen and Not Seen Images
# #  seen_recall_dist and not_seen_recall_dist are already calculated
# plt.subplot(1, 3, 3)
# sns.barplot(x=seen_recall_dist.index, y=seen_recall_dist.values)
# plt.title('Recall Response for Seen Images', fontsize=14)
# plt.xlabel('Recall Response', fontsize=12)
# plt.ylabel('Count', fontsize=12)

# plt.tight_layout() 
# plt.show()

# %%
# plt.figure(figsize=(8, 5))
# recall_dist.plot(kind='bar', color='lightblue')
# plt.title('Overall Recall Response Distribution')
# plt.xlabel('Recall Response')
# plt.ylabel('Count')
# plt.xticks(rotation=0)  # Rotate x labels if necessary
# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(12, 5))

# # Subplot for seen images
# plt.subplot(1, 2, 1)
# seen_recall_dist.plot(kind='bar', color='lightgreen')
# plt.title('Recall Response Distribution for Seen Images')
# plt.xlabel('Recall Response')
# plt.ylabel('Count')
# plt.xticks(rotation=0)

# # Subplot for not seen images
# plt.subplot(1, 2, 2)
# not_seen_recall_dist.plot(kind='bar', color='salmon')
# plt.title('Recall Response Distribution for Not Seen Images')
# plt.xlabel('Recall Response')
# plt.ylabel('Count')
# plt.xticks(rotation=0)

# plt.tight_layout()
# plt.show()
