# %%
library(lme4)
library(simr)
library(dplyr)
library(lme4)
library(simr)
library(dplyr)
library(broom)
install.packages("sjPlot")
library(sjPlot)
install.packages("broom.mixed")
library(broom.mixed)
library(htmlTable)
library(dplyr)
library(stringr)
# library(gt)
library(car)
install.packages("stargazer")
library(stargazer)
# install.packages("car")
library(car)
library(lmerTest)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpGEDQbE/downloaded_packages
# Install package "strengejacke" from GitHub (`devtools::install_github("strengejacke/strengejacke")`) to load all sj-packages at once!
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpGEDQbE/downloaded_packages
# Attaching package: ‘stringr’
#
#
# The following object is masked from ‘package:simr’:
#
#     fixed
#
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpGEDQbE/downloaded_packages
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer
#
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
file_path1 <- "pilot5_cubic.csv"
file_path2 <- "pilot6_cubic.csv"
file_path3 <- "pilot_total_cubic.csv"
df5 <- read.csv(file_path1) %>%
    select(it_sim_dis_test_cube_z, v2_sim_dis_test_cube_z, it_sim_dis_diff_test_cube_z, v2_sim_dis_diff_test_cube_z, it_sim_dis_test_sign_cube_z, it_sim_dis_diff_test_sign_cube_z, v2_sim_dis_test_sign_cube_z, v2_sim_dis_diff_test_sign_cube_z, it_sim_dis_diff, it_sim_dis_diff_sq, validity_reliability_z, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z, rt,tested_memorability_resmem_z, it_pos_neg_z, v2_pos_neg_z, it_sim_dis_diff_test_sign_z, it_sim_dis_diff_test_sign_sq_z,v2_sim_dis_diff_test_sign_z, v2_sim_dis_diff_test_sign_sq_z, it_sim_dis_test_sign_z, it_sim_dis_test_sign_sq_z,v2_sim_dis_test_sign_z, v2_sim_dis_test_sign_sq_z,  it_int_rel, v2_int_rel, it_int_rel_sq, v2_int_rel_sq,  it_pos_neg, v2_pos_neg)
df6 <- read.csv(file_path2) %>%
    select(it_sim_dis_test_cube_z, v2_sim_dis_test_cube_z, it_sim_dis_diff_test_cube_z, v2_sim_dis_diff_test_cube_z, it_sim_dis_test_sign_cube_z, it_sim_dis_diff_test_sign_cube_z, v2_sim_dis_test_sign_cube_z, v2_sim_dis_diff_test_sign_cube_z, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z, rt,tested_memorability_resmem_z, it_pos_neg_z, v2_pos_neg_z, it_sim_dis_diff_test_sign_z, it_sim_dis_diff_test_sign_sq_z,v2_sim_dis_diff_test_sign_z, v2_sim_dis_diff_test_sign_sq_z, it_sim_dis_test_sign_z, it_sim_dis_test_sign_sq_z,v2_sim_dis_test_sign_z, v2_sim_dis_test_sign_sq_z, it_int_rel, v2_int_rel, it_int_rel_sq, v2_int_rel_sq,  it_pos_neg, v2_pos_neg)
df_total <- read.csv(file_path3) %>%
    select(it_sim_dis_test_cube_z, v2_sim_dis_test_cube_z, it_sim_dis_diff_test_cube_z, v2_sim_dis_diff_test_cube_z, it_sim_dis_test_sign_cube_z, it_sim_dis_diff_test_sign_cube_z, v2_sim_dis_test_sign_cube_z, v2_sim_dis_diff_test_sign_cube_z, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z, rt,tested_memorability_resmem_z, it_pos_neg_z, v2_pos_neg_z, it_sim_dis_diff_test_sign_z, it_sim_dis_diff_test_sign_sq_z,v2_sim_dis_diff_test_sign_z, v2_sim_dis_diff_test_sign_sq_z, it_sim_dis_test_sign_z, it_sim_dis_test_sign_sq_z,v2_sim_dis_test_sign_z, v2_sim_dis_test_sign_sq_z, it_int_rel, v2_int_rel, it_int_rel_sq, v2_int_rel_sq, it_pos_neg, v2_pos_neg)

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
class(df5$rt)

# More detailed type information
typeof(df5$rt)

# Structure information (especially useful for complex objects)
str(df5$rt)

# Summary statistics and class
summary(df5$rt)
# Out:
# [1] "numeric"
# [1] "double"
#  num [1:39933] 1.695 1.631 0.895 2.096 2.894 ...
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#  0.3143  1.2045  1.5297  1.6161  1.9623  2.9895    1205

# %%
run_models <- function(df) {

    # Accuracy model with absolute similarity including cubic terms
    acc_abs <- glmer(resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z + it_sim_dis_test_cube_z) * validity_binary_z * reliability_binary_z
                + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z + v2_sim_dis_test_cube_z) * validity_binary_z * reliability_binary_z +  (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

    # Accuracy model with relative similarity including cubic terms
    acc_rel <- glmer(resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z + it_sim_dis_diff_test_cube_z) * validity_binary_z * reliability_binary_z
                     + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z + v2_sim_dis_diff_test_cube_z) * validity_binary_z * reliability_binary_z
                     + (1 | participant), 
                      data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

    # Split model including cubic terms 
    acc_rel_split <- glmer(resp_correct ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z + it_sim_dis_diff_test_sign_cube_z) * it_pos_neg * validity_binary_z * reliability_binary_z
                           + (v2_sim_dis_diff_test_sign_z + v2_sim_dis_diff_test_sign_sq_z + v2_sim_dis_diff_test_sign_cube_z) * v2_pos_neg * validity_binary_z * reliability_binary_z
                           + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

    
    df_correct <- subset(df, resp_correct == 1)
    
    # Add scaling for cubic terms along with existing terms
    df_correct$it_sim_dis_test_z_new <- scale(df_correct$it_sim_dis_test_z)
    df_correct$it_sim_dis_test_sq_z_new <- scale(df_correct$it_sim_dis_test_sq_z)
    df_correct$it_sim_dis_test_cube_z_new <- scale(df_correct$it_sim_dis_test_cube_z)
    
    df_correct$it_sim_dis_diff_test_z_new <- scale(df_correct$it_sim_dis_diff_test_z)
    df_correct$it_sim_dis_diff_test_sq_z_new <- scale(df_correct$it_sim_dis_diff_test_sq_z)
    df_correct$it_sim_dis_diff_test_cube_z_new <- scale(df_correct$it_sim_dis_diff_test_cube_z)
    
    df_correct$validity_binary_z_new <- scale(df_correct$validity_binary_z)
    df_correct$reliability_binary_z_new <- scale(df_correct$reliability_binary_z)
    
    df_correct$v2_sim_dis_test_z_new <- scale(df_correct$v2_sim_dis_test_z)
    df_correct$v2_sim_dis_test_sq_z_new <- scale(df_correct$v2_sim_dis_test_sq_z)
    df_correct$v2_sim_dis_test_cube_z_new <- scale(df_correct$v2_sim_dis_test_cube_z)
    
    df_correct$v2_sim_dis_diff_test_z_new <- scale(df_correct$v2_sim_dis_diff_test_z)
    df_correct$v2_sim_dis_diff_test_sq_z_new <- scale(df_correct$v2_sim_dis_diff_test_sq_z)
    df_correct$v2_sim_dis_diff_test_cube_z_new <- scale(df_correct$v2_sim_dis_diff_test_cube_z)

    df_correct$it_sim_dis_diff_test_sign_z_new <- scale(df_correct$it_sim_dis_diff_test_sign_z)
    df_correct$it_sim_dis_diff_test_sign_sq_z_new <- scale(df_correct$it_sim_dis_diff_test_sign_sq_z)
    df_correct$it_sim_dis_diff_test_sign_cube_z_new <- scale(df_correct$it_sim_dis_diff_test_sign_cube_z)
    
    df_correct$v2_sim_dis_diff_test_sign_z_new <- scale(df_correct$v2_sim_dis_diff_test_sign_z)
    df_correct$v2_sim_dis_diff_test_sign_sq_z_new <- scale(df_correct$v2_sim_dis_diff_test_sign_sq_z)
    df_correct$v2_sim_dis_diff_test_sign_cube_z_new <- scale(df_correct$v2_sim_dis_diff_test_sign_cube_z)
    
    df_correct$log_rt <- log(df_correct$rt)

    # RT models including cubic terms
    rt_abs <- lmer(log_rt ~ (it_sim_dis_test_z_new + it_sim_dis_test_sq_z_new + it_sim_dis_test_cube_z_new) * validity_binary_z_new * reliability_binary_z_new
                   + (v2_sim_dis_test_z_new + v2_sim_dis_test_sq_z_new + v2_sim_dis_test_cube_z_new) * validity_binary_z_new * reliability_binary_z_new
                   +  (1 | participant), 
                    data = df_correct, control = lmerControl(optimizer = "bobyqa"))
                    
    rt_rel <- lmer(log_rt ~ (it_sim_dis_diff_test_z_new + it_sim_dis_diff_test_sq_z_new + it_sim_dis_diff_test_cube_z_new) * validity_binary_z_new * reliability_binary_z_new
                   + (v2_sim_dis_diff_test_z_new + v2_sim_dis_diff_test_sq_z_new + v2_sim_dis_diff_test_cube_z_new)  * validity_binary_z_new * reliability_binary_z_new
                   + (1 | participant), 
                      data = df_correct, control = lmerControl(optimizer = "bobyqa"))
                      
    rt_rel_split <- lmer(log_rt ~ (it_sim_dis_diff_test_sign_z_new + it_sim_dis_diff_test_sign_sq_z_new + it_sim_dis_diff_test_sign_cube_z_new) * it_pos_neg  * validity_binary_z_new * reliability_binary_z_new
                         + (v2_sim_dis_diff_test_sign_z_new + v2_sim_dis_diff_test_sign_sq_z_new + v2_sim_dis_diff_test_sign_cube_z_new) * v2_pos_neg  * validity_binary_z_new * reliability_binary_z_new
                         + (1 | participant), 
                  data = df_correct, control = lmerControl(optimizer = "bobyqa"))

    return(list(
        acc_abs = acc_abs,
        acc_rel = acc_rel,
        acc_rel_split = acc_rel_split, 
        rt_abs = rt_abs,
        rt_rel = rt_rel,
        rt_rel_split = rt_rel_split
    ))
}

# %%
results_old_stims <- run_models(df6)
results_new_stims <- run_models(df5)
results_total <- run_models(df_total)

# %%
extract_significance <- function(model_summary) {
  # For glmer models
  if ("coefficients" %in% names(model_summary)) {
    # Check more carefully for z value vs t value columns
    coef_table <- model_summary$coefficients
    var_names <- rownames(coef_table)
    
    # Check which p-value column exists
    if ("Pr(>|z|)" %in% colnames(coef_table)) {
      p_values <- coef_table[, "Pr(>|z|)"]
    } else if ("Pr(>|t|)" %in% colnames(coef_table)) {
      p_values <- coef_table[, "Pr(>|t|)"]
    } else {
      # If there's a z or t value, calculate p-values manually
      if ("z value" %in% colnames(coef_table)) {
        z_values <- coef_table[, "z value"]
        p_values <- 2 * pnorm(abs(z_values), lower.tail = FALSE)
      } else if ("t value" %in% colnames(coef_table)) {
        t_values <- coef_table[, "t value"]
        # Using a large df for approximation
        p_values <- 2 * pt(abs(t_values), df = 100, lower.tail = FALSE)
      } else {
        stop("Cannot find p-values or z/t values in coefficients table")
      }
    }
  } else {
    # More detailed debug info
    cat("Available names in model summary:\n")
    print(names(model_summary))
    
    # Try to access fixed effects via other means
    if ("fixed.effects" %in% names(model_summary)) {
      var_names <- names(model_summary$fixed.effects)
      # Manually calculate p-values using fixed effects and std errors
      # This is just a placeholder - would need to be adapted to actual structure
      stop("Found fixed.effects but need appropriate calculation of p-values")
    } else {
      stop("Could not extract coefficients from model summary")
    }
  }
  
  # Calculate significance stars
  significance <- sapply(p_values, function(p) {
    if (is.na(p)) return("")
    if (p < 0.001) return("***")
    if (p < 0.01) return("**")
    if (p < 0.05) return("*")
    if (p < 0.1) return(".")
    return("")
  })
  
  return(data.frame(
    variable = var_names,
    p_value = p_values,
    significance = significance,
    stringsAsFactors = FALSE
  ))
}

# %%
compare_models <- function(model_list, model_names, 
                          include_p_values = FALSE,
                          only_significant = TRUE,
                          significance_level = 0.1) {
  
  sig_list <- lapply(model_list, extract_significance)
  names(sig_list) <- model_names
  
  all_vars <- unique(unlist(lapply(sig_list, function(x) x$variable)))
  
  result_df <- data.frame(Variable = all_vars, stringsAsFactors = FALSE)
  
  # First, determine which rows have significance in any model
  has_significance_by_var <- sapply(all_vars, function(var) {
    any_significant <- FALSE
    for(model_name in model_names) {
      model_sig <- sig_list[[model_name]]
      idx <- which(model_sig$variable == var)
      if(length(idx) > 0) {
        stars <- model_sig$significance[idx]
        if(stars != "") {
          any_significant <- TRUE
          break
        }
      }
    }
    return(any_significant)
  })
  
  # Now populate the data frame with all p-values for rows with any significance
  for(model_name in model_names) {
    model_sig <- sig_list[[model_name]]
    result_df[[model_name]] <- sapply(all_vars, function(var) {
      idx <- which(model_sig$variable == var)
      if(length(idx) == 0) return("")
      
      p_val <- model_sig$p_value[idx]
      stars <- model_sig$significance[idx]
      
      # Always show p-value if this variable has significance in any model
      if(has_significance_by_var[var] || !only_significant) {
        return(paste0(stars, " (p=", sprintf("%.4f", p_val), ")"))
      } else if(stars != "") {
        # Show significance stars with p-value for significant results
        return(paste0(stars, " (p=", sprintf("%.4f", p_val), ")"))
      } else {
        # For non-significant results in rows without any significance
        return("")
      }
    })
  }
  
  # Filter rows if only_significant is TRUE
  if(only_significant) {
    result_df <- result_df[has_significance_by_var, ]
  }
  
  # Adjust HTML table styling to make first column wider
  html_table <- htmlTable(
    result_df,
    caption = "Significance Comparison Across Models",
    rnames = FALSE,
    css.cell = "padding: 8px;",
    css.table = "border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;",
    css.header = "background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd;",
    css.rgroup = "border-bottom: 1px solid #dddddd;",
    css.tspanner = "font-weight: bold; text-align: center; border-bottom: 2px solid #dddddd;",
    css.class = "table-hover"
  )
  
  # Add additional CSS to make the first column wider
  html_table <- gsub("<table", "<style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table", html_table)
  
  return(html_table)
}

# %%
# Create tables for the three accuracy models
acc_abs_old <- summary(results_old_stims$acc_abs)
acc_abs_new <- summary(results_new_stims$acc_abs)
acc_abs_total <- summary(results_total$acc_abs)

comparison_table_acc_abs <- compare_models(
  model_list = list(acc_abs_old, acc_abs_new, acc_abs_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_acc_abs, "comparison_table_wm_acc_abs.html")

acc_rel_old <- summary(results_old_stims$acc_rel)
acc_rel_new <- summary(results_new_stims$acc_rel)
acc_rel_total <- summary(results_total$acc_rel)

comparison_table_acc_rel <- compare_models(
  model_list = list(acc_rel_old, acc_rel_new, acc_rel_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_acc_rel, "comparison_table_wm_acc_rel.html")

acc_rel_split_old <- summary(results_old_stims$acc_rel_split)
acc_rel_split_new <- summary(results_new_stims$acc_rel_split)
acc_rel_split_total <- summary(results_total$acc_rel_split)

comparison_table_acc_rel_split <- compare_models(
  model_list = list(acc_rel_split_old, acc_rel_split_new, acc_rel_split_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_acc_rel_split, "comparison_table_wm_acc_rel_split.html")

# Create tables for the three RT models
rt_abs_old <- summary(results_old_stims$rt_abs)
rt_abs_new <- summary(results_new_stims$rt_abs)
rt_abs_total <- summary(results_total$rt_abs)

comparison_table_rt_abs <- compare_models(
  model_list = list(rt_abs_old, rt_abs_new, rt_abs_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_rt_abs, "comparison_table_wm_rt_abs.html")

rt_rel_old <- summary(results_old_stims$rt_rel)
rt_rel_new <- summary(results_new_stims$rt_rel)
rt_rel_total <- summary(results_total$rt_rel)

comparison_table_rt_rel <- compare_models(
  model_list = list(rt_rel_old, rt_rel_new, rt_rel_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_rt_rel, "comparison_table_wm_rt_rel.html")

rt_rel_split_old <- summary(results_old_stims$rt_rel_split)
rt_rel_split_new <- summary(results_new_stims$rt_rel_split)
rt_rel_split_total <- summary(results_total$rt_rel_split)

comparison_table_rt_rel_split <- compare_models(
  model_list = list(rt_rel_split_old, rt_rel_split_new, rt_rel_split_total),
  model_names = c("Old Stimuli", "New Stimuli", "Total"),
  include_p_values = TRUE,
  only_significant = TRUE
)
writeLines(comparison_table_rt_rel_split, "comparison_table_wm_rt_rel_split.html")

# Display all tables
IRdisplay::display_html(comparison_table_acc_abs)
IRdisplay::display_html(comparison_table_acc_rel)
IRdisplay::display_html(comparison_table_acc_rel_split)
IRdisplay::display_html(comparison_table_rt_abs)
IRdisplay::display_html(comparison_table_rt_rel)
IRdisplay::display_html(comparison_table_rt_rel_split)
# Out:
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_cube_z</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0518)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4069)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0183)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0099)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0473)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0012)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7063)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0001)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1693)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_sq_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.8050)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0022)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4751)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_cube_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2240)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0195)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.9869)</td>
# </tr>
# <tr>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>validity_binary_z:reliability_binary_z</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# </tbody>
# </table>
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.5687)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0002)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0012)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sq_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0107)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0097)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0373)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0010)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_z</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0431)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7765)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2584)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sq_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0001)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_cube_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1958)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2166)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0963)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_z:validity_binary_z</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0376)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1153)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0115)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sq_z:validity_binary_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4440)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0578)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4157)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_cube_z:validity_binary_z</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0046)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1378)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0026)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z:reliability_binary_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_z:validity_binary_z:reliability_binary_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4509)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0468)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0721)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sq_z:validity_binary_z:reliability_binary_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.8049)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0793)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3329)</td>
# </tr>
# <tr>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>it_sim_dis_diff_test_cube_z:validity_binary_z:reliability_binary_z</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'> (p=0.7439)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>* (p=0.0451)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'> (p=0.1324)</td>
# </tr>
# </tbody>
# </table>
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_z</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0205)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4206)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2071)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_sq_z</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0324)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0385)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.9717)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_cube_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7124)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0879)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.5120)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0004)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0064)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0484)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0010)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0003)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0160)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_sq_z</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0109)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4729)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1703)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_cube_z</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0215)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4903)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0247)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0511)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1466)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_z:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0001)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_sq_z:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0484)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0468)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_cube_z:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0002)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0018)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_sq_z:validity_binary_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1125)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4884)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0969)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z:reliability_binary_z</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_z:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0002)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7371)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0005)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7411)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0050)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0078)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_cube_z:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.8916)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0003)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z:v2_sim_dis_diff_test_sign_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7768)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0044)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0325)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z:v2_sim_dis_diff_test_sign_sq_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7897)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0837)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2947)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z:v2_sim_dis_diff_test_sign_cube_z</td>
# <td style='padding: 8px; text-align: center;'> (p=0.6008)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0073)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0331)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z:v2_sim_dis_diff_test_sign_z</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0526)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1562)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0233)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0936)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3591)</td>
# <td s
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0053)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_z_new</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0873)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0248)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_sq_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3668)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0048)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0062)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_test_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3509)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0430)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0179)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_z_new:validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0720)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.8910)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1232)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_test_cube_z_new:reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0594)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.9212)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1710)</td>
# </tr>
# <tr>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>validity_binary_z_new:reliability_binary_z_new</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# </tbody>
# </table>
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0002)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sq_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0099)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0033)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0230)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_z_new</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0511)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0011)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sq_z_new</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0015)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0550)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0004)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4259)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0003)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1221)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sq_z_new:validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0560)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7260)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1055)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new:reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new:v2_sim_dis_diff_test_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3913)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0778)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.6520)</td>
# </tr>
# <tr>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>reliability_binary_z_new:v2_sim_dis_diff_test_sq_z_new</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'> (p=0.8557)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'>. (p=0.0716)</td>
# <td style='padding: 8px; border-bottom: 2px solid grey; text-align: center;'> (p=0.1977)</td>
# </tr>
# </tbody>
# </table>
# <style>td:first-child, th:first-child { min-width: 300px; max-width: 500px; word-wrap: break-word; }</style><table class='table-hover' style='border-collapse: collapse; border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;' >
# <thead>
# <tr><td colspan='4' style='text-align: left;'>
# Significance Comparison Across Models</td></tr>
# <tr>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Variable</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Old Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>New Stimuli</th>
# <th style='background-color: #f2f2f2; font-weight: bold; border: 1px solid #dddddd; border-bottom: 1px solid grey; border-top: 2px solid grey; text-align: center;'>Total</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='padding: 8px; text-align: center;'>(Intercept)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_z_new</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0376)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2144)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.5996)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_cube_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2386)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0204)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0104)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0030)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_z_new</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0318)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.5204)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2771)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_sq_z_new</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0108)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0613)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0023)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0004)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_z_new:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3164)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0228)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0014)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_sq_z_new:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0590)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0001)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_cube_z_new:it_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4831)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1856)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0076)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_cube_z_new:validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0896)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2402)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.5905)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new:reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0000)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0010)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3556)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0020)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_sq_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4521)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0683)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1335)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>v2_sim_dis_diff_test_sign_cube_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>*** (p=0.0006)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.6369)</td>
# <td style='padding: 8px; text-align: center;'>** (p=0.0079)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>validity_binary_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0736)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1611)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.8688)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_z_new:it_pos_neg:validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.7362)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0335)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0596)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_cube_z_new:it_pos_neg:validity_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.9201)</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0342)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1051)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>it_sim_dis_diff_test_sign_sq_z_new:validity_binary_z_new:reliability_binary_z_new</td>
# <td style='padding: 8px; text-align: center;'> (p=0.1497)</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0740)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.8055)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z_new:v2_sim_dis_diff_test_sign_sq_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>* (p=0.0271)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.3985)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.4578)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>reliability_binary_z_new:v2_sim_dis_diff_test_sign_cube_z_new:v2_pos_neg</td>
# <td style='padding: 8px; text-align: center;'>. (p=0.0898)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.9499)</td>
# <td style='padding: 8px; text-align: center;'> (p=0.2241)</td>
# </tr>
# <tr>
# <td style='padding: 8px; text-align: center;'>val

# %%
##old - 136, new stims 134, total 270
