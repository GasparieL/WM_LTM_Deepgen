# %%
library(lme4)
library(simr)
library(dplyr)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# install.packages("car")
library(car)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode

# %%
file_path <- "pilot_TOTAL_TEST.csv"

df <- read.csv(file_path) %>%
    select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, v2_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z )

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
head(df$resp_correct)
#
# Out:
# [1] 1 1 1 1 1 1

# %%
# names(df)

# %%
# mean(df$it_sim_dis_diff)

# %%
# model <- glm(
#   resp_correct ~ it_sim_dis_diff_test_z * reliability_binary * validity_binary + 
#              v2_sim_dis_diff_test_z * reliability_binary * validity_binary,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # head(df$v2_sim_dis_test_z)



# formula1 <- glmer(resp_correct ~  v2_sim_dis_test_z * reliability_binary * validity_binary +  
#                    it_sim_dis_test_z * reliability_binary * validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# model <- glm(
#   resp_correct ~ reliability_binary * validity_binary + (1 | participant),
#              y,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # IT*V2*reliability*validity + itsq+v2sq



# formula1 <- glmer(resp_correct ~ it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z * reliability_binary * validity_binary +  
#                    v2_sim_dis_diff_test_sq_z + it_sim_dis_diff_test_sq_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  88177.7  88373.7 -44067.8  88135.7    83679
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0392 -0.7567  0.4425  0.5860  1.5956
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4772   0.6908
# Number of obs: 83700, groups:  participant, 275
#
# Fixed effects:
#                                                               Estimate
# (Intercept)                                                  1.1866019
# it_sim_dis_test_z                                            0.0672951
# it_sim_dis_test_sq_z                                        -0.0369200
# reliability_binary_z                                         0.0283082
# validity_binary_z                                            0.2001693
# v2_sim_dis_test_z                                            0.0040344
# v2_sim_dis_test_sq_z                                        -0.0290466
# it_sim_dis_test_z:reliability_binary_z                      -0.0103020
# it_sim_dis_test_sq_z:reliability_binary_z                    0.0119282
# it_sim_dis_test_z:validity_binary_z                          0.0053189
# it_sim_dis_test_sq_z:validity_binary_z                      -0.0026959
# reliability_binary_z:validity_binary_z                       0.0785379
# reliability_binary_z:v2_sim_dis_test_z                      -0.0090075
# reliability_binary_z:v2_sim_dis_test_sq_z                   -0.0059888
# validity_binary_z:v2_sim_dis_test_z                         -0.0071206
# validity_binary_z:v2_sim_dis_test_sq_z                       0.0034832
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    -0.0120448
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z -0.0003283
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.0016470
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.0114052
#                                                             Std. Error z value
# (Intercept)                                                  0.0426175  27.843
# it_sim_dis_test_z                                            0.0085727   7.850
# it_sim_dis_test_sq_z                                         0.0085137  -4.337
# reliability_binary_z                                         0.0084665   3.344
# validity_binary_z                                            0.0083152  24.073
# v2_sim_dis_test_z                                            0.0098725   0.409
# v2_sim_dis_test_sq_z                                         0.0094070  -3.088
# it_sim_dis_test_z:reliability_binary_z                       0.0085720  -1.202
# it_sim_dis_test_sq_z:reliability_binary_z                    0.0085211   1.400
# it_sim_dis_test_z:validity_binary_z                          0.0084334   0.631
# it_sim_dis_test_sq_z:validity_binary_z                       0.0083847  -0.322
# reliability_binary_z:validity_binary_z                       0.0083057   9.456
# reliability_binary_z:v2_sim_dis_test_z                       0.0095729  -0.941
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.0093996  -0.637
# validity_binary_z:v2_sim_dis_test_z                          0.0095298  -0.747
# validity_binary_z:v2_sim_dis_test_sq_z                       0.0092814   0.375
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.0084326  -1.428
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.0083870  -0.039
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.0095327   0.173
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.0092827   1.229
#                                                             Pr(>|z|)
# (Intercept)                                                  < 2e-16 ***
# it_sim_dis_test_z                                           4.16e-15 ***
# it_sim_dis_test_sq_z                                        1.45e-05 ***
# reliability_binary_z                                        0.000827 ***
# validity_binary_z                                            < 2e-16 ***
# v2_sim_dis_test_z                                           0.682797
# v2_sim_dis_test_sq_z                                        0.002017 **
# it_sim_dis_test_z:reliability_binary_z                      0.229431
# it_sim_dis_test_sq_z:reliability_binary_z                   0.161559
# it_sim_dis_test_z:validity_binary_z                         0.528238
# it_sim_dis_test_sq_z:validity_binary_z                      0.747815
# reliability_binary_z:validity_binary_z                       < 2e-16 ***
# reliability_binary_z:v2_sim_dis_test_z                      0.346737
# reliability_binary_z:v2_sim_dis_test_sq_z                   0.524033
# validity_binary_z:v2_sim_dis_test_z                         0.454947
# validity_binary_z:v2_sim_dis_test_sq_z                      0.707449
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    0.153187
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z 0.968779
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z    0.862830
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z 0.219202
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_z +
#     v2_sim_dis_diff_test_sq_z) * reliability_binary_z * validity_binary_z +
#     it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  88123.8  88329.2 -44039.9  88079.8    83678
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1561 -0.7502  0.4419  0.5856  1.6628
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4777   0.6911
# Number of obs: 83700, groups:  participant, 275
#
# Fixed effects:
#                                                                   Estimate
# (Intercept)                                                       1.185392
# it_sim_dis_diff_test_z                                            0.072198
# it_sim_dis_diff_test_sq_z                                        -0.043801
# reliability_binary_z                                              0.029021
# validity_binary_z                                                 0.199844
# v2_sim_dis_diff_test_z                                            0.009638
# v2_sim_dis_diff_test_sq_z                                        -0.052134
# it_sim_dis_diff_test_z:reliability_binary_z                      -0.008566
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.002747
# it_sim_dis_diff_test_z:validity_binary_z                          0.002244
# it_sim_dis_diff_test_sq_z:validity_binary_z                       0.005634
# reliability_binary_z:validity_binary_z                            0.078105
# reliability_binary_z:v2_sim_dis_diff_test_z                      -0.012901
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   -0.000285
# validity_binary_z:v2_sim_dis_diff_test_z                          0.005633
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       0.001474
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     0.013234
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    -0.009071
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  0.005668
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.014287
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z -0.005833
#                                                                  Std. Error
# (Intercept)                                                        0.042660
# it_sim_dis_diff_test_z                                             0.008537
# it_sim_dis_diff_test_sq_z                                          0.008774
# reliability_binary_z                                               0.008472
# validity_binary_z                                                  0.008321
# v2_sim_dis_diff_test_z                                             0.008526
# v2_sim_dis_diff_test_sq_z                                          0.008645
# it_sim_dis_diff_test_z:reliability_binary_z                        0.008538
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.008434
# it_sim_dis_diff_test_z:validity_binary_z                           0.008384
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.008253
# reliability_binary_z:validity_binary_z                             0.008312
# reliability_binary_z:v2_sim_dis_diff_test_z                        0.008520
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.008429
# validity_binary_z:v2_sim_dis_diff_test_z                           0.008364
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.008222
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      0.008900
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z      0.008384
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.008253
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      0.008366
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.008224
#                                                                  z value
# (Intercept)                                                       27.787
# it_sim_dis_diff_test_z                                             8.457
# it_sim_dis_diff_test_sq_z                                         -4.992
# reliability_binary_z                                               3.426
# validity_binary_z                                                 24.016
# v2_sim_dis_diff_test_z                                             1.130
# v2_sim_dis_diff_test_sq_z                                         -6.030
# it_sim_dis_diff_test_z:reliability_binary_z                       -1.003
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.326
# it_sim_dis_diff_test_z:validity_binary_z                           0.268
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.683
# reliability_binary_z:validity_binary_z                             9.397
# reliability_binary_z:v2_sim_dis_diff_test_z                       -1.514
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    -0.034
# validity_binary_z:v2_sim_dis_diff_test_z                           0.674
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.179
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      1.487
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     -1.082
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.687
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      1.708
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  -0.709
#                                                                  Pr(>|z|)
# (Intercept)                                                       < 2e-16 ***
# it_sim_dis_diff_test_z                                            < 2e-16 ***
# it_sim_dis_diff_test_sq_z                                        5.97e-07 ***
# reliability_binary_z                                             0.000613 ***
# validity_binary_z                                                 < 2e-16 ***
# v2_sim_dis_diff_test_z                                           0.258298
# v2_sim_dis_diff_test_sq_z                                        1.63e-09 ***
# it_sim_dis_diff_test_z:reliability_binary_z                      0.315716
# it_sim_dis_diff_test_sq_z:reliability_binary_z                   0.744696
# it_sim_dis_diff_test_z:validity_binary_z                         0.788926
# it_sim_dis_diff_test_sq_z:validity_binary_z                      0.494792
# reliability_binary_z:validity_binary_z                            < 2e-16 ***
# reliability_binary_z:v2_sim_dis_diff_test_z                      0.130000
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   0.973027
# validity_binary_z:v2_sim_dis_diff_test_z                         0.500621
# validity_binary_z:v2_sim_dis_diff_test_sq_z                      0.857733
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                    0.137003
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    0.279320
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z 0.492165
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    0.087679 .
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z 0.478157
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula11 <- glmer(resp_correct ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_attend_z + v2_sim_dis_attend_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula11)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: resp_correct ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_attend_z +
#     v2_sim_dis_attend_sq_z) * reliability_binary_z * validity_binary_z +
#     it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  88151.4  88356.8 -44053.7  88107.4    83678
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0241 -0.7505  0.4422  0.5855  1.7186
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4782   0.6915
# Number of obs: 83700, groups:  participant, 275
#
# Fixed effects:
#                                                                 Estimate
# (Intercept)                                                    1.1868456
# it_sim_dis_attend_z                                            0.0353001
# it_sim_dis_attend_sq_z                                        -0.0460276
# reliability_binary_z                                           0.0288802
# validity_binary_z                                              0.1990222
# v2_sim_dis_attend_z                                            0.0057608
# v2_sim_dis_attend_sq_z                                        -0.0300751
# it_sim_dis_attend_z:reliability_binary_z                      -0.0139877
# it_sim_dis_attend_sq_z:reliability_binary_z                    0.0007457
# it_sim_dis_attend_z:validity_binary_z                          0.0596350
# it_sim_dis_attend_sq_z:validity_binary_z                       0.0108854
# reliability_binary_z:validity_binary_z                         0.0776496
# reliability_binary_z:v2_sim_dis_attend_z                       0.0033518
# reliability_binary_z:v2_sim_dis_attend_sq_z                    0.0049563
# validity_binary_z:v2_sim_dis_attend_z                         -0.0104862
# validity_binary_z:v2_sim_dis_attend_sq_z                       0.0037035
# it_sim_dis_attend_z:v2_sim_dis_attend_z                        0.0047100
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z    -0.0055382
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z  0.0192053
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z    -0.0196574
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z -0.0076702
#                                                               Std. Error
# (Intercept)                                                    0.0426867
# it_sim_dis_attend_z                                            0.0085842
# it_sim_dis_attend_sq_z                                         0.0088139
# reliability_binary_z                                           0.0084702
# validity_binary_z                                              0.0083249
# v2_sim_dis_attend_z                                            0.0099405
# v2_sim_dis_attend_sq_z                                         0.0096492
# it_sim_dis_attend_z:reliability_binary_z                       0.0085608
# it_sim_dis_attend_sq_z:reliability_binary_z                    0.0084887
# it_sim_dis_attend_z:validity_binary_z                          0.0083922
# it_sim_dis_attend_sq_z:validity_binary_z                       0.0082753
# reliability_binary_z:validity_binary_z                         0.0083155
# reliability_binary_z:v2_sim_dis_attend_z                       0.0096018
# reliability_binary_z:v2_sim_dis_attend_sq_z                    0.0095155
# validity_binary_z:v2_sim_dis_attend_z                          0.0094213
# validity_binary_z:v2_sim_dis_attend_sq_z                       0.0094754
# it_sim_dis_attend_z:v2_sim_dis_attend_z                        0.0086553
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z     0.0083936
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z  0.0082732
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z     0.0094225
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z  0.0094740
#                                                               z value Pr(>|z|)
# (Intercept)                                                    27.804  < 2e-16
# it_sim_dis_attend_z                                             4.112 3.92e-05
# it_sim_dis_attend_sq_z                                         -5.222 1.77e-07
# reliability_binary_z                                            3.410 0.000651
# validity_binary_z                                              23.907  < 2e-16
# v2_sim_dis_attend_z                                             0.580 0.562235
# v2_sim_dis_attend_sq_z                                         -3.117 0.001828
# it_sim_dis_attend_z:reliability_binary_z                       -1.634 0.102274
# it_sim_dis_attend_sq_z:reliability_binary_z                     0.088 0.929999
# it_sim_dis_attend_z:validity_binary_z                           7.106 1.19e-12
# it_sim_dis_attend_sq_z:validity_binary_z                        1.315 0.188373
# reliability_binary_z:validity_binary_z                          9.338  < 2e-16
# reliability_binary_z:v2_sim_dis_attend_z                        0.349 0.727030
# reliability_binary_z:v2_sim_dis_attend_sq_z                     0.521 0.602460
# validity_binary_z:v2_sim_dis_attend_z                          -1.113 0.265693
# validity_binary_z:v2_sim_dis_attend_sq_z                        0.391 0.695906
# it_sim_dis_attend_z:v2_sim_dis_attend_z                         0.544 0.586323
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z     -0.660 0.509376
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z   2.321 0.020267
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z     -2.086 0.036960
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z  -0.810 0.418164
#
# (Intercept)                                                   ***
# it_sim_dis_attend_z                                           ***
# it_sim_dis_attend_sq_z                                        ***
# reliability_binary_z                                          ***
# validity_binary_z                                             ***
# v2_sim_dis_attend_z
# v2_sim_dis_attend_sq_z                                        **
# it_sim_dis_attend_z:reliability_binary_z
# it_sim_dis_attend_sq_z:reliability_binary_z
# it_sim_dis_attend_z:validity_binary_z                         ***
# it_sim_dis_attend_sq_z:validity_binary_z
# reliability_binary_z:validity_binary_z                        ***
# reliability_binary_z:v2_sim_dis_attend_z
# reliability_binary_z:v2_sim_dis_attend_sq_z
# validity_binary_z:v2_sim_dis_attend_z
# validity_binary_z:v2_sim_dis_attend_sq_z
# it_sim_dis_attend_z:v2_sim_dis_attend_z
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z *
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z    *
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula10 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_z * v2_sim_dis_diff_z +  (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula10)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) *
#     reliability_binary_z * validity_binary_z + it_sim_dis_diff_z *
#     v2_sim_dis_diff_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  88123.8  88329.2 -44039.9  88079.8    83678
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1561 -0.7502  0.4419  0.5856  1.6628
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4777   0.6911
# Number of obs: 83700, groups:  participant, 275
#
# Fixed effects:
#                                                               Estimate
# (Intercept)                                                  1.1858333
# it_sim_dis_diff_z                                            0.0378185
# it_sim_dis_diff_sq_z                                        -0.0437989
# reliability_binary_z                                         0.0288843
# validity_binary_z                                            0.1997851
# v2_sim_dis_diff_z                                            0.0101990
# v2_sim_dis_diff_sq_z                                        -0.0521347
# it_sim_dis_diff_z:reliability_binary_z                      -0.0120371
# it_sim_dis_diff_sq_z:reliability_binary_z                    0.0027463
# it_sim_dis_diff_z:validity_binary_z                          0.0607304
# it_sim_dis_diff_sq_z:validity_binary_z                       0.0056341
# reliability_binary_z:validity_binary_z                       0.0782087
# reliability_binary_z:v2_sim_dis_diff_z                       0.0058747
# reliability_binary_z:v2_sim_dis_diff_sq_z                   -0.0002851
# validity_binary_z:v2_sim_dis_diff_z                          0.0051358
# validity_binary_z:v2_sim_dis_diff_sq_z                       0.0014738
# it_sim_dis_diff_z:v2_sim_dis_diff_z                          0.0132346
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z    -0.0029061
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z  0.0056683
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z    -0.0182092
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z -0.0058333
#                                                             Std. Error z value
# (Intercept)                                                  0.0426733  27.789
# it_sim_dis_diff_z                                            0.0085393   4.429
# it_sim_dis_diff_sq_z                                         0.0087734  -4.992
# reliability_binary_z                                         0.0084735   3.409
# validity_binary_z                                            0.0083230  24.004
# v2_sim_dis_diff_z                                            0.0085231   1.197
# v2_sim_dis_diff_sq_z                                         0.0086453  -6.030
# it_sim_dis_diff_z:reliability_binary_z                       0.0085391  -1.410
# it_sim_dis_diff_sq_z:reliability_binary_z                    0.0084341   0.326
# it_sim_dis_diff_z:validity_binary_z                          0.0083860   7.242
# it_sim_dis_diff_sq_z:validity_binary_z                       0.0082525   0.683
# reliability_binary_z:validity_binary_z                       0.0083137   9.407
# reliability_binary_z:v2_sim_dis_diff_z                       0.0085221   0.689
# reliability_binary_z:v2_sim_dis_diff_sq_z                    0.0084289  -0.034
# validity_binary_z:v2_sim_dis_diff_z                          0.0083667   0.614
# validity_binary_z:v2_sim_dis_diff_sq_z                       0.0082223   0.179
# it_sim_dis_diff_z:v2_sim_dis_diff_z                          0.0089001   1.487
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z     0.0083878  -0.346
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z  0.0082524   0.687
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z     0.0083623  -2.178
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z  0.0082243  -0.709
#                                                             Pr(>|z|)
# (Intercept)                                                  < 2e-16 ***
# it_sim_dis_diff_z                                           9.48e-06 ***
# it_sim_dis_diff_sq_z                                        5.97e-07 ***
# reliability_binary_z                                        0.000653 ***
# validity_binary_z                                            < 2e-16 ***
# v2_sim_dis_diff_z                                           0.231452
# v2_sim_dis_diff_sq_z                                        1.64e-09 ***
# it_sim_dis_diff_z:reliability_binary_z                      0.158643
# it_sim_dis_diff_sq_z:reliability_binary_z                   0.744710
# it_sim_dis_diff_z:validity_binary_z                         4.42e-13 ***
# it_sim_dis_diff_sq_z:validity_binary_z                      0.494792
# reliability_binary_z:validity_binary_z                       < 2e-16 ***
# reliability_binary_z:v2_sim_dis_diff_z                      0.490600
# reliability_binary_z:v2_sim_dis_diff_sq_z                   0.973020
# validity_binary_z:v2_sim_dis_diff_z                         0.539321
# validity_binary_z:v2_sim_dis_diff_sq_z                      0.857743
# it_sim_dis_diff_z:v2_sim_dis_diff_z                         0.137009
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z    0.728986
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z 0.492167
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z    0.029441 *
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z 0.478152
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# formula1 <- glmer(resp_correct ~ (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary *  
#                   validity_binary + (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_attend * reliability_binary *  
#                   validity_binary + v2_sim_dis_attend * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# formula2 <- glmer(resp_correct ~ it_sim_dis_unattend * reliability_binary *  
#                   validity_binary + v2_sim_dis_unattend * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula2)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# head(df$reliability_binary)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))


# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula10 <- glmer(resp_correct ~ (it_sim_dis_unattend_z + it_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_unattend_z + v2_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula10)
