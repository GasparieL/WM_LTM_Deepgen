# %%
library(lme4)
library(simr)
library(dplyr)
library(broom)
install.packages("sjPlot")
library(sjPlot)

install.packages("broom.mixed")
library(broom.mixed)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpNZXkgZ/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpNZXkgZ/downloaded_packages

# %%
# install.packages("car")
library(car)
install.packages("stargazer")

library(stargazer)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpNZXkgZ/downloaded_packages
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %%
file_path <- 'pilot6_stats/distractor_wm_ltm.csv'
df <- read.csv(file_path) 
# %>%
#     select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z )

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
# head(df$resp_correct)

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) * it_pos_neg_abs * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 44 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) *
#     it_pos_neg_abs * reliability_binary_z * validity_binary_z +
#     (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs *
#         reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   4908.1   5187.6  -2409.1   4818.1     3638
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.8085 -0.8133 -0.5771  0.9919  2.6230
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3803   0.6167
# Number of obs: 3683, groups:  participant, 132
#
# Fixed effects:
#                                                                                  Estimate
# (Intercept)                                                                     -0.283833
# it_sim_dis_test_sign_z                                                           0.050795
# it_sim_dis_test_sign_sq_z                                                        0.105441
# it_pos_neg_abs                                                                   0.016061
# reliability_binary_z                                                            -0.019266
# validity_binary_z                                                                0.023604
# v2_sim_dis_test_sign_z                                                           0.062152
# v2_sim_dis_test_sign_sq_z                                                        0.042908
# v2_pos_neg_abs                                                                   0.078387
# it_sim_dis_test_sign_z:it_pos_neg_abs                                            0.003509
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                         0.142740
# it_sim_dis_test_sign_z:reliability_binary_z                                      0.029793
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                  -0.027383
# it_pos_neg_abs:reliability_binary_z                                             -0.020880
# it_sim_dis_test_sign_z:validity_binary_z                                         0.054640
# it_sim_dis_test_sign_sq_z:validity_binary_z                                     -0.052823
# it_pos_neg_abs:validity_binary_z                                                -0.023386
# reliability_binary_z:validity_binary_z                                          -0.018792
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                           -0.017270
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                        -0.050535
# reliability_binary_z:v2_sim_dis_test_sign_z                                     -0.031893
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                   0.079470
# reliability_binary_z:v2_pos_neg_abs                                              0.023294
# validity_binary_z:v2_sim_dis_test_sign_z                                         0.050848
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                     -0.011803
# validity_binary_z:v2_pos_neg_abs                                                -0.003638
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                       0.035864
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                   -0.001431
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                          0.003256
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                      -0.037962
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                    0.018121
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                -0.066732
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           -0.069577
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                       0.025879
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                   -0.028072
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                         -0.005797
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                      -0.045615
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                    0.001485
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                 0.151736
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                           -0.025643
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z     0.102587
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z -0.006422
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs     0.036703
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs -0.097535
#                                                                                 Std. Error
# (Intercept)                                                                       0.067238
# it_sim_dis_test_sign_z                                                            0.040667
# it_sim_dis_test_sign_sq_z                                                         0.040592
# it_pos_neg_abs                                                                    0.038367
# reliability_binary_z                                                              0.040086
# validity_binary_z                                                                 0.044199
# v2_sim_dis_test_sign_z                                                            0.042996
# v2_sim_dis_test_sign_sq_z                                                         0.068091
# v2_pos_neg_abs                                                                    0.039108
# it_sim_dis_test_sign_z:it_pos_neg_abs                                             0.041014
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                          0.040329
# it_sim_dis_test_sign_z:reliability_binary_z                                       0.040918
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                    0.040502
# it_pos_neg_abs:reliability_binary_z                                               0.038337
# it_sim_dis_test_sign_z:validity_binary_z                                          0.046756
# it_sim_dis_test_sign_sq_z:validity_binary_z                                       0.046176
# it_pos_neg_abs:validity_binary_z                                                  0.041964
# reliability_binary_z:validity_binary_z                                            0.044251
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                             0.042531
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                          0.067577
# reliability_binary_z:v2_sim_dis_test_sign_z                                       0.043053
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                    0.068043
# reliability_binary_z:v2_pos_neg_abs                                               0.039008
# validity_binary_z:v2_sim_dis_test_sign_z                                          0.045814
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                       0.072229
# validity_binary_z:v2_pos_neg_abs                                                  0.040548
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                        0.041080
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                     0.040432
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                           0.047326
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                        0.045873
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                     0.046876
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                  0.046380
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                             0.042204
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                        0.042516
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                     0.067951
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                           0.045077
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                        0.071955
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                     0.045762
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                  0.072665
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                             0.040854
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z      0.047677
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z   0.046092
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs      0.045230
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs   0.072153
#                                                                                 z value
# (Intercept)                                                                      -4.221
# it_sim_dis_test_sign_z                                                            1.249
# it_sim_dis_test_sign_sq_z                                                         2.598
# it_pos_neg_abs                                                                    0.419
# reliability_binary_z                                                             -0.481
# validity_binary_z                                                                 0.534
# v2_sim_dis_test_sign_z                                                            1.446
# v2_sim_dis_test_sign_sq_z                                                         0.630
# v2_pos_neg_abs                                                                    2.004
# it_sim_dis_test_sign_z:it_pos_neg_abs                                             0.086
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                          3.539
# it_sim_dis_test_sign_z:reliability_binary_z                                       0.728
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                   -0.676
# it_pos_neg_abs:reliability_binary_z                                              -0.545
# it_sim_dis_test_sign_z:validity_binary_z                                          1.169
# it_sim_dis_test_sign_sq_z:validity_binary_z                                      -1.144
# it_pos_neg_abs:validity_binary_z                                                 -0.557
# reliability_binary_z:validity_binary_z                                           -0.425
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                            -0.406
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                         -0.748
# reliability_binary_z:v2_sim_dis_test_sign_z                                      -0.741
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                    1.168
# reliability_binary_z:v2_pos_neg_abs                                               0.597
# validity_binary_z:v2_sim_dis_test_sign_z                                          1.110
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                      -0.163
# validity_binary_z:v2_pos_neg_abs                                                 -0.090
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                        0.873
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                    -0.035
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                           0.069
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                       -0.828
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                     0.387
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                 -1.439
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                            -1.649
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                        0.609
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                    -0.413
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                          -0.129
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                       -0.634
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                     0.032
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                  2.088
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                            -0.628
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z      2.152
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z  -0.139
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs      0.811
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs  -1.352
#                                                                                 Pr(>|z|)
# (Intercept)                                                                     2.43e-05
# it_sim_dis_test_sign_z                                                          0.211644
# it_sim_dis_test_sign_sq_z                                                       0.009388
# it_pos_neg_abs                                                                  0.675495
# reliability_binary_z                                                            0.630791
# validity_binary_z                                                               0.593313
# v2_sim_dis_test_sign_z                                                          0.148302
# v2_sim_dis_test_sign_sq_z                                                       0.528590
# v2_pos_neg_abs                                                                  0.045032
# it_sim_dis_test_sign_z:it_pos_neg_abs                                           0.931826
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        0.000401
# it_sim_dis_test_sign_z:reliability_binary_z                                     0.466546
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                  0.498982
# it_pos_neg_abs:reliability_binary_z                                             0.586003
# it_sim_dis_test_sign_z:validity_binary_z                                        0.242558
# it_sim_dis_test_sign_sq_z:validity_binary_z                                     0.252645
# it_pos_neg_abs:validity_binary_z                                                0.577330
# reliability_binary_z:validity_binary_z                                          0.671086
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                           0.684707
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                        0.454570
# reliability_binary_z:v2_sim_dis_test_sign_z                                     0.458826
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                  0.242835
# reliability_binary_z:v2_pos_neg_abs                                             0.550396
# validity_binary_z:v2_sim_dis_test_sign_z                                        0.267047
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                     0.870198
# validity_binary_z:v2_pos_neg_abs                                                0.928499
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                      0.382649
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                   0.971766
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                         0.945151
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                      0.407923
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                   0.699072
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                0.150207
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           0.099231
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                      0.542733
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                   0.679512
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                         0.897677
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                      0.526119
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                   0.974113
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                0.036785
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                           0.530210
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z    0.031422
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z 0.889188
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs    0.417088
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs 0.176446
#
# (Intercept)                                                                     ***
# it_sim_dis_test_sign_z
# it_sim_dis_test_sign_sq_z                                                       **
# it_pos_neg_abs
# reliability_binary_z
# validity_binary_z
# v2_sim_dis_test_sign_z
# v2_sim_dis_test_sign_sq_z
# v2_pos_neg_abs                                                                  *
# it_sim_dis_test_sign_z:it_pos_neg_abs
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        ***
# it_sim_dis_test_sign_z:reliability_binary_z
# it_sim_dis_test_sign_sq_z:reliability_binary_z
# it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:validity_binary_z
# it_pos_neg_abs:validity_binary_z
# reliability_binary_z:validity_binary_z
# v2_sim_dis_test_sign_z:v2_pos_neg_abs
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# reliability_binary_z:v2_sim_dis_test_sign_z
# reliability_binary_z:v2_sim_dis_test_sign_sq_z
# reliability_binary_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_z
# validity_binary_z:v2_sim_dis_test_sign_sq_z
# validity_binary_z:v2_pos_neg_abs
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           .
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                *
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z    *
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) * it_pos_neg * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_sign_z + v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 44 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) *
#     it_pos_neg * reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_sign_z +
#     v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *
#     validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   4886.8   5166.3  -2398.4   4796.8     3638
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4699 -0.8040 -0.5588  0.9852  2.6578
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4165   0.6454
# Number of obs: 3683, groups:  participant, 132
#
# Fixed effects:
#                                                                                    Estimate
# (Intercept)                                                                      -0.3065575
# it_sim_dis_diff_test_sign_z                                                       0.0458544
# it_sim_dis_diff_test_sign_sq_z                                                    0.2548994
# it_pos_neg                                                                        0.0315844
# reliability_binary_z                                                             -0.0154047
# validity_binary_z                                                                 0.0219338
# v2_sim_dis_diff_test_sign_z                                                       0.1184438
# v2_sim_dis_diff_test_sign_sq_z                                                   -0.0282843
# v2_pos_neg                                                                        0.0435393
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            0.0331173
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                        -0.0160937
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  0.0241345
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                              -0.0054815
# it_pos_neg:reliability_binary_z                                                  -0.0440169
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     0.0377360
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                 -0.0325016
# it_pos_neg:validity_binary_z                                                     -0.0410116
# reliability_binary_z:validity_binary_z                                           -0.0040175
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            0.0006092
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                        -0.0238474
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                 -0.0026654
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               0.0173733
# reliability_binary_z:v2_pos_neg                                                   0.0069485
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                    -0.0408439
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                 -0.0386975
# validity_binary_z:v2_pos_neg                                                      0.0064099
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       0.0006392
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    0.0524986
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          0.0119264
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                      -0.0555738
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                0.0622366
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z            -0.0145179
# it_pos_neg:reliability_binary_z:validity_binary_z                                -0.0152221
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       0.0336915
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                   -0.0215059
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          0.0039863
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                      -0.0553894
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z               -0.0001737
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             0.0206077
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 0.0277755
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     0.0342035
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  0.0111430
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     0.0339239
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  0.0240169
#                                                                                  Std. Error
# (Intercept)                                                                       0.0672618
# it_sim_dis_diff_test_sign_z                                                       0.0372188
# it_sim_dis_diff_test_sign_sq_z                                                    0.0373127
# it_pos_neg                                                                        0.0380852
# reliability_binary_z                                                              0.0364354
# validity_binary_z                                                                 0.0389562
# v2_sim_dis_diff_test_sign_z                                                       0.0365798
# v2_sim_dis_diff_test_sign_sq_z                                                    0.0366702
# v2_pos_neg                                                                        0.0379120
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            0.0375937
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         0.0385636
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  0.0375294
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               0.0371916
# it_pos_neg:reliability_binary_z                                                   0.0381499
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     0.0404049
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  0.0398550
# it_pos_neg:validity_binary_z                                                      0.0393555
# reliability_binary_z:validity_binary_z                                            0.0389951
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            0.0375060
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         0.0367884
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  0.0365205
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               0.0366398
# reliability_binary_z:v2_pos_neg                                                   0.0379934
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     0.0378975
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  0.0378166
# validity_binary_z:v2_pos_neg                                                      0.0403655
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       0.0374893
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    0.0387137
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          0.0406091
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       0.0423188
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                0.0405606
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             0.0398733
# it_pos_neg:reliability_binary_z:validity_binary_z                                 0.0395103
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       0.0373868
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    0.0368061
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          0.0383089
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       0.0378034
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                0.0377379
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             0.0379341
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 0.0406134
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     0.0406168
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  0.0424489
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     0.0383335
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  0.0378868
#                                                                                  z value
# (Intercept)                                                                       -4.558
# it_sim_dis_diff_test_sign_z                                                        1.232
# it_sim_dis_diff_test_sign_sq_z                                                     6.831
# it_pos_neg                                                                         0.829
# reliability_binary_z                                                              -0.423
# validity_binary_z                                                                  0.563
# v2_sim_dis_diff_test_sign_z                                                        3.238
# v2_sim_dis_diff_test_sign_sq_z                                                    -0.771
# v2_pos_neg                                                                         1.148
# it_sim_dis_diff_test_sign_z:it_pos_neg                                             0.881
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         -0.417
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                   0.643
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               -0.147
# it_pos_neg:reliability_binary_z                                                   -1.154
# it_sim_dis_diff_test_sign_z:validity_binary_z                                      0.934
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  -0.815
# it_pos_neg:validity_binary_z                                                      -1.042
# reliability_binary_z:validity_binary_z                                            -0.103
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                             0.016
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         -0.648
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  -0.073
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                                0.474
# reliability_binary_z:v2_pos_neg                                                    0.183
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     -1.078
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  -1.023
# validity_binary_z:v2_pos_neg                                                       0.159
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                        0.017
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                     1.356
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                           0.294
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       -1.313
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                 1.534
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             -0.364
# it_pos_neg:reliability_binary_z:validity_binary_z                                 -0.385
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                        0.901
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    -0.584
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                           0.104
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       -1.465
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                -0.005
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z              0.543
# reliability_binary_z:validity_binary_z:v2_pos_neg                                  0.684
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z      0.842
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z   0.263
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg      0.885
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg   0.634
#                                                                                  Pr(>|z|)
# (Intercept)                                                                      5.17e-06
# it_sim_dis_diff_test_sign_z                                                        0.2179
# it_sim_dis_diff_test_sign_sq_z                                                   8.41e-12
# it_pos_neg                                                                         0.4069
# reliability_binary_z                                                               0.6724
# validity_binary_z                                                                  0.5734
# v2_sim_dis_diff_test_sign_z                                                        0.0012
# v2_sim_dis_diff_test_sign_sq_z                                                     0.4405
# v2_pos_neg                                                                         0.2508
# it_sim_dis_diff_test_sign_z:it_pos_neg                                             0.3784
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                          0.6764
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                   0.5202
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                                0.8828
# it_pos_neg:reliability_binary_z                                                    0.2486
# it_sim_dis_diff_test_sign_z:validity_binary_z                                      0.3503
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                   0.4148
# it_pos_neg:validity_binary_z                                                       0.2974
# reliability_binary_z:validity_binary_z                                             0.9179
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                             0.9870
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                          0.5168
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                   0.9418
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                                0.6354
# reliability_binary_z:v2_pos_neg                                                    0.8549
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                      0.2811
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                   0.3062
# validity_binary_z:v2_pos_neg                                                       0.8738
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                        0.9864
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                     0.1751
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                           0.7690
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                        0.1891
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                 0.1249
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z              0.7158
# it_pos_neg:reliability_binary_z:validity_binary_z                                  0.7000
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                        0.3675
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                     0.5590
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                           0.9171
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                        0.1429
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                 0.9963
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z              0.5870
# reliability_binary_z:validity_binary_z:v2_pos_neg                                  0.4940
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z      0.3997
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z   0.7929
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg      0.3762
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg   0.5261
#
# (Intercept)                                                                      ***
# it_sim_dis_diff_test_sign_z
# it_sim_dis_diff_test_sign_sq_z                                                   ***
# it_pos_neg
# reliability_binary_z
# validity_binary_z
# v2_sim_dis_diff_test_sign_z                                                      **
# v2_sim_dis_diff_test_sign_sq_z
# v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg
# it_sim_dis_diff_test_sign_z:reliability_binary_z
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z
# it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z
# it_pos_neg:validity_binary_z
# reliability_binary_z:validity_binary_z
# v2_sim_dis_diff_test_sign_z:v2_pos_neg
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# reliability_binary_z:v2_sim_dis_diff_test_sign_z
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z
# reliability_binary_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_z
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z
# validity_binary_z:v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z
# it_pos_neg:reliability_binary_z:validity_binary_z
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z
# reliability_binary_z:validity_binary_z:v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z)  * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z)  * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   4905.8   5036.2  -2431.9   4863.8     3662
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4016 -0.8233 -0.5959  1.0129  2.7192
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3788   0.6154
# Number of obs: 3683, groups:  participant, 132
#
# Fixed effects:
#                                                              Estimate
# (Intercept)                                                 -0.308151
# it_sim_dis_test_z                                            0.006090
# it_sim_dis_test_sq_z                                         0.114118
# reliability_binary_z                                        -0.022997
# validity_binary_z                                            0.027549
# v2_sim_dis_test_z                                            0.067424
# v2_sim_dis_test_sq_z                                         0.052621
# it_sim_dis_test_z:reliability_binary_z                      -0.017324
# it_sim_dis_test_sq_z:reliability_binary_z                    0.033906
# it_sim_dis_test_z:validity_binary_z                         -0.017704
# it_sim_dis_test_sq_z:validity_binary_z                       0.002782
# reliability_binary_z:validity_binary_z                       0.003713
# reliability_binary_z:v2_sim_dis_test_z                       0.040209
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.023985
# validity_binary_z:v2_sim_dis_test_z                         -0.024493
# validity_binary_z:v2_sim_dis_test_sq_z                       0.004039
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    -0.011050
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z -0.006189
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.021949
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.032032
#                                                             Std. Error z value
# (Intercept)                                                   0.064652  -4.766
# it_sim_dis_test_z                                             0.037480   0.162
# it_sim_dis_test_sq_z                                          0.036627   3.116
# reliability_binary_z                                          0.035690  -0.644
# validity_binary_z                                             0.037712   0.731
# v2_sim_dis_test_z                                             0.038771   1.739
# v2_sim_dis_test_sq_z                                          0.038534   1.366
# it_sim_dis_test_z:reliability_binary_z                        0.037406  -0.463
# it_sim_dis_test_sq_z:reliability_binary_z                     0.036775   0.922
# it_sim_dis_test_z:validity_binary_z                           0.039550  -0.448
# it_sim_dis_test_sq_z:validity_binary_z                        0.039375   0.071
# reliability_binary_z:validity_binary_z                        0.037760   0.098
# reliability_binary_z:v2_sim_dis_test_z                        0.038754   1.038
# reliability_binary_z:v2_sim_dis_test_sq_z                     0.038321   0.626
# validity_binary_z:v2_sim_dis_test_z                           0.040650  -0.603
# validity_binary_z:v2_sim_dis_test_sq_z                        0.038848   0.104
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z      0.039692  -0.278
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z   0.039434  -0.157
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z      0.040960   0.536
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z   0.038780   0.826
#                                                             Pr(>|z|)
# (Intercept)                                                 1.88e-06 ***
# it_sim_dis_test_z                                            0.87093
# it_sim_dis_test_sq_z                                         0.00184 **
# reliability_binary_z                                         0.51935
# validity_binary_z                                            0.46508
# v2_sim_dis_test_z                                            0.08203 .
# v2_sim_dis_test_sq_z                                         0.17207
# it_sim_dis_test_z:reliability_binary_z                       0.64327
# it_sim_dis_test_sq_z:reliability_binary_z                    0.35654
# it_sim_dis_test_z:validity_binary_z                          0.65442
# it_sim_dis_test_sq_z:validity_binary_z                       0.94367
# reliability_binary_z:validity_binary_z                       0.92168
# reliability_binary_z:v2_sim_dis_test_z                       0.29948
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.53138
# validity_binary_z:v2_sim_dis_test_z                          0.54682
# validity_binary_z:v2_sim_dis_test_sq_z                       0.91720
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.78071
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.87529
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.59205
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.40881
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))
summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_z +
#     v2_sim_dis_diff_test_sq_z) * reliability_binary_z * validity_binary_z +
#     (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   4892.3   5022.7  -2425.1   4850.3     3662
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.0234 -0.8203 -0.5910  1.0030  2.4512
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.386    0.6213
# Number of obs: 3683, groups:  participant, 132
#
# Fixed effects:
#                                                                   Estimate
# (Intercept)                                                      -0.307733
# it_sim_dis_diff_test_z                                            0.038313
# it_sim_dis_diff_test_sq_z                                         0.136853
# reliability_binary_z                                             -0.016569
# validity_binary_z                                                 0.021277
# v2_sim_dis_diff_test_z                                            0.038164
# v2_sim_dis_diff_test_sq_z                                         0.132378
# it_sim_dis_diff_test_z:reliability_binary_z                      -0.022145
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.015567
# it_sim_dis_diff_test_z:validity_binary_z                         -0.038581
# it_sim_dis_diff_test_sq_z:validity_binary_z                       0.017560
# reliability_binary_z:validity_binary_z                            0.012475
# reliability_binary_z:v2_sim_dis_diff_test_z                       0.030613
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   -0.008809
# validity_binary_z:v2_sim_dis_diff_test_z                         -0.007987
# validity_binary_z:v2_sim_dis_diff_test_sq_z                      -0.052416
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     0.003655
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  0.042590
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.041139
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  0.014840
#                                                                  Std. Error
# (Intercept)                                                        0.065118
# it_sim_dis_diff_test_z                                             0.036519
# it_sim_dis_diff_test_sq_z                                          0.036046
# reliability_binary_z                                               0.035736
# validity_binary_z                                                  0.037582
# v2_sim_dis_diff_test_z                                             0.035953
# v2_sim_dis_diff_test_sq_z                                          0.035586
# it_sim_dis_diff_test_z:reliability_binary_z                        0.036527
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.036243
# it_sim_dis_diff_test_z:validity_binary_z                           0.038315
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.038415
# reliability_binary_z:validity_binary_z                             0.037600
# reliability_binary_z:v2_sim_dis_diff_test_z                        0.035968
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.035446
# validity_binary_z:v2_sim_dis_diff_test_z                           0.037105
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.037057
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z      0.038456
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.038551
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      0.037312
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.036941
#                                                                  z value
# (Intercept)                                                       -4.726
# it_sim_dis_diff_test_z                                             1.049
# it_sim_dis_diff_test_sq_z                                          3.797
# reliability_binary_z                                              -0.464
# validity_binary_z                                                  0.566
# v2_sim_dis_diff_test_z                                             1.062
# v2_sim_dis_diff_test_sq_z                                          3.720
# it_sim_dis_diff_test_z:reliability_binary_z                       -0.606
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.430
# it_sim_dis_diff_test_z:validity_binary_z                          -1.007
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.457
# reliability_binary_z:validity_binary_z                             0.332
# reliability_binary_z:v2_sim_dis_diff_test_z                        0.851
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    -0.249
# validity_binary_z:v2_sim_dis_diff_test_z                          -0.215
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       -1.414
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z      0.095
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   1.105
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      1.103
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.402
#                                                                  Pr(>|z|)
# (Intercept)                                                      2.29e-06 ***
# it_sim_dis_diff_test_z                                           0.294125
# it_sim_dis_diff_test_sq_z                                        0.000147 ***
# reliability_binary_z                                             0.642888
# validity_binary_z                                                0.571290
# v2_sim_dis_diff_test_z                                           0.288455
# v2_sim_dis_diff_test_sq_z                                        0.000199 ***
# it_sim_dis_diff_test_z:reliability_binary_z                      0.544338
# it_sim_dis_diff_test_sq_z:reliability_binary_z                   0.667556
# it_sim_dis_diff_test_z:validity_binary_z                         0.313966
# it_sim_dis_diff_test_sq_z:validity_binary_z                      0.647585
# reliability_binary_z:validity_binary_z                           0.740061
# reliability_binary_z:v2_sim_dis_diff_test_z                      0.394709
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   0.803743
# validity_binary_z:v2_sim_dis_diff_test_z                         0.829565
# validity_binary_z:v2_sim_dis_diff_test_sq_z                      0.157224
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    0.924280
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z 0.269259
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    0.270222
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z 0.687901
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
