# %%
library(lme4)
library(simr)
library(dplyr)

# %%
# install.packages("car")
library(car)

# %%
file_path <- "pilot6.csv"

df <- read.csv(file_path) %>%
    select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z , rt)

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
# head(df$reliability_binary)
#

# %%
# names(df)

# %%
# mean(df$it_sim_dis_diff)

# %%
# model <- glm(
#   resp_correct ~ it_sim_dis_diff_test_z * reliability_binary * validity_binary + 
#              v2_sim_dis_diff_test_z * reliability_binary * validity_binary,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # head(df$v2_sim_dis_test_z)



# formula1 <- glmer(resp_correct ~  v2_sim_dis_test_z * reliability_binary * validity_binary +  
#                    it_sim_dis_test_z * reliability_binary * validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# model <- glm(
#   resp_correct ~ reliability_binary * validity_binary + (1 | participant),
#              y,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # IT*V2*reliability*validity + itsq+v2sq



# formula1 <- glmer(resp_correct ~ it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z * reliability_binary * validity_binary +  
#                    v2_sim_dis_diff_test_sq_z + it_sim_dis_diff_test_sq_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  43876.0  44056.9 -21917.0  43834.0    40779
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0207 -0.8625  0.4575  0.5967  1.5690
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4389   0.6625
# Number of obs: 40800, groups:  participant, 136
#
# Fixed effects:
#                                                             Estimate Std. Error
# (Intercept)                                                  1.13082    0.05820
# it_sim_dis_test_z                                            0.11028    0.02079
# it_sim_dis_test_sq_z                                        -0.08380    0.02094
# reliability_binary_z                                         0.03111    0.01199
# validity_binary_z                                            0.24115    0.01172
# v2_sim_dis_test_z                                            0.06994    0.03260
# v2_sim_dis_test_sq_z                                        -0.11127    0.03261
# it_sim_dis_test_z:reliability_binary_z                      -0.02028    0.02080
# it_sim_dis_test_sq_z:reliability_binary_z                    0.01160    0.02096
# it_sim_dis_test_z:validity_binary_z                          0.04309    0.02048
# it_sim_dis_test_sq_z:validity_binary_z                      -0.03004    0.02053
# reliability_binary_z:validity_binary_z                       0.07802    0.01170
# reliability_binary_z:v2_sim_dis_test_z                      -0.02867    0.03263
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.03392    0.03263
# validity_binary_z:v2_sim_dis_test_z                          0.01183    0.03184
# validity_binary_z:v2_sim_dis_test_sq_z                      -0.01075    0.03114
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    -0.01809    0.02048
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.00785    0.02054
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z    -0.01624    0.03182
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.01790    0.03113
#                                                             z value Pr(>|z|)
# (Intercept)                                                  19.431  < 2e-16
# it_sim_dis_test_z                                             5.306 1.12e-07
# it_sim_dis_test_sq_z                                         -4.003 6.26e-05
# reliability_binary_z                                          2.595 0.009449
# validity_binary_z                                            20.580  < 2e-16
# v2_sim_dis_test_z                                             2.145 0.031952
# v2_sim_dis_test_sq_z                                         -3.413 0.000644
# it_sim_dis_test_z:reliability_binary_z                       -0.975 0.329672
# it_sim_dis_test_sq_z:reliability_binary_z                     0.553 0.580126
# it_sim_dis_test_z:validity_binary_z                           2.104 0.035348
# it_sim_dis_test_sq_z:validity_binary_z                       -1.463 0.143387
# reliability_binary_z:validity_binary_z                        6.670 2.57e-11
# reliability_binary_z:v2_sim_dis_test_z                       -0.879 0.379536
# reliability_binary_z:v2_sim_dis_test_sq_z                     1.040 0.298519
# validity_binary_z:v2_sim_dis_test_z                           0.372 0.710129
# validity_binary_z:v2_sim_dis_test_sq_z                       -0.345 0.730058
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     -0.883 0.377087
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z   0.382 0.702285
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     -0.510 0.609829
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z   0.575 0.565307
#
# (Intercept)                                                 ***
# it_sim_dis_test_z                                           ***
# it_sim_dis_test_sq_z                                        ***
# reliability_binary_z                                        **
# validity_binary_z                                           ***
# v2_sim_dis_test_z                                           *
# v2_sim_dis_test_sq_z                                        ***
# it_sim_dis_test_z:reliability_binary_z
# it_sim_dis_test_sq_z:reliability_binary_z
# it_sim_dis_test_z:validity_binary_z                         *
# it_sim_dis_test_sq_z:validity_binary_z
# reliability_binary_z:validity_binary_z                      ***
# reliability_binary_z:v2_sim_dis_test_z
# reliability_binary_z:v2_sim_dis_test_sq_z
# validity_binary_z:v2_sim_dis_test_z
# validity_binary_z:v2_sim_dis_test_sq_z
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: resp_correct ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_z +
#     v2_sim_dis_diff_test_sq_z) * reliability_binary_z * validity_binary_z +
#     it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#  43868.8  44058.4 -21912.4  43824.8    40778
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.0724 -0.8582  0.4566  0.5959  1.5968
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4384   0.6621
# Number of obs: 40800, groups:  participant, 136
#
# Fixed effects:
#                                                                   Estimate
# (Intercept)                                                       1.130787
# it_sim_dis_diff_test_z                                            0.043940
# it_sim_dis_diff_test_sq_z                                        -0.052890
# reliability_binary_z                                              0.030989
# validity_binary_z                                                 0.241355
# v2_sim_dis_diff_test_z                                           -0.024009
# v2_sim_dis_diff_test_sq_z                                        -0.052144
# it_sim_dis_diff_test_z:reliability_binary_z                      -0.007429
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.005758
# it_sim_dis_diff_test_z:validity_binary_z                          0.016436
# it_sim_dis_diff_test_sq_z:validity_binary_z                      -0.009181
# reliability_binary_z:validity_binary_z                            0.076924
# reliability_binary_z:v2_sim_dis_diff_test_z                      -0.001252
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    0.009564
# validity_binary_z:v2_sim_dis_diff_test_z                          0.004225
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       0.004094
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     0.004665
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    -0.009654
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z -0.002588
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.009494
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z -0.004707
#                                                                  Std. Error
# (Intercept)                                                        0.058198
# it_sim_dis_diff_test_z                                             0.012024
# it_sim_dis_diff_test_sq_z                                          0.012420
# reliability_binary_z                                               0.011994
# validity_binary_z                                                  0.011722
# v2_sim_dis_diff_test_z                                             0.012028
# v2_sim_dis_diff_test_sq_z                                          0.012410
# it_sim_dis_diff_test_z:reliability_binary_z                        0.012029
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.011898
# it_sim_dis_diff_test_z:validity_binary_z                           0.011820
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.011548
# reliability_binary_z:validity_binary_z                             0.011703
# reliability_binary_z:v2_sim_dis_diff_test_z                        0.012028
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.011909
# validity_binary_z:v2_sim_dis_diff_test_z                           0.011722
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.011465
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      0.012741
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z      0.011816
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.011551
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      0.011731
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.011465
#                                                                  z value
# (Intercept)                                                       19.430
# it_sim_dis_diff_test_z                                             3.654
# it_sim_dis_diff_test_sq_z                                         -4.258
# reliability_binary_z                                               2.584
# validity_binary_z                                                 20.589
# v2_sim_dis_diff_test_z                                            -1.996
# v2_sim_dis_diff_test_sq_z                                         -4.202
# it_sim_dis_diff_test_z:reliability_binary_z                       -0.618
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.484
# it_sim_dis_diff_test_z:validity_binary_z                           1.390
# it_sim_dis_diff_test_sq_z:validity_binary_z                       -0.795
# reliability_binary_z:validity_binary_z                             6.573
# reliability_binary_z:v2_sim_dis_diff_test_z                       -0.104
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.803
# validity_binary_z:v2_sim_dis_diff_test_z                           0.360
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.357
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      0.366
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     -0.817
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  -0.224
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      0.809
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  -0.411
#                                                                  Pr(>|z|)
# (Intercept)                                                       < 2e-16 ***
# it_sim_dis_diff_test_z                                           0.000258 ***
# it_sim_dis_diff_test_sq_z                                        2.06e-05 ***
# reliability_binary_z                                             0.009771 **
# validity_binary_z                                                 < 2e-16 ***
# v2_sim_dis_diff_test_z                                           0.045928 *
# v2_sim_dis_diff_test_sq_z                                        2.65e-05 ***
# it_sim_dis_diff_test_z:reliability_binary_z                      0.536862
# it_sim_dis_diff_test_sq_z:reliability_binary_z                   0.628437
# it_sim_dis_diff_test_z:validity_binary_z                         0.164386
# it_sim_dis_diff_test_sq_z:validity_binary_z                      0.426588
# reliability_binary_z:validity_binary_z                           4.93e-11 ***
# reliability_binary_z:v2_sim_dis_diff_test_z                      0.917120
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   0.421901
# validity_binary_z:v2_sim_dis_diff_test_z                         0.718517
# validity_binary_z:v2_sim_dis_diff_test_sq_z                      0.721053
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                    0.714253
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    0.413930
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z 0.822685
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    0.418315
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z 0.681372
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# formula11 <- glmer(resp_correct ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_attend_z + v2_sim_dis_attend_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula11)

# %%
# formula10 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_diff_z * v2_sim_dis_diff_z +  (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula10)

# %%
library(lmerTest)

# %%
df_correct <- subset(df, resp_correct == 1)

# %%
formula_rt1 <- lmer(rt ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
                validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
                validity_binary_z + (1 | participant), 
                data = df_correct, control = lmerControl(optimizer = "bobyqa"))
summary(formula_rt1)  # Will now include p-values
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# rt ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df_correct
# Control: lmerControl(optimizer = "bobyqa")
#
# REML criterion at convergence: 40142.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.0547 -0.7384 -0.1689  0.5764  3.9734
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.03243  0.1801
#  Residual                0.21773  0.4666
# Number of obs: 30078, groups:  participant, 136
#
# Fixed effects:
#                                                               Estimate
# (Intercept)                                                  1.576e+00
# it_sim_dis_test_z                                           -3.687e-02
# it_sim_dis_test_sq_z                                         2.566e-02
# reliability_binary_z                                        -1.811e-02
# validity_binary_z                                           -3.759e-02
# v2_sim_dis_test_z                                            1.328e-02
# v2_sim_dis_test_sq_z                                         8.901e-04
# it_sim_dis_test_z:reliability_binary_z                       1.065e-03
# it_sim_dis_test_sq_z:reliability_binary_z                    1.949e-03
# it_sim_dis_test_z:validity_binary_z                         -1.122e-02
# it_sim_dis_test_sq_z:validity_binary_z                       8.899e-03
# reliability_binary_z:validity_binary_z                      -2.019e-02
# reliability_binary_z:v2_sim_dis_test_z                      -4.828e-03
# reliability_binary_z:v2_sim_dis_test_sq_z                    4.942e-03
# validity_binary_z:v2_sim_dis_test_z                         -1.919e-02
# validity_binary_z:v2_sim_dis_test_sq_z                       2.784e-02
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    -5.494e-03
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  2.199e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z    -1.452e-02
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  1.728e-02
#                                                             Std. Error
# (Intercept)                                                  1.570e-02
# it_sim_dis_test_z                                            4.882e-03
# it_sim_dis_test_sq_z                                         4.893e-03
# reliability_binary_z                                         2.772e-03
# validity_binary_z                                            2.975e-03
# v2_sim_dis_test_z                                            7.728e-03
# v2_sim_dis_test_sq_z                                         7.848e-03
# it_sim_dis_test_z:reliability_binary_z                       4.887e-03
# it_sim_dis_test_sq_z:reliability_binary_z                    4.900e-03
# it_sim_dis_test_z:validity_binary_z                          5.221e-03
# it_sim_dis_test_sq_z:validity_binary_z                       5.240e-03
# reliability_binary_z:validity_binary_z                       2.964e-03
# reliability_binary_z:v2_sim_dis_test_z                       7.736e-03
# reliability_binary_z:v2_sim_dis_test_sq_z                    7.855e-03
# validity_binary_z:v2_sim_dis_test_z                          8.238e-03
# validity_binary_z:v2_sim_dis_test_sq_z                       8.163e-03
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     5.219e-03
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  5.239e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     8.236e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  8.160e-03
#                                                                     df t value
# (Intercept)                                                  1.359e+02 100.402
# it_sim_dis_test_z                                            2.993e+04  -7.551
# it_sim_dis_test_sq_z                                         2.993e+04   5.244
# reliability_binary_z                                         2.993e+04  -6.533
# validity_binary_z                                            2.994e+04 -12.635
# v2_sim_dis_test_z                                            2.993e+04   1.718
# v2_sim_dis_test_sq_z                                         2.993e+04   0.113
# it_sim_dis_test_z:reliability_binary_z                       2.993e+04   0.218
# it_sim_dis_test_sq_z:reliability_binary_z                    2.993e+04   0.398
# it_sim_dis_test_z:validity_binary_z                          2.993e+04  -2.149
# it_sim_dis_test_sq_z:validity_binary_z                       2.993e+04   1.698
# reliability_binary_z:validity_binary_z                       2.993e+04  -6.814
# reliability_binary_z:v2_sim_dis_test_z                       2.993e+04  -0.624
# reliability_binary_z:v2_sim_dis_test_sq_z                    2.993e+04   0.629
# validity_binary_z:v2_sim_dis_test_z                          2.993e+04  -2.329
# validity_binary_z:v2_sim_dis_test_sq_z                       2.993e+04   3.410
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     2.993e+04  -1.053
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  2.993e+04   0.420
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     2.993e+04  -1.763
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  2.993e+04   2.117
#                                                             Pr(>|t|)
# (Intercept)                                                  < 2e-16 ***
# it_sim_dis_test_z                                           4.44e-14 ***
# it_sim_dis_test_sq_z                                        1.58e-07 ***
# reliability_binary_z                                        6.53e-11 ***
# validity_binary_z                                            < 2e-16 ***
# v2_sim_dis_test_z                                            0.08579 .
# v2_sim_dis_test_sq_z                                         0.90971
# it_sim_dis_test_z:reliability_binary_z                       0.82755
# it_sim_dis_test_sq_z:reliability_binary_z                    0.69078
# it_sim_dis_test_z:validity_binary_z                          0.03163 *
# it_sim_dis_test_sq_z:validity_binary_z                       0.08947 .
# reliability_binary_z:validity_binary_z                      9.69e-12 ***
# reliability_binary_z:v2_sim_dis_test_z                       0.53257
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.52924
# validity_binary_z:v2_sim_dis_test_z                          0.01986 *
# validity_binary_z:v2_sim_dis_test_sq_z                       0.00065 ***
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.29250
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.67475
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.07794 .
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.03423 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula_rt2 <- lmer(rt ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant), 
                  data = df_correct, control = lmerControl(optimizer = "bobyqa"))

summary(formula_rt2)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# rt ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + it_sim_dis_diff_test_z *
#     v2_sim_dis_diff_test_z + (1 | participant)
#    Data: df_correct
# Control: lmerControl(optimizer = "bobyqa")
#
# REML criterion at convergence: 40151.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.9035 -0.7384 -0.1717  0.5793  3.9670
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.03243  0.1801
#  Residual                0.21763  0.4665
# Number of obs: 30078, groups:  participant, 136
#
# Fixed effects:
#                                                                    Estimate
# (Intercept)                                                       1.577e+00
# it_sim_dis_diff_test_z                                           -1.717e-02
# it_sim_dis_diff_test_sq_z                                         2.124e-02
# reliability_binary_z                                             -1.798e-02
# validity_binary_z                                                -3.784e-02
# v2_sim_dis_diff_test_z                                            1.002e-02
# v2_sim_dis_diff_test_sq_z                                         1.107e-02
# it_sim_dis_diff_test_z:reliability_binary_z                       2.463e-03
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    1.184e-03
# it_sim_dis_diff_test_z:validity_binary_z                         -1.324e-03
# it_sim_dis_diff_test_sq_z:validity_binary_z                       5.667e-03
# reliability_binary_z:validity_binary_z                           -1.994e-02
# reliability_binary_z:v2_sim_dis_diff_test_z                       2.173e-04
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   -6.574e-04
# validity_binary_z:v2_sim_dis_diff_test_z                          3.552e-03
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       5.868e-03
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                    -8.511e-03
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    -2.857e-03
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  5.528e-04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    -3.137e-04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  3.914e-03
#                                                                  Std. Error
# (Intercept)                                                       1.570e-02
# it_sim_dis_diff_test_z                                            2.815e-03
# it_sim_dis_diff_test_sq_z                                         2.874e-03
# reliability_binary_z                                              2.771e-03
# validity_binary_z                                                 2.974e-03
# v2_sim_dis_diff_test_z                                            2.814e-03
# v2_sim_dis_diff_test_sq_z                                         2.890e-03
# it_sim_dis_diff_test_z:reliability_binary_z                       2.815e-03
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    2.765e-03
# it_sim_dis_diff_test_z:validity_binary_z                          3.017e-03
# it_sim_dis_diff_test_sq_z:validity_binary_z                       2.941e-03
# reliability_binary_z:validity_binary_z                            2.963e-03
# reliability_binary_z:v2_sim_dis_diff_test_z                       2.812e-03
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    2.776e-03
# validity_binary_z:v2_sim_dis_diff_test_z                          2.997e-03
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       2.926e-03
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     2.975e-03
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     3.016e-03
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  2.939e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     2.999e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  2.928e-03
#                                                                          df
# (Intercept)                                                       1.361e+02
# it_sim_dis_diff_test_z                                            2.993e+04
# it_sim_dis_diff_test_sq_z                                         2.993e+04
# reliability_binary_z                                              2.992e+04
# validity_binary_z                                                 2.994e+04
# v2_sim_dis_diff_test_z                                            2.993e+04
# v2_sim_dis_diff_test_sq_z                                         2.993e+04
# it_sim_dis_diff_test_z:reliability_binary_z                       2.993e+04
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    2.993e+04
# it_sim_dis_diff_test_z:validity_binary_z                          2.993e+04
# it_sim_dis_diff_test_sq_z:validity_binary_z                       2.993e+04
# reliability_binary_z:validity_binary_z                            2.993e+04
# reliability_binary_z:v2_sim_dis_diff_test_z                       2.993e+04
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    2.993e+04
# validity_binary_z:v2_sim_dis_diff_test_z                          2.993e+04
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       2.993e+04
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     2.992e+04
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     2.992e+04
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  2.993e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     2.993e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  2.993e+04
#                                                                  t value
# (Intercept)                                                      100.449
# it_sim_dis_diff_test_z                                            -6.098
# it_sim_dis_diff_test_sq_z                                          7.389
# reliability_binary_z                                              -6.490
# validity_binary_z                                                -12.723
# v2_sim_dis_diff_test_z                                             3.560
# v2_sim_dis_diff_test_sq_z                                          3.831
# it_sim_dis_diff_test_z:reliability_binary_z                        0.875
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.428
# it_sim_dis_diff_test_z:validity_binary_z                          -0.439
# it_sim_dis_diff_test_sq_z:validity_binary_z                        1.927
# reliability_binary_z:validity_binary_z                            -6.731
# reliability_binary_z:v2_sim_dis_diff_test_z                        0.077
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    -0.237
# validity_binary_z:v2_sim_dis_diff_test_z                           1.185
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        2.006
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     -2.861
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     -0.947
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.188
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     -0.105
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   1.337
#                                                                  Pr(>|t|)
# (Intercept)                                                       < 2e-16 ***
# it_sim_dis_diff_test_z                                           1.08e-09 ***
# it_sim_dis_diff_test_sq_z                                        1.51e-13 ***
# reliability_binary_z                                             8.74e-11 ***
# validity_binary_z                                                 < 2e-16 ***
# v2_sim_dis_diff_test_z                                           0.000371 ***
# v2_sim_dis_diff_test_sq_z                                        0.000128 ***
# it_sim_dis_diff_test_z:reliability_binary_z                      0.381625
# it_sim_dis_diff_test_sq_z:reliability_binary_z                   0.668677
# it_sim_dis_diff_test_z:validity_binary_z                         0.660728
# it_sim_dis_diff_test_sq_z:validity_binary_z                      0.053989 .
# reliability_binary_z:validity_binary_z                           1.72e-11 ***
# reliability_binary_z:v2_sim_dis_diff_test_z                      0.938411
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   0.812830
# validity_binary_z:v2_sim_dis_diff_test_z                         0.235941
# validity_binary_z:v2_sim_dis_diff_test_sq_z                      0.044916 *
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                    0.004222 **
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    0.343429
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z 0.850814
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    0.916690
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z 0.181323
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# formula_rt3 <- lmer(rt ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_attend_z + v2_sim_dis_attend_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant), 
#                   data = df_correct, control = lmerControl(optimizer = "bobyqa"))
# summary(formula_rt3)

# %%
# formula_rt4 <- lmer(rt ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *  
#                   validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary_z *  
#                   validity_binary_z + it_sim_dis_diff_z * v2_sim_dis_diff_z +  (1 | participant), 
#                   data = df_correct, control = lmerControl(optimizer = "bobyqa"))
# summary(formula_rt4)

# %%
# formula1 <- glmer(resp_correct ~ (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary *  
#                   validity_binary + (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_attend * reliability_binary *  
#                   validity_binary + v2_sim_dis_attend * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# formula2 <- glmer(resp_correct ~ it_sim_dis_unattend * reliability_binary *  
#                   validity_binary + v2_sim_dis_unattend * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula2)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# head(df$reliability_binary)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))


# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula10 <- glmer(resp_correct ~ (it_sim_dis_unattend_z + it_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_unattend_z + v2_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula10)
