# %%
library(lme4)
library(simr)
library(dplyr)
library(lmerTest)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
# install.packages("car")
library(car)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode

# %%
file_path <- "pilot_total.csv"
# file_path <- "pilot_TOTAL_clean.csv"


df <- read.csv(file_path) %>%
    select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z, v2_sim_dis_test_z, it_sim_dis_test_z, it_sim_dis_diff_test, it_sim_dis_diff_test_sq, v2_sim_dis_diff_test, v2_sim_dis_diff_test_z,it_sim_dis_diff_test_z, v2_sim_dis_diff_test_sq_z, it_sim_dis_diff_test_sq_z, it_sim_dis_test_sq_z, validity_binary_z, reliability_binary_z, v2_sim_dis_test_sq_z, rt,tested_memorability_resmem_z, v2_pos_neg_abs_z, it_pos_neg_abs_z, it_pos_neg_z, v2_pos_neg_z, it_sim_dis_diff_test_sign_z, it_sim_dis_diff_test_sign_sq_z,v2_sim_dis_diff_test_sign_z, v2_sim_dis_diff_test_sign_sq_z, it_sim_dis_test_sign_z, it_sim_dis_test_sign_sq_z,v2_sim_dis_test_sign_z, v2_sim_dis_test_sign_sq_z, it_int_abs, v2_int_abs, it_int_rel, v2_int_rel, it_int_rel_sq, v2_int_rel_sq, it_int_abs, v2_int_abs, it_int_abs_sq, v2_int_abs_sq, it_pos_neg_abs, v2_pos_neg_abs, it_pos_neg, v2_pos_neg)

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
df_correct <- subset(df, resp_correct == 1)
#

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) * it_pos_neg_abs * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 44 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: resp_correct ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) *
#     it_pos_neg_abs * reliability_binary_z * validity_binary_z +
#     (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs *
#         reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#  84470.4  84888.5 -42190.2  84380.4    80055
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1120 -0.7733  0.4400  0.5868  1.6566
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4815   0.6939
# Number of obs: 80100, groups:  participant, 267
#
# Fixed effects:
#                                                                                   Estimate
# (Intercept)                                                                      1.1840433
# it_sim_dis_test_sign_z                                                          -0.0353379
# it_sim_dis_test_sign_sq_z                                                       -0.0222466
# it_pos_neg_abs                                                                   0.0559641
# reliability_binary_z                                                             0.0322360
# validity_binary_z                                                                0.2120103
# v2_sim_dis_test_sign_z                                                          -0.0201414
# v2_sim_dis_test_sign_sq_z                                                       -0.0218397
# v2_pos_neg_abs                                                                   0.0172820
# it_sim_dis_test_sign_z:it_pos_neg_abs                                            0.0420372
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        -0.0380838
# it_sim_dis_test_sign_z:reliability_binary_z                                      0.0092852
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                   0.0111391
# it_pos_neg_abs:reliability_binary_z                                             -0.0077442
# it_sim_dis_test_sign_z:validity_binary_z                                        -0.0028928
# it_sim_dis_test_sign_sq_z:validity_binary_z                                      0.0090385
# it_pos_neg_abs:validity_binary_z                                                -0.0058089
# reliability_binary_z:validity_binary_z                                           0.0760433
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                           -0.0262083
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                         0.0263777
# reliability_binary_z:v2_sim_dis_test_sign_z                                      0.0057235
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                   0.0015051
# reliability_binary_z:v2_pos_neg_abs                                             -0.0079542
# validity_binary_z:v2_sim_dis_test_sign_z                                        -0.0005765
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                      0.0204723
# validity_binary_z:v2_pos_neg_abs                                                -0.0006175
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                      -0.0049969
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                   -0.0048236
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                          0.0202306
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                      -0.0104716
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                    0.0024477
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                 0.0107680
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           -0.0194885
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                      -0.0031230
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                   -0.0187032
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                         -0.0202001
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                      -0.0117125
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                    0.0080921
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                -0.0108625
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                            0.0106095
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z     0.0135998
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z -0.0059339
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs    -0.0137629
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs  0.0170072
#                                                                                 Std. Error
# (Intercept)                                                                      0.0436293
# it_sim_dis_test_sign_z                                                           0.0087936
# it_sim_dis_test_sign_sq_z                                                        0.0087748
# it_pos_neg_abs                                                                   0.0087479
# reliability_binary_z                                                             0.0095551
# validity_binary_z                                                                0.0094363
# v2_sim_dis_test_sign_z                                                           0.0109415
# v2_sim_dis_test_sign_sq_z                                                        0.0174544
# v2_pos_neg_abs                                                                   0.0098049
# it_sim_dis_test_sign_z:it_pos_neg_abs                                            0.0089459
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                         0.0088165
# it_sim_dis_test_sign_z:reliability_binary_z                                      0.0088003
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                   0.0087793
# it_pos_neg_abs:reliability_binary_z                                              0.0087483
# it_sim_dis_test_sign_z:validity_binary_z                                         0.0086349
# it_sim_dis_test_sign_sq_z:validity_binary_z                                      0.0086229
# it_pos_neg_abs:validity_binary_z                                                 0.0085781
# reliability_binary_z:validity_binary_z                                           0.0094275
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                            0.0111795
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                         0.0174687
# reliability_binary_z:v2_sim_dis_test_sign_z                                      0.0108902
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                   0.0174231
# reliability_binary_z:v2_pos_neg_abs                                              0.0096705
# validity_binary_z:v2_sim_dis_test_sign_z                                         0.0106822
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                      0.0173927
# validity_binary_z:v2_pos_neg_abs                                                 0.0095186
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                       0.0089201
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                    0.0088187
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                          0.0087304
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                       0.0086785
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                    0.0086371
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                 0.0086227
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                            0.0085763
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                       0.0108811
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                    0.0174000
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                          0.0106867
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                       0.0173636
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                    0.0106762
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                 0.0173897
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                            0.0095204
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z     0.0087284
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z  0.0086800
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs     0.0106841
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs  0.0173610
#                                                                                 z value
# (Intercept)                                                                      27.139
# it_sim_dis_test_sign_z                                                           -4.019
# it_sim_dis_test_sign_sq_z                                                        -2.535
# it_pos_neg_abs                                                                    6.397
# reliability_binary_z                                                              3.374
# validity_binary_z                                                                22.467
# v2_sim_dis_test_sign_z                                                           -1.841
# v2_sim_dis_test_sign_sq_z                                                        -1.251
# v2_pos_neg_abs                                                                    1.763
# it_sim_dis_test_sign_z:it_pos_neg_abs                                             4.699
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                         -4.320
# it_sim_dis_test_sign_z:reliability_binary_z                                       1.055
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                    1.269
# it_pos_neg_abs:reliability_binary_z                                              -0.885
# it_sim_dis_test_sign_z:validity_binary_z                                         -0.335
# it_sim_dis_test_sign_sq_z:validity_binary_z                                       1.048
# it_pos_neg_abs:validity_binary_z                                                 -0.677
# reliability_binary_z:validity_binary_z                                            8.066
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                            -2.344
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                          1.510
# reliability_binary_z:v2_sim_dis_test_sign_z                                       0.526
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                    0.086
# reliability_binary_z:v2_pos_neg_abs                                              -0.823
# validity_binary_z:v2_sim_dis_test_sign_z                                         -0.054
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                       1.177
# validity_binary_z:v2_pos_neg_abs                                                 -0.065
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                       -0.560
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                    -0.547
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                           2.317
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                       -1.207
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                     0.283
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                  1.249
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                            -2.272
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                       -0.287
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                    -1.075
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                          -1.890
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                       -0.675
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                     0.758
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                 -0.625
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                             1.114
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z      1.558
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z  -0.684
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs     -1.288
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs   0.980
#                                                                                 Pr(>|z|)
# (Intercept)                                                                      < 2e-16
# it_sim_dis_test_sign_z                                                          5.85e-05
# it_sim_dis_test_sign_sq_z                                                       0.011236
# it_pos_neg_abs                                                                  1.58e-10
# reliability_binary_z                                                            0.000742
# validity_binary_z                                                                < 2e-16
# v2_sim_dis_test_sign_z                                                          0.065647
# v2_sim_dis_test_sign_sq_z                                                       0.210845
# v2_pos_neg_abs                                                                  0.077971
# it_sim_dis_test_sign_z:it_pos_neg_abs                                           2.61e-06
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        1.56e-05
# it_sim_dis_test_sign_z:reliability_binary_z                                     0.291377
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                  0.204517
# it_pos_neg_abs:reliability_binary_z                                             0.376038
# it_sim_dis_test_sign_z:validity_binary_z                                        0.737615
# it_sim_dis_test_sign_sq_z:validity_binary_z                                     0.294548
# it_pos_neg_abs:validity_binary_z                                                0.498298
# reliability_binary_z:validity_binary_z                                          7.26e-16
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                           0.019061
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                        0.131044
# reliability_binary_z:v2_sim_dis_test_sign_z                                     0.599192
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                  0.931160
# reliability_binary_z:v2_pos_neg_abs                                             0.410777
# validity_binary_z:v2_sim_dis_test_sign_z                                        0.956962
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                     0.239171
# validity_binary_z:v2_pos_neg_abs                                                0.948277
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                      0.575348
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                   0.584397
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                         0.020490
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                      0.227579
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                   0.776879
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                0.211740
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           0.023065
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                      0.774105
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                   0.282420
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                         0.058730
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                      0.499968
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                   0.448480
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                0.532198
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                           0.265108
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z    0.119206
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z 0.494213
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs    0.197687
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs 0.327273
#
# (Intercept)                                                                     ***
# it_sim_dis_test_sign_z                                                          ***
# it_sim_dis_test_sign_sq_z                                                       *
# it_pos_neg_abs                                                                  ***
# reliability_binary_z                                                            ***
# validity_binary_z                                                               ***
# v2_sim_dis_test_sign_z                                                          .
# v2_sim_dis_test_sign_sq_z
# v2_pos_neg_abs                                                                  .
# it_sim_dis_test_sign_z:it_pos_neg_abs                                           ***
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        ***
# it_sim_dis_test_sign_z:reliability_binary_z
# it_sim_dis_test_sign_sq_z:reliability_binary_z
# it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:validity_binary_z
# it_pos_neg_abs:validity_binary_z
# reliability_binary_z:validity_binary_z                                          ***
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                           *
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# reliability_binary_z:v2_sim_dis_test_sign_z
# reliability_binary_z:v2_sim_dis_test_sign_sq_z
# reliability_binary_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_z
# validity_binary_z:v2_sim_dis_test_sign_sq_z
# validity_binary_z:v2_pos_neg_abs
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                         *
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           *
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                         .
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) * it_pos_neg * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_sign_z + v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 44 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# resp_correct ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) *
#     it_pos_neg * reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_sign_z +
#     v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *
#     validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#  84436.3  84854.4 -42173.1  84346.3    80055
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.2619 -0.7682  0.4402  0.5868  1.7626
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.4816   0.694
# Number of obs: 80100, groups:  participant, 267
#
# Fixed effects:
#                                                                                    Estimate
# (Intercept)                                                                       1.1838400
# it_sim_dis_diff_test_sign_z                                                      -0.0430719
# it_sim_dis_diff_test_sign_sq_z                                                    0.0015379
# it_pos_neg                                                                        0.0531067
# reliability_binary_z                                                              0.0282796
# validity_binary_z                                                                 0.2051146
# v2_sim_dis_diff_test_sign_z                                                      -0.0504168
# v2_sim_dis_diff_test_sign_sq_z                                                   -0.0096452
# v2_pos_neg                                                                        0.0072096
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            0.0558731
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                        -0.0186466
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  0.0029539
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               0.0028600
# it_pos_neg:reliability_binary_z                                                  -0.0062905
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     0.0029916
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  0.0139687
# it_pos_neg:validity_binary_z                                                     -0.0033028
# reliability_binary_z:validity_binary_z                                            0.0762008
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            0.0073218
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         0.0234774
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  0.0037519
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                              -0.0071776
# reliability_binary_z:v2_pos_neg                                                  -0.0116772
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                    -0.0026073
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  0.0114761
# validity_binary_z:v2_pos_neg                                                      0.0008020
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                      -0.0009820
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                   -0.0110914
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          0.0139069
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       0.0257662
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                0.0055833
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             0.0059252
# it_pos_neg:reliability_binary_z:validity_binary_z                                -0.0085895
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       0.0003655
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                   -0.0068709
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                         -0.0010118
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                      -0.0040987
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z               -0.0066728
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             0.0033841
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 0.0013970
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z    -0.0041985
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  0.0213575
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     0.0157001
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  0.0001990
#                                                                                  Std. Error
# (Intercept)                                                                       0.0434377
# it_sim_dis_diff_test_sign_z                                                       0.0086549
# it_sim_dis_diff_test_sign_sq_z                                                    0.0086661
# it_pos_neg                                                                        0.0087969
# reliability_binary_z                                                              0.0086630
# validity_binary_z                                                                 0.0085080
# v2_sim_dis_diff_test_sign_z                                                       0.0086596
# v2_sim_dis_diff_test_sign_sq_z                                                    0.0086512
# v2_pos_neg                                                                        0.0088474
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            0.0087199
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         0.0088328
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  0.0086682
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               0.0086779
# it_pos_neg:reliability_binary_z                                                   0.0087962
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     0.0084365
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  0.0084970
# it_pos_neg:validity_binary_z                                                      0.0086266
# reliability_binary_z:validity_binary_z                                            0.0084982
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            0.0088264
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         0.0086705
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  0.0086694
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               0.0086668
# reliability_binary_z:v2_pos_neg                                                   0.0088472
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     0.0084408
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  0.0084125
# validity_binary_z:v2_pos_neg                                                      0.0086714
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       0.0087251
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    0.0088291
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          0.0084891
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       0.0086505
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                0.0084363
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             0.0084941
# it_pos_neg:reliability_binary_z:validity_binary_z                                 0.0086265
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       0.0088249
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    0.0086774
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          0.0085934
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       0.0084226
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                0.0084435
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             0.0084156
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 0.0086747
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     0.0084859
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  0.0086499
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     0.0085876
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  0.0084221
#                                                                                  z value
# (Intercept)                                                                       27.254
# it_sim_dis_diff_test_sign_z                                                       -4.977
# it_sim_dis_diff_test_sign_sq_z                                                     0.177
# it_pos_neg                                                                         6.037
# reliability_binary_z                                                               3.264
# validity_binary_z                                                                 24.109
# v2_sim_dis_diff_test_sign_z                                                       -5.822
# v2_sim_dis_diff_test_sign_sq_z                                                    -1.115
# v2_pos_neg                                                                         0.815
# it_sim_dis_diff_test_sign_z:it_pos_neg                                             6.408
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         -2.111
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                   0.341
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                                0.330
# it_pos_neg:reliability_binary_z                                                   -0.715
# it_sim_dis_diff_test_sign_z:validity_binary_z                                      0.355
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                   1.644
# it_pos_neg:validity_binary_z                                                      -0.383
# reliability_binary_z:validity_binary_z                                             8.967
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                             0.830
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                          2.708
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                   0.433
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               -0.828
# reliability_binary_z:v2_pos_neg                                                   -1.320
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     -0.309
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                   1.364
# validity_binary_z:v2_pos_neg                                                       0.092
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       -0.113
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    -1.256
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                           1.638
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                        2.979
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                 0.662
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z              0.698
# it_pos_neg:reliability_binary_z:validity_binary_z                                 -0.996
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                        0.041
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    -0.792
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          -0.118
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       -0.487
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                -0.790
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z              0.402
# reliability_binary_z:validity_binary_z:v2_pos_neg                                  0.161
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     -0.495
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z   2.469
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg      1.828
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg   0.024
#                                                                                  Pr(>|z|)
# (Intercept)                                                                       < 2e-16
# it_sim_dis_diff_test_sign_z                                                      6.47e-07
# it_sim_dis_diff_test_sign_sq_z                                                    0.85915
# it_pos_neg                                                                       1.57e-09
# reliability_binary_z                                                              0.00110
# validity_binary_z                                                                 < 2e-16
# v2_sim_dis_diff_test_sign_z                                                      5.81e-09
# v2_sim_dis_diff_test_sign_sq_z                                                    0.26489
# v2_pos_neg                                                                        0.41514
# it_sim_dis_diff_test_sign_z:it_pos_neg                                           1.48e-10
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         0.03477
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  0.73327
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               0.74173
# it_pos_neg:reliability_binary_z                                                   0.47452
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     0.72289
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  0.10018
# it_pos_neg:validity_binary_z                                                      0.70183
# reliability_binary_z:validity_binary_z                                            < 2e-16
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            0.40680
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         0.00677
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  0.66518
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               0.40757
# reliability_binary_z:v2_pos_neg                                                   0.18688
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     0.75740
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  0.17251
# validity_binary_z:v2_pos_neg                                                      0.92631
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       0.91039
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    0.20903
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          0.10138
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       0.00290
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                0.50809
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             0.48545
# it_pos_neg:reliability_binary_z:validity_binary_z                                 0.31939
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       0.96696
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    0.42847
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          0.90627
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       0.62652
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                0.42935
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             0.68760
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 0.87206
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     0.62077
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  0.01354
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     0.06751
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  0.98115
#
# (Intercept)                                                                      ***
# it_sim_dis_diff_test_sign_z                                                      ***
# it_sim_dis_diff_test_sign_sq_z
# it_pos_neg                                                                       ***
# reliability_binary_z                                                             **
# validity_binary_z                                                                ***
# v2_sim_dis_diff_test_sign_z                                                      ***
# v2_sim_dis_diff_test_sign_sq_z
# v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg                                           ***
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                        *
# it_sim_dis_diff_test_sign_z:reliability_binary_z
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z
# it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z
# it_pos_neg:validity_binary_z
# reliability_binary_z:validity_binary_z                                           ***
# v2_sim_dis_diff_test_sign_z:v2_pos_neg
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                        **
# reliability_binary_z:v2_sim_dis_diff_test_sign_z
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z
# reliability_binary_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_z
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z
# validity_binary_z:v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                      **
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z
# it_pos_neg:reliability_binary_z:validity_binary_z
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z
# reliability_binary_z:validity_binary_z:v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z *
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg    .
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula_rt1 <- lmer(rt ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) * it_pos_neg_abs * reliability_binary_z *  
                validity_binary_z + (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs * reliability_binary_z *  
                validity_binary_z + (1 | participant), 
                data = df_correct, control = lmerControl(optimizer = "bobyqa"))
summary(formula_rt1)
# Out:
# Correlation matrix not shown by default, as p = 44 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# rt ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) * it_pos_neg_abs *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_test_sign_z +
#     v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs * reliability_binary_z *
#     validity_binary_z + (1 | participant)
#    Data: df_correct
# Control: lmerControl(optimizer = "bobyqa")
#
# REML criterion at convergence: 79472.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.3593 -0.7352 -0.1704  0.5746  3.9228
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.03528  0.1878
#  Residual                0.21713  0.4660
# Number of obs: 59591, groups:  participant, 267
#
# Fixed effects:
#                                                                                   Estimate
# (Intercept)                                                                      1.566e+00
# it_sim_dis_test_sign_z                                                           1.381e-02
# it_sim_dis_test_sign_sq_z                                                        6.390e-03
# it_pos_neg_abs                                                                  -1.367e-02
# reliability_binary_z                                                            -1.680e-02
# validity_binary_z                                                               -4.285e-02
# v2_sim_dis_test_sign_z                                                          -3.213e-03
# v2_sim_dis_test_sign_sq_z                                                       -1.086e-02
# v2_pos_neg_abs                                                                  -6.183e-03
# it_sim_dis_test_sign_z:it_pos_neg_abs                                            3.896e-04
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                         7.974e-03
# it_sim_dis_test_sign_z:reliability_binary_z                                      2.032e-03
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                  -1.671e-03
# it_pos_neg_abs:reliability_binary_z                                              2.215e-03
# it_sim_dis_test_sign_z:validity_binary_z                                         3.637e-03
# it_sim_dis_test_sign_sq_z:validity_binary_z                                     -1.009e-03
# it_pos_neg_abs:validity_binary_z                                                -5.337e-04
# reliability_binary_z:validity_binary_z                                          -1.951e-02
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                            8.687e-03
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                         5.848e-03
# reliability_binary_z:v2_sim_dis_test_sign_z                                      2.005e-03
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                   1.335e-06
# reliability_binary_z:v2_pos_neg_abs                                             -1.576e-03
# validity_binary_z:v2_sim_dis_test_sign_z                                         2.270e-03
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                      3.429e-03
# validity_binary_z:v2_pos_neg_abs                                                -2.010e-03
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                      -1.358e-04
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                    5.334e-03
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                         -1.273e-03
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                       2.622e-04
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                   -3.886e-05
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                 1.867e-04
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           -2.187e-04
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                       2.486e-03
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                   -3.879e-03
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                         -1.073e-03
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                       5.412e-04
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                    1.745e-04
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                 2.000e-03
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                           -3.297e-03
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z    -2.317e-03
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z  3.803e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs     1.932e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs -3.563e-03
#                                                                                 Std. Error
# (Intercept)                                                                      1.170e-02
# it_sim_dis_test_sign_z                                                           2.019e-03
# it_sim_dis_test_sign_sq_z                                                        2.004e-03
# it_pos_neg_abs                                                                   1.985e-03
# reliability_binary_z                                                             2.176e-03
# validity_binary_z                                                                2.339e-03
# v2_sim_dis_test_sign_z                                                           2.494e-03
# v2_sim_dis_test_sign_sq_z                                                        4.012e-03
# v2_pos_neg_abs                                                                   2.235e-03
# it_sim_dis_test_sign_z:it_pos_neg_abs                                            2.050e-03
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                         2.012e-03
# it_sim_dis_test_sign_z:reliability_binary_z                                      2.021e-03
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                   2.005e-03
# it_pos_neg_abs:reliability_binary_z                                              1.985e-03
# it_sim_dis_test_sign_z:validity_binary_z                                         2.151e-03
# it_sim_dis_test_sign_sq_z:validity_binary_z                                      2.137e-03
# it_pos_neg_abs:validity_binary_z                                                 2.109e-03
# reliability_binary_z:validity_binary_z                                           2.333e-03
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                            2.554e-03
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                         4.013e-03
# reliability_binary_z:v2_sim_dis_test_sign_z                                      2.480e-03
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                   4.005e-03
# reliability_binary_z:v2_pos_neg_abs                                              2.203e-03
# validity_binary_z:v2_sim_dis_test_sign_z                                         2.644e-03
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                      4.318e-03
# validity_binary_z:v2_pos_neg_abs                                                 2.358e-03
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                       2.046e-03
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                    2.013e-03
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                          2.175e-03
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                       2.151e-03
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                    2.151e-03
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                 2.138e-03
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                            2.108e-03
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                       2.479e-03
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                    4.000e-03
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                          2.643e-03
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                       4.310e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                    2.643e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                 4.318e-03
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                            2.358e-03
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z     2.174e-03
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z  2.151e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs     2.642e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs  4.310e-03
#                                                                                         df
# (Intercept)                                                                      2.706e+02
# it_sim_dis_test_sign_z                                                           5.929e+04
# it_sim_dis_test_sign_sq_z                                                        5.929e+04
# it_pos_neg_abs                                                                   5.929e+04
# reliability_binary_z                                                             5.929e+04
# validity_binary_z                                                                5.931e+04
# v2_sim_dis_test_sign_z                                                           5.933e+04
# v2_sim_dis_test_sign_sq_z                                                        5.931e+04
# v2_pos_neg_abs                                                                   5.939e+04
# it_sim_dis_test_sign_z:it_pos_neg_abs                                            5.931e+04
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                         5.929e+04
# it_sim_dis_test_sign_z:reliability_binary_z                                      5.930e+04
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                   5.930e+04
# it_pos_neg_abs:reliability_binary_z                                              5.929e+04
# it_sim_dis_test_sign_z:validity_binary_z                                         5.930e+04
# it_sim_dis_test_sign_sq_z:validity_binary_z                                      5.929e+04
# it_pos_neg_abs:validity_binary_z                                                 5.929e+04
# reliability_binary_z:validity_binary_z                                           5.929e+04
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                            5.946e+04
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                         5.932e+04
# reliability_binary_z:v2_sim_dis_test_sign_z                                      5.930e+04
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                   5.929e+04
# reliability_binary_z:v2_pos_neg_abs                                              5.930e+04
# validity_binary_z:v2_sim_dis_test_sign_z                                         5.930e+04
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                      5.930e+04
# validity_binary_z:v2_pos_neg_abs                                                 5.929e+04
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                       5.930e+04
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                    5.929e+04
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                          5.930e+04
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                       5.929e+04
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                    5.930e+04
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                 5.929e+04
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                            5.929e+04
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                       5.929e+04
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                    5.929e+04
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                          5.930e+04
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                       5.930e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                    5.929e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                 5.930e+04
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                            5.930e+04
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z     5.929e+04
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z  5.929e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs     5.929e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs  5.930e+04
#                                                                                 t value
# (Intercept)                                                                     133.815
# it_sim_dis_test_sign_z                                                            6.840
# it_sim_dis_test_sign_sq_z                                                         3.189
# it_pos_neg_abs                                                                   -6.886
# reliability_binary_z                                                             -7.723
# validity_binary_z                                                               -18.322
# v2_sim_dis_test_sign_z                                                           -1.288
# v2_sim_dis_test_sign_sq_z                                                        -2.707
# v2_pos_neg_abs                                                                   -2.766
# it_sim_dis_test_sign_z:it_pos_neg_abs                                             0.190
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                          3.962
# it_sim_dis_test_sign_z:reliability_binary_z                                       1.006
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                   -0.833
# it_pos_neg_abs:reliability_binary_z                                               1.116
# it_sim_dis_test_sign_z:validity_binary_z                                          1.691
# it_sim_dis_test_sign_sq_z:validity_binary_z                                      -0.472
# it_pos_neg_abs:validity_binary_z                                                 -0.253
# reliability_binary_z:validity_binary_z                                           -8.363
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                             3.401
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                          1.457
# reliability_binary_z:v2_sim_dis_test_sign_z                                       0.808
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                    0.000
# reliability_binary_z:v2_pos_neg_abs                                              -0.715
# validity_binary_z:v2_sim_dis_test_sign_z                                          0.858
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                       0.794
# validity_binary_z:v2_pos_neg_abs                                                 -0.853
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                       -0.066
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                     2.650
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                          -0.585
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                        0.122
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                    -0.018
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                  0.087
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                            -0.104
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                        1.003
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                    -0.970
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                          -0.406
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                        0.126
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                     0.066
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                  0.463
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                            -1.398
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z     -1.065
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z   1.768
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs      0.731
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs  -0.827
#                                                                                 Pr(>|t|)
# (Intercept)                                                                      < 2e-16
# it_sim_dis_test_sign_z                                                          7.98e-12
# it_sim_dis_test_sign_sq_z                                                       0.001429
# it_pos_neg_abs                                                                  5.78e-12
# reliability_binary_z                                                            1.15e-14
# validity_binary_z                                                                < 2e-16
# v2_sim_dis_test_sign_z                                                          0.197610
# v2_sim_dis_test_sign_sq_z                                                       0.006791
# v2_pos_neg_abs                                                                  0.005677
# it_sim_dis_test_sign_z:it_pos_neg_abs                                           0.849282
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        7.43e-05
# it_sim_dis_test_sign_z:reliability_binary_z                                     0.314602
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                  0.404680
# it_pos_neg_abs:reliability_binary_z                                             0.264557
# it_sim_dis_test_sign_z:validity_binary_z                                        0.090893
# it_sim_dis_test_sign_sq_z:validity_binary_z                                     0.636912
# it_pos_neg_abs:validity_binary_z                                                0.800239
# reliability_binary_z:validity_binary_z                                           < 2e-16
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                           0.000671
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                        0.145038
# reliability_binary_z:v2_sim_dis_test_sign_z                                     0.418810
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                  0.999734
# reliability_binary_z:v2_pos_neg_abs                                             0.474486
# validity_binary_z:v2_sim_dis_test_sign_z                                        0.390695
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                     0.427085
# validity_binary_z:v2_pos_neg_abs                                                0.393909
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                      0.947103
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                   0.008059
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                         0.558447
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                      0.902987
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                   0.985589
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                0.930399
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           0.917382
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                      0.315861
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                   0.332105
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                         0.684733
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                      0.900064
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                   0.947353
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                0.643306
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                           0.162093
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z    0.286669
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z 0.077062
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs    0.464673
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs 0.408399
#
# (Intercept)                                                                     ***
# it_sim_dis_test_sign_z                                                          ***
# it_sim_dis_test_sign_sq_z                                                       **
# it_pos_neg_abs                                                                  ***
# reliability_binary_z                                                            ***
# validity_binary_z                                                               ***
# v2_sim_dis_test_sign_z
# v2_sim_dis_test_sign_sq_z                                                       **
# v2_pos_neg_abs                                                                  **
# it_sim_dis_test_sign_z:it_pos_neg_abs
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        ***
# it_sim_dis_test_sign_z:reliability_binary_z
# it_sim_dis_test_sign_sq_z:reliability_binary_z
# it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_z:validity_binary_z                                        .
# it_sim_dis_test_sign_sq_z:validity_binary_z
# it_pos_neg_abs:validity_binary_z
# reliability_binary_z:validity_binary_z                                          ***
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                           ***
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# reliability_binary_z:v2_sim_dis_test_sign_z
# reliability_binary_z:v2_sim_dis_test_sign_sq_z
# reliability_binary_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_z
# validity_binary_z:v2_sim_dis_test_sign_sq_z
# validity_binary_z:v2_pos_neg_abs
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                   **
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z
# it_pos_neg_abs:reliability_binary_z:validity_binary_z
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z .
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula_rt2 <- lmer(rt ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) * it_pos_neg  * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_sign_z + v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *  
                  validity_binary_z   + (1 | participant), 
                  data = df_correct, control =lmerControl(optimizer = "bobyqa"))



summary(formula_rt2)
# Out:
# Correlation matrix not shown by default, as p = 44 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: rt ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) *
#     it_pos_neg * reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_sign_z +
#     v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *
#     validity_binary_z + (1 | participant)
#    Data: df_correct
# Control: lmerControl(optimizer = "bobyqa")
#
# REML criterion at convergence: 79517.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.3568 -0.7351 -0.1697  0.5768  3.9641
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.0353   0.1879
#  Residual                0.2173   0.4661
# Number of obs: 59591, groups:  participant, 267
#
# Fixed effects:
#                                                                                    Estimate
# (Intercept)                                                                       1.570e+00
# it_sim_dis_diff_test_sign_z                                                       1.277e-02
# it_sim_dis_diff_test_sign_sq_z                                                    1.121e-05
# it_pos_neg                                                                       -1.371e-02
# reliability_binary_z                                                             -1.719e-02
# validity_binary_z                                                                -4.279e-02
# v2_sim_dis_diff_test_sign_z                                                       5.349e-03
# v2_sim_dis_diff_test_sign_sq_z                                                    5.773e-03
# v2_pos_neg                                                                       -6.743e-03
# it_sim_dis_diff_test_sign_z:it_pos_neg                                           -4.590e-03
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         6.973e-03
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  1.757e-03
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               4.353e-04
# it_pos_neg:reliability_binary_z                                                   1.188e-03
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     4.588e-03
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                 -8.467e-04
# it_pos_neg:validity_binary_z                                                      8.748e-04
# reliability_binary_z:validity_binary_z                                           -1.980e-02
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                           -3.817e-03
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         2.585e-03
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  1.929e-03
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                              -3.525e-04
# reliability_binary_z:v2_pos_neg                                                   2.097e-04
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     2.608e-03
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  1.961e-03
# validity_binary_z:v2_pos_neg                                                      1.824e-04
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       5.897e-04
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    3.233e-03
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                         -1.950e-03
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                      -2.434e-03
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                2.701e-04
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             5.817e-04
# it_pos_neg:reliability_binary_z:validity_binary_z                                -2.053e-04
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                      -2.157e-03
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    1.688e-03
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          1.250e-03
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       5.264e-04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                1.032e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             1.198e-04
# reliability_binary_z:validity_binary_z:v2_pos_neg                                -2.140e-03
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z    -9.677e-04
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z -3.656e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg    -1.077e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg -7.929e-04
#                                                                                  Std. Error
# (Intercept)                                                                       1.167e-02
# it_sim_dis_diff_test_sign_z                                                       1.963e-03
# it_sim_dis_diff_test_sign_sq_z                                                    1.962e-03
# it_pos_neg                                                                        1.996e-03
# reliability_binary_z                                                              1.965e-03
# validity_binary_z                                                                 2.091e-03
# v2_sim_dis_diff_test_sign_z                                                       1.967e-03
# v2_sim_dis_diff_test_sign_sq_z                                                    1.965e-03
# v2_pos_neg                                                                        2.007e-03
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            1.978e-03
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         1.999e-03
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  1.966e-03
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               1.965e-03
# it_pos_neg:reliability_binary_z                                                   1.996e-03
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     2.080e-03
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  2.081e-03
# it_pos_neg:validity_binary_z                                                      2.119e-03
# reliability_binary_z:validity_binary_z                                            2.085e-03
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            2.006e-03
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         1.969e-03
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  1.970e-03
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               1.968e-03
# reliability_binary_z:v2_pos_neg                                                   2.006e-03
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     2.083e-03
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  2.072e-03
# validity_binary_z:v2_pos_neg                                                      2.129e-03
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       1.980e-03
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    1.998e-03
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          2.091e-03
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       2.119e-03
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                2.079e-03
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             2.080e-03
# it_pos_neg:reliability_binary_z:validity_binary_z                                 2.118e-03
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       2.005e-03
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    1.971e-03
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          2.122e-03
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       2.074e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                2.084e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             2.072e-03
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 2.130e-03
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     2.090e-03
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  2.119e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     2.121e-03
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  2.074e-03
#                                                                                          df
# (Intercept)                                                                       2.671e+02
# it_sim_dis_diff_test_sign_z                                                       5.929e+04
# it_sim_dis_diff_test_sign_sq_z                                                    5.929e+04
# it_pos_neg                                                                        5.929e+04
# reliability_binary_z                                                              5.929e+04
# validity_binary_z                                                                 5.931e+04
# v2_sim_dis_diff_test_sign_z                                                       5.929e+04
# v2_sim_dis_diff_test_sign_sq_z                                                    5.929e+04
# v2_pos_neg                                                                        5.930e+04
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            5.929e+04
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         5.929e+04
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  5.930e+04
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               5.930e+04
# it_pos_neg:reliability_binary_z                                                   5.929e+04
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     5.930e+04
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  5.930e+04
# it_pos_neg:validity_binary_z                                                      5.929e+04
# reliability_binary_z:validity_binary_z                                            5.929e+04
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            5.930e+04
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         5.929e+04
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  5.929e+04
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               5.930e+04
# reliability_binary_z:v2_pos_neg                                                   5.930e+04
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     5.930e+04
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  5.929e+04
# validity_binary_z:v2_pos_neg                                                      5.929e+04
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       5.930e+04
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    5.929e+04
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          5.930e+04
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       5.930e+04
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                5.929e+04
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             5.930e+04
# it_pos_neg:reliability_binary_z:validity_binary_z                                 5.929e+04
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       5.929e+04
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    5.930e+04
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          5.930e+04
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       5.930e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                5.930e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             5.930e+04
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 5.930e+04
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     5.929e+04
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  5.930e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     5.929e+04
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  5.930e+04
#                                                                                  t value
# (Intercept)                                                                      134.557
# it_sim_dis_diff_test_sign_z                                                        6.505
# it_sim_dis_diff_test_sign_sq_z                                                     0.006
# it_pos_neg                                                                        -6.867
# reliability_binary_z                                                              -8.749
# validity_binary_z                                                                -20.462
# v2_sim_dis_diff_test_sign_z                                                        2.719
# v2_sim_dis_diff_test_sign_sq_z                                                     2.938
# v2_pos_neg                                                                        -3.359
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            -2.320
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                          3.489
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                   0.894
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                                0.222
# it_pos_neg:reliability_binary_z                                                    0.595
# it_sim_dis_diff_test_sign_z:validity_binary_z                                      2.206
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  -0.407
# it_pos_neg:validity_binary_z                                                       0.413
# reliability_binary_z:validity_binary_z                                            -9.496
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            -1.903
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                          1.313
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                   0.980
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               -0.179
# reliability_binary_z:v2_pos_neg                                                    0.105
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                      1.252
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                   0.946
# validity_binary_z:v2_pos_neg                                                       0.086
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                        0.298
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                     1.618
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          -0.932
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       -1.148
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                 0.130
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z              0.280
# it_pos_neg:reliability_binary_z:validity_binary_z                                 -0.097
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       -1.076
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                     0.857
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                           0.589
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                        0.254
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                 0.495
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z              0.058
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 -1.005
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     -0.463
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  -1.725
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     -0.508
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  -0.382
#                                                                                  Pr(>|t|)
# (Intercept)                                                                       < 2e-16
# it_sim_dis_diff_test_sign_z                                                      7.86e-11
# it_sim_dis_diff_test_sign_sq_z                                                   0.995441
# it_pos_neg                                                                       6.61e-12
# reliability_binary_z                                                              < 2e-16
# validity_binary_z                                                                 < 2e-16
# v2_sim_dis_diff_test_sign_z                                                      0.006547
# v2_sim_dis_diff_test_sign_sq_z                                                   0.003304
# v2_pos_neg                                                                       0.000783
# it_sim_dis_diff_test_sign_z:it_pos_neg                                           0.020320
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                        0.000485
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                 0.371499
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                              0.824687
# it_pos_neg:reliability_binary_z                                                  0.551810
# it_sim_dis_diff_test_sign_z:validity_binary_z                                    0.027391
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                 0.684022
# it_pos_neg:validity_binary_z                                                     0.679706
# reliability_binary_z:validity_binary_z                                            < 2e-16
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                           0.057074
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                        0.189287
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                 0.327297
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                              0.857864
# reliability_binary_z:v2_pos_neg                                                  0.916767
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                    0.210538
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                 0.343939
# validity_binary_z:v2_pos_neg                                                     0.931709
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                      0.765773
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                   0.105694
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                         0.351165
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                      0.250767
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z               0.896616
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z            0.779753
# it_pos_neg:reliability_binary_z:validity_binary_z                                0.922811
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                      0.282041
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                   0.391561
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                         0.555683
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                      0.799619
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z               0.620538
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z            0.953894
# reliability_binary_z:validity_binary_z:v2_pos_neg                                0.314908
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z    0.643368
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z 0.084562
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg    0.611469
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg 0.702237
#
# (Intercept)                                                                      ***
# it_sim_dis_diff_test_sign_z                                                      ***
# it_sim_dis_diff_test_sign_sq_z
# it_pos_neg                                                                       ***
# reliability_binary_z                                                             ***
# validity_binary_z                                                                ***
# v2_sim_dis_diff_test_sign_z                                                      **
# v2_sim_dis_diff_test_sign_sq_z                                                   **
# v2_pos_neg                                                                       ***
# it_sim_dis_diff_test_sign_z:it_pos_neg                                           *
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                        ***
# it_sim_dis_diff_test_sign_z:reliability_binary_z
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z
# it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_z:validity_binary_z                                    *
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z
# it_pos_neg:validity_binary_z
# reliability_binary_z:validity_binary_z                                           ***
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                           .
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# reliability_binary_z:v2_sim_dis_diff_test_sign_z
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z
# reliability_binary_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_z
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z
# validity_binary_z:v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z
# it_pos_neg:reliability_binary_z:validity_binary_z
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z
# reliability_binary_z:validity_binary_z:v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z .
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
