# %%
library(lme4)
library(simr)
library(dplyr)
library(broom)
install.packages("sjPlot")
library(sjPlot)

install.packages("broom.mixed")
library(broom.mixed)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpMuTOm6/downloaded_packages
# Install package "strengejacke" from GitHub (`devtools::install_github("strengejacke/strengejacke")`) to load all sj-packages at once!
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpMuTOm6/downloaded_packages

# %%
# install.packages("car")
library(car)
install.packages("stargazer")

library(stargazer)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmpMuTOm6/downloaded_packages
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %%
file_path <- 'pilot5_stats/distractor_wm_ltm.csv'
df <- read.csv(file_path) 
# %>%
#     select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z )

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
# head(df$resp_correct)

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) * it_pos_neg_abs * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 44 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_sim_dis_test_sign_z + it_sim_dis_test_sign_sq_z) *
#     it_pos_neg_abs * reliability_binary_z * validity_binary_z +
#     (v2_sim_dis_test_sign_z + v2_sim_dis_test_sign_sq_z) * v2_pos_neg_abs *
#         reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   5713.1   5999.9  -2811.5   5623.1     4285
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4310 -0.8124 -0.5497  0.9737  2.8106
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3995   0.6321
# Number of obs: 4330, groups:  participant, 133
#
# Fixed effects:
#                                                                                  Estimate
# (Intercept)                                                                     -0.316199
# it_sim_dis_test_sign_z                                                           0.141606
# it_sim_dis_test_sign_sq_z                                                        0.032588
# it_pos_neg_abs                                                                   0.047023
# reliability_binary_z                                                            -0.012476
# validity_binary_z                                                                0.028667
# v2_sim_dis_test_sign_z                                                          -0.025611
# v2_sim_dis_test_sign_sq_z                                                       -0.104639
# v2_pos_neg_abs                                                                   0.071423
# it_sim_dis_test_sign_z:it_pos_neg_abs                                            0.168909
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                         0.211359
# it_sim_dis_test_sign_z:reliability_binary_z                                     -0.021627
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                   0.019682
# it_pos_neg_abs:reliability_binary_z                                             -0.002789
# it_sim_dis_test_sign_z:validity_binary_z                                         0.030511
# it_sim_dis_test_sign_sq_z:validity_binary_z                                     -0.040119
# it_pos_neg_abs:validity_binary_z                                                 0.048231
# reliability_binary_z:validity_binary_z                                          -0.040278
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                            0.020017
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                         0.120468
# reliability_binary_z:v2_sim_dis_test_sign_z                                      0.074177
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                  -0.010751
# reliability_binary_z:v2_pos_neg_abs                                             -0.063553
# validity_binary_z:v2_sim_dis_test_sign_z                                         0.010088
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                      0.031244
# validity_binary_z:v2_pos_neg_abs                                                -0.001690
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                      -0.017391
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                   -0.011450
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                          0.044142
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                       0.027931
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                    0.009333
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                -0.035956
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                            0.067914
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                      -0.023473
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                    0.024903
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                          0.008039
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                      -0.142710
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                    0.011666
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                 0.003570
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                           -0.031802
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z     0.037648
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z -0.060076
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs    -0.026655
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs -0.022940
#                                                                                 Std. Error
# (Intercept)                                                                       0.068147
# it_sim_dis_test_sign_z                                                            0.037112
# it_sim_dis_test_sign_sq_z                                                         0.037649
# it_pos_neg_abs                                                                    0.034201
# reliability_binary_z                                                              0.039909
# validity_binary_z                                                                 0.042280
# v2_sim_dis_test_sign_z                                                            0.043849
# v2_sim_dis_test_sign_sq_z                                                         0.088311
# v2_pos_neg_abs                                                                    0.041044
# it_sim_dis_test_sign_z:it_pos_neg_abs                                             0.036693
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                          0.036408
# it_sim_dis_test_sign_z:reliability_binary_z                                       0.037144
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                    0.037371
# it_pos_neg_abs:reliability_binary_z                                               0.034199
# it_sim_dis_test_sign_z:validity_binary_z                                          0.038318
# it_sim_dis_test_sign_sq_z:validity_binary_z                                       0.038737
# it_pos_neg_abs:validity_binary_z                                                  0.035712
# reliability_binary_z:validity_binary_z                                            0.042188
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                             0.045314
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                          0.087738
# reliability_binary_z:v2_sim_dis_test_sign_z                                       0.043912
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                    0.088402
# reliability_binary_z:v2_pos_neg_abs                                               0.041013
# validity_binary_z:v2_sim_dis_test_sign_z                                          0.046821
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                       0.094448
# validity_binary_z:v2_pos_neg_abs                                                  0.043556
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                        0.036670
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                     0.036610
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                           0.037394
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                        0.037280
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                     0.038037
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                  0.038514
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                             0.035615
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                        0.045451
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                     0.087831
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                           0.048129
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                        0.094024
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                     0.046552
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                  0.093911
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                             0.043388
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z      0.037193
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z   0.037241
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs      0.047835
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs   0.093526
#                                                                                 z value
# (Intercept)                                                                      -4.640
# it_sim_dis_test_sign_z                                                            3.816
# it_sim_dis_test_sign_sq_z                                                         0.866
# it_pos_neg_abs                                                                    1.375
# reliability_binary_z                                                             -0.313
# validity_binary_z                                                                 0.678
# v2_sim_dis_test_sign_z                                                           -0.584
# v2_sim_dis_test_sign_sq_z                                                        -1.185
# v2_pos_neg_abs                                                                    1.740
# it_sim_dis_test_sign_z:it_pos_neg_abs                                             4.603
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                          5.805
# it_sim_dis_test_sign_z:reliability_binary_z                                      -0.582
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                    0.527
# it_pos_neg_abs:reliability_binary_z                                              -0.082
# it_sim_dis_test_sign_z:validity_binary_z                                          0.796
# it_sim_dis_test_sign_sq_z:validity_binary_z                                      -1.036
# it_pos_neg_abs:validity_binary_z                                                  1.351
# reliability_binary_z:validity_binary_z                                           -0.955
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                             0.442
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                          1.373
# reliability_binary_z:v2_sim_dis_test_sign_z                                       1.689
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                   -0.122
# reliability_binary_z:v2_pos_neg_abs                                              -1.550
# validity_binary_z:v2_sim_dis_test_sign_z                                          0.215
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                       0.331
# validity_binary_z:v2_pos_neg_abs                                                 -0.039
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                       -0.474
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                    -0.313
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                           1.180
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                        0.749
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                     0.245
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                 -0.934
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                             1.907
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                       -0.516
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                     0.284
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                           0.167
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                       -1.518
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                     0.251
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                  0.038
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                            -0.733
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z      1.012
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z  -1.613
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs     -0.557
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs  -0.245
#                                                                                 Pr(>|z|)
# (Intercept)                                                                     3.49e-06
# it_sim_dis_test_sign_z                                                          0.000136
# it_sim_dis_test_sign_sq_z                                                       0.386724
# it_pos_neg_abs                                                                  0.169170
# reliability_binary_z                                                            0.754574
# validity_binary_z                                                               0.497747
# v2_sim_dis_test_sign_z                                                          0.559170
# v2_sim_dis_test_sign_sq_z                                                       0.236058
# v2_pos_neg_abs                                                                  0.081834
# it_sim_dis_test_sign_z:it_pos_neg_abs                                           4.16e-06
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        6.43e-09
# it_sim_dis_test_sign_z:reliability_binary_z                                     0.560403
# it_sim_dis_test_sign_sq_z:reliability_binary_z                                  0.598423
# it_pos_neg_abs:reliability_binary_z                                             0.935010
# it_sim_dis_test_sign_z:validity_binary_z                                        0.425880
# it_sim_dis_test_sign_sq_z:validity_binary_z                                     0.300351
# it_pos_neg_abs:validity_binary_z                                                0.176836
# reliability_binary_z:validity_binary_z                                          0.339715
# v2_sim_dis_test_sign_z:v2_pos_neg_abs                                           0.658674
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                                        0.169741
# reliability_binary_z:v2_sim_dis_test_sign_z                                     0.091182
# reliability_binary_z:v2_sim_dis_test_sign_sq_z                                  0.903202
# reliability_binary_z:v2_pos_neg_abs                                             0.121238
# validity_binary_z:v2_sim_dis_test_sign_z                                        0.829405
# validity_binary_z:v2_sim_dis_test_sign_sq_z                                     0.740791
# validity_binary_z:v2_pos_neg_abs                                                0.969047
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z                      0.635317
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z                   0.754470
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z                         0.237815
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z                      0.453717
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z                   0.806176
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z                0.350520
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           0.056532
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                      0.605547
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                   0.776767
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs                         0.867353
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs                      0.129062
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z                   0.802123
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z                0.969674
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs                           0.463576
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z    0.311427
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z 0.106710
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs    0.577371
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs 0.806237
#
# (Intercept)                                                                     ***
# it_sim_dis_test_sign_z                                                          ***
# it_sim_dis_test_sign_sq_z
# it_pos_neg_abs
# reliability_binary_z
# validity_binary_z
# v2_sim_dis_test_sign_z
# v2_sim_dis_test_sign_sq_z
# v2_pos_neg_abs                                                                  .
# it_sim_dis_test_sign_z:it_pos_neg_abs                                           ***
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs                                        ***
# it_sim_dis_test_sign_z:reliability_binary_z
# it_sim_dis_test_sign_sq_z:reliability_binary_z
# it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:validity_binary_z
# it_pos_neg_abs:validity_binary_z
# reliability_binary_z:validity_binary_z
# v2_sim_dis_test_sign_z:v2_pos_neg_abs
# v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# reliability_binary_z:v2_sim_dis_test_sign_z                                     .
# reliability_binary_z:v2_sim_dis_test_sign_sq_z
# reliability_binary_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_z
# validity_binary_z:v2_sim_dis_test_sign_sq_z
# validity_binary_z:v2_pos_neg_abs
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z
# it_sim_dis_test_sign_z:it_pos_neg_abs:validity_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:validity_binary_z
# it_sim_dis_test_sign_z:reliability_binary_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:reliability_binary_z:validity_binary_z
# it_pos_neg_abs:reliability_binary_z:validity_binary_z                           .
# reliability_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# reliability_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z
# reliability_binary_z:validity_binary_z:v2_pos_neg_abs
# it_sim_dis_test_sign_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z
# it_sim_dis_test_sign_sq_z:it_pos_neg_abs:reliability_binary_z:validity_binary_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_z:v2_pos_neg_abs
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sign_sq_z:v2_pos_neg_abs
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) * it_pos_neg * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_sign_z + v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 44 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_sim_dis_diff_test_sign_z + it_sim_dis_diff_test_sign_sq_z) *
#     it_pos_neg * reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_sign_z +
#     v2_sim_dis_diff_test_sign_sq_z) * v2_pos_neg * reliability_binary_z *
#     validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   5719.5   6006.3  -2814.7   5629.5     4285
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.9712 -0.8174 -0.5486  0.9633  2.4783
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3864   0.6216
# Number of obs: 4330, groups:  participant, 133
#
# Fixed effects:
#                                                                                    Estimate
# (Intercept)                                                                      -0.2876946
# it_sim_dis_diff_test_sign_z                                                       0.2072990
# it_sim_dis_diff_test_sign_sq_z                                                   -0.0708459
# it_pos_neg                                                                        0.0536113
# reliability_binary_z                                                             -0.0115285
# validity_binary_z                                                                -0.0067346
# v2_sim_dis_diff_test_sign_z                                                       0.0178946
# v2_sim_dis_diff_test_sign_sq_z                                                    0.0652968
# v2_pos_neg                                                                       -0.0419613
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            0.0949346
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         0.0399796
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                 -0.0026628
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                              -0.0051066
# it_pos_neg:reliability_binary_z                                                   0.0182455
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     0.0712845
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                 -0.0280149
# it_pos_neg:validity_binary_z                                                      0.0274608
# reliability_binary_z:validity_binary_z                                           -0.0534605
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            0.0428916
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         0.0604131
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  0.0391216
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               0.0518614
# reliability_binary_z:v2_pos_neg                                                  -0.0290978
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     0.0064233
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                 -0.0224071
# validity_binary_z:v2_pos_neg                                                     -0.0033887
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                      -0.0484107
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    0.0305742
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          0.0932147
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                      -0.0174674
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                0.0063931
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             0.0452748
# it_pos_neg:reliability_binary_z:validity_binary_z                                 0.0864061
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                      -0.0337985
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    0.0885069
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                         -0.0846213
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                      -0.0735682
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                0.0064125
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z            -0.0454620
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 0.0008192
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     0.0090952
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z -0.0634761
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg    -0.0786967
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  0.0019831
#                                                                                  Std. Error
# (Intercept)                                                                       0.0640035
# it_sim_dis_diff_test_sign_z                                                       0.0345118
# it_sim_dis_diff_test_sign_sq_z                                                    0.0347530
# it_pos_neg                                                                        0.0356392
# reliability_binary_z                                                              0.0339668
# validity_binary_z                                                                 0.0361568
# v2_sim_dis_diff_test_sign_z                                                       0.0350722
# v2_sim_dis_diff_test_sign_sq_z                                                    0.0353513
# v2_pos_neg                                                                        0.0343875
# it_sim_dis_diff_test_sign_z:it_pos_neg                                            0.0353863
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                         0.0354924
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  0.0346373
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               0.0349094
# it_pos_neg:reliability_binary_z                                                   0.0356019
# it_sim_dis_diff_test_sign_z:validity_binary_z                                     0.0372162
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  0.0368529
# it_pos_neg:validity_binary_z                                                      0.0378397
# reliability_binary_z:validity_binary_z                                            0.0361185
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                            0.0373389
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                         0.0356478
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                  0.0351323
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                               0.0356808
# reliability_binary_z:v2_pos_neg                                                   0.0343537
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                     0.0397639
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  0.0395582
# validity_binary_z:v2_pos_neg                                                      0.0366143
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       0.0353592
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                    0.0354311
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                          0.0378714
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       0.0375952
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                0.0369035
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z             0.0368173
# it_pos_neg:reliability_binary_z:validity_binary_z                                 0.0377625
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       0.0372790
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                    0.0354803
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          0.0413814
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       0.0406848
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                0.0395569
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             0.0393476
# reliability_binary_z:validity_binary_z:v2_pos_neg                                 0.0365967
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z     0.0375261
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  0.0373549
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     0.0410547
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg  0.0404344
#                                                                                  z value
# (Intercept)                                                                       -4.495
# it_sim_dis_diff_test_sign_z                                                        6.007
# it_sim_dis_diff_test_sign_sq_z                                                    -2.039
# it_pos_neg                                                                         1.504
# reliability_binary_z                                                              -0.339
# validity_binary_z                                                                 -0.186
# v2_sim_dis_diff_test_sign_z                                                        0.510
# v2_sim_dis_diff_test_sign_sq_z                                                     1.847
# v2_pos_neg                                                                        -1.220
# it_sim_dis_diff_test_sign_z:it_pos_neg                                             2.683
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                          1.126
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                  -0.077
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                               -0.146
# it_pos_neg:reliability_binary_z                                                    0.512
# it_sim_dis_diff_test_sign_z:validity_binary_z                                      1.915
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                  -0.760
# it_pos_neg:validity_binary_z                                                       0.726
# reliability_binary_z:validity_binary_z                                            -1.480
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                             1.149
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                          1.695
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                   1.114
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                                1.453
# reliability_binary_z:v2_pos_neg                                                   -0.847
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                      0.162
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                  -0.566
# validity_binary_z:v2_pos_neg                                                      -0.093
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                       -1.369
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                     0.863
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                           2.461
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                       -0.465
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                 0.173
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z              1.230
# it_pos_neg:reliability_binary_z:validity_binary_z                                  2.288
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                       -0.907
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                     2.495
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                          -2.045
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                       -1.808
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                 0.162
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z             -1.155
# reliability_binary_z:validity_binary_z:v2_pos_neg                                  0.022
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z      0.242
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z  -1.699
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg     -1.917
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg   0.049
#                                                                                  Pr(>|z|)
# (Intercept)                                                                      6.96e-06
# it_sim_dis_diff_test_sign_z                                                      1.89e-09
# it_sim_dis_diff_test_sign_sq_z                                                     0.0415
# it_pos_neg                                                                         0.1325
# reliability_binary_z                                                               0.7343
# validity_binary_z                                                                  0.8522
# v2_sim_dis_diff_test_sign_z                                                        0.6099
# v2_sim_dis_diff_test_sign_sq_z                                                     0.0647
# v2_pos_neg                                                                         0.2224
# it_sim_dis_diff_test_sign_z:it_pos_neg                                             0.0073
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg                                          0.2600
# it_sim_dis_diff_test_sign_z:reliability_binary_z                                   0.9387
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z                                0.8837
# it_pos_neg:reliability_binary_z                                                    0.6083
# it_sim_dis_diff_test_sign_z:validity_binary_z                                      0.0554
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z                                   0.4471
# it_pos_neg:validity_binary_z                                                       0.4680
# reliability_binary_z:validity_binary_z                                             0.1388
# v2_sim_dis_diff_test_sign_z:v2_pos_neg                                             0.2507
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                          0.0901
# reliability_binary_z:v2_sim_dis_diff_test_sign_z                                   0.2655
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z                                0.1461
# reliability_binary_z:v2_pos_neg                                                    0.3970
# validity_binary_z:v2_sim_dis_diff_test_sign_z                                      0.8717
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z                                   0.5711
# validity_binary_z:v2_pos_neg                                                       0.9263
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z                        0.1710
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z                     0.3882
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                           0.0138
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z                        0.6422
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z                 0.8625
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z              0.2188
# it_pos_neg:reliability_binary_z:validity_binary_z                                  0.0221
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                        0.3646
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                     0.0126
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                           0.0409
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                        0.0706
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z                 0.8712
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z              0.2479
# reliability_binary_z:validity_binary_z:v2_pos_neg                                  0.9821
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z      0.8085
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z   0.0893
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg      0.0553
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg   0.9609
#
# (Intercept)                                                                      ***
# it_sim_dis_diff_test_sign_z                                                      ***
# it_sim_dis_diff_test_sign_sq_z                                                   *
# it_pos_neg
# reliability_binary_z
# validity_binary_z
# v2_sim_dis_diff_test_sign_z
# v2_sim_dis_diff_test_sign_sq_z                                                   .
# v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg                                           **
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg
# it_sim_dis_diff_test_sign_z:reliability_binary_z
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z
# it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_z:validity_binary_z                                    .
# it_sim_dis_diff_test_sign_sq_z:validity_binary_z
# it_pos_neg:validity_binary_z
# reliability_binary_z:validity_binary_z
# v2_sim_dis_diff_test_sign_z:v2_pos_neg
# v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                                        .
# reliability_binary_z:v2_sim_dis_diff_test_sign_z
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z
# reliability_binary_z:v2_pos_neg
# validity_binary_z:v2_sim_dis_diff_test_sign_z
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z
# validity_binary_z:v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z
# it_sim_dis_diff_test_sign_z:it_pos_neg:validity_binary_z                         *
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:validity_binary_z
# it_sim_dis_diff_test_sign_z:reliability_binary_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:reliability_binary_z:validity_binary_z
# it_pos_neg:reliability_binary_z:validity_binary_z                                *
# reliability_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg
# reliability_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                   *
# validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg                         *
# validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg                      .
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z
# reliability_binary_z:validity_binary_z:v2_pos_neg
# it_sim_dis_diff_test_sign_z:it_pos_neg:reliability_binary_z:validity_binary_z
# it_sim_dis_diff_test_sign_sq_z:it_pos_neg:reliability_binary_z:validity_binary_z .
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_z:v2_pos_neg    .
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sign_sq_z:v2_pos_neg
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z)  * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z)  * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   5714.9   5848.7  -2836.4   5672.9     4309
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.1059 -0.8230 -0.5703  0.9797  2.5103
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3738   0.6114
# Number of obs: 4330, groups:  participant, 133
#
# Fixed effects:
#                                                               Estimate
# (Intercept)                                                 -0.2868026
# it_sim_dis_test_z                                            0.0871109
# it_sim_dis_test_sq_z                                         0.1837784
# reliability_binary_z                                        -0.0083248
# validity_binary_z                                            0.0065578
# v2_sim_dis_test_z                                            0.0551956
# v2_sim_dis_test_sq_z                                        -0.0002455
# it_sim_dis_test_z:reliability_binary_z                      -0.0088077
# it_sim_dis_test_sq_z:reliability_binary_z                   -0.0242309
# it_sim_dis_test_z:validity_binary_z                          0.0470879
# it_sim_dis_test_sq_z:validity_binary_z                       0.0370352
# reliability_binary_z:validity_binary_z                      -0.0430625
# reliability_binary_z:v2_sim_dis_test_z                      -0.0985216
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.0804313
# validity_binary_z:v2_sim_dis_test_z                          0.0375789
# validity_binary_z:v2_sim_dis_test_sq_z                      -0.0478123
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.0768915
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.0008421
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z    -0.0266708
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.0043855
#                                                             Std. Error z value
# (Intercept)                                                  0.0630457  -4.549
# it_sim_dis_test_z                                            0.0340982   2.555
# it_sim_dis_test_sq_z                                         0.0340677   5.395
# reliability_binary_z                                         0.0336067  -0.248
# validity_binary_z                                            0.0357643   0.183
# v2_sim_dis_test_z                                            0.0383410   1.440
# v2_sim_dis_test_sq_z                                         0.0412720  -0.006
# it_sim_dis_test_z:reliability_binary_z                       0.0341371  -0.258
# it_sim_dis_test_sq_z:reliability_binary_z                    0.0340157  -0.712
# it_sim_dis_test_z:validity_binary_z                          0.0355244   1.326
# it_sim_dis_test_sq_z:validity_binary_z                       0.0354793   1.044
# reliability_binary_z:validity_binary_z                       0.0356861  -1.207
# reliability_binary_z:v2_sim_dis_test_z                       0.0383762  -2.567
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.0410794   1.958
# validity_binary_z:v2_sim_dis_test_z                          0.0414288   0.907
# validity_binary_z:v2_sim_dis_test_sq_z                       0.0506127  -0.945
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.0354545   2.169
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.0352260   0.024
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.0413776  -0.645
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.0499941   0.088
#                                                             Pr(>|z|)
# (Intercept)                                                 5.39e-06 ***
# it_sim_dis_test_z                                             0.0106 *
# it_sim_dis_test_sq_z                                        6.87e-08 ***
# reliability_binary_z                                          0.8044
# validity_binary_z                                             0.8545
# v2_sim_dis_test_z                                             0.1500
# v2_sim_dis_test_sq_z                                          0.9953
# it_sim_dis_test_z:reliability_binary_z                        0.7964
# it_sim_dis_test_sq_z:reliability_binary_z                     0.4763
# it_sim_dis_test_z:validity_binary_z                           0.1850
# it_sim_dis_test_sq_z:validity_binary_z                        0.2966
# reliability_binary_z:validity_binary_z                        0.2275
# reliability_binary_z:v2_sim_dis_test_z                        0.0103 *
# reliability_binary_z:v2_sim_dis_test_sq_z                     0.0502 .
# validity_binary_z:v2_sim_dis_test_z                           0.3644
# validity_binary_z:v2_sim_dis_test_sq_z                        0.3448
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z      0.0301 *
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z   0.9809
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z      0.5192
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z   0.9301
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial,control = glmerControl(optimizer = "bobyqa",
                                        optCtrl = list(maxfun = 500000),
                                        calc.derivs = FALSE))
summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_z +
#     v2_sim_dis_diff_test_sq_z) * reliability_binary_z * validity_binary_z +
#     (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05),
#     calc.derivs = FALSE)
#
#      AIC      BIC   logLik deviance df.resid
#   5718.3   5852.2  -2838.2   5676.3     4309
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8915 -0.8223 -0.5744  0.9799  2.3815
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3729   0.6107
# Number of obs: 4330, groups:  participant, 133
#
# Fixed effects:
#                                                                  Estimate
# (Intercept)                                                      -0.29008
# it_sim_dis_diff_test_z                                            0.09825
# it_sim_dis_diff_test_sq_z                                         0.19290
# reliability_binary_z                                             -0.01199
# validity_binary_z                                                 0.01064
# v2_sim_dis_diff_test_z                                           -0.02275
# v2_sim_dis_diff_test_sq_z                                         0.02277
# it_sim_dis_diff_test_z:reliability_binary_z                      -0.01691
# it_sim_dis_diff_test_sq_z:reliability_binary_z                   -0.01068
# it_sim_dis_diff_test_z:validity_binary_z                          0.05347
# it_sim_dis_diff_test_sq_z:validity_binary_z                       0.06619
# reliability_binary_z:validity_binary_z                           -0.03254
# reliability_binary_z:v2_sim_dis_diff_test_z                      -0.04350
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    0.02933
# validity_binary_z:v2_sim_dis_diff_test_z                         -0.01661
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       0.03759
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     0.07284
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  0.01184
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z    -0.02131
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  0.02820
#                                                                  Std. Error
# (Intercept)                                                         0.06284
# it_sim_dis_diff_test_z                                              0.03406
# it_sim_dis_diff_test_sq_z                                           0.03321
# reliability_binary_z                                                0.03329
# validity_binary_z                                                   0.03487
# v2_sim_dis_diff_test_z                                              0.03468
# v2_sim_dis_diff_test_sq_z                                           0.03358
# it_sim_dis_diff_test_z:reliability_binary_z                         0.03407
# it_sim_dis_diff_test_sq_z:reliability_binary_z                      0.03334
# it_sim_dis_diff_test_z:validity_binary_z                            0.03564
# it_sim_dis_diff_test_sq_z:validity_binary_z                         0.03534
# reliability_binary_z:validity_binary_z                              0.03483
# reliability_binary_z:v2_sim_dis_diff_test_z                         0.03463
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                      0.03361
# validity_binary_z:v2_sim_dis_diff_test_z                            0.03707
# validity_binary_z:v2_sim_dis_diff_test_sq_z                         0.03682
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z       0.03559
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z    0.03513
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z       0.03707
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z    0.03667
#                                                                  z value
# (Intercept)                                                       -4.616
# it_sim_dis_diff_test_z                                             2.884
# it_sim_dis_diff_test_sq_z                                          5.808
# reliability_binary_z                                              -0.360
# validity_binary_z                                                  0.305
# v2_sim_dis_diff_test_z                                            -0.656
# v2_sim_dis_diff_test_sq_z                                          0.678
# it_sim_dis_diff_test_z:reliability_binary_z                       -0.496
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    -0.320
# it_sim_dis_diff_test_z:validity_binary_z                           1.500
# it_sim_dis_diff_test_sq_z:validity_binary_z                        1.873
# reliability_binary_z:validity_binary_z                            -0.934
# reliability_binary_z:v2_sim_dis_diff_test_z                       -1.256
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.873
# validity_binary_z:v2_sim_dis_diff_test_z                          -0.448
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        1.021
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z      2.047
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.337
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     -0.575
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.769
#                                                                  Pr(>|z|)
# (Intercept)                                                      3.91e-06 ***
# it_sim_dis_diff_test_z                                            0.00392 **
# it_sim_dis_diff_test_sq_z                                        6.31e-09 ***
# reliability_binary_z                                              0.71874
# validity_binary_z                                                 0.76031
# v2_sim_dis_diff_test_z                                            0.51182
# v2_sim_dis_diff_test_sq_z                                         0.49780
# it_sim_dis_diff_test_z:reliability_binary_z                       0.61962
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.74872
# it_sim_dis_diff_test_z:validity_binary_z                          0.13359
# it_sim_dis_diff_test_sq_z:validity_binary_z                       0.06105 .
# reliability_binary_z:validity_binary_z                            0.35020
# reliability_binary_z:v2_sim_dis_diff_test_z                       0.20901
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    0.38278
# validity_binary_z:v2_sim_dis_diff_test_z                          0.65399
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       0.30730
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     0.04070 *
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  0.73617
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.56532
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  0.44183
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
head(df$v2_pos_neg)
# Out:
# [1]  1  1  1  1 -1  1

# %%
head(df$v2_sim_dis_diff_test_sign_z)
# Out:
# [1] -0.6033288  1.2751263 -1.6278248  0.8637777 -1.1361874  1.6611417

# %%
head(df$v2_sim_dis_diff_test_sign)
# Out:
# [1] 0.05636242 0.13726351 0.01223954 0.11954760 0.03341333 0.15388838
