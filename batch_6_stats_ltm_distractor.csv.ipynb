# %%
library(lme4)
library(simr)
library(dplyr)
library(broom)
install.packages("sjPlot")
library(sjPlot)

install.packages("broom.mixed")
library(broom.mixed)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmptZizFE/downloaded_packages
# #refugeeswelcome
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmptZizFE/downloaded_packages

# %%
# install.packages("car")
library(car)
install.packages("stargazer")

library(stargazer)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
# The downloaded binary packages are in
# 	/var/folders/h_/pm5z54tn7rj170br8494ljz80000gn/T//RtmptZizFE/downloaded_packages
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %%
file_path <- 'pilot6_stats/distractor_wm_ltm.csv'
df <- read.csv(file_path) 
# %>%
#     select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z )

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
# head(df$resp_correct)

# %%
head(df$recall_answ)
# Out:
# [1] 1 1 1 1 1 1

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 20 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_sim_dis_test_z + it_sim_dis_test_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_test_z + v2_sim_dis_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#   5118.2   5249.6  -2538.1   5076.2     3821
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.3833 -0.8229 -0.5949  1.0056  2.5471
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3807   0.617
# Number of obs: 3842, groups:  participant, 135
#
# Fixed effects:
#                                                               Estimate
# (Intercept)                                                 -0.2849632
# it_sim_dis_test_z                                            0.0006458
# it_sim_dis_test_sq_z                                         0.1320932
# reliability_binary_z                                        -0.0001702
# validity_binary_z                                            0.0006515
# v2_sim_dis_test_z                                            0.0894667
# v2_sim_dis_test_sq_z                                         0.0693258
# it_sim_dis_test_z:reliability_binary_z                      -0.0076257
# it_sim_dis_test_sq_z:reliability_binary_z                    0.0360845
# it_sim_dis_test_z:validity_binary_z                         -0.0239994
# it_sim_dis_test_sq_z:validity_binary_z                       0.0117729
# reliability_binary_z:validity_binary_z                      -0.0095306
# reliability_binary_z:v2_sim_dis_test_z                       0.0473259
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.0094218
# validity_binary_z:v2_sim_dis_test_z                         -0.0064279
# validity_binary_z:v2_sim_dis_test_sq_z                       0.0157143
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z    -0.0141846
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.0036849
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.0251201
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.0261230
#                                                             Std. Error z value
# (Intercept)                                                  0.0673807  -4.229
# it_sim_dis_test_z                                            0.0445953   0.014
# it_sim_dis_test_sq_z                                         0.0441008   2.995
# reliability_binary_z                                         0.0312428  -0.005
# validity_binary_z                                            0.0483956   0.013
# v2_sim_dis_test_z                                            0.0440954   2.029
# v2_sim_dis_test_sq_z                                         0.0476106   1.456
# it_sim_dis_test_z:reliability_binary_z                       0.0335723  -0.227
# it_sim_dis_test_sq_z:reliability_binary_z                    0.0331498   1.089
# it_sim_dis_test_z:validity_binary_z                          0.0529350  -0.453
# it_sim_dis_test_sq_z:validity_binary_z                       0.0527605   0.223
# reliability_binary_z:validity_binary_z                       0.0339592  -0.281
# reliability_binary_z:v2_sim_dis_test_z                       0.0342746   1.381
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.0366939   0.257
# validity_binary_z:v2_sim_dis_test_z                          0.0510245  -0.126
# validity_binary_z:v2_sim_dis_test_sq_z                       0.0513906   0.306
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.0365365  -0.388
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.0362800   0.102
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.0370563   0.678
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.0378608   0.690
#                                                             Pr(>|z|)
# (Intercept)                                                 2.35e-05 ***
# it_sim_dis_test_z                                            0.98845
# it_sim_dis_test_sq_z                                         0.00274 **
# reliability_binary_z                                         0.99565
# validity_binary_z                                            0.98926
# v2_sim_dis_test_z                                            0.04246 *
# v2_sim_dis_test_sq_z                                         0.14537
# it_sim_dis_test_z:reliability_binary_z                       0.82031
# it_sim_dis_test_sq_z:reliability_binary_z                    0.27636
# it_sim_dis_test_z:validity_binary_z                          0.65028
# it_sim_dis_test_sq_z:validity_binary_z                       0.82343
# reliability_binary_z:validity_binary_z                       0.77898
# reliability_binary_z:v2_sim_dis_test_z                       0.16734
# reliability_binary_z:v2_sim_dis_test_sq_z                    0.79736
# validity_binary_z:v2_sim_dis_test_z                          0.89975
# validity_binary_z:v2_sim_dis_test_sq_z                       0.75977
# it_sim_dis_test_z:reliability_binary_z:validity_binary_z     0.69784
# it_sim_dis_test_sq_z:reliability_binary_z:validity_binary_z  0.91910
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_z     0.49784
# reliability_binary_z:validity_binary_z:v2_sim_dis_test_sq_z  0.49021
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(recall_answ ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_test_z + v2_sim_dis_diff_test_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_sim_dis_diff_test_z + it_sim_dis_diff_test_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_diff_test_z +
#     v2_sim_dis_diff_test_sq_z) * reliability_binary_z * validity_binary_z +
#     it_sim_dis_diff_test_z * v2_sim_dis_diff_test_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#   5102.5   5240.1  -2529.2   5058.5     3820
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.0397 -0.8234 -0.5898  1.0003  2.4451
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3874   0.6224
# Number of obs: 3842, groups:  participant, 135
#
# Fixed effects:
#                                                                   Estimate
# (Intercept)                                                      -0.303290
# it_sim_dis_diff_test_z                                            0.028225
# it_sim_dis_diff_test_sq_z                                         0.102894
# reliability_binary_z                                              0.002285
# validity_binary_z                                                -0.005971
# v2_sim_dis_diff_test_z                                            0.059615
# v2_sim_dis_diff_test_sq_z                                         0.086605
# it_sim_dis_diff_test_z:reliability_binary_z                      -0.020867
# it_sim_dis_diff_test_sq_z:reliability_binary_z                    0.007223
# it_sim_dis_diff_test_z:validity_binary_z                         -0.038049
# it_sim_dis_diff_test_sq_z:validity_binary_z                       0.041135
# reliability_binary_z:validity_binary_z                           -0.003870
# reliability_binary_z:v2_sim_dis_diff_test_z                       0.038375
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                   -0.021693
# validity_binary_z:v2_sim_dis_diff_test_z                          0.025378
# validity_binary_z:v2_sim_dis_diff_test_sq_z                      -0.036640
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                     0.097134
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z    -0.003326
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z  0.043737
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z     0.041901
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z  0.020508
#                                                                  Std. Error
# (Intercept)                                                        0.068294
# it_sim_dis_diff_test_z                                             0.043576
# it_sim_dis_diff_test_sq_z                                          0.045930
# reliability_binary_z                                               0.031216
# validity_binary_z                                                  0.047805
# v2_sim_dis_diff_test_z                                             0.040834
# v2_sim_dis_diff_test_sq_z                                          0.042186
# it_sim_dis_diff_test_z:reliability_binary_z                        0.033027
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.032596
# it_sim_dis_diff_test_z:validity_binary_z                           0.050411
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.050505
# reliability_binary_z:validity_binary_z                             0.033721
# reliability_binary_z:v2_sim_dis_diff_test_z                        0.031405
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.030564
# validity_binary_z:v2_sim_dis_diff_test_z                           0.046786
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.044872
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      0.044578
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z      0.035425
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.035273
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      0.033677
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.032764
#                                                                  z value
# (Intercept)                                                       -4.441
# it_sim_dis_diff_test_z                                             0.648
# it_sim_dis_diff_test_sq_z                                          2.240
# reliability_binary_z                                               0.073
# validity_binary_z                                                 -0.125
# v2_sim_dis_diff_test_z                                             1.460
# v2_sim_dis_diff_test_sq_z                                          2.053
# it_sim_dis_diff_test_z:reliability_binary_z                       -0.632
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.222
# it_sim_dis_diff_test_z:validity_binary_z                          -0.755
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.814
# reliability_binary_z:validity_binary_z                            -0.115
# reliability_binary_z:v2_sim_dis_diff_test_z                        1.222
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                    -0.710
# validity_binary_z:v2_sim_dis_diff_test_z                           0.542
# validity_binary_z:v2_sim_dis_diff_test_sq_z                       -0.817
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      2.179
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z     -0.094
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   1.240
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      1.244
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.626
#                                                                  Pr(>|z|)
# (Intercept)                                                      8.96e-06 ***
# it_sim_dis_diff_test_z                                             0.5172
# it_sim_dis_diff_test_sq_z                                          0.0251 *
# reliability_binary_z                                               0.9416
# validity_binary_z                                                  0.9006
# v2_sim_dis_diff_test_z                                             0.1443
# v2_sim_dis_diff_test_sq_z                                          0.0401 *
# it_sim_dis_diff_test_z:reliability_binary_z                        0.5275
# it_sim_dis_diff_test_sq_z:reliability_binary_z                     0.8246
# it_sim_dis_diff_test_z:validity_binary_z                           0.4504
# it_sim_dis_diff_test_sq_z:validity_binary_z                        0.4154
# reliability_binary_z:validity_binary_z                             0.9086
# reliability_binary_z:v2_sim_dis_diff_test_z                        0.2217
# reliability_binary_z:v2_sim_dis_diff_test_sq_z                     0.4779
# validity_binary_z:v2_sim_dis_diff_test_z                           0.5875
# validity_binary_z:v2_sim_dis_diff_test_sq_z                        0.4142
# it_sim_dis_diff_test_z:v2_sim_dis_diff_test_z                      0.0293 *
# it_sim_dis_diff_test_z:reliability_binary_z:validity_binary_z      0.9252
# it_sim_dis_diff_test_sq_z:reliability_binary_z:validity_binary_z   0.2150
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_z      0.2134
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_test_sq_z   0.5314
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
### absolute prioritized - deprioritized

formula11 <- glmer(recall_answ ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_attend_z + v2_sim_dis_attend_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula11)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) *
#     reliability_binary_z * validity_binary_z + (v2_sim_dis_attend_z +
#     v2_sim_dis_attend_sq_z) * reliability_binary_z * validity_binary_z +
#     it_sim_dis_attend_z * v2_sim_dis_attend_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#   5098.9   5236.5  -2527.5   5054.9     3820
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.5793 -0.8165 -0.5879  1.0003  2.3424
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3879   0.6228
# Number of obs: 3842, groups:  participant, 135
#
# Fixed effects:
#                                                                 Estimate
# (Intercept)                                                   -0.2988363
# it_sim_dis_attend_z                                           -0.0390841
# it_sim_dis_attend_sq_z                                         0.0962584
# reliability_binary_z                                          -0.0008449
# validity_binary_z                                             -0.0104485
# v2_sim_dis_attend_z                                            0.0622866
# v2_sim_dis_attend_sq_z                                         0.0886436
# it_sim_dis_attend_z:reliability_binary_z                      -0.0007773
# it_sim_dis_attend_sq_z:reliability_binary_z                   -0.0039574
# it_sim_dis_attend_z:validity_binary_z                          0.0537146
# it_sim_dis_attend_sq_z:validity_binary_z                       0.0358036
# reliability_binary_z:validity_binary_z                        -0.0125179
# reliability_binary_z:v2_sim_dis_attend_z                       0.0680378
# reliability_binary_z:v2_sim_dis_attend_sq_z                    0.0020654
# validity_binary_z:v2_sim_dis_attend_z                          0.0395850
# validity_binary_z:v2_sim_dis_attend_sq_z                      -0.0765350
# it_sim_dis_attend_z:v2_sim_dis_attend_z                        0.0770773
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z    -0.0307008
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z  0.0739803
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z    -0.0048945
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z  0.0393482
#                                                               Std. Error
# (Intercept)                                                    0.0682320
# it_sim_dis_attend_z                                            0.0432069
# it_sim_dis_attend_sq_z                                         0.0449127
# reliability_binary_z                                           0.0310766
# validity_binary_z                                              0.0472602
# v2_sim_dis_attend_z                                            0.0443704
# v2_sim_dis_attend_sq_z                                         0.0523740
# it_sim_dis_attend_z:reliability_binary_z                       0.0331139
# it_sim_dis_attend_sq_z:reliability_binary_z                    0.0327317
# it_sim_dis_attend_z:validity_binary_z                          0.0493728
# it_sim_dis_attend_sq_z:validity_binary_z                       0.0492967
# reliability_binary_z:validity_binary_z                         0.0334301
# reliability_binary_z:v2_sim_dis_attend_z                       0.0342180
# reliability_binary_z:v2_sim_dis_attend_sq_z                    0.0373800
# validity_binary_z:v2_sim_dis_attend_z                          0.0513293
# validity_binary_z:v2_sim_dis_attend_sq_z                       0.0584025
# it_sim_dis_attend_z:v2_sim_dis_attend_z                        0.0437670
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z     0.0350983
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z  0.0349066
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z     0.0365925
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z  0.0408081
#                                                               z value Pr(>|z|)
# (Intercept)                                                    -4.380 1.19e-05
# it_sim_dis_attend_z                                            -0.905   0.3657
# it_sim_dis_attend_sq_z                                          2.143   0.0321
# reliability_binary_z                                           -0.027   0.9783
# validity_binary_z                                              -0.221   0.8250
# v2_sim_dis_attend_z                                             1.404   0.1604
# v2_sim_dis_attend_sq_z                                          1.693   0.0905
# it_sim_dis_attend_z:reliability_binary_z                       -0.023   0.9813
# it_sim_dis_attend_sq_z:reliability_binary_z                    -0.121   0.9038
# it_sim_dis_attend_z:validity_binary_z                           1.088   0.2766
# it_sim_dis_attend_sq_z:validity_binary_z                        0.726   0.4677
# reliability_binary_z:validity_binary_z                         -0.374   0.7081
# reliability_binary_z:v2_sim_dis_attend_z                        1.988   0.0468
# reliability_binary_z:v2_sim_dis_attend_sq_z                     0.055   0.9559
# validity_binary_z:v2_sim_dis_attend_z                           0.771   0.4406
# validity_binary_z:v2_sim_dis_attend_sq_z                       -1.310   0.1900
# it_sim_dis_attend_z:v2_sim_dis_attend_z                         1.761   0.0782
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z     -0.875   0.3817
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z   2.119   0.0341
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z     -0.134   0.8936
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z   0.964   0.3349
#
# (Intercept)                                                   ***
# it_sim_dis_attend_z
# it_sim_dis_attend_sq_z                                        *
# reliability_binary_z
# validity_binary_z
# v2_sim_dis_attend_z
# v2_sim_dis_attend_sq_z                                        .
# it_sim_dis_attend_z:reliability_binary_z
# it_sim_dis_attend_sq_z:reliability_binary_z
# it_sim_dis_attend_z:validity_binary_z
# it_sim_dis_attend_sq_z:validity_binary_z
# reliability_binary_z:validity_binary_z
# reliability_binary_z:v2_sim_dis_attend_z                      *
# reliability_binary_z:v2_sim_dis_attend_sq_z
# validity_binary_z:v2_sim_dis_attend_z
# validity_binary_z:v2_sim_dis_attend_sq_z
# it_sim_dis_attend_z:v2_sim_dis_attend_z                       .
# it_sim_dis_attend_z:reliability_binary_z:validity_binary_z
# it_sim_dis_attend_sq_z:reliability_binary_z:validity_binary_z *
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_z
# reliability_binary_z:validity_binary_z:v2_sim_dis_attend_sq_z
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
### relative prioritized - deprioritized
formula10 <- glmer(recall_answ ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *  
                  validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary_z *  
                  validity_binary_z + it_sim_dis_diff_z * v2_sim_dis_diff_z +  (1 | participant), 
                  data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
summary(formula10)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary_z *
#     validity_binary_z + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) *
#     reliability_binary_z * validity_binary_z + it_sim_dis_diff_z *
#     v2_sim_dis_diff_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#   5102.5   5240.1  -2529.2   5058.5     3820
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.0397 -0.8234 -0.5898  1.0003  2.4451
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.3874   0.6224
# Number of obs: 3842, groups:  participant, 135
#
# Fixed effects:
#                                                              Estimate
# (Intercept)                                                 -0.303261
# it_sim_dis_diff_z                                           -0.019164
# it_sim_dis_diff_sq_z                                         0.102898
# reliability_binary_z                                         0.001227
# validity_binary_z                                           -0.007291
# v2_sim_dis_diff_z                                            0.047014
# v2_sim_dis_diff_sq_z                                         0.086645
# it_sim_dis_diff_z:reliability_binary_z                      -0.012289
# it_sim_dis_diff_sq_z:reliability_binary_z                    0.007223
# it_sim_dis_diff_z:validity_binary_z                          0.046286
# it_sim_dis_diff_sq_z:validity_binary_z                       0.041137
# reliability_binary_z:validity_binary_z                      -0.003451
# reliability_binary_z:v2_sim_dis_diff_z                       0.057079
# reliability_binary_z:v2_sim_dis_diff_sq_z                   -0.021704
# validity_binary_z:v2_sim_dis_diff_z                          0.045685
# validity_binary_z:v2_sim_dis_diff_sq_z                      -0.036657
# it_sim_dis_diff_z:v2_sim_dis_diff_z                          0.097119
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z    -0.017155
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z  0.043739
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z     0.009906
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z  0.020518
#                                                             Std. Error z value
# (Intercept)                                                   0.068249  -4.443
# it_sim_dis_diff_z                                             0.043379  -0.442
# it_sim_dis_diff_sq_z                                          0.045932   2.240
# reliability_binary_z                                          0.031170   0.039
# validity_binary_z                                             0.047530  -0.153
# v2_sim_dis_diff_z                                             0.041119   1.143
# v2_sim_dis_diff_sq_z                                          0.042206   2.053
# it_sim_dis_diff_z:reliability_binary_z                        0.032936  -0.373
# it_sim_dis_diff_sq_z:reliability_binary_z                     0.032598   0.222
# it_sim_dis_diff_z:validity_binary_z                           0.050036   0.925
# it_sim_dis_diff_sq_z:validity_binary_z                        0.050507   0.814
# reliability_binary_z:validity_binary_z                        0.033602  -0.103
# reliability_binary_z:v2_sim_dis_diff_z                        0.031451   1.815
# reliability_binary_z:v2_sim_dis_diff_sq_z                     0.030579  -0.710
# validity_binary_z:v2_sim_dis_diff_z                           0.046771   0.977
# validity_binary_z:v2_sim_dis_diff_sq_z                        0.044893  -0.817
# it_sim_dis_diff_z:v2_sim_dis_diff_z                           0.044571   2.179
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z      0.035256  -0.487
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z   0.035275   1.240
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z      0.033803   0.293
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z   0.032779   0.626
#                                                             Pr(>|z|)
# (Intercept)                                                 8.85e-06 ***
# it_sim_dis_diff_z                                             0.6586
# it_sim_dis_diff_sq_z                                          0.0251 *
# reliability_binary_z                                          0.9686
# validity_binary_z                                             0.8781
# v2_sim_dis_diff_z                                             0.2529
# v2_sim_dis_diff_sq_z                                          0.0401 *
# it_sim_dis_diff_z:reliability_binary_z                        0.7091
# it_sim_dis_diff_sq_z:reliability_binary_z                     0.8246
# it_sim_dis_diff_z:validity_binary_z                           0.3549
# it_sim_dis_diff_sq_z:validity_binary_z                        0.4154
# reliability_binary_z:validity_binary_z                        0.9182
# reliability_binary_z:v2_sim_dis_diff_z                        0.0695 .
# reliability_binary_z:v2_sim_dis_diff_sq_z                     0.4779
# validity_binary_z:v2_sim_dis_diff_z                           0.3287
# validity_binary_z:v2_sim_dis_diff_sq_z                        0.4142
# it_sim_dis_diff_z:v2_sim_dis_diff_z                           0.0293 *
# it_sim_dis_diff_z:reliability_binary_z:validity_binary_z      0.6266
# it_sim_dis_diff_sq_z:reliability_binary_z:validity_binary_z   0.2150
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_z      0.7695
# reliability_binary_z:validity_binary_z:v2_sim_dis_diff_sq_z   0.5313
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
