# %%
library(lme4)
library(simr)
library(dplyr)
library(broom)
install.packages("sjPlot")
library(sjPlot)
install.packages("broom.mixed")
library(broom.mixed)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘simr’
#
#
# The following object is masked from ‘package:lme4’:
#
#     getData
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open URL 'https://cran.r-project.org/src/contrib/PACKAGES'”
# Warning message:
# “package ‘sjPlot’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Warning message:
# “unable to access index for repository https://cran.r-project.org/bin/macosx/big-sur-arm64/contrib/4.3:
#   cannot open URL 'https://cran.r-project.org/bin/macosx/big-sur-arm64/contrib/4.3/PACKAGES'”
# Warning message:
# “unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open URL 'https://cran.r-project.org/src/contrib/PACKAGES'”
# Warning message:
# “package ‘broom.mixed’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Warning message:
# “unable to access index for repository https://cran.r-project.org/bin/macosx/big-sur-arm64/contrib/4.3:
#   cannot open URL 'https://cran.r-project.org/bin/macosx/big-sur-arm64/contrib/4.3/PACKAGES'”

# %%
# install.packages("car")
library(car)
install.packages("stargazer")

library(stargazer)
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# Warning message:
# “unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open URL 'https://cran.r-project.org/src/contrib/PACKAGES'”
# Warning message:
# “package ‘stargazer’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Warning message:
# “unable to access index for repository https://cran.r-project.org/bin/macosx/big-sur-arm64/contrib/4.3:
#   cannot open URL 'https://cran.r-project.org/bin/macosx/big-sur-arm64/contrib/4.3/PACKAGES'”
#
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %%
file_path <- 'pilot5_stats/correct_wm_ltm.csv'
df <- read.csv(file_path) 
# %>%
#     select(it_sim_dis_diff, it_sim_dis_diff_sq, reliability, v2_sim_dis_diff, v2_sim_dis_diff_sq, participant, validity, resp_correct, Accuracy, validity_binary, reliability_binary, v2_sim_dis_attend, v2_sim_dis_attend_z, v2_sim_dis_attend_sq_z, it_sim_dis_attend, it_sim_dis_attend_z, it_sim_dis_attend_sq_z, v2_sim_dis_unattend, v2_sim_dis_unattend_z, v2_sim_dis_unattend_sq_z, it_sim_dis_unattend, it_sim_dis_unattend_z, it_sim_dis_unattend_sq_z, it_sim_dis_diff_z, v2_sim_dis_diff_z,it_sim_dis_diff_sq_z, v2_sim_dis_diff_sq_z )

# %%
control <- lmerControl(optimizer = "bobyqa")#, optCtrl = list(maxfun = 10000))

# %%
head(df$recall_answ)
# Out:
# [1] 1 0 1 1 1 1

# %%
names(df)
# Out:
#   [1] "setup_js.started"
#   [2] "setup_js.stopped"
#   [3] "participant"
#   [4] "date"
#   [5] "expName"
#   [6] "psychopyVersion"
#   [7] "OS"
#   [8] "frameRate"
#   [9] "Instructions1.started"
#  [10] "Instructions1.stopped"
#  [11] "key_resp_2.keys"
#  [12] "key_resp_2.rt"
#  [13] "key_resp_2.duration"
#  [14] "Instructions2.started"
#  [15] "Instructions2.stopped"
#  [16] "key_resp_3.keys"
#  [17] "key_resp_3.rt"
#  [18] "key_resp_3.duration"
#  [19] "Instructions3.started"
#  [20] "Instructions3.stopped"
#  [21] "key_resp_4.keys"
#  [22] "key_resp_4.rt"
#  [23] "key_resp_4.duration"
#  [24] "Instructions4.started"
#  [25] "Instructions4.stopped"
#  [26] "key_resp_5.keys"
#  [27] "key_resp_5.rt"
#  [28] "key_resp_5.duration"
#  [29] "Instructions5.started"
#  [30] "Instructions5.stopped"
#  [31] "key_resp_10.keys"
#  [32] "key_resp_10.rt"
#  [33] "key_resp_10.duration"
#  [34] "Instructions6b.started"
#  [35] "Instructions6b.stopped"
#  [36] "key_resp_16.keys"
#  [37] "key_resp_16.rt"
#  [38] "key_resp_16.duration"
#  [39] "Instructions6.started"
#  [40] "Instructions6.stopped"
#  [41] "key_resp_13.keys"
#  [42] "key_resp_13.rt"
#  [43] "key_resp_13.duration"
#  [44] "memoranda.started"
#  [45] "memoranda.stopped"
#  [46] "isi1.started"
#  [47] "isi1.stopped"
#  [48] "probe.started"
#  [49] "probe.stopped"
#  [50] "mouse.x"
#  [51] "mouse.y"
#  [52] "mouse.leftButton"
#  [53] "mouse.midButton"
#  [54] "mouse.rightButton"
#  [55] "mouse.time"
#  [56] "mouse.clicked_name"
#  [57] "resp_correct"
#  [58] "taskPhase"
#  [59] "correct_ans.started"
#  [60] "correct_ans.stopped"
#  [61] "ITI.started"
#  [62] "ITI.stopped"
#  [63] "prac_trials.thisRepN"
#  [64] "prac_trials.thisTrialN"
#  [65] "prac_trials.thisN"
#  [66] "prac_trials.thisIndex"
#  [67] "prac_trials.ran"
#  [68] "attend"
#  [69] "reliability"
#  [70] "validity"
#  [71] "test_item"
#  [72] "reliability_time"
#  [73] "cue_time"
#  [74] "delay_1_time"
#  [75] "delay_2_time"
#  [76] "ping_time"
#  [77] "delay_3_time"
#  [78] "probe_time"
#  [79] "noise_mask_time"
#  [80] "iti_dur"
#  [81] "pilot_info"
#  [82] "ping_im_flash1"
#  [83] "ping_im_flash2"
#  [84] "ping_im_flash3"
#  [85] "ping_im_flash4"
#  [86] "ping_im_flash5"
#  [87] "stim_side"
#  [88] "img1"
#  [89] "img2"
#  [90] "ping_img"
#  [91] "left_img"
#  [92] "right_img"
#  [93] "right_cue_length"
#  [94] "left_cue_length"
#  [95] "right_cue_offset"
#  [96] "left_cue_offset"
#  [97] "attend_direction"
#  [98] "rec_length"
#  [99] "distractor_0"
# [100] "distractor_0_type"
# [101] "distractor_1"
# [102] "distractor_1_type"
# [103] "distractor_2"
# [104] "distractor_2_type"
# [105] "distractor_3"
# [106] "distractor_3_type"
# [107] "mem_x"
# [108] "mem_y"
# [109] "dismem_x"
# [110] "dismem_y"
# [111] "dis0_x"
# [112] "dis0_y"
# [113] "dis1_x"
# [114] "dis1_y"
# [115] "dis2_x"
# [116] "dis2_y"
# [117] "dis3_x"
# [118] "dis3_y"
# [119] "mem_stim"
# [120] "distractor_stim"
# [121] "probe_direction"
# [122] "cue_img"
# [123] "repeat_code.started"
# [124] "repeat_code.stopped"
# [125] "key_resp_14.keys"
# [126] "repeat_prac.thisRepN"
# [127] "repeat_prac.thisTrialN"
# [128] "repeat_prac.thisN"
# [129] "repeat_prac.thisIndex"
# [130] "repeat_prac.ran"
# [131] "Instructions7.started"
# [132] "Instructions7.stopped"
# [133] "key_resp_15.keys"
# [134] "key_resp_15.rt"
# [135] "key_resp_15.duration"
# [136] "Instructions8.started"
# [137] "Instructions8.stopped"
# [138] "key_resp_6.keys"
# [139] "key_resp_6.rt"
# [140] "key_resp_6.duration"
# [141] "key_resp_7.keys"
# [142] "key_resp_7.rt"
# [143] "key_resp_7.duration"
# [144] "Instructions9.started"
# [145] "Instructions9.stopped"
# [146] "key_resp_8.keys"
# [147] "key_resp_8.rt"
# [148] "key_resp_8.duration"
# [149] "Instructions10.started"
# [150] "Instructions10.stopped"
# [151] "key_resp_9.keys"
# [152] "key_resp_9.rt"
# [153] "key_resp_9.duration"
# [154] "intro_txt.started"
# [155] "intro_txt.stopped"
# [156] "key_resp_11.keys"
# [157] "key_resp_11.rt"
# [158] "key_resp_11.duration"
# [159] "initial_wait.started"
# [160] "initial_wait.stopped"
# [161] "reliability_cue.started"
# [162] "reliability_cue.stopped"
# [163] "isi2.started"
# [164] "isi2.stopped"
# [165] "ping.started"
# [166] "ping.stopped"
# [167] "noise_mask.started"
# [168] "noise_mask.stopped"
# [169] "isi3.started"
# [170] "isi3.stopped"
# [171] "block_break.started"
# [172] "block_break.stopped"
# [173] "key_resp.keys"
# [174] "loop_trials.thisRepN"
# [175] "loop_trials.thisTrialN"
# [176] "loop_trials.thisN"
# [177] "loop_trials.thisIndex"
# [178] "loop_trials.ran"
# [179] "repeat_practice_code.started"
# [180] "repeat_practice_code.stopped"
# [181] "key_resp_12.keys"
# [182] "repeat_practice.thisRepN"
# [183] "repeat_practice.thisTrialN"
# [184] "repeat_practice.thisN"
# [185] "repeat_practice.thisIndex"
# [186] "repeat_practice.ran"
# [187] "demo_prac_task.thisRepN"
# [188] "demo_prac_task.thisTrialN"
# [189] "demo_prac_task.thisN"
# [190] "demo_prac_task.thisIndex"
# [191] "demo_prac_task.ran"
# [192] "condsFile"
# [193] "introTXT"
# [194] "trial"
# [195] "root"
# [196] "Unnamed..0"
# [197] "IT_diff"
# [198] "V2_diff"
# [199] "Image1"
# [200] "Image2"
# [201] "IT_root_im1"
# [202] "IT_root_im2"
# [203] "IT_im1_im2"
# [204] "V2_root_im1"
# [205] "V2_root_im2"
# [206] "V2_im1_im2"
# [207] "cat_root"
# [208] "cat_im1"
# [209] "cat_im2"
# [210] "V2_im2_minus_im1"
# [211] "IT_im2_minus_im1"
# [212] "IT_most_similar"
# [213] "V2_most_similar"
# [214] "cond_file"
# [215] "key_resp.rt"
# [216] "key_resp.duration"
# [217] "trials.thisRepN"
# [218] "trials.thisTrialN"
# [219] "trials.thisN"
# [220] "trials.thisIndex"
# [221] "trials.ran"
# [222] "Instructions.started"
# [223] "Instructions.stopped"
# [224] "key_resp_17.keys"
# [225] "key_resp_17.rt"
# [226] "key_resp_17.duration"
# [227] "image_recall_task.started"
# [228] "image_recall_task.stopped"
# [229] "image_recall_response.keys"
# [230] "image_recall_response.rt"
# [231] "image_recall_response.duration"
# [232] "small_break.started"
# [233] "small_break.stopped"
# [234] "break_2.started"
# [235] "break_2.stopped"
# [236] "key_resp_18.keys"
# [237] "trials_2.thisRepN"
# [238] "trials_2.thisTrialN"
# [239] "trials_2.thisN"
# [240] "trials_2.thisIndex"
# [241] "trials_2.ran"
# [242] "ImagePath"
# [243] "key_resp_18.rt"
# [244] "key_resp_18.duration"
# [245] "end_exp.started"
# [246] "end_exp.stopped"
# [247] "key_resp_14.rt"
# [248] "key_resp_14.duration"
# [249] "key_resp_12.rt"
# [250] "key_resp_12.duration"
# [251] "trials_2.order"
# [252] "concept_root"
# [253] "concept_im1"
# [254] "concept_im2"
# [255] "filename"
# [256] "concept_root_x"
# [257] "concept_im1_x"
# [258] "concept_im2_x"
# [259] "concept_root_y"
# [260] "concept_im1_y"
# [261] "concept_im2_y"
# [262] "trials.order"
# [263] "demo_prac_task.order"
# [264] "repeat_practice.order"
# [265] "loop_trials.order"
# [266] "trials_3.thisRepN"
# [267] "trials_3.thisTrialN"
# [268] "trials_3.thisN"
# [269] "trials_3.thisIndex"
# [270] "trials_3.ran"
# [271] "trials_3.order"
# [272] "taskPhases"
# [273] "conditions_choice"
# [274] "repeat_prac.order"
# [275] "prac_trials.order"
# [276] "Retrocue.Reliability"
# [277] "Trial_Number"
# [278] "Trial_Batch"
# [279] "conditions_batch"
# [280] "participants_count"
# [281] "participants_list"
# [282] "Tested.Item"
# [283] "it_sim_dis_attend"
# [284] "v2_sim_dis_attend"
# [285] "it_sim_dis_test"
# [286] "v2_sim_dis_test"
# [287] "it_sim_dis_unattend"
# [288] "v2_sim_dis_unattend"
# [289] "it_sim_dis_untest"
# [290] "v2_sim_dis_untest"
# [291] "it_sim_dis_diff"
# [292] "v2_sim_dis_diff"
# [293] "it_sim_dis_diff_test"
# [294] "v2_sim_dis_diff_test"
# [295] "v2_converges"
# [296] "v2_prefers"
# [297] "it_prefers"
# [298] "v2_prefers_test"
# [299] "it_prefers_test"
# [300] "Distractor.V2.Similarity.Preference.Tested"
# [301] "Distractor.IT.Similarity.Preference.Tested"
# [302] "Distractor.V2.Similarity.Preference"
# [303] "Distractor.IT.Similarity.Preference"
# [304] "it_im1_im2"
# [305] "v2_im1_im2"
# [306] "IT_diff_binned"
# [307] "V2_diff_binned"
# [308] "IT_diff_binned_test"
# [309] "V2_diff_binned_test"
# [310] "it_sim_dis_attend_cat"
# [311] "v2_sim_dis_attend_cat"
# [312] "it_sim_dis_unattend_cat"
# [313] "v2_sim_dis_unattend_cat"
# [314] "it_sim_dis_diff_cat"
# [315] "v2_sim_dis_diff_cat"
# [316] "it_im1_im2_cat"
# [317] "v2_im1_im2_cat"
# [318] "it_sim_dis_test_cat"
# [319] "v2_sim_dis_test_cat"
# [320] "it_sim_dis_untest_cat"
# [321] "v2_sim_dis_untest_cat"
# [322] "it_sim_dis_diff_test_cat"
# [323] "v2_sim_dis_diff_test_cat"
# [324] "V2.Distractor.Similarity.to.Prioritized.Item"
# [325] "IT.Distractor.Similarity.to.Prioritized.Item"
# [326] "V2.Distractor.Similarity.to.Deprioritized.Item"
# [327] "IT.Distractor.Similarity.to.Deprioritized.Item"
# [328] "Prioritized...Deprioritized.IT.Distractor.Similarity"
# [329] "Prioritized...Deprioritized.V2.Distractor.Similarity"
# [330] "V2.Distractor.Similarity.to.Tested.Item"
# [331] "IT.Distractor.Similarity.to.Tested.Item"
# [332] "V2.Distractor.Similarity.to.Untested.Item"
# [333] "IT.Distractor.Similarity.to.Untested.Item"
# [334] "Tested...Untested.IT.Distractor.Similarity"
# [335] "Tested...Untested.V2.Distractor.Similarity"
# [336] "Prioritized...Deprioritized.V2.Distractor.Similarity.Ranges"
# [337] "Prioritized...Deprioritized.IT.Distractor.Similarity.Ranges"
# [338] "Tested...Untested.V2.Distractor.Similarity.Ranges"
# [339] "Tested...Untested.IT.Distractor.Similarity.Ranges"
# [340] "tested_item"
# [341] "ret_rel"
# [342] "validity_binary"
# [343] "reliability_binary"
# [344] "processed_mouse.time"
# [345] "processed_mouse.click"
# [346] "mouse.time_length"
# [347] "mouse.time_first"
# [348] "mouse.time_last"
# [349] "mouse.clicked_name_first"
# [350] "mouse.clicked_name_last"
# [351] "resp_correct_within"
# [352] "Accuracy"
# [353] "mouse.time_last_within"
# [354] "analysis_rt"
# [355] "pilot_number"
# [356] "tested_memorability_resmem"
# [357] "untested_memorability_resmem"
# [358] "attended_memorability_resmem"
# [359] "unattended_memorability_resmem"
# [360] "distractor_memorability"
# [361] "tested_memorability_resmem_z"
# [362] "it_sim_dis_diff_z"
# [363] "v2_sim_dis_diff_z"
# [364] "it_sim_dis_attend_z"
# [365] "v2_sim_dis_attend_z"
# [366] "it_sim_dis_unattend_z"
# [367] "v2_sim_dis_unattend_z"
# [368] "it_sim_dis_test_z"
# [369] "v2_sim_dis_test_z"
# [370] "it_sim_dis_untest_z"
# [371] "v2_sim_dis_untest_z"
# [372] "it_sim_dis_diff_test_z"
# [373] "v2_sim_dis_diff_test_z"
# [374] "it_sim_dis_diff_sq"
# [375] "it_sim_dis_diff_sq_z"
# [376] "v2_sim_dis_diff_sq"
# [377] "v2_sim_dis_diff_sq_z"
# [378] "it_sim_dis_attend_sq"
# [379] "it_sim_dis_attend_sq_z"
# [380] "v2_sim_dis_attend_sq"
# [381] "v2_sim_dis_attend_sq_z"
# [382] "it_sim_dis_unattend_sq"
# [383] "it_sim_dis_unattend_sq_z"
# [384] "v2_sim_dis_unattend_sq"
# [385] "v2_sim_dis_unattend_sq_z"
# [386] "it_sim_dis_test_sq"
# [387] "it_sim_dis_test_sq_z"
# [388] "v2_sim_dis_test_sq"
# [389] "v2_sim_dis_test_sq_z"
# [390] "it_sim_dis_untest_sq"
# [391] "it_sim_dis_untest_sq_z"
# [392] "v2_sim_dis_untest_sq"
# [393] "v2_sim_dis_untest_sq_z"
# [394] "it_sim_dis_diff_test_sq"
# [395] "it_sim_dis_diff_test_sq_z"
# [396] "v2_sim_dis_diff_test_sq"
# [397] "v2_sim_dis_diff_test_sq_z"
# [398] "validity_binary_z"
# [399] "reliability_binary_z"
# [400] "V2.Distractor.Similarity.to.Tested.Item.1"
# [401] "IT.Distractor.Similarity.to.Tested.Item.1"
# [402] "it_pos_neg"
# [403] "v2_pos_neg"
# [404] "it_pos_neg_abs"
# [405] "v2_pos_neg_abs"
# [406] "it_sim_dis_diff_test_sign"
# [407] "it_sim_dis_diff_test_sign_z"
# [408] "it_sim_dis_diff_test_sign_sq"
# [409] "it_sim_dis_diff_test_sign_sq_z"
# [410] "v2_sim_dis_diff_test_sign"
# [411] "v2_sim_dis_diff_test_sign_z"
# [412] "v2_sim_dis_diff_test_sign_sq"
# [413] "v2_sim_dis_diff_test_sign_sq_z"
# [414] "it_sim_dis_test_sign"
# [415] "it_sim_dis_test_sign_z"
# [416] "it_sim_dis_test_sign_sq"
# [417] "it_sim_dis_test_sign_sq_z"
# [418] "v2_sim_dis_test_sign"
# [419] "v2_sim_dis_test_sign_z"
# [420] "v2_sim_dis_test_sign_sq"
# [421] "v2_sim_dis_test_sign_sq_z"
# [422] "rt"
# [423] "it_pos_neg_abs_z"
# [424] "v2_pos_neg_abs_z"
# [425] "it_pos_neg_z"
# [426] "v2_pos_neg_z"
# [427] "it_int_rel"
# [428] "v2_int_rel"
# [429] "it_int_abs"
# [430] "v2_int_abs"
# [431] "it_int_rel_sq"
# [432] "v2_int_rel_sq"
# [433] "it_int_abs_sq"
# [434] "v2_int_abs_sq"
# [435] "acc_recall"
# [436] "mem_answ"
# [437] "recall_answ"
# [438] "Answer.Labels"
# [439] "recall_category"
# [440] "correct_recall"
# [441] "confidence_level"
# [442] "Past.Response.Correctness"
# [443] "v2_sim_dis_diff_sq_cat"
# [444] "it_sim_dis_diff_sq_cat"
# [445] "v2_sim_dis_diff_test_sq_cat"
# [446] "it_sim_dis_diff_test_sq_cat"
# [447] "Prioritized...Deprioritized.IT.Distractor.Similarity.Squared"
# [448] "Prioritized...Deprioritized.V2.Distractor.Similarity.Squared"
# [449] "Tested...Untested.IT.Distractor.Similarity.Squared"
# [450] "Tested...Untested.V2.Distractor.Similarity.Squared"
# [451] "IT_diff_binned_sq"
# [452] "V2_diff_binned_sq"
# [453] "IT_diff_binned_test_sq"
# [454] "V2_diff_binned_test_sq"
# [455] "Prioritized...Deprioritized.V2.Distractor.Similarity.Squared.Ranges"
# [456] "Prioritized...Deprioritized.IT.Distractor.Similarity.Squared.Ranges"
# [457] "Tested...Untested.V2.Distractor.Similarity.Squared.Ranges"
# [458] "Tested...Untested.IT.Distractor.Similarity.Squared.Ranges"
# [459] "V2.Distractor.Similarity.to.LTM.Item"
# [460] "IT.Distractor.Similarity.to.LTM.Item"
# [461] "LTM...NonLTM.V2.Distractor.Similarity"
# [462] "LTM...NonLTM.IT.Distractor.Similarity"
# [463] "category"
# [464] "mem_stim_type"
# [465] "Tested"
# [466] "Attend"
# [467] "Reliability"
# [468] "tested_binary"
# [469] "priority_binary"
# [470] "tested_binary_z"
# [471] "priority_binary_z"
# [472] "recall_answ_within"
# [473] "attend_binary"
# [474] "attend_binary_z"
# [475] "it_ltm"
# [476] "v2_ltm"
# [477] "it_ltm_diff"
# [478] "v2_ltm_diff"
# [479] "it_ltm_cat"
# [480] "v2_ltm_cat"
# [481] "it_ltm_diff_cat"
# [482] "v2_ltm_diff_cat"
# [483] "V2.Distractor.Similarity.to.LTM.Item.1"
# [484] "IT.Distractor.Similarity.to.LTM.Item.1"
# [485] "LTM...NonLTM.V2.Distractor.Similarity.Ranges"
# [486] "LTM...NonLTM.IT.Distractor.Similarity.Ranges"
# [487] "v2_ltm_sq"
# [488] "it_ltm_sq"
# [489] "v2_ltm_diff_sq"
# [490] "it_ltm_diff_sq"
# [491] "v2_ltm_z"
# [492] "it_ltm_z"
# [493] "v2_ltm_diff_z"
# [494] "it_ltm_diff_z"
# [495] "v2_ltm_sq_z"
# [496] "it_ltm_sq_z"
# [497] "v2_ltm_diff_sq_z"
# [498] "it_ltm_diff_sq_z"
# [499] "it_pos_neg_abs_ltm"
# [500] "v2_pos_neg_abs_ltm"
# [501] "it_pos_neg_ltm"
# [502] "v2_pos_neg_ltm"
# [503] "it_pos_neg_ltm_abs"
# [504] "v2_pos_neg_ltm_abs"
# [505] "v2_ltm_diff_sign"
# [506] "v2_ltm_diff_sign_z"
# [507] "v2_ltm_diff_sign_sq"
# [508] "v2_ltm_diff_sign_sq_z"
# [509] "it_ltm_diff_sign"
# [510] "it_ltm_diff_sign_z"
# [511] "it_ltm_diff_sign_sq"
# [512] "it_ltm_diff_sign_sq_z"
# [513] "v2_ltm_sign"
# [514] "v2_ltm_sign_z"
# [515] "v2_ltm_sign_sq"
# [516] "v2_ltm_sign_sq_z"
# [517] "it_ltm_sign"
# [518] "it_ltm_sign_z"
# [519] "it_ltm_sign_sq"
# [520] "it_ltm_sign_sq_z"
# [521] "it_pos_neg_ltm_sign"
# [522] "it_pos_neg_ltm_sign_z"
# [523] "it_pos_neg_ltm_sign_sq"
# [524] "it_pos_neg_ltm_sign_sq_z"
# [525] "v2_pos_neg_ltm_sign"
# [526] "v2_pos_neg_ltm_sign_z"
# [527] "v2_pos_neg_ltm_sign_sq"
# [528] "v2_pos_neg_ltm_sign_sq_z"
# [529] "it_pos_neg_ltm_abs_sign"
# [530] "it_pos_neg_ltm_abs_sign_z"
# [531] "it_pos_neg_ltm_abs_sign_sq"
# [532] "it_pos_neg_ltm_abs_sign_sq_z"
# [533] "v2_pos_neg_ltm_abs_sign"
# [534] "v2_pos_neg_ltm_abs_sign_z"
# [535] "v2_pos_neg_ltm_abs_sign_sq"
# [536] "v2_pos_neg_ltm_abs_sign_sq_z"

# %%
head(df$attend_binary_z)
# Out:
# [1]  0.4291719  0.4291719  0.4291719 -2.3300687 -2.3300687  0.4291719

# %%
formula1 <- glmer(
  recall_answ ~  
     attend_binary_z * reliability_binary_z * (it_ltm_z + it_ltm_sq_z) + attend_binary_z * reliability_binary_z * (v2_ltm_z + v2_ltm_sq_z) +
     tested_binary_z + (1 | participant),
  data = df,
  family = binomial, control = glmerControl(optimizer = "bobyqa"))


# View the model summary
summary(formula1)
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ attend_binary_z * reliability_binary_z * (it_ltm_z +
#     it_ltm_sq_z) + attend_binary_z * reliability_binary_z * (v2_ltm_z +
#     v2_ltm_sq_z) + tested_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#   6855.8   7007.3  -3405.9   6811.8     7208
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.4279  0.2148  0.3530  0.5497  1.8157
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5774   0.7599
# Number of obs: 7230, groups:  participant, 133
#
# Fixed effects:
#                                                   Estimate Std. Error z value
# (Intercept)                                       1.050707   0.076869  13.669
# attend_binary_z                                  -0.032262   0.030783  -1.048
# reliability_binary_z                              0.041096   0.030397   1.352
# it_ltm_z                                         -0.117219   0.067680  -1.732
# it_ltm_sq_z                                       0.097857   0.068844   1.421
# v2_ltm_z                                          0.177140   0.149029   1.189
# v2_ltm_sq_z                                      -0.112208   0.152741  -0.735
# tested_binary_z                                  -0.427838   0.028357 -15.088
# attend_binary_z:reliability_binary_z              0.006413   0.020174   0.318
# attend_binary_z:it_ltm_z                         -0.036947   0.045911  -0.805
# attend_binary_z:it_ltm_sq_z                       0.029895   0.046642   0.641
# reliability_binary_z:it_ltm_z                     0.037120   0.053054   0.700
# reliability_binary_z:it_ltm_sq_z                 -0.046874   0.054584  -0.859
# attend_binary_z:v2_ltm_z                          0.146470   0.100040   1.464
# attend_binary_z:v2_ltm_sq_z                      -0.097696   0.101283  -0.965
# reliability_binary_z:v2_ltm_z                     0.219000   0.120907   1.811
# reliability_binary_z:v2_ltm_sq_z                 -0.230321   0.125435  -1.836
# attend_binary_z:reliability_binary_z:it_ltm_z     0.009850   0.034904   0.282
# attend_binary_z:reliability_binary_z:it_ltm_sq_z -0.017376   0.035973  -0.483
# attend_binary_z:reliability_binary_z:v2_ltm_z    -0.004594   0.078705  -0.058
# attend_binary_z:reliability_binary_z:v2_ltm_sq_z  0.052495   0.080951   0.648
#                                                  Pr(>|z|)
# (Intercept)                                        <2e-16 ***
# attend_binary_z                                    0.2946
# reliability_binary_z                               0.1764
# it_ltm_z                                           0.0833 .
# it_ltm_sq_z                                        0.1552
# v2_ltm_z                                           0.2346
# v2_ltm_sq_z                                        0.4626
# tested_binary_z                                    <2e-16 ***
# attend_binary_z:reliability_binary_z               0.7506
# attend_binary_z:it_ltm_z                           0.4210
# attend_binary_z:it_ltm_sq_z                        0.5216
# reliability_binary_z:it_ltm_z                      0.4841
# reliability_binary_z:it_ltm_sq_z                   0.3905
# attend_binary_z:v2_ltm_z                           0.1432
# attend_binary_z:v2_ltm_sq_z                        0.3348
# reliability_binary_z:v2_ltm_z                      0.0701 .
# reliability_binary_z:v2_ltm_sq_z                   0.0663 .
# attend_binary_z:reliability_binary_z:it_ltm_z      0.7778
# attend_binary_z:reliability_binary_z:it_ltm_sq_z   0.6291
# attend_binary_z:reliability_binary_z:v2_ltm_z      0.9535
# attend_binary_z:reliability_binary_z:v2_ltm_sq_z   0.5167
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(
  recall_answ ~  
     attend_binary_z * reliability_binary_z * (it_ltm_diff_z + it_ltm_diff_sq_z) + attend_binary_z * reliability_binary_z * (v2_ltm_diff_z + v2_ltm_diff_sq_z) +
     tested_binary_z + (1 | participant),
  data = df,
  family = binomial, control = glmerControl(optimizer = "bobyqa"))


# View the model summary
summary(formula1)

### here recall_answ = 1 if ltm task correct, 0 if its wrong
### resp_correct = 1 if wm correct
### category : tested, not tested, distractor, foil?
### and all columns are sometimes NaN - like validity for foils or distractors, etc
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# recall_answ ~ attend_binary_z * reliability_binary_z * (it_ltm_diff_z +
#     it_ltm_diff_sq_z) + attend_binary_z * reliability_binary_z *
#     (v2_ltm_diff_z + v2_ltm_diff_sq_z) + tested_binary_z + (1 |
#     participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#   6948.6   7100.4  -3452.3   6904.6     7305
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.2725  0.2184  0.3548  0.5500  1.7669
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5684   0.7539
# Number of obs: 7327, groups:  participant, 134
#
# Fixed effects:
#                                                        Estimate Std. Error
# (Intercept)                                            1.055949   0.076118
# attend_binary_z                                       -0.030282   0.030556
# reliability_binary_z                                   0.047236   0.030263
# it_ltm_diff_z                                         -0.025766   0.040630
# it_ltm_diff_sq_z                                       0.086939   0.038271
# v2_ltm_diff_z                                          0.060512   0.039710
# v2_ltm_diff_sq_z                                      -0.064029   0.038625
# tested_binary_z                                       -0.424837   0.028202
# attend_binary_z:reliability_binary_z                   0.014408   0.020144
# attend_binary_z:it_ltm_diff_z                         -0.000488   0.026951
# attend_binary_z:it_ltm_diff_sq_z                       0.058545   0.025905
# reliability_binary_z:it_ltm_diff_z                    -0.018723   0.032099
# reliability_binary_z:it_ltm_diff_sq_z                  0.005169   0.030628
# attend_binary_z:v2_ltm_diff_z                          0.034849   0.026957
# attend_binary_z:v2_ltm_diff_sq_z                      -0.037158   0.025382
# reliability_binary_z:v2_ltm_diff_z                     0.041560   0.031885
# reliability_binary_z:v2_ltm_diff_sq_z                 -0.053614   0.031050
# attend_binary_z:reliability_binary_z:it_ltm_diff_z    -0.010848   0.020748
# attend_binary_z:reliability_binary_z:it_ltm_diff_sq_z  0.028657   0.020084
# attend_binary_z:reliability_binary_z:v2_ltm_diff_z     0.023522   0.021080
# attend_binary_z:reliability_binary_z:v2_ltm_diff_sq_z  0.018770   0.020012
#                                                       z value Pr(>|z|)
# (Intercept)                                            13.872   <2e-16 ***
# attend_binary_z                                        -0.991   0.3217
# reliability_binary_z                                    1.561   0.1186
# it_ltm_diff_z                                          -0.634   0.5260
# it_ltm_diff_sq_z                                        2.272   0.0231 *
# v2_ltm_diff_z                                           1.524   0.1275
# v2_ltm_diff_sq_z                                       -1.658   0.0974 .
# tested_binary_z                                       -15.064   <2e-16 ***
# attend_binary_z:reliability_binary_z                    0.715   0.4745
# attend_binary_z:it_ltm_diff_z                          -0.018   0.9856
# attend_binary_z:it_ltm_diff_sq_z                        2.260   0.0238 *
# reliability_binary_z:it_ltm_diff_z                     -0.583   0.5597
# reliability_binary_z:it_ltm_diff_sq_z                   0.169   0.8660
# attend_binary_z:v2_ltm_diff_z                           1.293   0.1961
# attend_binary_z:v2_ltm_diff_sq_z                       -1.464   0.1432
# reliability_binary_z:v2_ltm_diff_z                      1.303   0.1924
# reliability_binary_z:v2_ltm_diff_sq_z                  -1.727   0.0842 .
# attend_binary_z:reliability_binary_z:it_ltm_diff_z     -0.523   0.6011
# attend_binary_z:reliability_binary_z:it_ltm_diff_sq_z   1.427   0.1536
# attend_binary_z:reliability_binary_z:v2_ltm_diff_z      1.116   0.2645
# attend_binary_z:reliability_binary_z:v2_ltm_diff_sq_z   0.938   0.3483
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
formula1 <- glmer(
  recall_answ ~  
       (it_ltm_diff_z + it_ltm_diff_sq_z) + (v2_ltm_diff_z + v2_ltm_diff_sq_z) +
     tested_binary_z + (1 | participant),
  data = df,
  family = binomial, control = glmerControl(optimizer = "bobyqa"))


# View the model summary
summary(formula1)

### here recall_answ = 1 if ltm task correct, 0 if its wrong
### resp_correct = 1 if wm correct
### category : tested, not tested, distractor, foil?
### and all columns are sometimes NaN - like validity for foils or distractors, etc
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: recall_answ ~ (it_ltm_diff_z + it_ltm_diff_sq_z) + (v2_ltm_diff_z +
#     v2_ltm_diff_sq_z) + tested_binary_z + (1 | participant)
#    Data: df
# Control: glmerControl(optimizer = "bobyqa")
#
#      AIC      BIC   logLik deviance df.resid
#   6943.3   6991.6  -3464.7   6929.3     7320
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.4923  0.2218  0.3550  0.5555  1.7141
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  participant (Intercept) 0.5601   0.7484
# Number of obs: 7327, groups:  participant, 134
#
# Fixed effects:
#                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)       1.04213    0.07317  14.242   <2e-16 ***
# it_ltm_diff_z    -0.02433    0.03215  -0.757   0.4491
# it_ltm_diff_sq_z  0.05717    0.03118   1.833   0.0667 .
# v2_ltm_diff_z     0.02754    0.03248   0.848   0.3965
# v2_ltm_diff_sq_z  0.00377    0.03106   0.121   0.9034
# tested_binary_z  -0.44119    0.02341 -18.848   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) it_l__ it____ v2_l__ v2____
# it_ltm_dff_  0.007
# it_ltm_df__  0.009  0.015
# v2_ltm_dff_  0.016 -0.272 -0.095
# v2_ltm_df__  0.006 -0.035 -0.072 -0.069
# tstd_bnry_z  0.160  0.031 -0.014  0.022 -0.010

# %%
# tidy_model <- broom::tidy(formula1)
# significant_terms <- tidy_model %>% filter(p.value < 0.05)
# print(significant_terms)

# %%
# # Assuming your model is called `model`
# tidy_results <- tidy(formula1, effects = "fixed", conf.int = TRUE)

# # Filter for significant terms (e.g., p < 0.05)
# significant_results <- tidy_results %>% filter(p.value < 0.05)

# print(significant_results)

# %%
# stargazer(formula1, type="text", digits=2)

# %%
# # Create a compact summary table
# tab_model(formula1,
#           show.ci = FALSE,          # Hide confidence intervals if not needed
#           show.se = TRUE,           # Show standard errors
#           p.style = "stars",        # Add stars for significance levels
#           digits = 3)               # Round values to 3 decimal places

# %%
# # Get the summary of the model
# model_summary <- summary(formula1)

# # Extract fixed effects
# fixed_effects <- as.data.frame(model_summary$coefficients)

# # Filter for significant terms (p < 0.05)
# significant_terms <- fixed_effects[fixed_effects[, "Pr(>|z|)"] < 0.05, ]

# # Print the filtered results
# print(significant_terms)

# %%
# 'pilot5_stats/distractor_wm_ltm.csv'

# %%
# model <- glm(
#   resp_correct ~ reliability_binary * validity_binary + (1 | participant),
#              y,
#   data = df,
#   family = binomial(link = "logit")
# )

# # View the model summary
# summary(model)

# %%
# # IT*V2*reliability*validity + itsq+v2sq



# formula1 <- glmer(resp_correct ~ it_sim_dis_diff_z * v2_sim_dis_diff_z * reliability_binary * validity_binary +  
#                    it_sim_dis_diff_sq_z + v2_sim_dis_diff_sq_z + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff + it_sim_dis_diff_sq) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_diff + v2_sim_dis_diff_sq) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_attend * reliability_binary *  
#                   validity_binary + v2_sim_dis_attend * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# formula2 <- glmer(resp_correct ~ it_sim_dis_unattend * reliability_binary *  
#                   validity_binary + v2_sim_dis_unattend * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula2)

# %%
# formula1 <- glmer(resp_correct ~ (it_sim_dis_diff_z + it_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_diff_z + v2_sim_dis_diff_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))

# %%
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_attend*reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ v2_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula1 <- glmer(resp_correct ~ it_sim_dis_diff *reliability_binary * validity_binary  + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula1)

# %%
# formula10 <- glmer(resp_correct ~ (it_sim_dis_attend_z + it_sim_dis_attend_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_attend_z + v2_sim_dis_attend_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula10)

# %%
# formula10 <- glmer(resp_correct ~ (it_sim_dis_unattend_z + it_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (v2_sim_dis_unattend_z + v2_sim_dis_unattend_sq_z) * reliability_binary *  
#                   validity_binary + (1 | participant), 
#                   data = df, family = binomial, control = glmerControl(optimizer = "bobyqa"))
# summary(formula10)
