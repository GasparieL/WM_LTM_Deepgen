# %%
import pandas as pd

df = pd.read_csv("stats_wm/pilot5/correct/df_it_rel_neg.csv")

cols = ["it_sim_dis_diff_test_z", "it_sim_dis_diff_test_sq_z", "it_sim_dis_diff_test_cube_z"]

cov_matrix = df[cols].cov()

print(cov_matrix)

check = df[cols].agg(['mean', 'std']).T

print(check)
# Out:
#                              it_sim_dis_diff_test_z  \
# it_sim_dis_diff_test_z                     1.000067
# it_sim_dis_diff_test_sq_z                 -0.050128
# it_sim_dis_diff_test_cube_z                0.921803
#
#                              it_sim_dis_diff_test_sq_z  \
# it_sim_dis_diff_test_z                       -0.050128
# it_sim_dis_diff_test_sq_z                     1.000067
# it_sim_dis_diff_test_cube_z                  -0.080812
#
#                              it_sim_dis_diff_test_cube_z
# it_sim_dis_diff_test_z                          0.921803
# it_sim_dis_diff_test_sq_z                      -0.080812
# it_sim_dis_diff_test_cube_z                     1.000067
#                                      mean       std
# it_sim_dis_diff_test_z       1.312298e-16  1.000033
# it_sim_dis_diff_test_sq_z   -1.074563e-16  1.000033
# it_sim_dis_diff_test_cube_z  5.705643e-18  1.000033
# ...

# %%
df = pd.read_csv("stats_wm/pilot6/correct/df_it_rel_neg.csv")

cols = ["it_sim_dis_diff_test_z", "it_sim_dis_diff_test_sq_z", "it_sim_dis_diff_test_cube_z"]

cov_matrix = df[cols].cov()

print(cov_matrix)

check = df[cols].agg(['mean', 'std']).T

print(check)
# Out:
#                              it_sim_dis_diff_test_z  \
# it_sim_dis_diff_test_z                     1.000067
# it_sim_dis_diff_test_sq_z                 -0.016090
# it_sim_dis_diff_test_cube_z                0.923112
#
#                              it_sim_dis_diff_test_sq_z  \
# it_sim_dis_diff_test_z                       -0.016090
# it_sim_dis_diff_test_sq_z                     1.000067
# it_sim_dis_diff_test_cube_z                  -0.018561
#
#                              it_sim_dis_diff_test_cube_z
# it_sim_dis_diff_test_z                          0.923112
# it_sim_dis_diff_test_sq_z                      -0.018561
# it_sim_dis_diff_test_cube_z                     1.000067
#                                      mean       std
# it_sim_dis_diff_test_z       9.663533e-17  1.000033
# it_sim_dis_diff_test_sq_z    7.669094e-17  1.000033
# it_sim_dis_diff_test_cube_z -7.835297e-18  1.000033

# %%
df = pd.read_csv("stats_wm/total/correct/df_it_rel_neg.csv")

cols = ["it_sim_dis_diff_test_z", "it_sim_dis_diff_test_sq_z", "it_sim_dis_diff_test_cube_z"]

cov_matrix = df[cols].cov()

print(cov_matrix)

check = df[cols].agg(['mean', 'std']).T

print(check)
# Out:
#                              it_sim_dis_diff_test_z  \
# it_sim_dis_diff_test_z                     1.000033
# it_sim_dis_diff_test_sq_z                 -0.034307
# it_sim_dis_diff_test_cube_z                0.922403
#
#                              it_sim_dis_diff_test_sq_z  \
# it_sim_dis_diff_test_z                       -0.034307
# it_sim_dis_diff_test_sq_z                     1.000033
# it_sim_dis_diff_test_cube_z                  -0.051658
#
#                              it_sim_dis_diff_test_cube_z
# it_sim_dis_diff_test_z                          0.922403
# it_sim_dis_diff_test_sq_z                      -0.051658
# it_sim_dis_diff_test_cube_z                     1.000033
#                                      mean       std
# it_sim_dis_diff_test_z       2.404351e-16  1.000017
# it_sim_dis_diff_test_sq_z    1.482525e-16  1.000017
# it_sim_dis_diff_test_cube_z  0.000000e+00  1.000017
# ...

# %%
df['it_sim_dis_diff_test']
# Out:
# 0       -0.358048
# 1       -0.359391
# 2       -0.841904
# 3       -0.247490
# 4       -0.728407
#            ...
# 29902   -0.856483
# 29903   -0.861376
# 29904   -1.215095
# 29905   -0.234965
# 29906   -0.248842
# Name: it_sim_dis_diff_test, Length: 29907, dtype: float64
